# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# Đường dẫn đến thư mục chứa dữ liệu
base_dir = ["BFA_w_CICDts2023", "BFA_w_IoTID20 dataset", "WUSTL"] # hoặc thay đổi thành đường dẫn gốc chứa các thư mục model
models = ["CustomModel", "CustomModel2"]
attack_schemas = ["PBS", "RandomFlip", "PBS_to_RandomFlip", "RandomFlip_to_PBS"]  # ví dụ, thay bằng tên thực tế nếu khác

for model in models:
    csv_path = os.path.join(base_dir, model, "Aggregate_Results", "aggregated_results.csv")
    
    if not os.path.exists(csv_path):
        print(f"Không tìm thấy file: {csv_path}")
        continue

    df = pd.read_csv(csv_path)

    # Đảm bảo cột 'Epoch' và các schema có trong file
    if "Epoch" not in df.columns:
        print(f"Thiếu cột Epoch trong {csv_path}")
        continue

    plt.figure(figsize=(10, 6))
    for schema in attack_schemas:
        if schema in df.columns:
            plt.plot(df["Epoch"], df[schema], label=schema)
        else:
            print(f"Thiếu schema {schema} trong {csv_path}")

    plt.title(f"MCC trung bình theo Epoch - {model}")
    plt.xlabel("Epoch")
    plt.ylabel("MCC")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.savefig(f"{model}_MCC_Chart.png")  # Lưu hình
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 11
#       8 attack_schemas = ["PBS", "RandomFlip", "PBS_to_RandomFlip", "RandomFlip_to_PBS"]  # ví dụ, thay bằng tên thực tế nếu khác
#      10 for model in models:
# ---> 11     csv_path = os.path.join(base_dir, model, "Aggregate_Results", "aggregated_results.csv")
#      13     if not os.path.exists(csv_path):
#      14         print(f"Không tìm thấy file: {csv_path}")
#
# File /opt/tljh/user/lib/python3.10/posixpath.py:76, in join(a, *p)
#      71 def join(a, *p):
#      72     """Join two or more pathname components, inserting '/' as needed.
#      73     If any component is an absolute path, all previous path components
#      74     will be discarded.  An empty last part will result in a path that
#      75     ends with a separator."""
# ---> 76     a = os.fspath(a)
#      77     sep = _get_sep(a)
#      78     path = a
#
# TypeError: expected str, bytes or os.PathLike object, not list

# %%
class RecorderMeter(object):
    """Computes and stores the minimum loss value and its epoch index, along with MCC"""

    def __init__(self, total_epoch):
        self.reset(total_epoch)

    def reset(self, total_epoch):
        assert total_epoch > 0
        self.total_epoch = total_epoch
        self.current_epoch = 0
        self.epoch_losses = np.zeros((self.total_epoch, 2), dtype=np.float32)  # [epoch, train/val]
        self.epoch_losses = self.epoch_losses - 1

        self.epoch_mcc = np.zeros((self.total_epoch, 2), dtype=np.float32)  # [epoch, train/val]
        self.epoch_mcc = self.epoch_mcc

    def update(self, idx, train_loss, train_mcc, val_loss, val_mcc):
        assert idx >= 0 and idx < self.total_epoch, 'total_epoch : {} , but update with the {} index'.format(
            self.total_epoch, idx)
        self.epoch_losses[idx, 0] = train_loss
        self.epoch_losses[idx, 1] = val_loss
        self.epoch_mcc[idx, 0] = train_mcc
        self.epoch_mcc[idx, 1] = val_mcc
        self.current_epoch = idx + 1

    def max_mcc(self, istrain):
        if self.current_epoch <= 0:
            return 0
        if istrain:
            return self.epoch_mcc[:self.current_epoch, 0].max()
        else:
            return self.epoch_mcc[:self.current_epoch, 1].max()

# %%
def time_string():
    ISOTIMEFORMAT = '%Y-%m-%d %X'
    string = '[{}]'.format(
        time.strftime(ISOTIMEFORMAT, time.gmtime(time.time())))
    return string


def convert_secs2time(epoch_time):
    need_hour = int(epoch_time / 3600)
    need_mins = int((epoch_time - 3600 * need_hour) / 60)
    need_secs = int(epoch_time - 3600 * need_hour - 60 * need_mins)
    return need_hour, need_mins, need_secs


def time_file_str():
    ISOTIMEFORMAT = '%Y-%m-%d'
    string = '{}'.format(time.strftime(ISOTIMEFORMAT,
                                       time.gmtime(time.time())))
    return string + '-{}'.format(random.randint(1, 10000))

# %% [markdown]
# ### Class quan_Linear

# %%
class quan_Linear(nn.Linear):
    def __init__(self, in_features, out_features, bias=True):
        super(quan_Linear, self).__init__(in_features, out_features, bias=bias)

        self.N_bits = 8
        self.full_lvls = 2**self.N_bits
        self.half_lvls = (self.full_lvls - 2) / 2
        # Initialize the step size
        self.step_size = nn.Parameter(torch.Tensor([1]), requires_grad=True)
        self.__reset_stepsize__()
        # flag to enable the inference with quantized weight or self.weight
        self.inf_with_weight = False  # disabled by default

        # create a vector to identify the weight to each bit
        self.b_w = nn.Parameter(2**torch.arange(start=self.N_bits - 1,
                                                end=-1,
                                                step=-1).unsqueeze(-1).float(),
                                requires_grad=False)

        self.b_w[0] = -self.b_w[0]  #in-place reverse

    def forward(self, input):
        if self.inf_with_weight:
            return F.linear(input, self.weight * self.step_size, self.bias)
        else:
            self.__reset_stepsize__()
            weight_quan = quantize(self.weight, self.step_size,
                                   self.half_lvls) * self.step_size
            return F.linear(input, weight_quan, self.bias)

    def __reset_stepsize__(self):
        with torch.no_grad():
            self.step_size.data = self.weight.abs().max() / self.half_lvls

    def __reset_weight__(self):
        '''
        This function will reconstruct the weight stored in self.weight.
        Replacing the orginal floating-point with the quantized fix-point
        weight representation.
        '''
        # replace the weight with the quantized version
        with torch.no_grad():
            self.weight.data = quantize(self.weight, self.step_size,
                                        self.half_lvls)
        # enable the flag, thus now computation does not invovle weight quantization
        self.inf_with_weight = True

# %% [markdown]
# ### Class quan_Conv1d

# %%
class quan_Conv1d(nn.Conv1d):
    def __init__(self,
                 in_channels,
                 out_channels,
                 kernel_size,
                 stride=1,
                 padding=1,
                 dilation=1,
                 groups=1,
                 bias=True):
        super(quan_Conv1d, self).__init__(in_channels,
                                          out_channels,
                                          kernel_size,
                                          stride=stride,
                                          padding=padding,
                                          dilation=dilation,
                                          groups=groups,
                                          bias=bias)

        # Số lượng bit để lượng tử hóa trọng số
        self.N_bits = 8
        self.full_lvls = 2 ** self.N_bits
        self.half_lvls = (self.full_lvls - 2) / 2

        # Bước lượng tử hóa (step size), là một tham số có thể học được
        self.step_size = nn.Parameter(torch.Tensor([1]), requires_grad=True)
        self.__reset_stepsize__()

        # Cờ để bật hoặc tắt sử dụng trọng số lượng tử hóa
        self.inf_with_weight = False  # Tắt theo mặc định

        # Tạo một vector để biểu diễn trọng số cho từng bit
        self.b_w = nn.Parameter(2 ** torch.arange(start=self.N_bits - 1,
                                                  end=-1,
                                                  step=-1).unsqueeze(-1).float(),
                                requires_grad=False)
        self.b_w[0] = -self.b_w[0]  # Biến đổi MSB thành giá trị âm để hỗ trợ bù hai

    def __reset_stepsize__(self):
        """Hàm này dùng để đặt lại giá trị `step_size`."""
        # Giá trị này có thể được tùy chỉnh tùy thuộc vào yêu cầu của mô hình
        self.step_size.data.fill_(1.0)

    def forward(self, x):
        # Kiểm tra cờ `inf_with_weight` để quyết định sử dụng trọng số đã lượng tử hóa hay không
        if self.inf_with_weight:
            quantized_weight = self.quantize_weight(self.weight)
            return nn.functional.conv1d(x, quantized_weight, self.bias, self.stride,
                                        self.padding, self.dilation, self.groups)
        else:
            return nn.functional.conv1d(x, self.weight, self.bias, self.stride,
                                        self.padding, self.dilation, self.groups)

    def quantize_weight(self, weight):
        """Lượng tử hóa trọng số theo số bit đã định."""
        # Tạo trọng số lượng tử hóa bằng cách sử dụng step_size
        quantized_weight = torch.round(weight / self.step_size) * self.step_size
        quantized_weight = torch.clamp(quantized_weight, -self.half_lvls * self.step_size,
                                       (self.half_lvls - 1) * self.step_size)
        return quantized_weight

# %%
def change_quan_bitwidth(model, n_bit):
    '''This script change the quantization bit-width of entire model to n_bit'''
    for m in model.modules():
        if isinstance(m, quan_Conv1d) or isinstance(m, quan_Linear):
            m.N_bits = n_bit
            # print("Change weight bit-width as {}.".format(m.N_bits))
            m.b_w.data = m.b_w.data[-m.N_bits:]
            m.b_w[0] = -m.b_w[0]
            print(m.b_w)
    return

# %%
class _quantize_func(torch.autograd.Function):
    @staticmethod
    def forward(ctx, input, step_size, half_lvls):
        # ctx is a context object that can be used to stash information
        # for backward computation
        ctx.step_size = step_size
        ctx.half_lvls = half_lvls
        output = F.hardtanh(input,
                            min_val=-ctx.half_lvls * ctx.step_size.item(),
                            max_val=ctx.half_lvls * ctx.step_size.item())

        output = torch.round(output / ctx.step_size)
        return output

    @staticmethod
    def backward(ctx, grad_output):
        grad_input = grad_output.clone() / ctx.step_size

        return grad_input, None, None

quantize = _quantize_func.apply

# %%
class _bin_func(torch.autograd.Function):

    @staticmethod
    def forward(ctx, input, mu):
        ctx.mu = mu
        output = input.clone().zero_()
        output[input.ge(0)] = 1
        output[input.lt(0)] = -1

        return output

    @staticmethod
    def backward(ctx, grad_output):
        grad_input = grad_output.clone() / ctx.mu
        return grad_input, None

w_bin = _bin_func.apply

# %%
def quantize(tensor, step_size, half_lvls):
    """Quantization function."""
    return torch.clamp(torch.round(tensor / step_size), min=-half_lvls, max=half_lvls)

# %% [markdown]
# ### Class CustomBlock

# %%
class CustomBlock(nn.Module):
    def __init__(self, in_features, out_features, bias=True, apply_softmax=False):
        super(CustomBlock, self).__init__()
        self.N_bits = 16
        self.full_lvls = 2 ** self.N_bits
        self.half_lvls = (self.full_lvls - 2) / 2
        self.apply_softmax = apply_softmax

        # Initialize the step size
        self.step_size = nn.Parameter(torch.Tensor([1]), requires_grad=True)

        # Initialize weights and bias
        self.weight = nn.Parameter(torch.Tensor(out_features, in_features))
        self.bias = nn.Parameter(torch.Tensor(out_features)) if bias else None

        # Reset parameters
        self.__reset_stepsize__()
        self.reset_parameters()

        # Flag for inference with quantized weights
        self.inf_with_weight = False

        self.b_w = nn.Parameter(2**torch.arange(start=self.N_bits - 1,
                                             end=-1,
                                             step=-1).unsqueeze(-1).float(),
                           requires_grad=False)
        self.b_w[0] = -self.b_w[0]  #in-place reverse
        
    def reset_parameters(self):
        nn.init.kaiming_uniform_(self.weight, a=5 ** 0.5)
        if self.bias is not None:
            nn.init.zeros_(self.bias)

    def forward(self, input):
        if self.inf_with_weight:
            weight_applied = self.weight * self.step_size
        else:
            self.__reset_stepsize__()
            weight_quan = quantize(self.weight, self.step_size, self.half_lvls) * self.step_size
            weight_applied = weight_quan

        # Linear transformation
        input = input.view(input.size(0), -1)  # Flatten input to 2D for matmul
        output = input @ weight_applied.T
        if self.bias is not None:
            output += self.bias

        if self.apply_softmax:
            output = F.softmax(output, dim=-1)
        return output

    def __reset_stepsize__(self):
        with torch.no_grad():
            self.step_size.data = self.weight.abs().max() / self.half_lvls

    def __reset_weight__(self):
        with torch.no_grad():
            self.weight.data = quantize(self.weight, self.step_size, self.half_lvls)
        self.inf_with_weight = True

# %%
class DownsampleA(nn.Module):
    def __init__(self, nIn, nOut, stride):
        super(DownsampleA, self).__init__()
        assert stride == 2
        self.avg = nn.AvgPool1d(kernel_size=1, stride=stride)

    def forward(self, x):
        x = self.avg(x)
        return torch.cat((x, x.mul(0)), 1)
        
class SEBlock(nn.Module):
    expansion = 1

    def __init__(self, inplanes, planes, stride=1, downsample=None):
        super(SEBlock, self).__init__()
        self.conv_a = quan_Conv1d(inplanes, planes, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn_a = nn.BatchNorm1d(planes)
        self.dropout_a = nn.Dropout(p=0.3)  # Dropout sau BatchNorm

        self.conv_b = quan_Conv1d(planes, planes, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn_b = nn.BatchNorm1d(planes)
        self.dropout_b = nn.Dropout(p=0.3)  # Dropout sau BatchNorm

        self.downsample = downsample

    def forward(self, x):
        residual = x
        
        basicblock = self.conv_a(x)
        basicblock = self.bn_a(basicblock)
        basicblock = F.relu(basicblock, inplace=True)
        basicblock = self.dropout_a(basicblock)  # Áp dụng dropout

        basicblock = self.conv_b(basicblock)
        basicblock = self.bn_b(basicblock)
        basicblock = self.dropout_b(basicblock)  # Áp dụng dropout

        if self.downsample:
            residual = self.downsample(x)

        return F.relu(residual + basicblock, inplace=True)

# %% [markdown]
# ### Class CustomModel

# %%
class CustomModel(nn.Module):
    def __init__(self, input_size=42, hidden_sizes=[32, 64, 128, 256, 512], output_size=5):
        super(CustomModel, self).__init__()
        self.fc1 = quan_Conv1d(input_size, hidden_sizes[0], kernel_size=3, stride=1, padding=1)
        self.bn_1 = nn.BatchNorm1d(hidden_sizes[0])

        self.inplanes = 32
        self.stage_1 = self._make_layer(SEBlock, 32, 16, 1)
        self.stage_2 = self._make_layer(SEBlock, 64, 16, 2)
        self.stage_3 = self._make_layer(SEBlock, 128, 16, 2)
        self.avgpool = nn.AdaptiveAvgPool1d(1)

        self.classifier = CustomBlock(128 * SEBlock.expansion, output_size)

        for m in self.modules():
            if isinstance(m, nn.Conv1d):
                n = m.kernel_size[0] * m.out_channels
                m.weight.data.normal_(0, math.sqrt(2. / n))
                #m.bias.data.zero_()
            elif isinstance(m, nn.BatchNorm1d):
                m.weight.data.fill_(1)
                m.bias.data.zero_()
            elif isinstance(m, nn.Linear):
                init.kaiming_normal(m.weight)
                m.bias.data.zero_()
        
    def _make_layer(self, block, planes, blocks, stride=1):
        downsample = None
        downsample = None
        if stride == 2 or self.inplanes != planes * SEBlock.expansion:
            downsample = DownsampleA(self.inplanes, planes * SEBlock.expansion, stride) if stride == 2 else None

        layers = []
        layers.append(block(self.inplanes, planes, stride=1, downsample=downsample))
        self.inplanes = planes * SEBlock.expansion
        for i in range(1, blocks):
            layers.append(block(self.inplanes, planes))

        return nn.Sequential(*layers)
    def forward(self, x):
        x = self.fc1(x)
        x = F.relu(self.bn_1(x), inplace=True)
        
        x = self.stage_1(x)
        x = self.stage_2(x)
        x = self.stage_3(x)

        x = self.avgpool(x)
        x = x.view(x.size(0), -1)
        return self.classifier(x)

# %% [markdown]
# ### Class CustomModel2

# %%
class CustomModel2(nn.Module):
    def __init__(self, input_size=42, hidden_sizes=[32, 64, 128, 100], output_size=5):
        super(CustomModel2, self).__init__()
        self.hidden_sizes = hidden_sizes

        # Define layers
        self.fc1 = nn.Conv1d(input_size, hidden_sizes[0], kernel_size=3, stride=2, padding=1)
        self.pool = nn.AdaptiveMaxPool1d(1)
        self.activation = nn.ReLU()
        self.dropout = nn.Dropout(0.1)
        
        self.stage_1 = nn.Conv1d(hidden_sizes[0], hidden_sizes[1], kernel_size=3, stride=2, padding=1)
        self.stage_2 = nn.Conv1d(hidden_sizes[1], hidden_sizes[2], kernel_size=3, stride=2, padding=1)
        self.stage_3 = nn.Conv1d(hidden_sizes[2], hidden_sizes[3], kernel_size=3, stride=2, padding=1)

        # Global Pooling
        self.global_pool = nn.AdaptiveAvgPool1d(1)

        # Classifier
        self.classifier = CustomBlock(hidden_sizes[-1], output_size, apply_softmax=True)
        nn.Dropout(0.15)
        
    def forward(self, x):
        # Pass through layers
        x = self.fc1(x)
        x = self.activation(self.pool(x))

        x = self.stage_1(x)
        x = self.activation(self.pool(x))

        x = self.stage_2(x)
        x = self.activation(self.pool(x))

        x = self.stage_3(x)
        x = self.activation(self.pool(x))

        # Global Pooling
        x = self.global_pool(x)
        x = x.view(x.size(0), -1)  # Flatten
        return self.classifier(x)

# %% [markdown]
# ### Init dataset

# %%
class Args:
    def __init__(self):
        self.arch = 'CustomModel'
        self.data_path = '../../dataset/'
        self.dataset = 'inid'
        self.save_path = './save/attack_random'
        self.epochs = 20
        self.optimizer = 'SGD'
        self.test_batch_size = 32
        self.learning_rate = 0.001
        self.momentum = 0.9
        self.decay = 1e-4
        self.schedule = [80, 120]
        self.gammas = [0.1, 0.1]
        self.print_freq = 100
        self.resume = 'save\model_best.pth.tar'
        self.start_epoch = 0
        self.enable_bfa = False
        self.evaluate = False
        self.ngpu = 1
        self.gpu_id = 0
        self.workers = 4
        self.manualSeed = None
        self.quan_bitwidth = 16
        self.reset_weight = False
        self.bfa = True
        self.attack_sample_size = 128
        self.n_iter = 40
        self.k_top = None
        self.random_bfa = True
        self.progressive_bit_search= True
        self.random_flip = True
        self.clustering = False
        self.lambda_coeff = 1e-3
        self.use_cuda = True  

args = Args()
args.use_cuda = torch.cuda.is_available()

# %%
# Thiết lập cấu hình logging
logging.basicConfig(level=logging.INFO, format='%(message)s')
logger = logging.getLogger()

# Init logger
if not os.path.isdir(args.save_path):
    os.makedirs(args.save_path)

# Tạo tệp log
log_file_path = os.path.join(args.save_path, 'log_seed_{}.txt'.format(args.manualSeed))
file_handler = logging.FileHandler(log_file_path)
file_handler.setLevel(logging.INFO)

# Định dạng cho tệp log
formatter = logging.Formatter('%(asctime)s - %(message)s')
file_handler.setFormatter(formatter)

# Thêm file handler vào logger
logger.addHandler(file_handler)

# Ghi log vào console và tệp
logger.info('Save path: {}'.format(args.save_path))
state = {k: getattr(args, k) for k in dir(args) if not k.startswith('__')}
logger.info('State: {}'.format(state))
logger.info("Random Seed: {}".format(args.manualSeed))
logger.info("Python version: {}".format(sys.version.replace('\n', ' ')))
logger.info("Torch version: {}".format(torch.__version__))
logger.info("CUDNN version: {}".format(torch.backends.cudnn.version()))

# Init the tensorboard path and writer
tb_path = os.path.join(args.save_path, 'tb_log', 'run_' + str(args.manualSeed))
writer = SummaryWriter(tb_path)
# Out:
# Save path: ./save/attack_random
# State: {'arch': 'CustomModel', 'attack_sample_size': 128, 'bfa': True, 'clustering': False, 'data_path': '../../dataset/', 'dataset': 'inid', 'decay': 0.0001, 'enable_bfa': False, 'epochs': 20, 'evaluate': False, 'gammas': [0.1, 0.1], 'gpu_id': 0, 'k_top': None, 'lambda_coeff': 0.001, 'learning_rate': 0.001, 'manualSeed': None, 'momentum': 0.9, 'n_iter': 40, 'ngpu': 1, 'optimizer': 'SGD', 'print_freq': 100, 'progressive_bit_search': True, 'quan_bitwidth': 16, 'random_bfa': True, 'random_flip': True, 'reset_weight': False, 'resume': 'save\\model_best.pth.tar', 'save_path': './save/attack_random', 'schedule': [80, 120], 'start_epoch': 0, 'test_batch_size': 32, 'use_cuda': True, 'workers': 4}
# Random Seed: None
# Python version: 3.10.14 | packaged by conda-forge | (main, Mar 20 2024, 12:45:18) [GCC 12.3.0]
# Torch version: 2.2.2+cu118
# CUDNN version: 8907

# %%
# Init dataset
if not os.path.isdir(args.data_path):
    os.makedirs(args.data_path)

if args.dataset == 'inid':
    print("Inid dataset import sucsess!")
else:
    assert False, "Unknow dataset : {}".format(args.dataset)
# Out:
# Inid dataset import sucsess!

# %% [markdown]
# ### Xử lý dữ liệu

# %%
# Init dataset
if args.dataset == 'inid':
    data = pd.read_csv("../../dataset/wustl_iiot_2021_reduced.csv",
                               skipinitialspace=True)
    data = data.drop_duplicates()
    columns_to_remove = ['StartTime', 'LastTime', 'SrcAddr', 'DstAddr', 'sIpId', 'dIpId']
    data.drop(columns=columns_to_remove, inplace=True, errors='ignore')
    
    
    datalabel = data[['Traffic']]
    data = data.drop(columns=['Traffic'])
    
    scaler = StandardScaler()
    onc = LabelEncoder()
    
    # Tách dữ liệu thành tập huấn luyện và tập kiểm tra
    X_train, X_test, y_train, y_test = train_test_split(data, datalabel, test_size=0.2, random_state=42)
    X_train= scaler.fit_transform(X_train)
    X_test= scaler.transform(X_test)
    print(y_train['Traffic'])
    # Chuyển đổi y_train và y_test thành mã số
    y_train = onc.fit_transform(y_train['Traffic'].to_numpy().reshape(-1,1))  # Chuyển đổi thành mã số
    y_test= onc.transform(y_test['Traffic'].to_numpy().reshape(-1,1))  # Chuyển đổi thành mã số
    
    # Kiểm tra kiểu dữ liệu của y_train và y_test
    print("Kiểu dữ liệu y_train:", y_train.shape)
    print("Kiểu dữ liệu y_test:", y_test.shape)
    
    # Tạo DataLoader cho tập huấn luyện
    train_loader = DataLoader(
        torch.utils.data.TensorDataset(
            torch.FloatTensor(X_train),
            torch.LongTensor(y_train)  # y_train đã được chuyển đổi thành mã số
        ),
        batch_size=256,
        num_workers=8,
        shuffle=True,
        pin_memory=True
    )
    
    # Tạo DataLoader cho tập kiểm tra
    test_loader = DataLoader(
        torch.utils.data.TensorDataset(
            torch.FloatTensor(X_test),
            torch.LongTensor(y_test)  # y_test đã được chuyển đổi thành mã số
        ),
        batch_size=256,
        num_workers=8,
        shuffle=False,
        pin_memory=True
    )
else:
    train_loader = torch.utils.data.DataLoader(
        train_data,
        batch_size=args.attack_sample_size,
        shuffle=True,
        num_workers=args.workers,
        pin_memory=True)
    test_loader = torch.utils.data.DataLoader(test_data,
                                              batch_size=args.test_batch_size,
                                              shuffle=False,
                                              num_workers=args.workers,
                                              pin_memory=True)

logger.info("=> creating model '{}'".format(args.arch))
data
# Out:
# /opt/tljh/user/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/tljh/user/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# => creating model 'CustomModel'
# 29625        DoS
# 9585      normal
# 608618    normal
# 667287    normal
# 521918    normal
#            ...
# 259178    normal
# 365838    normal
# 131932    normal
# 671155    normal
# 121958    normal
# Name: Traffic, Length: 559997, dtype: object
# Kiểu dữ liệu y_train: (559997,)
# Kiểu dữ liệu y_test: (140000,)
#         Mean  Sport  Dport  SrcPkts  DstPkts  TotPkts  DstBytes  SrcBytes  \
# 0          0  54134    502        6        6       12       386       396
# 1          4  28031    502      110        0      110         0      8360
# 2          0  61809    502       10        8       18       508       644
# 3          1  37474     80        4        0        4         0       248
# 4          0  62644    502        6        6       12       384       396
# ...      ...    ...    ...      ...      ...      ...       ...       ...
# 699992     0  62204    502       10        8       18       508       644
# 699993     0  54676    502       10        8       18       508       644
# 699994     0  49410    502       10        8       18       508       644
# 699995     2  63526     80        4        0        4         0       248
# 699996     0  55746    502       10        8       18       508       644
#
#         TotBytes       SrcLoad  ...  dTtl  SAppBytes  DAppBytes  TotAppByte  \
# 0            782  82657.562500  ...    64         24         22          46
# 1           8360  13311.402344  ...     0       3520          0        3520
# 2           1152  69684.312500  ...    64         24         20          44
# 3            248   1044.395264  ...     0          0          0           0
# 4            780  77453.421875  ...    64         24         20          44
# ...          ...           ...  ...   ...        ...        ...         ...
# 699992      1152  88662.984375  ...    64         24         20          44
# 699993      1152  88718.929688  ...    64         24         20          44
# 699994      1152  89618.539062  ...    64         24         20          44
# 699995       248    556.956665  ...     0          0          0           0
# 699996      1152  88674.843750  ...    64         24         20          44
#
#           SynAck   RunTime  sTos    SrcJitAct  DstJitAct  Target
# 0       0.000648  0.031939     0     0.000000        0.0       0
# 1       0.000000  4.978589     0    88.529836        0.0       1
# 2       0.001251  0.066586     0     0.000000        0.0       0
# 3       0.000000  1.424748     0   712.373000        0.0       1
# 4       0.001211  0.034085     0     0.000000        0.0       0
# ...          ...       ...   ...          ...        ...     ...
# 699992  0.000659  0.052333     0     0.000000        0.0       0
# 699993  0.000645  0.052300     0     0.000000        0.0       0
# 699994  0.000740  0.051775     0     0.000000        0.0       0
# 699995  0.000000  2.671662     0  1259.432125        0.0       1
# 699996  0.000752  0.052326     0     0.000000        0.0       0
#
# [699997 rows x 42 columns]

# %%
def mcc_score(preds, targets):
    preds = preds.cpu().numpy()
    targets = targets.cpu().numpy()
    return matthews_corrcoef(targets, preds)

# %%
def mcc2(outputs_label, y_label_batch, y_cat_batch):
    """Compute MCC for each output of the model (label, category, sub-category)."""
    with torch.no_grad():
        # Ensure target has at least one dimension
        if y_label_batch.dim() == 0:
            y_label_batch = y_label_batch.unsqueeze(0)
     
      

        # Get the predicted classes (top-1 prediction) for each output
        _, pred_label = outputs_label.topk(1, 1, True, True)

        # Compute MCC for each output type
        mcc_label = mcc_score(pred_label.view(-1), y_label_batch)


        return mcc_label


def mcc(output, target):
    """Compute the Matthews Correlation Coefficient (MCC) for the given output and target."""
    with torch.no_grad():
        # Ensure target has at least one dimension
        if target.dim() == 0:
            target = target.unsqueeze(0)

        # Get the predicted classes (top-1 prediction)
        _, pred = output.topk(1, 1, True, True)
        return mcc_score(pred.view(-1), target)

# %%
class AverageMeter(object):
    """Computes and stores the average and current value"""

    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

# %% [markdown]
# ### Train dataset

# %%
def train(train_loader, model, criterion, optimizer, epoch):
    batch_time = AverageMeter()
    data_time = AverageMeter()
    losses = AverageMeter()
    mcc_meter = AverageMeter()  # Track MCC instead of accuracy

    # Switch to train mode
    model.train()

    end = time.time()
    for i, (input, target) in enumerate(train_loader):
        # Measure data loading time
        data_time.update(time.time() - end)

        if args.use_cuda:
            input = input.cuda(non_blocking=True)
            target = target.cuda(non_blocking=True)
            
        input = input.view(input.size(0), 42, -1)  # Reshape input
        
        # Compute output and loss
        output = model(input)
        loss = criterion(output, target)

        if args.clustering:
            loss += clustering_loss(model, args.lambda_coeff)

        # Compute MCC and record loss
        mcc_value = mcc(output.data, target)  # MCC calculation instead of topk accuracy
        losses.update(loss.item(), input.size(0))
        mcc_meter.update(mcc_value, input.size(0))

        # Compute gradient and do SGD step
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # Measure elapsed time
        batch_time.update(time.time() - end)
        end = time.time()

    return mcc_meter.avg, losses.avg


def validate(val_loader, model, criterion, summary_output=True):
    losses = AverageMeter()
    mcc_meter = AverageMeter()
    acc_meter = AverageMeter()
    tpr_meter = AverageMeter()
    f1_meter = AverageMeter()

    # Chuyển model sang chế độ đánh giá
    model.eval()
    output_summary = []

    with torch.no_grad():
        for i, (input, target) in enumerate(test_loader):
            if input.size(1) == 42 and input.dim() == 2:  # Kiểm tra nếu thiếu chiều thứ 3
                input = input.unsqueeze(-1)

            if torch.cuda.is_available() and args.use_cuda:
                target = target.cuda(non_blocking=True)
                input = input.cuda(non_blocking=True)

            # Tính toán output và loss
            output = model(input)
            pred = torch.argmax(output, dim=1)  # Chọn nhãn dự đoán có xác suất cao nhất
            loss = criterion(output, target)
            losses.update(loss.item(), input.size(0))  # Cập nhật losses

            # Chuyển sang numpy để tính toán các chỉ số
            pred_np = pred.cpu().numpy()
            target_np = target.cpu().numpy()

            if summary_output:
                tmp_list = output.max(1, keepdim=True)[1].flatten().cpu().numpy() # get the index of the max log-probability
                output_summary.append(tmp_list)

            # Tính các chỉ số đánh giá
            mcc_value = matthews_corrcoef(target_np, pred_np)
            acc_value = accuracy_score(target_np, pred_np)
            tpr_value = recall_score(target_np, pred_np, average='macro')  # Macro recall ~ TPR
            f1_value = f1_score(target_np, pred_np, average='macro')

            # Cập nhật giá trị trung bình
            mcc_meter.update(mcc_value, input.size(0))
            acc_meter.update(acc_value, input.size(0))
            tpr_meter.update(tpr_value, input.size(0))
            f1_meter.update(f1_value, input.size(0))

    return mcc_meter.avg, acc_meter.avg, tpr_meter.avg, f1_meter.avg, losses.avg, output_summary

# %% [markdown]
# ### Validate

# %%
# def test( model, test_loader):
#     losses = AverageMeter()
#     mcc_meter = AverageMeter()  # Sử dụng MCC thay vì accuracy

#     with torch.no_grad():
#         for i, (input, target) in enumerate(test_loader):
#             if input.size(1) == 42 and input.dim() == 2:  # Kiểm tra nếu thiếu chiều thứ 3
#                 input = input.unsqueeze(-1)

#             if torch.cuda.is_available() and args.use_cuda:
#                 target = target.cuda(non_blocking=True)
#                 input = input.cuda(non_blocking=True)

#             # Tính toán output và loss
#             output = model(input)

                
#             # Tính MCC
#             mcc_value = mcc(output.data, target)
#             mcc_meter.update(mcc_value, input.size(0))

#     return mcc_meter.avg

from sklearn.metrics import matthews_corrcoef, accuracy_score, recall_score, f1_score
import warnings
from sklearn.exceptions import UndefinedMetricWarning

# Tắt cảnh báo UndefinedMetricWarning
warnings.filterwarnings("ignore", category=UndefinedMetricWarning)

def validate_score(model, test_loader):
    losses = AverageMeter()
    mcc_meter = AverageMeter()
    acc_meter = AverageMeter()
    tpr_meter = AverageMeter()
    f1_meter = AverageMeter()

    with torch.no_grad():
        for i, (input, target) in enumerate(test_loader):
            if input.size(1) == 42 and input.dim() == 2:  # Kiểm tra nếu thiếu chiều thứ 3
                input = input.unsqueeze(-1)

            if torch.cuda.is_available() and args.use_cuda:
                target = target.cuda(non_blocking=True)
                input = input.cuda(non_blocking=True)

            # Tính toán output và loss
            output = model(input)
            pred = torch.argmax(output, dim=1)  # Chọn nhãn dự đoán có xác suất cao nhất

            # Chuyển sang numpy để tính toán các chỉ số
            pred_np = pred.cpu().numpy()
            target_np = target.cpu().numpy()

            # Tính các chỉ số đánh giá
            mcc_value = matthews_corrcoef(target_np, pred_np)
            acc_value = accuracy_score(target_np, pred_np)
            tpr_value = recall_score(target_np, pred_np, average='macro')  # Macro recall ~ TPR
            f1_value = f1_score(target_np, pred_np, average='macro')

            # Cập nhật giá trị trung bình
            mcc_meter.update(mcc_value, input.size(0))
            acc_meter.update(acc_value, input.size(0))
            tpr_meter.update(tpr_value, input.size(0))
            f1_meter.update(f1_value, input.size(0))

    return {
        "MCC": mcc_meter.avg,
        "Accuracy": acc_meter.avg,
        "TPR": tpr_meter.avg,
        "F1 Score": f1_meter.avg
    }

# %% [markdown]
# ### class BFA

# %%
class BFA(object):
    def __init__(self, criterion, model, k_top=10):
        self.criterion = criterion
        self.loss_dict = {}
        self.bit_counter = 0
        self.k_top = k_top
        self.n_bits2flip = 0
        self.loss = 0
        self.num_bit_flipped = 0
        
        # Attributes for random attack
        self.module_list = []

        for name, m in model.named_modules():
            if isinstance(m, (quan_Conv1d, quan_Linear, CustomBlock)):
                self.module_list.append(name)

    def flip_bit(self, m):
        '''
        the data type of input param is 32-bit floating, then return the data should
        be in the same data_type.
        '''
        if self.k_top is None:
            k_top = m.weight.detach().flatten().__len__()
        else: 
            k_top = self.k_top
        # 1. flatten the gradient tensor to perform topk
        w_grad_topk, w_idx_topk = m.weight.grad.detach().abs().view(-1).topk(k_top)
        # update the b_grad to its signed representation
        w_grad_topk = m.weight.grad.detach().view(-1)[w_idx_topk]

        # 2. create the b_grad matrix in shape of [N_bits, k_top]
        b_grad_topk = w_grad_topk * m.b_w.data

        # 3. generate the gradient mask to zero-out the bit-gradient
        # which can not be flipped
        b_grad_topk_sign = (b_grad_topk.sign() +
                            1) * 0.5  # zero -> negative, one -> positive
        # convert to twos complement into unsigned integer
        w_bin = int2bin(m.weight.detach().view(-1), m.N_bits).short()
        w_bin_topk = w_bin[w_idx_topk]  # get the weights whose grads are topk
        
        # generate two's complement bit-map
        b_bin_topk = (w_bin_topk.repeat(m.N_bits, 1) & m.b_w.abs().repeat(1, k_top).short()) \
           // m.b_w.abs().repeat(1, k_top).short()

        grad_mask = b_bin_topk ^ b_grad_topk_sign.short()

        # 4. apply the gradient mask upon ```b_grad_topk``` and in-place update it
        b_grad_topk *= grad_mask.float()

        # 5. identify the several maximum of absolute bit gradient and return the index, the number of bits to flip is self.n_bits2flip

        grad_max = b_grad_topk.abs().max()
        num_elements = b_grad_topk.nelement()  # Get the total number of elements
        k = min(self.n_bits2flip, num_elements)  # Clamp the value of k
    
        _, b_grad_max_idx = b_grad_topk.abs().view(-1).topk(k)  # Use clamped k
        bit2flip = b_grad_topk.clone().view(-1).zero_()

        if grad_max.item() != 0:  # ensure the max grad is not zero
            bit2flip[b_grad_max_idx] = 1
            bit2flip = bit2flip.view(b_grad_topk.size())
        else:
            pass

        # 6. Based on the identified bit indexed by ```bit2flip```, generate another
        # mask, then perform the bitwise xor operation to realize the bit-flip.
        bit2flip = bit2flip.reshape(m.b_w.abs().shape[0], -1)  # Định hình lại

        w_bin_topk_flipped = (bit2flip.short() * m.b_w.abs().short()).sum(0, dtype=torch.int16) \
            ^ w_bin_topk

        # 7. update the weight in the original weight tensor
        w_bin[w_idx_topk] = w_bin_topk_flipped  # in-place change
        param_flipped = bin2int(w_bin,
                                m.N_bits).view(m.weight.data.size()).float()

        return param_flipped

    def progressive_bit_search(self, model, data, target, test_loader):
        ''' 
        Given the model, based on the current data and target, go through
        all the layers and identify the bits to be flipped. 
        '''
        model.eval()
        output = model(data)
        self.loss = self.criterion(output, target)
    
        # Zero out the grads first, then get the grads
        for m in model.modules():
            if isinstance(m, (quan_Conv1d, quan_Linear, CustomBlock)):
                if m.weight.grad is not None:
                    m.weight.grad.data.zero_()
    
        self.loss.backward()
        self.loss_max = self.loss.item()
        attack_log = []
        max_loss_module = None
    
        # 3. Flip bits until no further loss degradation is observed
        while self.loss_max <= self.loss.item():
            self.n_bits2flip += 1
            self.loss_dict = {}
    
            for name, module in model.named_modules():
                if isinstance(module, CustomBlock) or isinstance(module, quan_Conv1d):
                    clean_weight = module.weight.data.detach()
                    attack_weight = self.flip_bit(module)
                    self.num_bit_flipped += 1
    
                    module.weight.data = attack_weight
                    output = model(data)
    
                    self.loss_dict[name] = self.criterion(output, target).item()
                    module.weight.data = clean_weight
    
            # Check if loss_dict is not empty
            if not self.loss_dict:
                break
    
            max_loss_module = max(self.loss_dict.items(), key=lambda item: item[1])[0]
            self.loss_max = self.loss_dict[max_loss_module]
    
            if self.n_bits2flip == 200:
                break
    
        # Check if max_loss_module was never assigned
        if max_loss_module is None:
            attack_last_status = [self.bit_counter, "No module attacked", "No attack", "No attack"]
            return [], validate_score(model, test_loader), self.bit_counter, attack_last_status
    
        weight_prior = None
        weight_post = None
    
        # If loss_max does lead to degradation, change that layer's weight
        for module_idx, (name, module) in enumerate(model.named_modules()):
            if name == max_loss_module:
                attack_weight = self.flip_bit(module)
                self.num_bit_flipped += 1
    
                ###########################################################
                ## Attack profiling
                ##########################################################
                
                weight_mismatch = attack_weight - module.weight.detach()
                attack_weight_idx = torch.nonzero(weight_mismatch)
                print('attacked module:', max_loss_module)
                
                attack_log = []
                for i in range(attack_weight_idx.size(0)):
                    weight_idx = attack_weight_idx[i, :].cpu().numpy()
                    weight_prior = module.weight.detach()[tuple(weight_idx)].item()
                    weight_post = attack_weight[tuple(weight_idx)].item()
                
                    tmp_list = [module_idx, self.bit_counter + (i + 1), max_loss_module,
                                weight_idx, weight_prior, weight_post]
                    attack_log.append(tmp_list)
    
                module.weight.data = attack_weight
    
        self.bit_counter += self.n_bits2flip
        self.n_bits2flip = 0
    
        if weight_prior is None or weight_post is None:
            attack_last_status = [self.bit_counter, max_loss_module, "No attack", "No attack"]
        else:
            attack_last_status = [self.bit_counter, max_loss_module, weight_prior, weight_post]
        
        return attack_log, validate_score(model, test_loader), self.bit_counter, attack_last_status

    def random_flip_one_bit(self, model, test_loader):
        """
        Randomly flip one bit in the weight of a chosen module.
        """
        weight_prior = None
        weight_post = None
        
        chosen_module = random.choice(self.module_list)
        for name, m in model.named_modules():
            if name == chosen_module:
                flatten_weight = m.weight.detach().view(-1)
                chosen_idx = random.choice(range(flatten_weight.numel()))
                bin_w = int2bin(flatten_weight[chosen_idx], m.N_bits).short()
                bit_idx = random.choice(range(m.N_bits))
                mask = (bin_w.clone().zero_() + 1) * (2 ** bit_idx)
                bin_w = bin_w ^ mask
                int_w = bin2int(bin_w, m.N_bits).float()

                ##############################################
                ###   attack profiling
                ###############################################
                
                weight_mismatch = flatten_weight[chosen_idx] - int_w
                attack_weight_idx = chosen_idx

                print('attacked module:', chosen_module)
                
                attack_log = []
                weight_idx = chosen_idx
                weight_prior = flatten_weight[chosen_idx]
                weight_post = int_w

                print('attacked weight index:', weight_idx)
                print('weight before attack:', weight_prior)
                print('weight after attack:', weight_post)

                tmp_list = ["module_idx", self.bit_counter + 1, "loss",
                            weight_idx, weight_prior, weight_post]
                attack_log.append(tmp_list)                            

                self.bit_counter += 1
                flatten_weight[chosen_idx] = int_w
                m.weight.data = flatten_weight.view(m.weight.data.size())
                
        if weight_prior is None or weight_post is None:
            attack_last_status = [self.bit_counter, chosen_module, "No attack", "No attack"]
        else:
            attack_last_status = [self.bit_counter, chosen_module, weight_prior, weight_post]

        return attack_log, validate_score(model, test_loader), self.bit_counter, attack_last_status

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
net = CustomModel().to(device)

if args.use_cuda:
    if args.ngpu > 1:
        net = torch.nn.DataParallel(net, device_ids=list(range(args.ngpu)))
criterion = torch.nn.CrossEntropyLoss()
optimizer = optim.AdamW(net.parameters(), lr=0.001, weight_decay=0.01)
# optimizer = optim.Adam(net.parameters(), lr=0.001)

# separate the parameters thus param groups can be updated by different optimizer
all_param = [
    param for name, param in net.named_parameters()
    if not 'step_size' in name
]

step_param = [
    param for name, param in net.named_parameters() if 'step_size' in name 
]

if args.optimizer == "SGD":
    print("using SGD as optimizer")
    optimizer = torch.optim.SGD(all_param,
                                lr=0.01,
                                momentum=0.9,
                                weight_decay=0.0001,
                                nesterov=True)

elif args.optimizer == "Adam":
    print("using Adam as optimizer")
    optimizer = torch.optim.Adam(filter(lambda param: param.requires_grad,
                                        all_param),
                                 lr=0.001,
                                 #momentum=0.9,
                                 weight_decay=0.001)


elif args.optimizer == "RMSprop":
    print("using RMSprop as optimizer")
    optimizer = torch.optim.RMSprop(
        filter(lambda param: param.requires_grad, net.parameters()),
        lr=0.01,
        alpha=0.99,
        eps=1e-08,
        momentum=0.9,
        weight_decay=0.0001)
# Out:
# using SGD as optimizer

# %% [markdown]
# ## BFA Attack

# %%
if args.use_cuda:
    net.cuda()
    criterion.cuda()

if args.resume:
    if os.path.isfile(args.resume):
        checkpoint = torch.load(args.resume)
        if not args.fine_tune:
            args.start_epoch = checkpoint['epoch']
            recorder = checkpoint['recorder']
            optimizer.load_state_dict(checkpoint['optimizer'])

        state_tmp = net.state_dict()
        if 'state_dict' in checkpoint.keys():
            state_tmp.update(checkpoint['state_dict'])
        else:
            state_tmp.update(checkpoint)

        net.load_state_dict(state_tmp, strict=False)
    else:
        print("No checkpoint found at '{}'".format(args.resume))
else:
    print("Do not use any checkpoint for {} model".format(args.arch))


# Configure the quantization bit-width
if args.quan_bitwidth is not None:
    change_quan_bitwidth(net, args.quan_bitwidth)

# Update the step_size once the model is loaded. This is used for quantization.
for m in net.modules():
    if isinstance(m, quan_Conv1d) or isinstance(m, quan_Linear) or isinstance(m, CustomBlock) or m.__class__.__name__ == "CustomBlock" or m.__class__.__name__ == "quan_Conv1d":
        m.__reset_stepsize__()

# Block for weight reset
if args.reset_weight:
    for m in net.modules():
        if isinstance(m, quan_Conv1d) or isinstance(m, quan_Linear) or isinstance(m, CustomBlock):
            m.__reset_weight__()

attacker = BFA(criterion, net, args.k_top)  # Khởi tạo đối tượng tấn công
net_clean = copy.deepcopy(net)
    # weight_conversion(net)

if args.enable_bfa:
    perform_attack(attacker, net, net_clean, train_loader, test_loader,
                   args.n_iter, writer, csv_save_path=args.save_path,
                   random_attack=args.random_bfa)

if args.evaluate:
    print("Evaluate mode")
    _, _, _, output_summary = validate(test_loader, net, criterion, summary_output=True)
    pd.DataFrame(output_summary).to_csv(os.path.join(args.save_path, 'output_summary_{}.csv'.format(args.arch)),
                                        header=['top-1 output'], index=False)
# Out:
# No checkpoint found at 'save\model_best.pth.tar'
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')

# %%
def adjust_learning_rate(optimizer, epoch, gammas, schedule):
    """Sets the learning rate to the initial LR decayed by 10 every 30 epochs"""
    lr = args.learning_rate
    mu = args.momentum

    if args.optimizer != "YF":
        assert len(gammas) == len(
            schedule), "length of gammas and schedule should be equal"
        for (gamma, step) in zip(gammas, schedule):
            if (epoch >= step):
                lr = lr * gamma
            else:
                break
        for param_group in optimizer.param_groups:
            param_group['lr'] = lr

    elif args.optimizer == "YF":
        lr = optimizer._lr
        mu = optimizer._mu

    return lr, mu

# %%
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
if args.ngpu == 1:
    os.environ["CUDA_VISIBLE_DEVICES"] = str(
        args.gpu_id)  # make only device #gpu_id visible, then

args.use_cuda = args.ngpu > 0 and torch.cuda.is_available()  # check GPU

# Give a random seed if no manual configuration
if args.manualSeed is None:
    args.manualSeed = random.randint(1, 10000)
random.seed(args.manualSeed)
torch.manual_seed(args.manualSeed)

if args.use_cuda:
    torch.cuda.manual_seed_all(args.manualSeed)

cudnn.benchmark = True

if args.use_cuda:
    print(f"Using GPU: {args.gpu_id} with seed: {args.manualSeed}")
else:
    print(f"Using CPU with seed: {args.manualSeed}")
# Out:
# Using GPU: 0 with seed: 450

# %% [markdown]
# ### Hàm để train

# %%
''' 
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = CustomModel().to(device)
criterion = torch.nn.CrossEntropyLoss()
optimizer = optim.AdamW(model.parameters(), lr=0.001, weight_decay=0.01)

num_epochs = 20
patience = 10  
counter = 0

scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=5)

best_val_loss = float('inf')
best_mcc = -1 

for epoch in range(num_epochs):
    train_mcc, train_loss = train(train_loader, model, criterion, optimizer, epoch)

    val_mcc, val_acc, val_tpr, val_f1, val_loss, output_summary = validate(test_loader, model, criterion, summary_output=True)
    
    scheduler.step(val_loss)

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        best_mcc = val_mcc
        counter = 0

        save_dir = "CustomModel"
        os.makedirs(save_dir, exist_ok=True)
        save_path = os.path.join(save_dir, "best_model.pth")

        torch.save(model.state_dict(), save_path)
    
    else:
        counter += 1
        if counter >= patience:
            print("Early stopping triggered")
            break

    print(f"Epoch {epoch+1}/{num_epochs}")
    print(f"Train Loss: {train_loss:.4f}, Train MCC: {train_mcc:.4f}")
    print(f"Validation Loss: {val_loss:.4f}, Validation MCC: {val_mcc:.4f}, ACC: {val_acc:.4f}, TPR: {val_tpr:.4f}, F1: {val_f1:.4f}")

print(f"Best MCC during training: {best_mcc:.4f}")
'''
# Out:
# ' \ndevice = torch.device("cuda" if torch.cuda.is_available() else "cpu")\nmodel = CustomModel().to(device)\ncriterion = torch.nn.CrossEntropyLoss()\noptimizer = optim.AdamW(model.parameters(), lr=0.001, weight_decay=0.01)\n\nnum_epochs = 20\npatience = 10  \ncounter = 0\n\nscheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode=\'min\', factor=0.5, patience=5)\n\nbest_val_loss = float(\'inf\')\nbest_mcc = -1 \n\nfor epoch in range(num_epochs):\n    train_mcc, train_loss = train(train_loader, model, criterion, optimizer, epoch)\n\n    val_mcc, val_acc, val_tpr, val_f1, val_loss, output_summary = validate(test_loader, model, criterion, summary_output=True)\n    \n    scheduler.step(val_loss)\n\n    if val_loss < best_val_loss:\n        best_val_loss = val_loss\n        best_mcc = val_mcc\n        counter = 0\n\n        save_dir = "CustomModel"\n        os.makedirs(save_dir, exist_ok=True)\n        save_path = os.path.join(save_dir, "best_model.pth")\n\n        torch.save(model.state_dict(), save_path)\n    \n    else:\n        counter += 1\n        if counter >= patience:\n            print("Early stopping triggered")\n            break\n\n    print(f"Epoch {epoch+1}/{num_epochs}")\n    print(f"Train Loss: {train_loss:.4f}, Train MCC: {train_mcc:.4f}")\n    print(f"Validation Loss: {val_loss:.4f}, Validation MCC: {val_mcc:.4f}, ACC: {val_acc:.4f}, TPR: {val_tpr:.4f}, F1: {val_f1:.4f}")\n\nprint(f"Best MCC during training: {best_mcc:.4f}")\n'

# %% [markdown]
# ## Random Attack
#
# ### import data_conversion

# %%
def int2bin(input, num_bits):
    '''
    convert the signed integer value into unsigned integer (2's complement equivalently).
    Note that, the conversion is different depends on number of bit used.
    '''
    output = input.clone()
    if num_bits == 1: # when it is binary, the conversion is different
        output = output/2 + .5
    elif num_bits > 1:
        output[input.lt(0)] = 2**num_bits + output[input.lt(0)]

    return output


def bin2int(input, num_bits):
    '''
    convert the unsigned integer (2's complement equivantly) back to the signed integer format
    with the bitwise operations. Note that, in order to perform the bitwise operation, the input
    tensor has to be in the integer format.
    '''
    if num_bits == 1:
        output = input*2-1
    elif num_bits > 1:
        mask = 2**(num_bits - 1) - 1
        output = -(input & ~mask) + (input & mask)
    return output


def weight_conversion(model):
    '''
    Perform the weight data type conversion between:
        signed integer <==> two's complement (unsigned integer)
    Such conversion is used as additional step to ensure the conversion correctness

    Note that, the data type conversion chosen is depend on the bits:
        N_bits <= 8   .char()   --> torch.CharTensor(), 8-bit signed integer
        N_bits <= 16  .short()  --> torch.shortTensor(), 16 bit signed integer
        N_bits <= 32  .int()    --> torch.IntTensor(), 32 bit signed integer
    '''
    for m in model.modules():
        if isinstance(m, quan_Conv1d) or isinstance(m, quan_Linear):
            w_bin = int2bin(m.weight.data, m.N_bits).short()
            m.weight.data = bin2int(w_bin, m.N_bits).float()
    return

def count_ones(t, n_bits):
    counter = 0
    for i in range(n_bits):
        counter += ((t & 2**i) // 2**i).sum()
    return counter.item()


def hamming_distance(model1, model2):
    '''
    Given two model whose structure, name and so on are identical.
    The only difference between the model1 and model2 are the weight.
    The function compute the hamming distance bewtween the bianry weights
    (two's complement) of model1 and model2.
    '''
    # TODO: add the function check model1 and model2 are same structure
    # check the keys of state_dict match or not.

    H_dist = 0  # hamming distance counter

    for name, module in model1.named_modules():
        if isinstance(module, quan_Conv1d) or isinstance(module, quan_Linear):
            # remember to convert the tensor into integer for bitwise operations
            binW_model1 = int2bin(model1.state_dict()[name + '.weight'],
                                  module.N_bits).short()
            binW_model2 = int2bin(model2.state_dict()[name + '.weight'],
                                  module.N_bits).short()
            H_dist += count_ones(binW_model1 ^ binW_model2, module.N_bits)

    return H_dist

# %% [markdown]
# ## Vẽ đồ thị MCC sau mỗi epoch

# %%
import matplotlib.pyplot as plt

def plot_mcc_vs_epoch(images_filename, x_data, y_data):
    titles = ["MCC", "ACC", "TPR", "F1-Score"]
    
    for image_filename, title in zip(images_filename, titles):
        if len(x_data) != len(y_data):
            raise ValueError("x_data and y_data must have the same length.")
    
        plt.figure(figsize=(10, 6))
        plt.plot(x_data, y_data, marker='o', linestyle='-', color='b', label='MCC')
        plt.title(f'{title} after Epochs', fontsize=14) 
        plt.xlabel('Epoch', fontsize=12)
        plt.ylabel(title, fontsize=12)
        
        plt.grid(True, linestyle='--', alpha=0.7)
        plt.legend()
        plt.tight_layout()
        
        # Save the plot as an image file
        plt.savefig(image_filename)
        plt.close()
        print(f"Plot saved as {image_filename}")

def plot_combined_metrics(image_filename, x_data, metric_dict):
    colors = {
        "MCC": "blue",
        "ACC": "orange",
        "TPR": "green",
        "F1": "red"
    }

    plt.figure(figsize=(10, 6))
    for metric in ["MCC", "ACC", "TPR", "F1"]:
        y = [float(v) for v in metric_dict[metric]]
        plt.plot(x_data, y, label=metric, color=colors[metric], linewidth=2)
        plt.fill_between(x_data,
                         [v * 0.95 for v in y],
                         [v * 1.05 for v in y],
                         alpha=0.2, color=colors[metric])

    plt.xlabel("Epoch", fontsize=12)
    plt.ylabel("Metric Value (%)", fontsize=12)
    plt.title("Combined Metrics during Attack", fontsize=14)
    plt.legend()
    plt.grid(True, linestyle="--", alpha=0.7)
    plt.tight_layout()
    plt.savefig(image_filename)
    plt.close()
    print(f"[Combined Plot] Saved as {image_filename}")

# %%
# import csv
# def perform_attack(attacker, model, model_clean, train_loader, test_loader,
#                    N_iter, writer, file, csv_file, csv_save_path=None, attack_type=1,):
#     model.eval()
#     losses = AverageMeter()
#     iter_time = AverageMeter()
#     attack_time = AverageMeter()

#     for _, (data, target) in enumerate(train_loader):
#         if args.use_cuda:
#             target = target.cuda()
#             data = data.cuda()

#         data = data.unsqueeze(-1)  # Kích thước [512, 42, 1]
#         _, target = model(data).data.max(1)
#         break

#     val_acc_top1, val_loss, output_summary = validate(test_loader, model, attacker.criterion, summary_output=True)
#     print(f'**Test** MCC: {val_acc_top1:.3f}. Val_Loss: {val_loss:.3f}')

#     tmp_df = pd.DataFrame(output_summary)
#     tmp_df['BFA iteration'] = 0
#     tmp_df.to_csv(os.path.join(args.save_path, 'output_summary_{}_BFA_0.csv'.format(args.arch)), index=False)

#     writer.add_scalar('attack/val_top1_acc', val_acc_top1, 0)
#     writer.add_scalar('attack/val_loss', val_loss, 0)

#     print('Attack sample size is {}'.format(data.size()[0]))
#     end = time.time()
#     df = pd.DataFrame()
#     last_val_acc_top1 = val_acc_top1

#     MCC_data = [val_acc_top1]
#     epochs = [0]
#     all_attack_status = []

#     for i_iter in range(N_iter):
#         print('**********************************')        
#         if attack_type == 1:
#             attack_log, new_mcc, bit_count, attack_last_status = attacker.progressive_bit_search(model, data, target, test_loader)
#             MCC_data.append(new_mcc)
#             epochs.append(bit_count)
#         elif attack_type == 2:
#             attack_log, new_mcc, bit_count, attack_last_status = attacker.random_flip_one_bit(model, test_loader)
#             MCC_data.append(new_mcc)
#             epochs.append(bit_count)
#         elif attack_type == 3:
#             attack_log, new_mcc, bit_count, attack_last_status = attacker.progressive_bit_search(model, data, target, test_loader)
#             attack_log, new_mcc, bit_count, attack_last_status = attacker.random_flip_one_bit(model, test_loader)
#             MCC_data.append(new_mcc)
#             epochs.append(bit_count)
#         elif attack_type == 4:
#             attack_log, new_mcc, bit_count, attack_last_status = attacker.random_flip_one_bit(model, test_loader)
#             attack_log, new_mcc, bit_count, attack_last_status = attacker.progressive_bit_search(model, data, target, test_loader)
#             MCC_data.append(new_mcc)
#             epochs.append(bit_count)
        
#         attack_time.update(time.time() - end)
#         end = time.time()

#         h_dist = hamming_distance(model, model_clean)

#         if hasattr(attacker, "loss_max"):
#             losses.update(attacker.loss_max, data.size(0))

#         print('Iteration: [{:03d}/{:03d}]   Attack Time {attack_time.val:.3f} ({attack_time.avg:.3f})'.format(i_iter + 1, N_iter, attack_time=attack_time))

#         try:
#             print('Loss before attack: {:.4f}'.format(attacker.loss.item()))
#             print('Loss after attack: {:.4f}'.format(attacker.loss_max))
#         except:
#             pass

#         print('Bit flips: {:.0f}'.format(attacker.bit_counter))
#         print('Hamming distance: {:.0f}'.format(h_dist))

#         writer.add_scalar('attack/bit_flip', attacker.bit_counter, i_iter + 1)
#         writer.add_scalar('attack/h_dist', h_dist, i_iter + 1)
#         writer.add_scalar('attack/sample_loss', losses.avg, i_iter + 1)

#         val_acc_top1, val_loss, output_summary = validate(test_loader, model, attacker.criterion, summary_output=True)
#         print(f'**Test** MCC: {val_acc_top1:.3f}. Val_Loss: {val_loss:.3f}')
#         tmp_df = pd.DataFrame(output_summary)
#         tmp_df['BFA iteration'] = i_iter + 1
#         tmp_df.to_csv(os.path.join(args.save_path, 'output_summary_{}_BFA_{}.csv'.format(args.arch, i_iter + 1)), index=False)

#         acc_drop = last_val_acc_top1 - val_acc_top1
#         last_val_acc_top1 = val_acc_top1

#         attack_last_status.append(val_acc_top1)
#         attack_last_status.append(acc_drop)

#         for entry in attack_log:
#             entry.append(val_acc_top1)
#             entry.append(acc_drop)
            
#         df = pd.concat([df, pd.DataFrame(attack_log)], ignore_index=True)

#         writer.add_scalar('attack/val_top1_acc', val_acc_top1, i_iter + 1)
#         writer.add_scalar('attack/val_loss', val_loss, i_iter + 1)

#         iter_time.update(time.time() - end)
#         print('Iteration Time {iter_time.val:.3f} ({iter_time.avg:.3f})'.format(iter_time=iter_time))
#         end = time.time()

#         all_attack_status.append(attack_last_status)

#     column_list = ['module idx', 'bit-flip idx', 'module name', 'weight idx', 'weight before attack', 'weight after attack', 'validation mcc', 'mcc drop']
#     df.columns = column_list
#     df['trial seed'] = args.manualSeed

#     if csv_save_path is not None:
#         csv_file_name = 'attack_profile_{}.csv'.format(args.manualSeed)
#         df.to_csv(os.path.join(csv_save_path, csv_file_name), index=None)

#     # Vẽ đồ thị
#     plot_mcc_vs_epoch(file, epochs, MCC_data)
    
#     with open(csv_file, mode='w', newline='') as file:
#         writer = csv.writer(file)
        
#         # Ghi tiêu đề (nếu cần)
#         writer.writerow(["Bit Counter", "Module", "Weight Before Attack", "Weight After Attack", "Validation", "MCC Drop"])
        
#         # Ghi dữ liệu
#         writer.writerows(all_attack_status)
    
#     return

# %%
import csv
def perform_attack(attacker, model, model_clean, train_loader, test_loader,
                   N_iter, writer, file, csv_file, csv_save_path=None, attack_type=1,):
    model.eval()
    losses = AverageMeter()
    iter_time = AverageMeter()
    attack_time = AverageMeter()

    for _, (data, target) in enumerate(train_loader):
        if args.use_cuda:
            target = target.cuda()
            data = data.cuda()

        data = data.unsqueeze(-1)  # Kích thước [512, 39, 1]
        _, target = model(data).data.max(1)
        break

    val_mcc_top1, val_acc_top1, val_tpr_top1, val_f1score_top1, val_loss, output_summary = validate(test_loader, model, attacker.criterion, summary_output=True)
    print(f'**Test** MCC: {val_mcc_top1:.3f}. Val_Loss: {val_loss:.3f}')
    print(f'ACC: {val_acc_top1:.3f}.')
    print(f'TPR: {val_tpr_top1:.3f}.')
    print(f'F1-score: {val_f1score_top1:.3f}.')

    tmp_df = pd.DataFrame(output_summary)
    tmp_df['BFA iteration'] = 0
    tmp_df.to_csv(os.path.join(args.save_path, 'output_summary_{}_BFA_0.csv'.format(args.arch)), index=False)

    writer.add_scalar('attack/val_top1_acc', val_mcc_top1, 0)
    writer.add_scalar('attack/val_loss', val_loss, 0)

    print('Attack sample size is {}'.format(data.size()[0]))
    end = time.time()
    df = pd.DataFrame()
    last_val_mcc_top1 = val_mcc_top1
    last_val_acc_top1 = val_acc_top1
    last_val_tpr_top1 = val_tpr_top1
    last_val_f1score_top1 = val_f1score_top1

    MCC_data = [val_mcc_top1]
    epochs = [0]
    all_attack_status = []
    
    metric_dict = {
            "MCC": [val_mcc_top1],
            "ACC": [val_acc_top1],
            "TPR": [val_tpr_top1],
            "F1": [val_f1score_top1]
        }
    
    for i_iter in range(N_iter):
        print('**********************************')        
        if attack_type == 1:
            attack_log, new_mcc, bit_count, attack_last_status = attacker.progressive_bit_search(model, data, target, test_loader)
            MCC_data.append(new_mcc['MCC'])
            epochs.append(i_iter)
        elif attack_type == 2:
            attack_log, new_mcc, bit_count, attack_last_status = attacker.random_flip_one_bit(model, test_loader)
            MCC_data.append(new_mcc['MCC'])
            epochs.append(i_iter)
        elif attack_type == 3:
            attack_log, new_mcc, bit_count, attack_last_status = attacker.progressive_bit_search(model, data, target, test_loader)
            attack_log, new_mcc, bit_count, attack_last_status = attacker.random_flip_one_bit(model, test_loader)
            MCC_data.append(new_mcc['MCC'])
            epochs.append(i_iter)
        elif attack_type == 4:
            attack_log, new_mcc, bit_count, attack_last_status = attacker.random_flip_one_bit(model, test_loader)
            attack_log, new_mcc, bit_count, attack_last_status = attacker.progressive_bit_search(model, data, target, test_loader)
            MCC_data.append(new_mcc['MCC'])
            epochs.append(i_iter)
            
        metric_dict["MCC"].append(new_mcc["MCC"])
        metric_dict["ACC"].append(new_mcc["Accuracy"])
        metric_dict["TPR"].append(new_mcc["TPR"])
        metric_dict["F1"].append(new_mcc["F1 Score"])
        
        attack_time.update(time.time() - end)
        end = time.time()

        h_dist = hamming_distance(model, model_clean)

        if hasattr(attacker, "loss_max"):
            losses.update(attacker.loss_max, data.size(0))

        print('Iteration: [{:03d}/{:03d}]   Attack Time {attack_time.val:.3f} ({attack_time.avg:.3f})'.format(i_iter + 1, N_iter, attack_time=attack_time))

        try:
            print('Loss before attack: {:.4f}'.format(attacker.loss.item()))
            print('Loss after attack: {:.4f}'.format(attacker.loss_max))
        except:
            pass

        print('Bit flips: {:.0f}'.format(attacker.bit_counter))
        print('Hamming distance: {:.0f}'.format(h_dist))

        writer.add_scalar('attack/bit_flip', attacker.bit_counter, i_iter + 1)
        writer.add_scalar('attack/h_dist', h_dist, i_iter + 1)
        writer.add_scalar('attack/sample_loss', losses.avg, i_iter + 1)

        val_mcc_top1, val_acc_top1, val_tpr_top1, val_f1score_top1, val_loss, output_summary = validate(test_loader, model, attacker.criterion, summary_output=True)
        print(f'**Test** MCC: {val_mcc_top1:.3f}. Val_Loss: {val_loss:.3f}')
        print(f'ACC: {val_acc_top1:.3f}.')
        print(f'TPR: {val_tpr_top1:.3f}.')
        print(f'F1-score: {val_f1score_top1:.3f}.')
        
        tmp_df = pd.DataFrame(output_summary)
        tmp_df['BFA iteration'] = i_iter + 1
        tmp_df.to_csv(os.path.join(args.save_path, 'output_summary_{}_BFA_{}.csv'.format(args.arch, i_iter + 1)), index=False)

        # last_val_mcc_top1 = val_mcc_top1
        # last_val_acc_top1 = val_acc_top1
        # last_val_tpr_top1 = val_tpr_top1
        # last_val_f1score_top1 = val_f1score_top1
        
        mcc_drop = last_val_mcc_top1 - val_mcc_top1
        last_val_mcc_top1 = val_mcc_top1

        acc_drop = last_val_acc_top1 - val_acc_top1
        last_val_acc_top1 = val_acc_top1

        tpr_drop = last_val_tpr_top1 - val_tpr_top1
        last_val_tpr_top1 = val_tpr_top1

        f1score_drop = last_val_f1score_top1 - val_f1score_top1
        last_val_f1score_top1 = val_f1score_top1

        attack_last_status.append(round(val_mcc_top1, 5))
        attack_last_status.append(round(mcc_drop, 5))
        
        attack_last_status.append(round(val_acc_top1, 5))
        attack_last_status.append(round(acc_drop, 5))
        
        attack_last_status.append(round(val_tpr_top1, 5))
        attack_last_status.append(round(tpr_drop, 5))
        
        attack_last_status.append(round(val_f1score_top1, 5))
        attack_last_status.append(round(f1score_drop, 5))

        for entry in attack_log:
            entry.append(val_mcc_top1)
            entry.append(mcc_drop)

            entry.append(val_acc_top1)
            entry.append(acc_drop)

            entry.append(val_tpr_top1)
            entry.append(tpr_drop)

            entry.append(val_f1score_top1)
            entry.append(f1score_drop)
            
        df = pd.concat([df, pd.DataFrame(attack_log)], ignore_index=True)

        writer.add_scalar('attack/val_top1_acc', val_mcc_top1, i_iter + 1)
        writer.add_scalar('attack/val_loss', val_loss, i_iter + 1)

        iter_time.update(time.time() - end)
        print('Iteration Time {iter_time.val:.3f} ({iter_time.avg:.3f})'.format(iter_time=iter_time))
        end = time.time()

        all_attack_status.append(attack_last_status)

    column_list = ['module idx', 'bit-flip idx', 'module name', 'weight idx', 'weight before attack', 'weight after attack'
                    , 'validation mcc', 'mcc drop'
                    , "ACC", "ACC Drop"
                    , "TPR", "TPR Drop"
                    , "F1-score", "F1-score Drop",]
    df.columns = column_list
    df['trial seed'] = args.manualSeed

    if csv_save_path is not None:
        csv_file_name = 'attack_profile_{}.csv'.format(args.manualSeed)
        df.to_csv(os.path.join(csv_save_path, csv_file_name), index=None)
        
    # Vẽ đồ thị với MCC
    plot_mcc_vs_epoch(file, epochs, MCC_data)
    
    try:
        if isinstance(file, list) and len(file) > 0:
            first_image_name = os.path.basename(file[0])
            suffix = first_image_name.split("_", 1)[-1] if "_" in first_image_name else "attack.png"
            combined_plot_path = os.path.join(os.path.dirname(file[0]), f"combined_metrics_{suffix}")
        else:
            combined_plot_path = "combined_metrics.png"

        plot_combined_metrics(combined_plot_path, epochs, metric_dict)
    except Exception as e:
        print(f"[Warning] Plotting combined metrics failed: {e}")
        
    with open(csv_file, mode='w', newline='') as file:
        writer = csv.writer(file)
        
        # Ghi tiêu đề (nếu cần)
        writer.writerow(["Bit Counter", "Module", "Weight Before Attack", "Weight After Attack"
                         , "MCC", "MCC Drop"
                         , "ACC", "ACC Drop"
                         , "TPR", "TPR Drop"
                         , "F1-score", "F1-score Drop",])
        
        # Ghi dữ liệu
        writer.writerows(all_attack_status)
    
    return

# %%
# Bước 1: Tải mô hình đã huấn luyện
model_path = os.path.join("CustomModel", "best_model.pth")
# Kiểm tra xem tệp có tồn tại không
if not os.path.exists(model_path):
    raise FileNotFoundError(f"Không tìm thấy mô hình tại: {model_path}")

trained_model = CustomModel()

# Tải trọng số từ file best_model.pth
trained_model.load_state_dict(torch.load(model_path, map_location=torch.device('cuda' if torch.cuda.is_available() else 'cpu')))
trained_model = trained_model.to(device)

results = validate_score(trained_model, test_loader)
print(f"MCC before attack: {results['MCC']}")
print(f"Accuracy before attack: {results['Accuracy']}")
print(f"TPR before attack: {results['TPR']}")
print(f"F1-score before attack: {results['F1 Score']}")
# Out:
# MCC before attack: 0.998303505142204
# Accuracy before attack: 0.9997571428571429
# TPR before attack: 0.9865040502754424
# F1-score before attack: 0.9860144039140872

# %%
# Bước 2: Tạo bản sao của mô hình để làm tham chiếu
model_clean = copy.deepcopy(trained_model)

# Bước 3: Khởi tạo đối tượng tấn công BFA
attacker = BFA(criterion=criterion, model=trained_model, k_top=10)

# Định nghĩa đường dẫn để lưu kết quả tấn công
attack_dir = os.path.join("CustomModel", "PBS_attack")

os.makedirs(attack_dir, exist_ok=True)
attack_image_paths = [os.path.join(attack_dir, f"{metric}_PBS_attack.png") 
                      for metric in ["MCC", "ACC", "TPR", "F1"]]
# attack_image_path = os.path.join(attack_dir, "PBS_attack.png")
attack_csv_path = os.path.join(attack_dir, "PBS_attack.csv")

# Bước 4: Thực hiện tấn công
perform_attack(
    attacker=attacker,               # Đối tượng tấn công
    model=trained_model,             # Mô hình bị tấn công
    model_clean=model_clean,         # Mô hình gốc làm tham chiếu
    train_loader=train_loader,       # Bộ dữ liệu huấn luyện
    test_loader=test_loader,         # Bộ dữ liệu kiểm tra
    N_iter=args.n_iter,              # Số vòng lặp tấn công
    writer=writer,                   # TensorBoard writer để ghi log
    file=attack_image_paths,          # Lưu ảnh vào thư mục tấn công
    csv_file=attack_csv_path, 
    csv_save_path=args.save_path,    # Đường dẫn lưu file CSV
    attack_type= 1,                  # Chế độ tấn công PBS
)

writer.close()  # Đóng TensorBoard writer
# best_mcc = validate_score(trained_model, test_loader)
# print(f"\nMCC after 100 times PBS attack: {best_mcc}")

results = validate_score(trained_model, test_loader)
print(f"MCC after 100 times PBS attack: {results['MCC']}")
print(f"Accuracy after 100 times PBS attack: {results['Accuracy']}")
print(f"TPR after 100 times PBS attack: {results['TPR']}")
print(f"F1-score after 100 times PBS attack: {results['F1 Score']}")
# Out:
# **Test** MCC: 0.999. Val_Loss: 0.005
# ACC: 1.000.
# TPR: 0.987.
# F1-score: 0.986.
# Attack sample size is 256
# **********************************
# attacked module: stage_2.12.conv_a
# Iteration: [001/040]   Attack Time 24.665 (24.665)
# Loss before attack: 0.0000
# Loss after attack: 37.7940
# Bit flips: 1
# Hamming distance: 1
# **Test** MCC: 0.479. Val_Loss: 37.514
# ACC: 0.073.
# TPR: 0.604.
# F1-score: 0.344.
# Iteration Time 11.332 (11.332)
# **********************************
# attacked module: stage_2.12.conv_b
# Iteration: [002/040]   Attack Time 23.562 (24.113)
# Loss before attack: 37.7940
# Loss after attack: 5307.0801
# Bit flips: 2
# Hamming distance: 2
# **Test** MCC: 0.479. Val_Loss: 5269.401
# ACC: 0.073.
# TPR: 0.604.
# F1-score: 0.344.
# Iteration Time 11.618 (11.475)
# **********************************
# attacked module: stage_3.4.conv_a
# Iteration: [003/040]   Attack Time 60.872 (36.366)
# Loss before attack: 5307.0801
# Loss after attack: 127135.8281
# Bit flips: 3
# Hamming distance: 3
# **Test** MCC: 0.479. Val_Loss: 126230.873
# ACC: 0.073.
# TPR: 0.604.
# F1-score: 0.344.
# Iteration Time 11.826 (11.592)
# **********************************
# attacked module: stage_3.12.conv_b
# Iteration: [004/040]   Attack Time 61.589 (42.672)
# Loss before attack: 127135.8281
# Loss after attack: 1516282.0000
# Bit flips: 4
# Hamming distance: 4
# **Test** MCC: 0.423. Val_Loss: 1505307.243
# ACC: 0.060.
# TPR: 0.208.
# F1-score: 0.205.
# Iteration Time 11.745 (11.630)
# **********************************
# attacked module: stage_3.12.conv_a
# Iteration: [005/040]   Attack Time 60.638 (46.265)
# Loss before attack: 1516282.0000
# Loss after attack: 225528800.0000
# Bit flips: 5
# Hamming distance: 5
# **Test** MCC: 0.476. Val_Loss: 223902754.619
# ACC: 0.067.
# TPR: 0.284.
# F1-score: 0.268.
# Iteration Time 11.361 (11.577)
# **********************************
# attacked module: stage_3.4.conv_b
# Iteration: [006/040]   Attack Time 16.421 (41.291)
# Loss before attack: 225528800.0000
# Loss after attack: 62081757184.0000
# Bit flips: 6
# Hamming distance: 6
# **Test** MCC: 0.396. Val_Loss: 61632050605.963
# ACC: 0.048.
# TPR: 0.208.
# F1-score: 0.222.
# Iteration Time 11.444 (11.555)
# **********************************
# attacked module: stage_2.13.conv_a
# Iteration: [007/040]   Attack Time 23.605 (38.765)
# Loss before attack: 62081757184.0000
# Loss after attack: 675442655232.0000
# Bit flips: 7
# Hamming distance: 7
# **Test** MCC: 0.061. Val_Loss: 670568736725.402
# ACC: 0.003.
# TPR: 0.031.
# F1-score: 0.023.
# Iteration Time 11.619 (11.564)
# **********************************
# attacked module: stage_2.13.conv_b
# Iteration: [008/040]   Attack Time 23.486 (36.855)
# Loss before attack: 675442655232.0000
# Loss after attack: 123802012876800.0000
# Bit flips: 8
# Hamming distance: 8
# **Test** MCC: 0.042. Val_Loss: 122908548742527.625
# ACC: 0.002.
# TPR: 0.027.
# F1-score: 0.016.
# Iteration Time 11.945 (11.611)
# **********************************
# attacked module: stage_2.7.conv_b
# Iteration: [009/040]   Attack Time 23.709 (35.394)
# Loss before attack: 123802012876800.0000
# Loss after attack: 1230527055003648.0000
# Bit flips: 9
# Hamming distance: 9
# **Test** MCC: 0.446. Val_Loss: 1216078180380543.750
# ACC: 0.059.
# TPR: 0.254.
# F1-score: 0.252.
# Iteration Time 11.573 (11.607)
# **********************************
# attacked module: stage_2.7.conv_a
# Iteration: [010/040]   Attack Time 23.452 (34.200)
# Loss before attack: 1230527055003648.0000
# Loss after attack: 616439063808835584.0000
# Bit flips: 10
# Hamming distance: 10
# **Test** MCC: 0.009. Val_Loss: 613933564409961344.000
# ACC: 0.001.
# TPR: 0.022.
# F1-score: 0.006.
# Iteration Time 11.517 (11.598)
# **********************************
# attacked module: stage_1.0.conv_b
# Iteration: [011/040]   Attack Time 14.174 (32.379)
# Loss before attack: 616439063808835584.0000
# Loss after attack: 7055800311415308288.0000
# Bit flips: 11
# Hamming distance: 11
# **Test** MCC: 0.000. Val_Loss: 6820475050683875328.000
# ACC: 0.000.
# TPR: 0.016.
# F1-score: 0.000.
# Iteration Time 11.548 (11.593)
# **********************************
# attacked module: stage_1.0.conv_a
# Iteration: [012/040]   Attack Time 14.181 (30.863)
# Loss before attack: 7055800311415308288.0000
# Loss after attack: 742834137112627904512.0000
# Bit flips: 12
# Hamming distance: 12
# **Test** MCC: 0.342. Val_Loss: 1006017879720247427072.000
# ACC: 0.036.
# TPR: 0.163.
# F1-score: 0.187.
# Iteration Time 11.606 (11.594)
# **********************************
# attacked module: fc1
# Iteration: [013/040]   Attack Time 15.155 (29.655)
# Loss before attack: 742834137112627904512.0000
# Loss after attack: 266022063539635768786944.0000
# Bit flips: 13
# Hamming distance: 13
# **Test** MCC: 0.051. Val_Loss: 261107851054279565508608.000
# ACC: 0.004.
# TPR: 0.029.
# F1-score: 0.022.
# Iteration Time 11.477 (11.585)
# **********************************
# attacked module: stage_1.10.conv_b
# Iteration: [014/040]   Attack Time 14.115 (28.545)
# Loss before attack: 266022063539635768786944.0000
# Loss after attack: 5945464013618901751431168.0000
# Bit flips: 14
# Hamming distance: 14
# **Test** MCC: 0.000. Val_Loss: 5835446245822243117465600.000
# ACC: 0.000.
# TPR: 0.016.
# F1-score: 0.000.
# Iteration Time 11.537 (11.582)
# **********************************
# attacked module: stage_1.10.conv_a
# Iteration: [015/040]   Attack Time 14.002 (27.575)
# Loss before attack: 5945464013618901751431168.0000
# Loss after attack: 1013796382163858422226747392.0000
# Bit flips: 15
# Hamming distance: 15
# **Test** MCC: 0.032. Val_Loss: 995012155603026166356639744.000
# ACC: 0.002.
# TPR: 0.023.
# F1-score: 0.013.
# Iteration Time 11.392 (11.569)
# **********************************
# attacked module: stage_1.5.conv_b
# Iteration: [016/040]   Attack Time 14.460 (26.755)
# Loss before attack: 1013796382163858422226747392.0000
# Loss after attack: 19989460923432855923345850368.0000
# Bit flips: 16
# Hamming distance: 16
# **Test** MCC: -0.000. Val_Loss: 19618992081590723881201565696.000
# ACC: 0.000.
# TPR: 0.016.
# F1-score: 0.000.
# Iteration Time 11.850 (11.587)
# **********************************
# attacked module: stage_1.5.conv_a
# Iteration: [017/040]   Attack Time 14.216 (26.018)
# Loss before attack: 19989460923432855923345850368.0000
# Loss after attack: 5213650361907548025027683155968.0000
# Bit flips: 17
# Hamming distance: 17
# **Test** MCC: 0.049. Val_Loss: 5117390114172824837963028365312.000
# ACC: 0.003.
# TPR: 0.026.
# F1-score: 0.017.
# Iteration Time 11.540 (11.584)
# **********************************
# attacked module: stage_1.4.conv_b
# Iteration: [018/040]   Attack Time 14.140 (25.358)
# Loss before attack: 5213650361907548025027683155968.0000
# Loss after attack: 99212857209874430978411359895552.0000
# Bit flips: 18
# Hamming distance: 18
# **Test** MCC: 0.000. Val_Loss: 97372210625792791765934581743616.000
# ACC: 0.000.
# TPR: 0.016.
# F1-score: 0.000.
# Iteration Time 11.607 (11.585)
# **********************************
# attacked module: stage_1.4.conv_a
# Iteration: [019/040]   Attack Time 14.018 (24.761)
# Loss before attack: 99212857209874430978411359895552.0000
# Loss after attack: 40043938604613467101906847467044864.0000
# Bit flips: 19
# Hamming distance: 19
# **Test** MCC: 0.035. Val_Loss: 39300900667213723738584501666709504.000
# ACC: 0.002.
# TPR: 0.022.
# F1-score: 0.011.
# Iteration Time 11.535 (11.583)
# **********************************
# attacked module: stage_1.8.conv_b
# Iteration: [020/040]   Attack Time 13.984 (24.222)
# Loss before attack: 40043938604613467101906847467044864.0000
# Loss after attack: 687165898211330708826217847883563008.0000
# Bit flips: 20
# Hamming distance: 20
# **Test** MCC: 0.001. Val_Loss: 674513842192038606999176865191559168.000
# ACC: 0.000.
# TPR: 0.017.
# F1-score: 0.000.
# Iteration Time 11.535 (11.580)
# **********************************
# attacked module: stage_1.1.conv_b
# Iteration: [021/040]   Attack Time 14.617 (23.765)
# Loss before attack: 687165898211330708826217847883563008.0000
# Loss after attack: inf
# Bit flips: 21
# Hamming distance: 21
# **Test** MCC: 0.003. Val_Loss: nan
# ACC: 0.000.
# TPR: 0.022.
# F1-score: 0.006.
# Iteration Time 11.753 (11.589)
# **********************************
# attacked module: fc1
# Iteration: [022/040]   Attack Time 15.242 (23.377)
# Loss before attack: inf
# Loss after attack: nan
# Bit flips: 24
# Hamming distance: 24
# **Test** MCC: 0.000. Val_Loss: nan
# ACC: 0.000.
# TPR: 0.015.
# F1-score: 0.000.
# Iteration Time 11.544 (11.587)
# **********************************
# Iteration: [023/040]   Attack Time 8.911 (22.748)
# Loss before attack: nan
# Loss after attack: nan
# Bit flips: 24
# Hamming distance: 24
# **Test** MCC: 0.000. Val_Loss: nan
# ACC: 0.000.
# TPR: 0.015.
# F1-score: 0.000.
# Iteration Time 11.333 (11.575)
# **********************************
# Iteration: [024/040]   Attack Time 9.001 (22.176)
# Loss before attack: nan
# Loss after attack: nan
# Bit flips: 24
# Hamming distance: 24
# **Test** MCC: 0.000. Val_Loss: nan
# ACC: 0.000.
# TPR: 0.015.
# F1-score: 0.000.
# Iteration Time 11.505 (11.573)
# **********************************
# Iteration: [025/040]   Attack Time 8.908 (21.645)
# Loss before attack: nan
# Loss after attack: nan
# Bit flips: 24
# Hamming distance: 24
# **Test** MCC: 0.000. Val_Loss: nan
# ACC: 0.000.
# TPR: 0.015.
# F1-score: 0.000.
# Iteration Time 11.568 (11.572)
# **********************************
# Iteration: [026/040]   Attack Time 9.020 (21.159)
# Loss before attack: nan
# Loss after attack: nan
# Bit flips: 24
# Hamming distance: 24
# **Test** MCC: 0.000. Val_Loss: nan
# ACC: 0.000.
# TPR: 0.015.
# F1-score: 0.000.
# Iteration Time 11.469 (11.568)
# **********************************
# Iteration: [027/040]   Attack Time 8.965 (20.708)
# Loss before attack: nan
# Loss after attack: nan
# Bit flips: 24
# Hamming distance: 24
# **Test** MCC: 0.000. Val_Loss: nan
# ACC: 0.000.
# TPR: 0.015.
# F1-score: 0.000.
# Iteration Time 11.288 (11.558)
# **********************************
# Iteration: [028/040]   Attack Time 8.967 (20.288)
# Loss before attack: nan
# Loss after attack: nan
# Bit flips: 24
# Hamming distance: 24
# **Test** MCC: 0.000. Val_Loss: nan
# ACC: 0.000.
# TPR: 0.015.
# F1-score: 0.000.
# Iteration Time 11.512 (11.556)
# **********************************
# Iteration: [029/040]   Attack Time 8.860 (19.894)
# Loss before attack: nan
# Loss after attack: nan
# Bit flips: 24
# Hamming distance: 24
# **Test** MCC: 0.000. Val_Loss: nan
# ACC: 0.000.
# TPR: 0.015.
# F1-score: 0.000.
# Iteration Time 11.436 (11.552)
# **********************************
# Iteration: [030/040]   Attack Time 9.110 (19.535)
# Loss before attack: nan
# Loss after attack: nan
# Bit flips: 24
# Hamming distance: 24
# **Test** MCC: 0.000. Val_Loss: nan
# ACC: 0.000.
# TPR: 0.015.
# F1-score: 0.000.
# Iteration Time 11.743 (11.559)
# **********************************
# Iteration: [031/040]   Attack Time 9.157 (19.200)
# Loss before attack: nan
# Loss after attack: nan
# Bit flips: 24
# Hamming distance: 24
# **Test** MCC: 0.000. Val_Loss: nan
# ACC: 0.000.
# TPR: 0.015.
# F1-score: 0.000.
# Iteration Time 11.607 (11.560)
# **********************************
# Iteration: [032/040]   Attack Time 8.914 (18.879)
# Loss before attack: nan
# Loss after attack: nan
# Bit flips: 24
# Hamming distance: 24
# **Test** MCC: 0.000. Val_Loss: nan
# ACC: 0.000.
# TPR: 0.015.
# F1-score: 0.000.
# Iteration Time 11.545 (11.560)
# **********************************
# Iteration: [033/040]   Attack Time 9.075 (18.582)
# Loss before attack: nan
# Loss after attack: nan
# Bit flips: 24
# Hamming distance: 24
# **Test** MCC: 0.000. Val_Loss: nan
# ACC: 0.000.
# TPR: 0.015.
# F1-score: 0.000.
# Iteration Time 11.711 (11.564)
# **********************************
# Iteration: [034/040]   Attack Time 8.901 (18.297)
# Loss before attack: nan
# Loss after attack: nan
# Bit flips: 24
# Hamming distance: 24
# **Test** MCC: 0.000. Val_Loss: nan
# ACC: 0.000.
# TPR: 0.015.
# F1-score: 0.000.
# Iteration Time 11.467 (11.561)
# **********************************
# Iteration: [035/040]   Attack Time 9.258 (18.039)
# Loss before attack: nan
# Loss after attack: nan
# Bit flips: 24
# Hamming distance: 24
# **Test** MCC: 0.000. Val_Loss: nan
# ACC: 0.000.
# TPR: 0.015.
# F1-score: 0.000.
# Iteration Time 11.497 (11.560)
# **********************************
# Iteration: [036/040]   Attack Time 9.036 (17.789)
# Loss before attack: nan
# Loss after attack: nan
# Bit flips: 24
# Hamming distance: 24
# **Test** MCC: 0.000. Val_Loss: nan
# ACC: 0.000.
# TPR: 0.015.
# F1-score: 0.000.
# Iteration Time 11.503 (11.558)
# **********************************
# Iteration: [037/040]   Attack Time 9.114 (17.554)
# Loss before attack: nan
# Loss after attack: nan
# Bit flips: 24
# Hamming distance: 24
# **Test** MCC: 0.000. Val_Loss: nan
# ACC: 0.000.
# TPR: 0.015.
# F1-score: 0.000.
# Iteration Time 11.571 (11.558)
# **********************************
# Iteration: [038/040]   Attack Time 8.967 (17.328)
# Loss before attack: nan
# Loss after attack: nan
# Bit flips: 24
# Hamming distance: 24
# **Test** MCC: 0.000. Val_Loss: nan
# ACC: 0.000.
# TPR: 0.015.
# F1-score: 0.000.
# Iteration Time 11.369 (11.553)
# **********************************
# Iteration: [039/040]   Attack Time 8.911 (17.112)
# Loss before attack: nan
# Loss after attack: nan
# Bit flips: 24
# Hamming distance: 24
# **Test** MCC: 0.000. Val_Loss: nan
# ACC: 0.000.
# TPR: 0.015.
# F1-score: 0.000.
# Iteration Time 11.461 (11.551)
# **********************************
# Iteration: [040/040]   Attack Time 8.970 (16.909)
# Loss before attack: nan
# Loss after attack: nan
# Bit flips: 24
# Hamming distance: 24
# **Test** MCC: 0.000. Val_Loss: nan
# ACC: 0.000.
# TPR: 0.015.
# F1-score: 0.000.
# Iteration Time 11.619 (11.553)
# Plot saved as CustomModel/PBS_attack/MCC_PBS_attack.png
# Plot saved as CustomModel/PBS_attack/ACC_PBS_attack.png
# Plot saved as CustomModel/PBS_attack/TPR_PBS_attack.png
# Plot saved as CustomModel/PBS_attack/F1_PBS_attack.png
# [Combined Plot] Saved as CustomModel/PBS_attack/combined_metrics_PBS_attack.png
# MCC after 100 times PBS attack: 0.00030477583052802626
# Accuracy after 100 times PBS attack: 0.00028571428571428574
# TPR after 100 times PBS attack: 0.014994285714285719
# F1-score after 100 times PBS attack: 0.00026562554992036816

# %%
# Bước 1: Tải mô hình đã huấn luyện
model_path = os.path.join("CustomModel", "best_model.pth")

trained_model = CustomModel()

# Tải trọng số từ file best_model.pth
trained_model.load_state_dict(torch.load(model_path, map_location=torch.device('cuda' if torch.cuda.is_available() else 'cpu')))
trained_model = trained_model.to(device)

# Bước 2: Tạo bản sao của mô hình để làm tham chiếu
model_clean = copy.deepcopy(trained_model)

# Bước 3: Khởi tạo đối tượng tấn công BFA
attacker = BFA(criterion=criterion, model=trained_model, k_top=10)

# Định nghĩa đường dẫn để lưu kết quả tấn công
attack_dir = os.path.join("CustomModel", "RandomFlip_attack")

os.makedirs(attack_dir, exist_ok=True)
attack_image_paths = [os.path.join(attack_dir, f"{metric}_RandomFlip_attack.png") 
                      for metric in ["MCC", "ACC", "TPR", "F1"]]
# attack_image_path = os.path.join(attack_dir, "RandomFlip_attack.png")
attack_csv_path = os.path.join(attack_dir, "RandomFlip_attack.csv")

# Bước 4: Thực hiện tấn công
perform_attack(
    attacker=attacker,               # Đối tượng tấn công
    model=trained_model,             # Mô hình bị tấn công
    model_clean=model_clean,         # Mô hình gốc làm tham chiếu
    train_loader=train_loader,       # Bộ dữ liệu huấn luyện
    test_loader=test_loader,         # Bộ dữ liệu kiểm tra
    N_iter=args.n_iter,              # Số vòng lặp tấn công
    writer=writer,                   # TensorBoard writer để ghi log
    file=attack_image_paths,          # Lưu ảnh vào thư mục tấn công
    csv_file=attack_csv_path, 
    csv_save_path=args.save_path,    # Đường dẫn lưu file CSV
    attack_type= 2,                  # Chế độ tấn công random
)

writer.close()  # Đóng TensorBoard writer

# best_mcc = validate_score(trained_model ,test_loader)
# print(f"\nMCC after 100 times random attack: {best_mcc}")

results = validate_score(trained_model, test_loader)
print(f"MCC after 100 times random attack: {results['MCC']}")
print(f"Accuracy after 100 times random attack: {results['Accuracy']}")
print(f"TPR after 100 times random attack: {results['TPR']}")
print(f"F1-score after 100 times random attack: {results['F1 Score']}")
# Out:
# **Test** MCC: 0.999. Val_Loss: 0.006
# ACC: 1.000.
# TPR: 0.988.
# F1-score: 0.988.
# Attack sample size is 256
# **********************************
# attacked module: stage_1.0.conv_b
# attacked weight index: 186
# weight before attack: tensor(-0.1882, device='cuda:0')
# weight after attack: tensor(-3., device='cuda:0')
# Iteration: [001/040]   Attack Time 9.255 (9.255)
# Bit flips: 1
# Hamming distance: 1
# **Test** MCC: 0.999. Val_Loss: 0.006
# ACC: 1.000.
# TPR: 0.988.
# F1-score: 0.988.
# Iteration Time 11.766 (11.766)
# **********************************
# attacked module: stage_3.7.conv_a
# attacked weight index: 13376
# weight before attack: tensor(0.0876, device='cuda:0')
# weight after attack: tensor(64., device='cuda:0')
# Iteration: [002/040]   Attack Time 8.989 (9.122)
# Bit flips: 2
# Hamming distance: 2
# **Test** MCC: 0.999. Val_Loss: 0.006
# ACC: 1.000.
# TPR: 0.988.
# F1-score: 0.988.
# Iteration Time 11.363 (11.564)
# **********************************
# attacked module: stage_1.2.conv_b
# attacked weight index: 2557
# weight before attack: tensor(0.1426, device='cuda:0')
# weight after attack: tensor(64., device='cuda:0')
# Iteration: [003/040]   Attack Time 9.018 (9.087)
# Bit flips: 3
# Hamming distance: 3
# **Test** MCC: 0.999. Val_Loss: 0.009
# ACC: 1.000.
# TPR: 0.988.
# F1-score: 0.988.
# Iteration Time 11.755 (11.628)
# **********************************
# attacked module: stage_3.13.conv_b
# attacked weight index: 41774
# weight before attack: tensor(0.0448, device='cuda:0')
# weight after attack: tensor(32., device='cuda:0')
# Iteration: [004/040]   Attack Time 9.021 (9.071)
# Bit flips: 4
# Hamming distance: 4
# **Test** MCC: 0.999. Val_Loss: 0.009
# ACC: 1.000.
# TPR: 0.988.
# F1-score: 0.988.
# Iteration Time 11.552 (11.609)
# **********************************
# attacked module: stage_2.4.conv_b
# attacked weight index: 3643
# weight before attack: tensor(-0.0216, device='cuda:0')
# weight after attack: tensor(127., device='cuda:0')
# Iteration: [005/040]   Attack Time 9.028 (9.062)
# Bit flips: 5
# Hamming distance: 5
# **Test** MCC: 0.330. Val_Loss: 0.741
# ACC: 0.246.
# TPR: 0.665.
# F1-score: 0.448.
# Iteration Time 11.341 (11.555)
# **********************************
# attacked module: stage_1.12.conv_a
# attacked weight index: 1483
# weight before attack: tensor(-0.1971, device='cuda:0')
# weight after attack: tensor(-33., device='cuda:0')
# Iteration: [006/040]   Attack Time 8.964 (9.046)
# Bit flips: 6
# Hamming distance: 6
# **Test** MCC: 0.330. Val_Loss: 0.741
# ACC: 0.246.
# TPR: 0.665.
# F1-score: 0.448.
# Iteration Time 11.464 (11.540)
# **********************************
# attacked module: stage_3.13.conv_b
# attacked weight index: 19514
# weight before attack: tensor(-0.1150, device='cuda:0')
# weight after attack: tensor(-3., device='cuda:0')
# Iteration: [007/040]   Attack Time 9.009 (9.040)
# Bit flips: 7
# Hamming distance: 7
# **Test** MCC: 0.330. Val_Loss: 0.741
# ACC: 0.246.
# TPR: 0.665.
# F1-score: 0.448.
# Iteration Time 11.574 (11.545)
# **********************************
# attacked module: stage_3.4.conv_b
# attacked weight index: 12682
# weight before attack: tensor(0.1234, device='cuda:0')
# weight after attack: tensor(4., device='cuda:0')
# Iteration: [008/040]   Attack Time 9.061 (9.043)
# Bit flips: 8
# Hamming distance: 8
# **Test** MCC: 0.330. Val_Loss: 0.743
# ACC: 0.246.
# TPR: 0.665.
# F1-score: 0.448.
# Iteration Time 11.571 (11.548)
# **********************************
# attacked module: stage_2.15.conv_a
# attacked weight index: 1047
# weight before attack: tensor(-0.0029, device='cuda:0')
# weight after attack: tensor(-3., device='cuda:0')
# Iteration: [009/040]   Attack Time 9.051 (9.044)
# Bit flips: 9
# Hamming distance: 9
# **Test** MCC: 0.330. Val_Loss: 0.743
# ACC: 0.246.
# TPR: 0.665.
# F1-score: 0.448.
# Iteration Time 11.683 (11.563)
# **********************************
# attacked module: stage_1.12.conv_b
# attacked weight index: 2253
# weight before attack: tensor(0.2683, device='cuda:0')
# weight after attack: tensor(8., device='cuda:0')
# Iteration: [010/040]   Attack Time 8.979 (9.037)
# Bit flips: 10
# Hamming distance: 10
# **Test** MCC: 0.330. Val_Loss: 0.743
# ACC: 0.246.
# TPR: 0.665.
# F1-score: 0.448.
# Iteration Time 11.393 (11.546)
# **********************************
# attacked module: stage_3.13.conv_b
# attacked weight index: 9740
# weight before attack: tensor(-0.0280, device='cuda:0')
# weight after attack: tensor(-3., device='cuda:0')
# Iteration: [011/040]   Attack Time 9.124 (9.045)
# Bit flips: 11
# Hamming distance: 11
# **Test** MCC: 0.330. Val_Loss: 0.743
# ACC: 0.246.
# TPR: 0.665.
# F1-score: 0.448.
# Iteration Time 11.311 (11.525)
# **********************************
# attacked module: stage_3.1.conv_b
# attacked weight index: 29707
# weight before attack: tensor(-0.0015, device='cuda:0')
# weight after attack: tensor(127., device='cuda:0')
# Iteration: [012/040]   Attack Time 8.942 (9.037)
# Bit flips: 12
# Hamming distance: 12
# **Test** MCC: 0.330. Val_Loss: 0.759
# ACC: 0.246.
# TPR: 0.665.
# F1-score: 0.448.
# Iteration Time 11.540 (11.526)
# **********************************
# attacked module: stage_3.9.conv_b
# attacked weight index: 45699
# weight before attack: tensor(0.0238, device='cuda:0')
# weight after attack: tensor(2., device='cuda:0')
# Iteration: [013/040]   Attack Time 8.874 (9.024)
# Bit flips: 13
# Hamming distance: 13
# **Test** MCC: 0.330. Val_Loss: 0.759
# ACC: 0.246.
# TPR: 0.665.
# F1-score: 0.448.
# Iteration Time 11.618 (11.533)
# **********************************
# attacked module: stage_2.5.conv_b
# attacked weight index: 7865
# weight before attack: tensor(-0.0602, device='cuda:0')
# weight after attack: tensor(-9., device='cuda:0')
# Iteration: [014/040]   Attack Time 8.922 (9.017)
# Bit flips: 14
# Hamming distance: 14
# **Test** MCC: 0.330. Val_Loss: 0.759
# ACC: 0.246.
# TPR: 0.665.
# F1-score: 0.448.
# Iteration Time 11.420 (11.525)
# **********************************
# attacked module: stage_2.0.conv_b
# attacked weight index: 3886
# weight before attack: tensor(-0.0200, device='cuda:0')
# weight after attack: tensor(-3., device='cuda:0')
# Iteration: [015/040]   Attack Time 8.879 (9.008)
# Bit flips: 15
# Hamming distance: 15
# **Test** MCC: 0.330. Val_Loss: 0.759
# ACC: 0.246.
# TPR: 0.665.
# F1-score: 0.448.
# Iteration Time 11.419 (11.518)
# **********************************
# attacked module: stage_2.0.conv_b
# attacked weight index: 7127
# weight before attack: tensor(-0.1056, device='cuda:0')
# weight after attack: tensor(-9., device='cuda:0')
# Iteration: [016/040]   Attack Time 9.074 (9.012)
# Bit flips: 16
# Hamming distance: 16
# **Test** MCC: 0.330. Val_Loss: 0.759
# ACC: 0.246.
# TPR: 0.665.
# F1-score: 0.448.
# Iteration Time 11.764 (11.533)
# **********************************
# attacked module: stage_1.3.conv_a
# attacked weight index: 2820
# weight before attack: tensor(0.1537, device='cuda:0')
# weight after attack: tensor(2., device='cuda:0')
# Iteration: [017/040]   Attack Time 9.252 (9.026)
# Bit flips: 17
# Hamming distance: 17
# **Test** MCC: 0.330. Val_Loss: 0.759
# ACC: 0.246.
# TPR: 0.665.
# F1-score: 0.448.
# Iteration Time 11.591 (11.537)
# **********************************
# attacked module: stage_1.14.conv_b
# attacked weight index: 994
# weight before attack: tensor(-0.3605, device='cuda:0')
# weight after attack: tensor(-65., device='cuda:0')
# Iteration: [018/040]   Attack Time 8.812 (9.014)
# Bit flips: 18
# Hamming distance: 18
# **Test** MCC: 0.330. Val_Loss: 0.759
# ACC: 0.246.
# TPR: 0.665.
# F1-score: 0.448.
# Iteration Time 11.812 (11.552)
# **********************************
# attacked module: stage_1.13.conv_a
# attacked weight index: 2823
# weight before attack: tensor(-0.0536, device='cuda:0')
# weight after attack: tensor(-17., device='cuda:0')
# Iteration: [019/040]   Attack Time 9.064 (9.017)
# Bit flips: 19
# Hamming distance: 19
# **Test** MCC: 0.330. Val_Loss: 0.759
# ACC: 0.246.
# TPR: 0.665.
# F1-score: 0.448.
# Iteration Time 11.598 (11.554)
# **********************************
# attacked module: stage_3.14.conv_a
# attacked weight index: 22215
# weight before attack: tensor(-0.1122, device='cuda:0')
# weight after attack: tensor(-33., device='cuda:0')
# Iteration: [020/040]   Attack Time 9.074 (9.020)
# Bit flips: 20
# Hamming distance: 20
# **Test** MCC: 0.330. Val_Loss: 0.759
# ACC: 0.246.
# TPR: 0.665.
# F1-score: 0.448.
# Iteration Time 11.359 (11.545)
# **********************************
# attacked module: stage_3.7.conv_a
# attacked weight index: 25701
# weight before attack: tensor(-0.0675, device='cuda:0')
# weight after attack: tensor(-9., device='cuda:0')
# Iteration: [021/040]   Attack Time 8.914 (9.014)
# Bit flips: 21
# Hamming distance: 21
# **Test** MCC: 0.330. Val_Loss: 0.759
# ACC: 0.246.
# TPR: 0.665.
# F1-score: 0.448.
# Iteration Time 11.437 (11.539)
# **********************************
# attacked module: stage_2.8.conv_b
# attacked weight index: 66
# weight before attack: tensor(0.0560, device='cuda:0')
# weight after attack: tensor(16., device='cuda:0')
# Iteration: [022/040]   Attack Time 8.894 (9.009)
# Bit flips: 22
# Hamming distance: 22
# **Test** MCC: 0.330. Val_Loss: 0.759
# ACC: 0.246.
# TPR: 0.665.
# F1-score: 0.448.
# Iteration Time 11.475 (11.536)
# **********************************
# attacked module: stage_3.5.conv_a
# attacked weight index: 10778
# weight before attack: tensor(-0.0450, device='cuda:0')
# weight after attack: tensor(-65., device='cuda:0')
# Iteration: [023/040]   Attack Time 9.099 (9.013)
# Bit flips: 23
# Hamming distance: 23
# **Test** MCC: 0.330. Val_Loss: 0.759
# ACC: 0.246.
# TPR: 0.665.
# F1-score: 0.448.
# Iteration Time 11.538 (11.537)
# **********************************
# attacked module: stage_3.2.conv_b
# attacked weight index: 46624
# weight before attack: tensor(0.0791, device='cuda:0')
# weight after attack: tensor(16., device='cuda:0')
# Iteration: [024/040]   Attack Time 8.963 (9.011)
# Bit flips: 24
# Hamming distance: 24
# **Test** MCC: 0.330. Val_Loss: 0.758
# ACC: 0.246.
# TPR: 0.665.
# F1-score: 0.448.
# Iteration Time 11.529 (11.536)
# **********************************
# attacked module: stage_1.10.conv_b
# attacked weight index: 2166
# weight before attack: tensor(0.0523, device='cuda:0')
# weight after attack: tensor(1., device='cuda:0')
# Iteration: [025/040]   Attack Time 8.918 (9.007)
# Bit flips: 25
# Hamming distance: 25
# **Test** MCC: 0.330. Val_Loss: 0.758
# ACC: 0.246.
# TPR: 0.665.
# F1-score: 0.448.
# Iteration Time 11.621 (11.540)
# **********************************
# attacked module: stage_2.5.conv_a
# attacked weight index: 5486
# weight before attack: tensor(-0.0127, device='cuda:0')
# weight after attack: tensor(-65., device='cuda:0')
# Iteration: [026/040]   Attack Time 9.135 (9.012)
# Bit flips: 26
# Hamming distance: 26
# **Test** MCC: 0.330. Val_Loss: 0.758
# ACC: 0.246.
# TPR: 0.665.
# F1-score: 0.448.
# Iteration Time 11.713 (11.546)
# **********************************
# attacked module: stage_1.9.conv_b
# attacked weight index: 1355
# weight before attack: tensor(0.1453, device='cuda:0')
# weight after attack: tensor(1., device='cuda:0')
# Iteration: [027/040]   Attack Time 9.002 (9.012)
# Bit flips: 27
# Hamming distance: 27
# **Test** MCC: 0.330. Val_Loss: 0.758
# ACC: 0.246.
# TPR: 0.665.
# F1-score: 0.448.
# Iteration Time 11.747 (11.554)
# **********************************
# attacked module: stage_3.11.conv_a
# attacked weight index: 20396
# weight before attack: tensor(-0.0745, device='cuda:0')
# weight after attack: tensor(127., device='cuda:0')
# Iteration: [028/040]   Attack Time 9.006 (9.011)
# Bit flips: 28
# Hamming distance: 28
# **Test** MCC: 0.330. Val_Loss: 0.758
# ACC: 0.246.
# TPR: 0.665.
# F1-score: 0.448.
# Iteration Time 11.523 (11.553)
# **********************************
# attacked module: stage_2.1.conv_a
# attacked weight index: 5973
# weight before attack: tensor(0.0366, device='cuda:0')
# weight after attack: tensor(-128., device='cuda:0')
# Iteration: [029/040]   Attack Time 8.751 (9.002)
# Bit flips: 29
# Hamming distance: 29
# **Test** MCC: 0.330. Val_Loss: 0.758
# ACC: 0.246.
# TPR: 0.665.
# F1-score: 0.448.
# Iteration Time 11.089 (11.537)
# **********************************
# attacked module: stage_1.1.conv_b
# attacked weight index: 2467
# weight before attack: tensor(-0.2858, device='cuda:0')
# weight after attack: tensor(-9., device='cuda:0')
# Iteration: [030/040]   Attack Time 8.822 (8.996)
# Bit flips: 30
# Hamming distance: 30
# **Test** MCC: 0.330. Val_Loss: 0.758
# ACC: 0.246.
# TPR: 0.665.
# F1-score: 0.448.
# Iteration Time 11.480 (11.535)
# **********************************
# attacked module: stage_1.13.conv_a
# attacked weight index: 1641
# weight before attack: tensor(0.1465, device='cuda:0')
# weight after attack: tensor(32., device='cuda:0')
# Iteration: [031/040]   Attack Time 9.132 (9.001)
# Bit flips: 31
# Hamming distance: 31
# **Test** MCC: 0.330. Val_Loss: 0.758
# ACC: 0.246.
# TPR: 0.665.
# F1-score: 0.448.
# Iteration Time 11.649 (11.538)
# **********************************
# attacked module: stage_2.9.conv_a
# attacked weight index: 7592
# weight before attack: tensor(-0.0674, device='cuda:0')
# weight after attack: tensor(-9., device='cuda:0')
# Iteration: [032/040]   Attack Time 8.889 (8.997)
# Bit flips: 32
# Hamming distance: 32
# **Test** MCC: 0.330. Val_Loss: 0.758
# ACC: 0.246.
# TPR: 0.665.
# F1-score: 0.448.
# Iteration Time 11.441 (11.535)
# **********************************
# attacked module: stage_2.10.conv_b
# attacked weight index: 4647
# weight before attack: tensor(0.2437, device='cuda:0')
# weight after attack: tensor(32., device='cuda:0')
# Iteration: [033/040]   Attack Time 9.064 (8.999)
# Bit flips: 33
# Hamming distance: 33
# **Test** MCC: 0.330. Val_Loss: 0.758
# ACC: 0.246.
# TPR: 0.665.
# F1-score: 0.448.
# Iteration Time 11.693 (11.540)
# **********************************
# attacked module: stage_2.10.conv_a
# attacked weight index: 684
# weight before attack: tensor(0.2022, device='cuda:0')
# weight after attack: tensor(1., device='cuda:0')
# Iteration: [034/040]   Attack Time 9.120 (9.003)
# Bit flips: 34
# Hamming distance: 34
# **Test** MCC: 0.330. Val_Loss: 0.758
# ACC: 0.246.
# TPR: 0.665.
# F1-score: 0.448.
# Iteration Time 11.599 (11.542)
# **********************************
# attacked module: stage_1.15.conv_a
# attacked weight index: 375
# weight before attack: tensor(0.1406, device='cuda:0')
# weight after attack: tensor(8., device='cuda:0')
# Iteration: [035/040]   Attack Time 9.200 (9.009)
# Bit flips: 35
# Hamming distance: 35
# **Test** MCC: 0.330. Val_Loss: 0.758
# ACC: 0.246.
# TPR: 0.665.
# F1-score: 0.448.
# Iteration Time 11.622 (11.544)
# **********************************
# attacked module: stage_1.12.conv_a
# attacked weight index: 1696
# weight before attack: tensor(0.0306, device='cuda:0')
# weight after attack: tensor(1., device='cuda:0')
# Iteration: [036/040]   Attack Time 9.080 (9.011)
# Bit flips: 36
# Hamming distance: 36
# **Test** MCC: 0.330. Val_Loss: 0.758
# ACC: 0.246.
# TPR: 0.665.
# F1-score: 0.448.
# Iteration Time 11.673 (11.548)
# **********************************
# attacked module: stage_3.4.conv_a
# attacked weight index: 43459
# weight before attack: tensor(0.1558, device='cuda:0')
# weight after attack: tensor(4., device='cuda:0')
# Iteration: [037/040]   Attack Time 9.199 (9.016)
# Bit flips: 37
# Hamming distance: 37
# **Test** MCC: 0.330. Val_Loss: 0.758
# ACC: 0.246.
# TPR: 0.665.
# F1-score: 0.448.
# Iteration Time 11.586 (11.549)
# **********************************
# attacked module: stage_3.10.conv_a
# attacked weight index: 41864
# weight before attack: tensor(0.0169, device='cuda:0')
# weight after attack: tensor(64., device='cuda:0')
# Iteration: [038/040]   Attack Time 9.199 (9.020)
# Bit flips: 38
# Hamming distance: 38
# **Test** MCC: 0.330. Val_Loss: 0.758
# ACC: 0.246.
# TPR: 0.665.
# F1-score: 0.448.
# Iteration Time 11.350 (11.544)
# **********************************
# attacked module: stage_1.10.conv_a
# attacked weight index: 1883
# weight before attack: tensor(0.1341, device='cuda:0')
# weight after attack: tensor(2., device='cuda:0')
# Iteration: [039/040]   Attack Time 8.985 (9.020)
# Bit flips: 39
# Hamming distance: 39
# **Test** MCC: 0.330. Val_Loss: 0.758
# ACC: 0.246.
# TPR: 0.665.
# F1-score: 0.448.
# Iteration Time 11.558 (11.544)
# **********************************
# attacked module: stage_1.3.conv_b
# attacked weight index: 1499
# weight before attack: tensor(0.1313, device='cuda:0')
# weight after attack: tensor(4., device='cuda:0')
# Iteration: [040/040]   Attack Time 8.849 (9.015)
# Bit flips: 40
# Hamming distance: 40
# **Test** MCC: 0.330. Val_Loss: 0.758
# ACC: 0.246.
# TPR: 0.665.
# F1-score: 0.448.
# Iteration Time 11.702 (11.548)
# Plot saved as CustomModel/RandomFlip_attack/MCC_RandomFlip_attack.png
# Plot saved as CustomModel/RandomFlip_attack/ACC_RandomFlip_attack.png
# Plot saved as CustomModel/RandomFlip_attack/TPR_RandomFlip_attack.png
# Plot saved as CustomModel/RandomFlip_attack/F1_RandomFlip_attack.png
# [Combined Plot] Saved as CustomModel/RandomFlip_attack/combined_metrics_RandomFlip_attack.png
# MCC after 100 times random attack: 0.32996774822732083
# Accuracy after 100 times random attack: 0.24567857142857144
# TPR after 100 times random attack: 0.665318484091032
# F1-score after 100 times random attack: 0.4476084223353436

# %%
# Bước 1: Tải mô hình đã huấn luyện
model_path = os.path.join("CustomModel", "best_model.pth")
trained_model = CustomModel()

# Tải trọng số từ file best_model.pth
trained_model.load_state_dict(torch.load(model_path, map_location=torch.device('cuda' if torch.cuda.is_available() else 'cpu')))
trained_model = trained_model.to(device)

# Bước 2: Tạo bản sao của mô hình để làm tham chiếu
model_clean = copy.deepcopy(trained_model)

# Bước 3: Khởi tạo đối tượng tấn công BFA
attacker = BFA(criterion=criterion, model=trained_model, k_top=10)

# Định nghĩa đường dẫn để lưu kết quả tấn công
attack_dir = os.path.join("CustomModel", "PBS_to_RandomFlip_attack")

os.makedirs(attack_dir, exist_ok=True)
attack_image_paths = [os.path.join(attack_dir, f"{metric}_PBS_to_RandomFlip_attack.png") 
                      for metric in ["MCC", "ACC", "TPR", "F1"]]
# attack_image_path = os.path.join(attack_dir, "PBS_to_RandomFlip_attack.png")
attack_csv_path = os.path.join(attack_dir, "PBS_to_RandomFlip_attack.csv")

# Bước 4: Thực hiện tấn công
perform_attack(
    attacker=attacker,               # Đối tượng tấn công
    model=trained_model,             # Mô hình bị tấn công
    model_clean=model_clean,         # Mô hình gốc làm tham chiếu
    train_loader=train_loader,       # Bộ dữ liệu huấn luyện
    test_loader=test_loader,         # Bộ dữ liệu kiểm tra
    N_iter=args.n_iter,              # Số vòng lặp tấn công
    writer=writer,                   # TensorBoard writer để ghi log
    file=attack_image_paths,          # Lưu ảnh vào thư mục tấn công
    csv_file=attack_csv_path,
    csv_save_path=args.save_path,    # Đường dẫn lưu file CSV
    attack_type= 3,                  # Chế độ tấn công PBS -> random
)

writer.close()  # Đóng TensorBoard writer
# best_mcc = validate_score( trained_model,test_loader)
# print(f"\nMCC after 100 times PBS to Random: {best_mcc}")

results = validate_score(trained_model, test_loader)
print(f"MCC after 100 times PBS to Random: {results['MCC']}")
print(f"Accuracy after 100 times PBS to Random: {results['Accuracy']}")
print(f"TPR after 100 times PBS to Random: {results['TPR']}")
print(f"F1-score after 100 times PBS to Random: {results['F1 Score']}")
# Out:
# **Test** MCC: 0.999. Val_Loss: 0.006
# ACC: 1.000.
# TPR: 0.988.
# F1-score: 0.988.
# Attack sample size is 256
# **********************************
# attacked module: fc1
# attacked module: stage_2.1.conv_b
# attacked weight index: 10463
# weight before attack: tensor(-0.1522, device='cuda:0')
# weight after attack: tensor(-5., device='cuda:0')
# Iteration: [001/040]   Attack Time 24.073 (24.073)
# Loss before attack: 0.0000
# Loss after attack: 36.0420
# Bit flips: 2
# Hamming distance: 2
# **Test** MCC: -0.435. Val_Loss: 35.372
# ACC: 0.054.
# TPR: 0.285.
# F1-score: 0.116.
# Iteration Time 11.455 (11.455)
# **********************************
# attacked module: stage_1.0.conv_a
# attacked module: stage_1.9.conv_a
# attacked weight index: 131
# weight before attack: tensor(-0.1638, device='cuda:0')
# weight after attack: tensor(-33., device='cuda:0')
# Iteration: [002/040]   Attack Time 23.189 (23.631)
# Loss before attack: 36.0420
# Loss after attack: 2779.0513
# Bit flips: 4
# Hamming distance: 4
# **Test** MCC: -0.538. Val_Loss: 2740.572
# ACC: 0.046.
# TPR: 0.224.
# F1-score: 0.089.
# Iteration Time 11.471 (11.463)
# **********************************
# attacked module: stage_1.0.conv_b
# attacked module: stage_2.11.conv_b
# attacked weight index: 4973
# weight before attack: tensor(-0.2539, device='cuda:0')
# weight after attack: tensor(-33., device='cuda:0')
# Iteration: [003/040]   Attack Time 23.784 (23.682)
# Loss before attack: 2779.0513
# Loss after attack: 204306.5156
# Bit flips: 6
# Hamming distance: 6
# **Test** MCC: -0.441. Val_Loss: 201412.792
# ACC: 0.053.
# TPR: 0.241.
# F1-score: 0.043.
# Iteration Time 11.553 (11.493)
# **********************************
# attacked module: stage_1.1.conv_b
# attacked module: stage_2.3.conv_a
# attacked weight index: 11918
# weight before attack: tensor(0.1547, device='cuda:0')
# weight after attack: tensor(64., device='cuda:0')
# Iteration: [004/040]   Attack Time 22.809 (23.464)
# Loss before attack: 204306.5156
# Loss after attack: 3233616.2500
# Bit flips: 8
# Hamming distance: 8
# **Test** MCC: -0.554. Val_Loss: 3187545.399
# ACC: 0.042.
# TPR: 0.219.
# F1-score: 0.030.
# Iteration Time 11.338 (11.454)
# **********************************
# attacked module: stage_1.1.conv_a
# attacked module: stage_2.11.conv_a
# attacked weight index: 6889
# weight before attack: tensor(-0.0867, device='cuda:0')
# weight after attack: tensor(-65., device='cuda:0')
# Iteration: [005/040]   Attack Time 22.974 (23.366)
# Loss before attack: 3233616.2500
# Loss after attack: 1156185216.0000
# Bit flips: 10
# Hamming distance: 10
# **Test** MCC: -0.462. Val_Loss: 1139702089.406
# ACC: 0.051.
# TPR: 0.230.
# F1-score: 0.042.
# Iteration Time 11.461 (11.456)
# **********************************
# attacked module: stage_1.4.conv_a
# attacked module: stage_3.5.conv_b
# attacked weight index: 15345
# weight before attack: tensor(-0.0900, device='cuda:0')
# weight after attack: tensor(-3., device='cuda:0')
# Iteration: [006/040]   Attack Time 23.184 (23.335)
# Loss before attack: 1156185216.0000
# Loss after attack: 21587075072.0000
# Bit flips: 12
# Hamming distance: 12
# **Test** MCC: -0.456. Val_Loss: 21288263245.122
# ACC: 0.051.
# TPR: 0.230.
# F1-score: 0.042.
# Iteration Time 11.609 (11.481)
# **********************************
# attacked module: stage_1.7.conv_b
# attacked module: stage_2.8.conv_a
# attacked weight index: 5638
# weight before attack: tensor(0.0189, device='cuda:0')
# weight after attack: tensor(1., device='cuda:0')
# Iteration: [007/040]   Attack Time 23.185 (23.314)
# Loss before attack: 21587075072.0000
# Loss after attack: 374354214912.0000
# Bit flips: 14
# Hamming distance: 14
# **Test** MCC: -0.458. Val_Loss: 369996594615.793
# ACC: 0.051.
# TPR: 0.227.
# F1-score: 0.036.
# Iteration Time 11.511 (11.486)
# **********************************
# attacked module: stage_1.7.conv_a
# attacked module: stage_2.14.conv_a
# attacked weight index: 694
# weight before attack: tensor(0.0178, device='cuda:0')
# weight after attack: tensor(64., device='cuda:0')
# Iteration: [008/040]   Attack Time 23.079 (23.285)
# Loss before attack: 375203528704.0000
# Loss after attack: 44080214048768.0000
# Bit flips: 16
# Hamming distance: 16
# **Test** MCC: -0.198. Val_Loss: 41533164742208.953
# ACC: 0.063.
# TPR: 0.325.
# F1-score: 0.042.
# Iteration Time 11.656 (11.507)
# **********************************
# attacked module: stage_1.4.conv_b
# attacked module: classifier
# attacked weight index: 48
# weight before attack: tensor(-0.0623, device='cuda:0')
# weight after attack: tensor(-17., device='cuda:0')
# Iteration: [009/040]   Attack Time 22.862 (23.238)
# Loss before attack: 42113538457600.0000
# Loss after attack: 6742303012028416.0000
# Bit flips: 18
# Hamming distance: 17
# **Test** MCC: -0.199. Val_Loss: 6652512985679262.000
# ACC: 0.063.
# TPR: 0.325.
# F1-score: 0.042.
# Iteration Time 11.609 (11.518)
# **********************************
# attacked module: stage_3.12.conv_a
# attacked module: stage_2.12.conv_a
# attacked weight index: 8645
# weight before attack: tensor(-0.0944, device='cuda:0')
# weight after attack: tensor(-65., device='cuda:0')
# Iteration: [010/040]   Attack Time 70.024 (27.916)
# Loss before attack: 6744249705955328.0000
# Loss after attack: 169302353768349696.0000
# Bit flips: 20
# Hamming distance: 19
# **Test** MCC: -0.097. Val_Loss: 166746504135065792.000
# ACC: 0.002.
# TPR: 0.017.
# F1-score: 0.001.
# Iteration Time 11.577 (11.524)
# **********************************
# attacked module: stage_3.12.conv_b
# attacked module: stage_1.1.conv_a
# attacked weight index: 891
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-9., device='cuda:0')
# Iteration: [011/040]   Attack Time 69.776 (31.722)
# Loss before attack: 169302353768349696.0000
# Loss after attack: 38834460421978587136.0000
# Bit flips: 22
# Hamming distance: 21
# **Test** MCC: -0.097. Val_Loss: 38187417395564363776.000
# ACC: 0.002.
# TPR: 0.017.
# F1-score: 0.001.
# Iteration Time 10.925 (11.470)
# **********************************
# attacked module: stage_2.14.conv_b
# attacked module: stage_3.9.conv_a
# attacked weight index: 45825
# weight before attack: tensor(0.0490, device='cuda:0')
# weight after attack: tensor(2., device='cuda:0')
# Iteration: [012/040]   Attack Time 32.840 (31.815)
# Loss before attack: 38834460421978587136.0000
# Loss after attack: 747242668566614376448.0000
# Bit flips: 24
# Hamming distance: 23
# **Test** MCC: 0.001. Val_Loss: 734802652705497284608.000
# ACC: 0.002.
# TPR: 0.017.
# F1-score: 0.001.
# Iteration Time 11.362 (11.461)
# **********************************
# attacked module: stage_2.9.conv_b
# attacked module: stage_3.12.conv_b
# attacked weight index: 15477
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-2., device='cuda:0')
# Iteration: [013/040]   Attack Time 32.344 (31.856)
# Loss before attack: 747242668566614376448.0000
# Loss after attack: 228263650076580907057152.0000
# Bit flips: 26
# Hamming distance: 25
# **Test** MCC: 0.000. Val_Loss: 224460457431960295309312.000
# ACC: 0.000.
# TPR: 0.016.
# F1-score: 0.000.
# Iteration Time 11.438 (11.459)
# **********************************
# attacked module: stage_2.9.conv_a
# attacked module: stage_2.15.conv_a
# attacked weight index: 8545
# weight before attack: tensor(-0.1738, device='cuda:0')
# weight after attack: tensor(127., device='cuda:0')
# Iteration: [014/040]   Attack Time 32.239 (31.883)
# Loss before attack: 228263650076580907057152.0000
# Loss after attack: 77970624063779237932302336.0000
# Bit flips: 28
# Hamming distance: 27
# **Test** MCC: 0.001. Val_Loss: 76674111661294295619469312.000
# ACC: 0.002.
# TPR: 0.017.
# F1-score: 0.001.
# Iteration Time 11.563 (11.466)
# **********************************
# attacked module: stage_2.12.conv_a
# attacked module: stage_2.9.conv_b
# attacked weight index: 9149
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(127., device='cuda:0')
# Iteration: [015/040]   Attack Time 32.234 (31.906)
# Loss before attack: 77970624063779237932302336.0000
# Loss after attack: 897131867731066028824723456.0000
# Bit flips: 30
# Hamming distance: 29
# **Test** MCC: 0.001. Val_Loss: 882221909524841089778843648.000
# ACC: 0.002.
# TPR: 0.017.
# F1-score: 0.001.
# Iteration Time 11.347 (11.458)
# **********************************
# attacked module: stage_2.12.conv_b
# attacked module: stage_1.9.conv_b
# attacked weight index: 22
# weight before attack: tensor(-0.2116, device='cuda:0')
# weight after attack: tensor(-65., device='cuda:0')
# Iteration: [016/040]   Attack Time 32.469 (31.941)
# Loss before attack: 897131867731066028824723456.0000
# Loss after attack: 185816016378341566482965594112.0000
# Bit flips: 32
# Hamming distance: 31
# **Test** MCC: 0.001. Val_Loss: 182728187406104216643248848896.000
# ACC: 0.002.
# TPR: 0.017.
# F1-score: 0.001.
# Iteration Time 11.506 (11.461)
# **********************************
# attacked module: stage_1.6.conv_b
# attacked module: stage_3.4.conv_a
# attacked weight index: 11859
# weight before attack: tensor(0.0594, device='cuda:0')
# weight after attack: tensor(16., device='cuda:0')
# Iteration: [017/040]   Attack Time 22.834 (31.406)
# Loss before attack: 185816016378341566482965594112.0000
# Loss after attack: 2008915102435953070773601566720.0000
# Bit flips: 34
# Hamming distance: 33
# **Test** MCC: 0.000. Val_Loss: 1975355790884831854887429996544.000
# ACC: 0.000.
# TPR: 0.016.
# F1-score: 0.000.
# Iteration Time 11.589 (11.469)
# **********************************
# attacked module: stage_1.6.conv_a
# attacked module: stage_3.4.conv_b
# attacked weight index: 40765
# weight before attack: tensor(-0.1047, device='cuda:0')
# weight after attack: tensor(-65., device='cuda:0')
# Iteration: [018/040]   Attack Time 23.887 (30.988)
# Loss before attack: 2008915102435953070773601566720.0000
# Loss after attack: 1001502931074672193417987603038208.0000
# Bit flips: 36
# Hamming distance: 35
# **Test** MCC: 0.002. Val_Loss: 984778159041372837723587351674880.000
# ACC: 0.001.
# TPR: 0.017.
# F1-score: 0.001.
# Iteration Time 12.069 (11.502)
# **********************************
# attacked module: stage_2.13.conv_a
# attacked module: stage_3.11.conv_b
# attacked weight index: 30417
# weight before attack: tensor(0.0634, device='cuda:0')
# weight after attack: tensor(1., device='cuda:0')
# Iteration: [019/040]   Attack Time 32.493 (31.067)
# Loss before attack: 1001503395302186925435590690209792.0000
# Loss after attack: 10584525985174401312978300817113088.0000
# Bit flips: 38
# Hamming distance: 37
# **Test** MCC: 0.002. Val_Loss: 10408141078363128714226178237399040.000
# ACC: 0.001.
# TPR: 0.017.
# F1-score: 0.001.
# Iteration Time 11.740 (11.515)
# **********************************
# attacked module: stage_2.13.conv_b
# attacked module: stage_2.13.conv_a
# attacked weight index: 8866
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-65., device='cuda:0')
# Iteration: [020/040]   Attack Time 32.698 (31.149)
# Loss before attack: 10584525985174401312978300817113088.0000
# Loss after attack: inf
# Bit flips: 40
# Hamming distance: 39
# **Test** MCC: 0.002. Val_Loss: inf
# ACC: 0.001.
# TPR: 0.017.
# F1-score: 0.001.
# Iteration Time 11.529 (11.515)
# **********************************
# attacked module: fc1
# attacked module: stage_1.10.conv_b
# attacked weight index: 1694
# weight before attack: tensor(-0.2633, device='cuda:0')
# weight after attack: tensor(-3., device='cuda:0')
# Iteration: [021/040]   Attack Time 131.698 (35.937)
# Loss before attack: inf
# Loss after attack: nan
# Bit flips: 97
# Hamming distance: 94
# **Test** MCC: 0.000. Val_Loss: nan
# ACC: 0.001.
# TPR: 0.013.
# F1-score: 0.001.
# Iteration Time 11.665 (11.523)
# **********************************
# attacked module: stage_2.15.conv_a
# attacked weight index: 9395
# weight before attack: tensor(0.0135, device='cuda:0')
# weight after attack: tensor(32., device='cuda:0')
# Iteration: [022/040]   Attack Time 17.934 (35.118)
# Loss before attack: nan
# Loss after attack: nan
# Bit flips: 98
# Hamming distance: 95
# **Test** MCC: 0.000. Val_Loss: nan
# ACC: 0.001.
# TPR: 0.013.
# F1-score: 0.001.
# Iteration Time 11.393 (11.517)
# **********************************
# attacked module: stage_3.10.conv_b
# attacked weight index: 36270
# weight before attack: tensor(0.0209, device='cuda:0')
# weight after attack: tensor(64., device='cuda:0')
# Iteration: [023/040]   Attack Time 17.999 (34.374)
# Loss before attack: nan
# Loss after attack: nan
# Bit flips: 99
# Hamming distance: 96
# **Test** MCC: 0.000. Val_Loss: nan
# ACC: 0.001.
# TPR: 0.013.
# F1-score: 0.001.
# Iteration Time 11.623 (11.521)
# **********************************
# attacked module: stage_3.7.conv_a
# attacked weight index: 47218
# weight before attack: tensor(-0.0415, device='cuda:0')
# weight after attack: tensor(-33., device='cuda:0')
# Iteration: [024/040]   Attack Time 17.952 (33.690)
# Loss before attack: nan
# Loss after attack: nan
# Bit flips: 100
# Hamming distance: 97
# **Test** MCC: 0.000. Val_Loss: nan
# ACC: 0.001.
# TPR: 0.013.
# F1-score: 0.001.
# Iteration Time 11.676 (11.528)
# **********************************
# attacked module: stage_2.4.conv_a
# attacked weight index: 4158
# weight before attack: tensor(-0.0591, device='cuda:0')
# weight after attack: tensor(-3., device='cuda:0')
# Iteration: [025/040]   Attack Time 18.009 (33.063)
# Loss before attack: nan
# Loss after attack: nan
# Bit flips: 101
# Hamming distance: 98
# **Test** MCC: 0.000. Val_Loss: nan
# ACC: 0.001.
# TPR: 0.013.
# F1-score: 0.001.
# Iteration Time 11.550 (11.529)
# **********************************
# attacked module: stage_3.7.conv_a
# attacked weight index: 35885
# weight before attack: tensor(0.0139, device='cuda:0')
# weight after attack: tensor(8., device='cuda:0')
# Iteration: [026/040]   Attack Time 17.820 (32.476)
# Loss before attack: nan
# Loss after attack: nan
# Bit flips: 102
# Hamming distance: 99
# **Test** MCC: 0.000. Val_Loss: nan
# ACC: 0.001.
# TPR: 0.013.
# F1-score: 0.001.
# Iteration Time 11.505 (11.528)
# **********************************
# attacked module: stage_2.10.conv_a
# attacked weight index: 11679
# weight before attack: tensor(0.0281, device='cuda:0')
# weight after attack: tensor(64., device='cuda:0')
# Iteration: [027/040]   Attack Time 17.723 (31.930)
# Loss before attack: nan
# Loss after attack: nan
# Bit flips: 103
# Hamming distance: 100
# **Test** MCC: 0.000. Val_Loss: nan
# ACC: 0.001.
# TPR: 0.013.
# F1-score: 0.001.
# Iteration Time 11.385 (11.522)
# **********************************
# attacked module: stage_2.4.conv_a
# attacked weight index: 7603
# weight before attack: tensor(0.0468, device='cuda:0')
# weight after attack: tensor(2., device='cuda:0')
# Iteration: [028/040]   Attack Time 18.102 (31.436)
# Loss before attack: nan
# Loss after attack: nan
# Bit flips: 104
# Hamming distance: 101
# **Test** MCC: 0.000. Val_Loss: nan
# ACC: 0.001.
# TPR: 0.013.
# F1-score: 0.001.
# Iteration Time 10.981 (11.503)
# **********************************
# attacked module: stage_3.6.conv_a
# attacked weight index: 43824
# weight before attack: tensor(-0.1495, device='cuda:0')
# weight after attack: tensor(-65., device='cuda:0')
# Iteration: [029/040]   Attack Time 18.603 (30.994)
# Loss before attack: nan
# Loss after attack: nan
# Bit flips: 105
# Hamming distance: 102
# **Test** MCC: 0.000. Val_Loss: nan
# ACC: 0.001.
# TPR: 0.013.
# F1-score: 0.001.
# Iteration Time 11.405 (11.500)
# **********************************
# attacked module: stage_3.7.conv_b
# attacked weight index: 14346
# weight before attack: tensor(-0.0944, device='cuda:0')
# weight after attack: tensor(-17., device='cuda:0')
# Iteration: [030/040]   Attack Time 17.953 (30.559)
# Loss before attack: nan
# Loss after attack: nan
# Bit flips: 106
# Hamming distance: 103
# **Test** MCC: 0.000. Val_Loss: nan
# ACC: 0.001.
# TPR: 0.013.
# F1-score: 0.001.
# Iteration Time 11.577 (11.502)
# **********************************
# attacked module: stage_2.15.conv_b
# attacked weight index: 7189
# weight before attack: tensor(0.0522, device='cuda:0')
# weight after attack: tensor(32., device='cuda:0')
# Iteration: [031/040]   Attack Time 17.924 (30.151)
# Loss before attack: nan
# Loss after attack: nan
# Bit flips: 107
# Hamming distance: 104
# **Test** MCC: 0.000. Val_Loss: nan
# ACC: 0.001.
# TPR: 0.013.
# F1-score: 0.001.
# Iteration Time 11.505 (11.502)
# **********************************
# attacked module: classifier
# attacked weight index: 374
# weight before attack: tensor(0.0143, device='cuda:0')
# weight after attack: tensor(4096., device='cuda:0')
# Iteration: [032/040]   Attack Time 17.914 (29.769)
# Loss before attack: nan
# Loss after attack: nan
# Bit flips: 108
# Hamming distance: 104
# **Test** MCC: -0.127. Val_Loss: nan
# ACC: 0.060.
# TPR: 0.246.
# F1-score: 0.031.
# Iteration Time 11.518 (11.503)
# **********************************
# attacked module: stage_3.15.conv_a
# attacked weight index: 1197
# weight before attack: tensor(0.0367, device='cuda:0')
# weight after attack: tensor(-128., device='cuda:0')
# Iteration: [033/040]   Attack Time 18.216 (29.419)
# Loss before attack: nan
# Loss after attack: nan
# Bit flips: 109
# Hamming distance: 105
# **Test** MCC: -0.127. Val_Loss: nan
# ACC: 0.060.
# TPR: 0.246.
# F1-score: 0.031.
# Iteration Time 11.656 (11.508)
# **********************************
# attacked module: stage_2.4.conv_b
# attacked weight index: 4161
# weight before attack: tensor(-0.0579, device='cuda:0')
# weight after attack: tensor(-17., device='cuda:0')
# Iteration: [034/040]   Attack Time 17.944 (29.081)
# Loss before attack: nan
# Loss after attack: nan
# Bit flips: 110
# Hamming distance: 106
# **Test** MCC: -0.127. Val_Loss: nan
# ACC: 0.060.
# TPR: 0.246.
# F1-score: 0.031.
# Iteration Time 11.628 (11.511)
# **********************************
# attacked module: stage_2.6.conv_a
# attacked weight index: 8526
# weight before attack: tensor(0.0045, device='cuda:0')
# weight after attack: tensor(1., device='cuda:0')
# Iteration: [035/040]   Attack Time 17.914 (28.762)
# Loss before attack: nan
# Loss after attack: nan
# Bit flips: 111
# Hamming distance: 107
# **Test** MCC: -0.127. Val_Loss: nan
# ACC: 0.060.
# TPR: 0.246.
# F1-score: 0.031.
# Iteration Time 11.346 (11.506)
# **********************************
# attacked module: stage_3.12.conv_a
# attacked weight index: 40565
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(127., device='cuda:0')
# Iteration: [036/040]   Attack Time 17.726 (28.456)
# Loss before attack: nan
# Loss after attack: nan
# Bit flips: 112
# Hamming distance: 108
# **Test** MCC: -0.127. Val_Loss: nan
# ACC: 0.060.
# TPR: 0.246.
# F1-score: 0.031.
# Iteration Time 11.358 (11.502)
# **********************************
# attacked module: stage_2.7.conv_b
# attacked weight index: 4829
# weight before attack: tensor(-0.0494, device='cuda:0')
# weight after attack: tensor(-3., device='cuda:0')
# Iteration: [037/040]   Attack Time 18.237 (28.180)
# Loss before attack: nan
# Loss after attack: nan
# Bit flips: 113
# Hamming distance: 109
# **Test** MCC: -0.127. Val_Loss: nan
# ACC: 0.060.
# TPR: 0.246.
# F1-score: 0.031.
# Iteration Time 11.300 (11.497)
# **********************************
# attacked module: stage_2.1.conv_a
# attacked weight index: 10722
# weight before attack: tensor(-1.7316e-05, device='cuda:0')
# weight after attack: tensor(127., device='cuda:0')
# Iteration: [038/040]   Attack Time 17.982 (27.911)
# Loss before attack: nan
# Loss after attack: nan
# Bit flips: 114
# Hamming distance: 110
# **Test** MCC: -0.127. Val_Loss: nan
# ACC: 0.060.
# TPR: 0.246.
# F1-score: 0.031.
# Iteration Time 11.356 (11.493)
# **********************************
# attacked module: stage_2.15.conv_b
# attacked weight index: 9316
# weight before attack: tensor(0.0740, device='cuda:0')
# weight after attack: tensor(1., device='cuda:0')
# Iteration: [039/040]   Attack Time 18.015 (27.657)
# Loss before attack: nan
# Loss after attack: nan
# Bit flips: 115
# Hamming distance: 111
# **Test** MCC: -0.127. Val_Loss: nan
# ACC: 0.060.
# TPR: 0.246.
# F1-score: 0.031.
# Iteration Time 11.363 (11.490)
# **********************************
# attacked module: stage_3.9.conv_b
# attacked weight index: 21528
# weight before attack: tensor(0.0009, device='cuda:0')
# weight after attack: tensor(16., device='cuda:0')
# Iteration: [040/040]   Attack Time 18.318 (27.424)
# Loss before attack: nan
# Loss after attack: nan
# Bit flips: 116
# Hamming distance: 112
# **Test** MCC: -0.127. Val_Loss: nan
# ACC: 0.060.
# TPR: 0.246.
# F1-score: 0.031.
# Iteration Time 11.893 (11.500)
# Plot saved as CustomModel/PBS_to_RandomFlip_attack/MCC_PBS_to_RandomFlip_attack.png
# Plot saved as CustomModel/PBS_to_RandomFlip_attack/ACC_PBS_to_RandomFlip_attack.png
# Plot saved as CustomModel/PBS_to_RandomFlip_attack/TPR_PBS_to_RandomFlip_attack.png
# Plot saved as CustomModel/PBS_to_RandomFlip_attack/F1_PBS_to_RandomFlip_attack.png
# [Combined Plot] Saved as CustomModel/PBS_to_RandomFlip_attack/combined_metrics_PBS_to_RandomFlip_attack.png
# MCC after 100 times PBS to Random: -0.12688017418114975
# Accuracy after 100 times PBS to Random: 0.05985714285714286
# TPR after 100 times PBS to Random: 0.24628817395870412
# F1-score after 100 times PBS to Random: 0.031121701298037246

# %%
# Bước 1: Tải mô hình đã huấn luyện
model_path = os.path.join("CustomModel", "best_model.pth")
trained_model = CustomModel()

# Tải trọng số từ file best_model.pth
trained_model.load_state_dict(torch.load(model_path, map_location=torch.device('cuda' if torch.cuda.is_available() else 'cpu')))
trained_model = trained_model.to(device)

# Bước 2: Tạo bản sao của mô hình để làm tham chiếu
model_clean = copy.deepcopy(trained_model)

# Bước 3: Khởi tạo đối tượng tấn công BFA
attacker = BFA(criterion=criterion, model=trained_model, k_top=10)

# Định nghĩa đường dẫn để lưu kết quả tấn công
attack_dir = os.path.join("CustomModel", "RandomFlip_to_PBS_attack")

os.makedirs(attack_dir, exist_ok=True)
attack_image_paths = [os.path.join(attack_dir, f"{metric}_RandomFlip_to_PBS_attack.png") 
                      for metric in ["MCC", "ACC", "TPR", "F1"]]
# attack_image_path = os.path.join(attack_dir, "RandomFlip_to_PBS_attack.png")
attack_csv_path = os.path.join(attack_dir, "RandomFlip_to_PBS_attack.csv")

# Bước 4: Thực hiện tấn công
perform_attack(
    attacker=attacker,               # Đối tượng tấn công
    model=trained_model,             # Mô hình bị tấn công
    model_clean=model_clean,         # Mô hình gốc làm tham chiếu
    train_loader=train_loader,       # Bộ dữ liệu huấn luyện
    test_loader=test_loader,         # Bộ dữ liệu kiểm tra
    N_iter=args.n_iter,              # Số vòng lặp tấn công
    writer=writer,                   # TensorBoard writer để ghi log
    file=attack_image_paths,          # Lưu ảnh vào thư mục tấn công
    csv_file=attack_csv_path,  
    csv_save_path=args.save_path,    # Đường dẫn lưu file CSV
    attack_type= 4,                  # Chế độ tấn công Random -> PBS
)

writer.close()  # Đóng TensorBoard writer
# best_mcc = validate_score( trained_model,test_loader)
# print(f"\nMCC after 100 times random to PBS: {best_mcc}")

results = validate_score(trained_model, test_loader)
print(f"MCC after 100 times random to PBS: {results['MCC']}")
print(f"Accuracy after 100 times random to PBS: {results['Accuracy']}")
print(f"TPR after 100 times random to PBS: {results['TPR']}")
print(f"F1-score after 100 times random to PBS: {results['F1 Score']}")
# Out:
# **Test** MCC: 0.999. Val_Loss: 0.006
# ACC: 1.000.
# TPR: 0.988.
# F1-score: 0.988.
# Attack sample size is 256
# **********************************
# attacked module: stage_1.13.conv_b
# attacked weight index: 914
# weight before attack: tensor(0.0163, device='cuda:0')
# weight after attack: tensor(1., device='cuda:0')
# attacked module: fc1
# Iteration: [001/040]   Attack Time 24.153 (24.153)
# Loss before attack: 0.0000
# Loss after attack: 35.3654
# Bit flips: 2
# Hamming distance: 2
# **Test** MCC: -0.435. Val_Loss: 35.372
# ACC: 0.054.
# TPR: 0.285.
# F1-score: 0.116.
# Iteration Time 11.393 (11.393)
# **********************************
# attacked module: stage_2.2.conv_b
# attacked weight index: 5476
# weight before attack: tensor(-0.0782, device='cuda:0')
# weight after attack: tensor(-3., device='cuda:0')
# attacked module: stage_1.0.conv_a
# Iteration: [002/040]   Attack Time 23.412 (23.782)
# Loss before attack: 35.2743
# Loss after attack: 2763.9385
# Bit flips: 4
# Hamming distance: 4
# **Test** MCC: -0.538. Val_Loss: 2736.851
# ACC: 0.046.
# TPR: 0.224.
# F1-score: 0.089.
# Iteration Time 11.758 (11.576)
# **********************************
# attacked module: stage_3.12.conv_a
# attacked weight index: 46070
# weight before attack: tensor(-0.0380, device='cuda:0')
# weight after attack: tensor(-17., device='cuda:0')
# attacked module: stage_1.0.conv_b
# Iteration: [003/040]   Attack Time 23.298 (23.621)
# Loss before attack: 2763.9385
# Loss after attack: 203472.8281
# Bit flips: 6
# Hamming distance: 6
# **Test** MCC: -0.441. Val_Loss: 201389.149
# ACC: 0.053.
# TPR: 0.241.
# F1-score: 0.043.
# Iteration Time 11.621 (11.591)
# **********************************
# attacked module: stage_1.9.conv_b
# attacked weight index: 673
# weight before attack: tensor(0.0315, device='cuda:0')
# weight after attack: tensor(2., device='cuda:0')
# attacked module: stage_1.1.conv_b
# Iteration: [004/040]   Attack Time 23.022 (23.471)
# Loss before attack: 203472.8281
# Loss after attack: 3220615.2500
# Bit flips: 8
# Hamming distance: 8
# **Test** MCC: -0.554. Val_Loss: 3187325.901
# ACC: 0.042.
# TPR: 0.219.
# F1-score: 0.030.
# Iteration Time 11.562 (11.584)
# **********************************
# attacked module: stage_3.6.conv_a
# attacked weight index: 26916
# weight before attack: tensor(-0.0412, device='cuda:0')
# weight after attack: tensor(-65., device='cuda:0')
# attacked module: stage_1.1.conv_a
# Iteration: [005/040]   Attack Time 23.262 (23.429)
# Loss before attack: 3220615.2500
# Loss after attack: 1151514496.0000
# Bit flips: 10
# Hamming distance: 10
# **Test** MCC: -0.462. Val_Loss: 1139611878.400
# ACC: 0.051.
# TPR: 0.230.
# F1-score: 0.042.
# Iteration Time 11.513 (11.570)
# **********************************
# attacked module: stage_3.1.conv_b
# attacked weight index: 9327
# weight before attack: tensor(0.0262, device='cuda:0')
# weight after attack: tensor(4., device='cuda:0')
# attacked module: stage_1.4.conv_a
# Iteration: [006/040]   Attack Time 23.008 (23.359)
# Loss before attack: 1151514496.0000
# Loss after attack: 21501114368.0000
# Bit flips: 12
# Hamming distance: 12
# **Test** MCC: -0.456. Val_Loss: 21288263245.122
# ACC: 0.051.
# TPR: 0.230.
# F1-score: 0.042.
# Iteration Time 11.784 (11.605)
# **********************************
# attacked module: stage_1.12.conv_b
# attacked weight index: 820
# weight before attack: tensor(0.1276, device='cuda:0')
# weight after attack: tensor(8., device='cuda:0')
# attacked module: stage_1.7.conv_b
# Iteration: [007/040]   Attack Time 25.354 (23.644)
# Loss before attack: 21565724672.0000
# Loss after attack: 394068164608.0000
# Bit flips: 14
# Hamming distance: 14
# **Test** MCC: -0.458. Val_Loss: 390139098551.325
# ACC: 0.051.
# TPR: 0.227.
# F1-score: 0.036.
# Iteration Time 12.982 (11.802)
# **********************************
# attacked module: stage_2.7.conv_a
# attacked weight index: 9469
# weight before attack: tensor(0.0215, device='cuda:0')
# weight after attack: tensor(1., device='cuda:0')
# attacked module: stage_1.7.conv_a
# Iteration: [008/040]   Attack Time 25.518 (23.878)
# Loss before attack: 394068164608.0000
# Loss after attack: 46316319145984.0000
# Bit flips: 16
# Hamming distance: 16
# **Test** MCC: -0.198. Val_Loss: 45853634381524.875
# ACC: 0.063.
# TPR: 0.326.
# F1-score: 0.043.
# Iteration Time 12.461 (11.884)
# **********************************
# attacked module: stage_1.11.conv_b
# attacked weight index: 1971
# weight before attack: tensor(0.0692, device='cuda:0')
# weight after attack: tensor(-128., device='cuda:0')
# attacked module: stage_1.4.conv_b
# Iteration: [009/040]   Attack Time 25.591 (24.069)
# Loss before attack: 46316319145984.0000
# Loss after attack: 7415593896509440.0000
# Bit flips: 18
# Hamming distance: 18
# **Test** MCC: -0.198. Val_Loss: 7341517561449916.000
# ACC: 0.063.
# TPR: 0.325.
# F1-score: 0.043.
# Iteration Time 13.018 (12.010)
# **********************************
# attacked module: stage_1.11.conv_a
# attacked weight index: 553
# weight before attack: tensor(-0.0721, device='cuda:0')
# weight after attack: tensor(-17., device='cuda:0')
# attacked module: stage_3.12.conv_a
# Iteration: [010/040]   Attack Time 37.314 (25.393)
# Loss before attack: 7415593896509440.0000
# Loss after attack: 179419750529499136.0000
# Bit flips: 20
# Hamming distance: 20
# **Test** MCC: -0.097. Val_Loss: 176535639437890208.000
# ACC: 0.002.
# TPR: 0.017.
# F1-score: 0.001.
# Iteration Time 12.963 (12.106)
# **********************************
# attacked module: stage_3.3.conv_a
# attacked weight index: 40586
# weight before attack: tensor(0.0860, device='cuda:0')
# weight after attack: tensor(16., device='cuda:0')
# attacked module: stage_3.12.conv_b
# Iteration: [011/040]   Attack Time 73.105 (29.731)
# Loss before attack: 179419750529499136.0000
# Loss after attack: 41228189594623672320.0000
# Bit flips: 22
# Hamming distance: 22
# **Test** MCC: -0.097. Val_Loss: 40492317885818544128.000
# ACC: 0.002.
# TPR: 0.017.
# F1-score: 0.001.
# Iteration Time 13.022 (12.189)
# **********************************
# attacked module: stage_2.0.conv_b
# attacked weight index: 5682
# weight before attack: tensor(-0.0462, device='cuda:0')
# weight after attack: tensor(-65., device='cuda:0')
# attacked module: stage_1.6.conv_b
# Iteration: [012/040]   Attack Time 25.779 (29.401)
# Loss before attack: 41228189594623672320.0000
# Loss after attack: 445490023427490185216.0000
# Bit flips: 24
# Hamming distance: 24
# **Test** MCC: -0.125. Val_Loss: 437520862590457937920.000
# ACC: 0.001.
# TPR: 0.016.
# F1-score: 0.000.
# Iteration Time 13.123 (12.267)
# **********************************
# attacked module: stage_2.6.conv_b
# attacked weight index: 10103
# weight before attack: tensor(0.1041, device='cuda:0')
# weight after attack: tensor(32., device='cuda:0')
# attacked module: stage_1.6.conv_a
# Iteration: [013/040]   Attack Time 25.872 (29.130)
# Loss before attack: 445490023427490185216.0000
# Loss after attack: 222105229787730886524928.0000
# Bit flips: 26
# Hamming distance: 26
# **Test** MCC: -0.001. Val_Loss: 218138513563251273367552.000
# ACC: 0.002.
# TPR: 0.017.
# F1-score: 0.001.
# Iteration Time 12.639 (12.295)
# **********************************
# attacked module: stage_3.5.conv_a
# attacked weight index: 40567
# weight before attack: tensor(-0.0244, device='cuda:0')
# weight after attack: tensor(-17., device='cuda:0')
# attacked module: stage_1.2.conv_b
# Iteration: [014/040]   Attack Time 25.604 (28.878)
# Loss before attack: 222105229787730886524928.0000
# Loss after attack: 2133975559370070514728960.0000
# Bit flips: 28
# Hamming distance: 28
# **Test** MCC: -0.104. Val_Loss: 2095763895450656818855936.000
# ACC: 0.003.
# TPR: 0.017.
# F1-score: 0.002.
# Iteration Time 12.774 (12.330)
# **********************************
# attacked module: stage_3.12.conv_a
# attacked weight index: 25467
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-9., device='cuda:0')
# attacked module: stage_1.2.conv_a
# Iteration: [015/040]   Attack Time 26.249 (28.703)
# Loss before attack: 2133975559370070514728960.0000
# Loss after attack: 850163063118491947852890112.0000
# Bit flips: 30
# Hamming distance: 30
# **Test** MCC: -0.095. Val_Loss: 834962446864483652686839808.000
# ACC: 0.001.
# TPR: 0.017.
# F1-score: 0.001.
# Iteration Time 13.052 (12.378)
# **********************************
# attacked module: stage_3.4.conv_b
# attacked weight index: 34862
# weight before attack: tensor(0.0715, device='cuda:0')
# weight after attack: tensor(8., device='cuda:0')
# attacked module: stage_1.3.conv_b
# Iteration: [016/040]   Attack Time 25.772 (28.520)
# Loss before attack: 850163063118491947852890112.0000
# Loss after attack: 7805854567325311534559657984.0000
# Bit flips: 32
# Hamming distance: 32
# **Test** MCC: -0.116. Val_Loss: 7666572967363100959385321472.000
# ACC: 0.003.
# TPR: 0.017.
# F1-score: 0.002.
# Iteration Time 13.191 (12.429)
# **********************************
# attacked module: stage_2.0.conv_b
# attacked weight index: 8918
# weight before attack: tensor(0.0603, device='cuda:0')
# weight after attack: tensor(16., device='cuda:0')
# attacked module: stage_1.3.conv_a
# Iteration: [017/040]   Attack Time 25.652 (28.351)
# Loss before attack: 7805854567325311534559657984.0000
# Loss after attack: 1736206824973104636172557090816.0000
# Bit flips: 34
# Hamming distance: 34
# **Test** MCC: -0.097. Val_Loss: 1705169587419640114483111657472.000
# ACC: 0.001.
# TPR: 0.016.
# F1-score: 0.000.
# Iteration Time 13.400 (12.486)
# **********************************
# attacked module: stage_3.8.conv_a
# attacked weight index: 43459
# weight before attack: tensor(0.0262, device='cuda:0')
# weight after attack: tensor(1., device='cuda:0')
# attacked module: stage_2.12.conv_b
# Iteration: [018/040]   Attack Time 34.976 (28.719)
# Loss before attack: 1736206824973104636172557090816.0000
# Loss after attack: 12844981904503788736754084741120.0000
# Bit flips: 36
# Hamming distance: 36
# **Test** MCC: -0.099. Val_Loss: 12615034562654646077206808231936.000
# ACC: 0.000.
# TPR: 0.016.
# F1-score: 0.000.
# Iteration Time 13.038 (12.516)
# **********************************
# attacked module: stage_3.7.conv_b
# attacked weight index: 1627
# weight before attack: tensor(-0.0710, device='cuda:0')
# weight after attack: tensor(-33., device='cuda:0')
# attacked module: stage_2.12.conv_a
# Iteration: [019/040]   Attack Time 35.647 (29.084)
# Loss before attack: 12844981904503788736754084741120.0000
# Loss after attack: 3778907910271667906100881375887360.0000
# Bit flips: 38
# Hamming distance: 38
# **Test** MCC: -0.097. Val_Loss: 3711324598743089472679362489745408.000
# ACC: 0.001.
# TPR: 0.016.
# F1-score: 0.000.
# Iteration Time 13.095 (12.547)
# **********************************
# attacked module: stage_1.12.conv_a
# attacked weight index: 82
# weight before attack: tensor(-0.0845, device='cuda:0')
# weight after attack: tensor(-3., device='cuda:0')
# attacked module: classifier
# Iteration: [020/040]   Attack Time 23.705 (28.815)
# Loss before attack: 3778907910271667906100881375887360.0000
# Loss after attack: 27723538434032005576817297487560704.0000
# Bit flips: 40
# Hamming distance: 39
# **Test** MCC: -0.097. Val_Loss: 27148641963127075297558993467080704.000
# ACC: 0.001.
# TPR: 0.016.
# F1-score: 0.000.
# Iteration Time 13.188 (12.579)
# **********************************
# attacked module: stage_1.15.conv_a
# attacked weight index: 3052
# weight before attack: tensor(0.0847, device='cuda:0')
# weight after attack: tensor(16., device='cuda:0')
# attacked module: stage_1.5.conv_b
# Iteration: [021/040]   Attack Time 26.226 (28.691)
# Loss before attack: 27723538434032005576817297487560704.0000
# Loss after attack: 201422193314908053917923549430939648.0000
# Bit flips: 42
# Hamming distance: 41
# **Test** MCC: -0.094. Val_Loss: 197245954300550114187606991902343168.000
# ACC: 0.002.
# TPR: 0.019.
# F1-score: 0.003.
# Iteration Time 12.917 (12.595)
# **********************************
# attacked module: stage_3.11.conv_b
# attacked weight index: 37326
# weight before attack: tensor(0.0455, device='cuda:0')
# weight after attack: tensor(2., device='cuda:0')
# attacked module: stage_1.5.conv_a
# Iteration: [022/040]   Attack Time 25.493 (28.546)
# Loss before attack: 201422193314908053917923549430939648.0000
# Loss after attack: inf
# Bit flips: 44
# Hamming distance: 43
# **Test** MCC: -0.099. Val_Loss: inf
# ACC: 0.000.
# TPR: 0.016.
# F1-score: 0.000.
# Iteration Time 13.265 (12.626)
# **********************************
# attacked module: stage_3.14.conv_a
# attacked weight index: 33471
# weight before attack: tensor(-0.0310, device='cuda:0')
# weight after attack: tensor(-2., device='cuda:0')
# attacked module: fc1
# Iteration: [023/040]   Attack Time 31.366 (28.669)
# Loss before attack: inf
# Loss after attack: nan
# Bit flips: 50
# Hamming distance: 49
# **Test** MCC: -0.063. Val_Loss: nan
# ACC: 0.001.
# TPR: 0.013.
# F1-score: 0.000.
# Iteration Time 12.945 (12.639)
# **********************************
# attacked module: stage_1.7.conv_b
# attacked weight index: 2055
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(-128., device='cuda:0')
# Iteration: [024/040]   Attack Time 20.145 (28.314)
# Loss before attack: nan
# Loss after attack: nan
# Bit flips: 51
# Hamming distance: 50
# **Test** MCC: -0.063. Val_Loss: nan
# ACC: 0.001.
# TPR: 0.013.
# F1-score: 0.000.
# Iteration Time 12.813 (12.647)
# **********************************
# attacked module: stage_3.12.conv_b
# attacked weight index: 19516
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-9., device='cuda:0')
# Iteration: [025/040]   Attack Time 19.887 (27.976)
# Loss before attack: nan
# Loss after attack: nan
# Bit flips: 52
# Hamming distance: 51
# **Test** MCC: -0.063. Val_Loss: nan
# ACC: 0.001.
# TPR: 0.013.
# F1-score: 0.000.
# Iteration Time 12.787 (12.652)
# **********************************
# attacked module: stage_1.11.conv_b
# attacked weight index: 1718
# weight before attack: tensor(-0.0538, device='cuda:0')
# weight after attack: tensor(-3., device='cuda:0')
# Iteration: [026/040]   Attack Time 20.189 (27.677)
# Loss before attack: nan
# Loss after attack: nan
# Bit flips: 53
# Hamming distance: 52
# **Test** MCC: -0.063. Val_Loss: nan
# ACC: 0.001.
# TPR: 0.013.
# F1-score: 0.000.
# Iteration Time 12.920 (12.663)
# **********************************
# attacked module: stage_3.2.conv_a
# attacked weight index: 23456
# weight before attack: tensor(0.0359, device='cuda:0')
# weight after attack: tensor(16., device='cuda:0')
# Iteration: [027/040]   Attack Time 20.302 (27.404)
# Loss before attack: nan
# Loss after attack: nan
# Bit flips: 54
# Hamming distance: 53
# **Test** MCC: -0.063. Val_Loss: nan
# ACC: 0.001.
# TPR: 0.013.
# F1-score: 0.000.
# Iteration Time 13.030 (12.676)
# **********************************
# attacked module: stage_3.12.conv_b
# attacked weight index: 563
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(-128., device='cuda:0')
# Iteration: [028/040]   Attack Time 20.379 (27.153)
# Loss before attack: nan
# Loss after attack: nan
# Bit flips: 55
# Hamming distance: 54
# **Test** MCC: -0.063. Val_Loss: nan
# ACC: 0.001.
# TPR: 0.013.
# F1-score: 0.000.
# Iteration Time 13.239 (12.696)
# **********************************
# attacked module: stage_1.5.conv_b
# attacked weight index: 2021
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-17., device='cuda:0')
# Iteration: [029/040]   Attack Time 19.554 (26.891)
# Loss before attack: nan
# Loss after attack: nan
# Bit flips: 56
# Hamming distance: 55
# **Test** MCC: -0.063. Val_Loss: nan
# ACC: 0.001.
# TPR: 0.013.
# F1-score: 0.000.
# Iteration Time 13.101 (12.710)
# **********************************
# attacked module: stage_2.5.conv_b
# attacked weight index: 9322
# weight before attack: tensor(-0.1044, device='cuda:0')
# weight after attack: tensor(127., device='cuda:0')
# Iteration: [030/040]   Attack Time 19.834 (26.656)
# Loss before attack: nan
# Loss after attack: nan
# Bit flips: 57
# Hamming distance: 56
# **Test** MCC: -0.062. Val_Loss: nan
# ACC: 0.001.
# TPR: 0.013.
# F1-score: 0.000.
# Iteration Time 12.928 (12.718)
# **********************************
# attacked module: stage_2.5.conv_b
# attacked weight index: 4617
# weight before attack: tensor(-0.0842, device='cuda:0')
# weight after attack: tensor(127., device='cuda:0')
# Iteration: [031/040]   Attack Time 19.784 (26.434)
# Loss before attack: nan
# Loss after attack: nan
# Bit flips: 58
# Hamming distance: 57
# **Test** MCC: -0.062. Val_Loss: nan
# ACC: 0.001.
# TPR: 0.013.
# F1-score: 0.000.
# Iteration Time 13.207 (12.733)
# **********************************
# attacked module: stage_2.2.conv_b
# attacked weight index: 1415
# weight before attack: tensor(-0.0609, device='cuda:0')
# weight after attack: tensor(-65., device='cuda:0')
# Iteration: [032/040]   Attack Time 19.895 (26.230)
# Loss before attack: nan
# Loss after attack: nan
# Bit flips: 59
# Hamming distance: 58
# **Test** MCC: -0.062. Val_Loss: nan
# ACC: 0.001.
# TPR: 0.013.
# F1-score: 0.000.
# Iteration Time 12.744 (12.734)
# **********************************
# attacked module: classifier
# attacked weight index: 299
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(256., device='cuda:0')
# Iteration: [033/040]   Attack Time 20.401 (26.053)
# Loss before attack: nan
# Loss after attack: nan
# Bit flips: 60
# Hamming distance: 58
# **Test** MCC: -0.062. Val_Loss: nan
# ACC: 0.001.
# TPR: 0.013.
# F1-score: 0.000.
# Iteration Time 13.087 (12.744)
# **********************************
# attacked module: stage_3.11.conv_a
# attacked weight index: 41778
# weight before attack: tensor(0.0441, device='cuda:0')
# weight after attack: tensor(4., device='cuda:0')
# Iteration: [034/040]   Attack Time 20.178 (25.880)
# Loss before attack: nan
# Loss after attack: nan
# Bit flips: 61
# Hamming distance: 59
# **Test** MCC: -0.062. Val_Loss: nan
# ACC: 0.001.
# TPR: 0.013.
# F1-score: 0.000.
# Iteration Time 13.143 (12.756)
# **********************************
# attacked module: stage_1.13.conv_b
# attacked weight index: 678
# weight before attack: tensor(-0.0745, device='cuda:0')
# weight after attack: tensor(-2., device='cuda:0')
# Iteration: [035/040]   Attack Time 20.033 (25.713)
# Loss before attack: nan
# Loss after attack: nan
# Bit flips: 62
# Hamming distance: 60
# **Test** MCC: -0.062. Val_Loss: nan
# ACC: 0.001.
# TPR: 0.013.
# F1-score: 0.000.
# Iteration Time 13.018 (12.764)
# **********************************
# attacked module: stage_2.4.conv_b
# attacked weight index: 10635
# weight before attack: tensor(0.0246, device='cuda:0')
# weight after attack: tensor(4., device='cuda:0')
# Iteration: [036/040]   Attack Time 20.024 (25.555)
# Loss before attack: nan
# Loss after attack: nan
# Bit flips: 63
# Hamming distance: 61
# **Test** MCC: -0.062. Val_Loss: nan
# ACC: 0.001.
# TPR: 0.013.
# F1-score: 0.000.
# Iteration Time 13.024 (12.771)
# **********************************
# attacked module: stage_1.11.conv_a
# attacked weight index: 1759
# weight before attack: tensor(-0.0199, device='cuda:0')
# weight after attack: tensor(-33., device='cuda:0')
# Iteration: [037/040]   Attack Time 19.969 (25.404)
# Loss before attack: nan
# Loss after attack: nan
# Bit flips: 64
# Hamming distance: 62
# **Test** MCC: -0.062. Val_Loss: nan
# ACC: 0.001.
# TPR: 0.013.
# F1-score: 0.000.
# Iteration Time 13.044 (12.778)
# **********************************
# attacked module: stage_3.0.conv_a
# attacked weight index: 2676
# weight before attack: tensor(0.0078, device='cuda:0')
# weight after attack: tensor(64., device='cuda:0')
# Iteration: [038/040]   Attack Time 19.750 (25.255)
# Loss before attack: nan
# Loss after attack: nan
# Bit flips: 65
# Hamming distance: 63
# **Test** MCC: -0.062. Val_Loss: nan
# ACC: 0.001.
# TPR: 0.013.
# F1-score: 0.000.
# Iteration Time 12.784 (12.778)
# **********************************
# attacked module: stage_3.1.conv_b
# attacked weight index: 6332
# weight before attack: tensor(-0.0419, device='cuda:0')
# weight after attack: tensor(-5., device='cuda:0')
# Iteration: [039/040]   Attack Time 20.646 (25.137)
# Loss before attack: nan
# Loss after attack: nan
# Bit flips: 66
# Hamming distance: 64
# **Test** MCC: -0.062. Val_Loss: nan
# ACC: 0.001.
# TPR: 0.013.
# F1-score: 0.000.
# Iteration Time 12.676 (12.776)
# **********************************
# attacked module: stage_1.9.conv_a
# attacked weight index: 2951
# weight before attack: tensor(0.1801, device='cuda:0')
# weight after attack: tensor(1., device='cuda:0')
# Iteration: [040/040]   Attack Time 20.344 (25.017)
# Loss before attack: nan
# Loss after attack: nan
# Bit flips: 67
# Hamming distance: 65
# **Test** MCC: -0.062. Val_Loss: nan
# ACC: 0.001.
# TPR: 0.013.
# F1-score: 0.000.
# Iteration Time 12.829 (12.777)
# Plot saved as CustomModel/RandomFlip_to_PBS_attack/MCC_RandomFlip_to_PBS_attack.png
# Plot saved as CustomModel/RandomFlip_to_PBS_attack/ACC_RandomFlip_to_PBS_attack.png
# Plot saved as CustomModel/RandomFlip_to_PBS_attack/TPR_RandomFlip_to_PBS_attack.png
# Plot saved as CustomModel/RandomFlip_to_PBS_attack/F1_RandomFlip_to_PBS_attack.png
# [Combined Plot] Saved as CustomModel/RandomFlip_to_PBS_attack/combined_metrics_RandomFlip_to_PBS_attack.png
# MCC after 100 times random to PBS: -0.061897213447078075
# Accuracy after 100 times random to PBS: 0.0005714285714285715
# TPR after 100 times random to PBS: 0.013241430870883026
# F1-score after 100 times random to PBS: 0.0002544964834188584

# %% [markdown]
# ## Train second model

# %%
'''
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = CustomModel2().to(device)
criterion = torch.nn.CrossEntropyLoss()
optimizer = optim.AdamW(model.parameters(), lr=0.001, weight_decay=0.01)

num_epochs = 20
patience = 10  # Số epoch để chờ trước khi dừng
counter = 0

scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=5)

best_val_loss = float('inf')
best_mcc = -1  # Khởi tạo MCC tốt nhất

for epoch in range(num_epochs):
    train_mcc, train_loss = train(train_loader, model, criterion, optimizer, epoch)

    val_mcc, val_acc, val_tpr, val_f1, val_loss, output_summary = validate(test_loader, model, criterion, summary_output=True)
    
    scheduler.step(val_loss)

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        best_mcc = val_mcc
        counter = 0

        save_dir = "CustomModel2"
        os.makedirs(save_dir, exist_ok=True)
        save_path = os.path.join(save_dir, "best_model.pth")

        torch.save(model.state_dict(), save_path)
    
    else:
        counter += 1
        if counter >= patience:
            print("Early stopping triggered")
            break

    print(f"Epoch {epoch+1}/{num_epochs}")
    print(f"Train Loss: {train_loss:.4f}, Train MCC: {train_mcc:.4f}")
    print(f"Validation Loss: {val_loss:.4f}, Validation MCC: {val_mcc:.4f}, ACC: {val_acc:.4f}, TPR: {val_tpr:.4f}, F1: {val_f1:.4f}")

print(f"Best MCC during training: {best_mcc:.4f}")
'''
# Out:
# '\ndevice = torch.device("cuda" if torch.cuda.is_available() else "cpu")\nmodel = CustomModel2().to(device)\ncriterion = torch.nn.CrossEntropyLoss()\noptimizer = optim.AdamW(model.parameters(), lr=0.001, weight_decay=0.01)\n\nnum_epochs = 20\npatience = 10  # Số epoch để chờ trước khi dừng\ncounter = 0\n\nscheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode=\'min\', factor=0.5, patience=5)\n\nbest_val_loss = float(\'inf\')\nbest_mcc = -1  # Khởi tạo MCC tốt nhất\n\nfor epoch in range(num_epochs):\n    train_mcc, train_loss = train(train_loader, model, criterion, optimizer, epoch)\n\n    val_mcc, val_acc, val_tpr, val_f1, val_loss, output_summary = validate(test_loader, model, criterion, summary_output=True)\n    \n    scheduler.step(val_loss)\n\n    if val_loss < best_val_loss:\n        best_val_loss = val_loss\n        best_mcc = val_mcc\n        counter = 0\n\n        save_dir = "CustomModel2"\n        os.makedirs(save_dir, exist_ok=True)\n        save_path = os.path.join(save_dir, "best_model.pth")\n\n        torch.save(model.state_dict(), save_path)\n    \n    else:\n        counter += 1\n        if counter >= patience:\n            print("Early stopping triggered")\n            break\n\n    print(f"Epoch {epoch+1}/{num_epochs}")\n    print(f"Train Loss: {train_loss:.4f}, Train MCC: {train_mcc:.4f}")\n    print(f"Validation Loss: {val_loss:.4f}, Validation MCC: {val_mcc:.4f}, ACC: {val_acc:.4f}, TPR: {val_tpr:.4f}, F1: {val_f1:.4f}")\n\nprint(f"Best MCC during training: {best_mcc:.4f}")\n'

# %% [markdown]
# ## Attack second model

# %%
model_path = os.path.join("CustomModel2", "best_model.pth")
if not os.path.exists(model_path):
    raise FileNotFoundError(f"Không tìm thấy mô hình tại: {best_model_path}")

trained_model = CustomModel2()

trained_model.load_state_dict(torch.load(model_path, map_location=torch.device('cuda' if torch.cuda.is_available() else 'cpu')))
trained_model = trained_model.to(device)

# best_mcc = validate_score(trained_model, test_loader)
# print(f"MCC before attack: {best_mcc}")

results = validate_score(trained_model, test_loader)
print(f"MCC before attack: {round(results['MCC'], 5)}")
print(f"Accuracy before attack: {round(results['Accuracy'], 5)}")
print(f"TPR before attack: {round(results['TPR'], 5)}")
print(f"F1-score before attack: {round(results['F1 Score'], 5)}")
# Out:
# MCC before attack: 0.99796
# Accuracy before attack: 0.99973
# TPR before attack: 0.97985
# F1-score before attack: 0.97903

# %%
model_path = os.path.join("CustomModel2", "best_model.pth")

trained_model = CustomModel2()

trained_model.load_state_dict(torch.load(model_path, map_location=torch.device('cuda' if torch.cuda.is_available() else 'cpu')))
trained_model = trained_model.to(device)

model_clean = copy.deepcopy(trained_model)

attacker = BFA(criterion=criterion, model=trained_model, k_top=10)

# Định nghĩa đường dẫn để lưu kết quả tấn công
attack_dir = os.path.join("CustomModel2", "PBS_attack")

os.makedirs(attack_dir, exist_ok=True)
attack_image_paths = [os.path.join(attack_dir, f"{metric}_PBS_attack.png") 
                      for metric in ["MCC", "ACC", "TPR", "F1"]]
# attack_image_path = os.path.join(attack_dir, "PBS_attack.png")
attack_csv_path = os.path.join(attack_dir, "PBS_attack.csv")

perform_attack(
    attacker=attacker,               # Đối tượng tấn công
    model=trained_model,             # Mô hình bị tấn công
    model_clean=model_clean,         # Mô hình gốc làm tham chiếu
    train_loader=train_loader,       # Bộ dữ liệu huấn luyện
    test_loader=test_loader,         # Bộ dữ liệu kiểm tra
    N_iter=args.n_iter,              # Số vòng lặp tấn công
    writer=writer,                   # TensorBoard writer để ghi log
    file=attack_image_paths,          # Lưu ảnh vào thư mục tấn công
    csv_file=attack_csv_path,  
    csv_save_path=args.save_path,    # Đường dẫn lưu file CSV
    attack_type= 1,                  # Chế độ tấn công PBS
)

writer.close()  # Đóng TensorBoard writer
# best_mcc = validate_score(trained_model, test_loader)
# print(f"\nMCC after 100 times PBS: {best_mcc}")

results = validate_score(trained_model, test_loader)
print(f"MCC after 100 times PBS attack: {results['MCC']}")
print(f"Accuracy after 100 times PBS attack: {results['Accuracy']}")
print(f"TPR after 100 times PBS attack: {results['TPR']}")
print(f"F1-score after 100 times PBS attack: {results['F1 Score']}")
# Out:
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.980.
# F1-score: 0.979.
# Attack sample size is 256
# **********************************
# attacked module: classifier
# Iteration: [001/040]   Attack Time 7.031 (7.031)
# Loss before attack: 0.9048
# Loss after attack: 0.9048
# Bit flips: 200
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.980.
# F1-score: 0.979.
# Iteration Time 5.930 (5.930)
# **********************************
# attacked module: classifier
# Iteration: [002/040]   Attack Time 6.594 (6.813)
# Loss before attack: 0.9048
# Loss after attack: 0.9048
# Bit flips: 400
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.980.
# F1-score: 0.979.
# Iteration Time 5.930 (5.930)
# **********************************
# attacked module: classifier
# Iteration: [003/040]   Attack Time 6.566 (6.731)
# Loss before attack: 0.9048
# Loss after attack: 0.9048
# Bit flips: 600
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.980.
# F1-score: 0.979.
# Iteration Time 6.041 (5.967)
# **********************************
# attacked module: classifier
# Iteration: [004/040]   Attack Time 6.112 (6.576)
# Loss before attack: 0.9048
# Loss after attack: 0.9048
# Bit flips: 800
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.980.
# F1-score: 0.979.
# Iteration Time 6.200 (6.025)
# **********************************
# attacked module: classifier
# Iteration: [005/040]   Attack Time 6.060 (6.473)
# Loss before attack: 0.9048
# Loss after attack: 0.9048
# Bit flips: 1000
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.980.
# F1-score: 0.979.
# Iteration Time 6.268 (6.074)
# **********************************
# attacked module: classifier
# Iteration: [006/040]   Attack Time 6.327 (6.449)
# Loss before attack: 0.9048
# Loss after attack: 0.9048
# Bit flips: 1200
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.980.
# F1-score: 0.979.
# Iteration Time 5.942 (6.052)
# **********************************
# attacked module: classifier
# Iteration: [007/040]   Attack Time 6.427 (6.445)
# Loss before attack: 0.9048
# Loss after attack: 0.9048
# Bit flips: 1400
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.980.
# F1-score: 0.979.
# Iteration Time 5.970 (6.040)
# **********************************
# attacked module: classifier
# Iteration: [008/040]   Attack Time 6.363 (6.435)
# Loss before attack: 0.9048
# Loss after attack: 0.9048
# Bit flips: 1600
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.980.
# F1-score: 0.979.
# Iteration Time 6.055 (6.042)
# **********************************
# attacked module: classifier
# Iteration: [009/040]   Attack Time 6.090 (6.397)
# Loss before attack: 0.9048
# Loss after attack: 0.9048
# Bit flips: 1800
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.980.
# F1-score: 0.979.
# Iteration Time 6.266 (6.067)
# **********************************
# attacked module: classifier
# Iteration: [010/040]   Attack Time 6.057 (6.363)
# Loss before attack: 0.9048
# Loss after attack: 0.9048
# Bit flips: 2000
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.980.
# F1-score: 0.979.
# Iteration Time 6.117 (6.072)
# **********************************
# attacked module: classifier
# Iteration: [011/040]   Attack Time 6.478 (6.373)
# Loss before attack: 0.9048
# Loss after attack: 0.9048
# Bit flips: 2200
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.980.
# F1-score: 0.979.
# Iteration Time 6.065 (6.071)
# **********************************
# attacked module: classifier
# Iteration: [012/040]   Attack Time 6.336 (6.370)
# Loss before attack: 0.9048
# Loss after attack: 0.9048
# Bit flips: 2400
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.980.
# F1-score: 0.979.
# Iteration Time 6.016 (6.066)
# **********************************
# attacked module: classifier
# Iteration: [013/040]   Attack Time 6.494 (6.380)
# Loss before attack: 0.9048
# Loss after attack: 0.9048
# Bit flips: 2600
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.980.
# F1-score: 0.979.
# Iteration Time 6.013 (6.062)
# **********************************
# attacked module: classifier
# Iteration: [014/040]   Attack Time 6.085 (6.359)
# Loss before attack: 0.9048
# Loss after attack: 0.9048
# Bit flips: 2800
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.980.
# F1-score: 0.979.
# Iteration Time 6.224 (6.074)
# **********************************
# attacked module: classifier
# Iteration: [015/040]   Attack Time 6.204 (6.348)
# Loss before attack: 0.9048
# Loss after attack: 0.9048
# Bit flips: 3000
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.980.
# F1-score: 0.979.
# Iteration Time 6.313 (6.090)
# **********************************
# attacked module: classifier
# Iteration: [016/040]   Attack Time 6.322 (6.347)
# Loss before attack: 0.9048
# Loss after attack: 0.9048
# Bit flips: 3200
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.980.
# F1-score: 0.979.
# Iteration Time 6.014 (6.085)
# **********************************
# attacked module: classifier
# Iteration: [017/040]   Attack Time 6.129 (6.334)
# Loss before attack: 0.9048
# Loss after attack: 0.9048
# Bit flips: 3400
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.980.
# F1-score: 0.979.
# Iteration Time 5.204 (6.033)
# **********************************
# attacked module: classifier
# Iteration: [018/040]   Attack Time 5.535 (6.289)
# Loss before attack: 0.9048
# Loss after attack: 0.9048
# Bit flips: 3600
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.980.
# F1-score: 0.979.
# Iteration Time 6.662 (6.068)
# **********************************
# attacked module: classifier
# Iteration: [019/040]   Attack Time 6.060 (6.277)
# Loss before attack: 0.9048
# Loss after attack: 0.9048
# Bit flips: 3800
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.980.
# F1-score: 0.979.
# Iteration Time 6.225 (6.076)
# **********************************
# attacked module: classifier
# Iteration: [020/040]   Attack Time 6.246 (6.276)
# Loss before attack: 0.9048
# Loss after attack: 0.9048
# Bit flips: 4000
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.980.
# F1-score: 0.979.
# Iteration Time 6.248 (6.085)
# **********************************
# attacked module: classifier
# Iteration: [021/040]   Attack Time 6.244 (6.274)
# Loss before attack: 0.9048
# Loss after attack: 0.9048
# Bit flips: 4200
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.980.
# F1-score: 0.979.
# Iteration Time 5.978 (6.080)
# **********************************
# attacked module: classifier
# Iteration: [022/040]   Attack Time 6.414 (6.281)
# Loss before attack: 0.9048
# Loss after attack: 0.9048
# Bit flips: 4400
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.980.
# F1-score: 0.979.
# Iteration Time 5.886 (6.071)
# **********************************
# attacked module: classifier
# Iteration: [023/040]   Attack Time 6.433 (6.287)
# Loss before attack: 0.9048
# Loss after attack: 0.9048
# Bit flips: 4600
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.980.
# F1-score: 0.979.
# Iteration Time 6.065 (6.071)
# **********************************
# attacked module: classifier
# Iteration: [024/040]   Attack Time 6.163 (6.282)
# Loss before attack: 0.9048
# Loss after attack: 0.9048
# Bit flips: 4800
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.980.
# F1-score: 0.979.
# Iteration Time 6.408 (6.085)
# **********************************
# attacked module: classifier
# Iteration: [025/040]   Attack Time 6.106 (6.275)
# Loss before attack: 0.9048
# Loss after attack: 0.9048
# Bit flips: 5000
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.980.
# F1-score: 0.979.
# Iteration Time 6.157 (6.088)
# **********************************
# attacked module: classifier
# Iteration: [026/040]   Attack Time 6.258 (6.274)
# Loss before attack: 0.9048
# Loss after attack: 0.9048
# Bit flips: 5200
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.980.
# F1-score: 0.979.
# Iteration Time 6.009 (6.085)
# **********************************
# attacked module: classifier
# Iteration: [027/040]   Attack Time 6.560 (6.285)
# Loss before attack: 0.9048
# Loss after attack: 0.9048
# Bit flips: 5400
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.980.
# F1-score: 0.979.
# Iteration Time 5.912 (6.078)
# **********************************
# attacked module: classifier
# Iteration: [028/040]   Attack Time 6.487 (6.292)
# Loss before attack: 0.9048
# Loss after attack: 0.9048
# Bit flips: 5600
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.980.
# F1-score: 0.979.
# Iteration Time 6.139 (6.080)
# **********************************
# attacked module: classifier
# Iteration: [029/040]   Attack Time 6.145 (6.287)
# Loss before attack: 0.9048
# Loss after attack: 0.9048
# Bit flips: 5800
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.980.
# F1-score: 0.979.
# Iteration Time 6.293 (6.088)
# **********************************
# attacked module: classifier
# Iteration: [030/040]   Attack Time 6.264 (6.286)
# Loss before attack: 0.9048
# Loss after attack: 0.9048
# Bit flips: 6000
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.980.
# F1-score: 0.979.
# Iteration Time 6.090 (6.088)
# **********************************
# attacked module: classifier
# Iteration: [031/040]   Attack Time 6.406 (6.290)
# Loss before attack: 0.9048
# Loss after attack: 0.9048
# Bit flips: 6200
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.980.
# F1-score: 0.979.
# Iteration Time 6.096 (6.088)
# **********************************
# attacked module: classifier
# Iteration: [032/040]   Attack Time 6.325 (6.291)
# Loss before attack: 0.9048
# Loss after attack: 0.9048
# Bit flips: 6400
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.980.
# F1-score: 0.979.
# Iteration Time 6.023 (6.086)
# **********************************
# attacked module: classifier
# Iteration: [033/040]   Attack Time 6.682 (6.303)
# Loss before attack: 0.9048
# Loss after attack: 0.9048
# Bit flips: 6600
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.980.
# F1-score: 0.979.
# Iteration Time 6.095 (6.086)
# **********************************
# attacked module: classifier
# Iteration: [034/040]   Attack Time 6.712 (6.315)
# Loss before attack: 0.9048
# Loss after attack: 0.9048
# Bit flips: 6800
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.980.
# F1-score: 0.979.
# Iteration Time 6.144 (6.088)
# **********************************
# attacked module: classifier
# Iteration: [035/040]   Attack Time 6.119 (6.310)
# Loss before attack: 0.9048
# Loss after attack: 0.9048
# Bit flips: 7000
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.980.
# F1-score: 0.979.
# Iteration Time 6.094 (6.088)
# **********************************
# attacked module: classifier
# Iteration: [036/040]   Attack Time 6.311 (6.310)
# Loss before attack: 0.9048
# Loss after attack: 0.9048
# Bit flips: 7200
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.980.
# F1-score: 0.979.
# Iteration Time 6.088 (6.088)
# **********************************
# attacked module: classifier
# Iteration: [037/040]   Attack Time 6.326 (6.310)
# Loss before attack: 0.9048
# Loss after attack: 0.9048
# Bit flips: 7400
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.980.
# F1-score: 0.979.
# Iteration Time 5.959 (6.085)
# **********************************
# attacked module: classifier
# Iteration: [038/040]   Attack Time 6.424 (6.313)
# Loss before attack: 0.9048
# Loss after attack: 0.9048
# Bit flips: 7600
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.980.
# F1-score: 0.979.
# Iteration Time 5.964 (6.082)
# **********************************
# attacked module: classifier
# Iteration: [039/040]   Attack Time 6.459 (6.317)
# Loss before attack: 0.9048
# Loss after attack: 0.9048
# Bit flips: 7800
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.980.
# F1-score: 0.979.
# Iteration Time 5.976 (6.079)
# **********************************
# attacked module: classifier
# Iteration: [040/040]   Attack Time 6.053 (6.310)
# Loss before attack: 0.9048
# Loss after attack: 0.9048
# Bit flips: 8000
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.980.
# F1-score: 0.979.
# Iteration Time 6.253 (6.083)
# Plot saved as CustomModel2/PBS_attack/MCC_PBS_attack.png
# Plot saved as CustomModel2/PBS_attack/ACC_PBS_attack.png
# Plot saved as CustomModel2/PBS_attack/TPR_PBS_attack.png
# Plot saved as CustomModel2/PBS_attack/F1_PBS_attack.png
# [Combined Plot] Saved as CustomModel2/PBS_attack/combined_metrics_PBS_attack.png
# MCC after 100 times PBS attack: 0.9979639547094823
# Accuracy after 100 times PBS attack: 0.9997285714285714
# TPR after 100 times PBS attack: 0.9798526443768999
# F1-score after 100 times PBS attack: 0.9790333567727282

# %%
model_path = os.path.join("CustomModel2", "best_model.pth")
trained_model = CustomModel2()

trained_model.load_state_dict(torch.load(model_path, map_location=torch.device('cuda' if torch.cuda.is_available() else 'cpu')))
trained_model = trained_model.to(device)

# Bước 2: Tạo bản sao của mô hình để làm tham chiếu
model_clean = copy.deepcopy(trained_model)

# Bước 3: Khởi tạo đối tượng tấn công BFA
attacker = BFA(criterion=criterion, model=trained_model, k_top=10)

# Định nghĩa đường dẫn để lưu kết quả tấn công
attack_dir = os.path.join("CustomModel2", "RandomFlip_attack")

os.makedirs(attack_dir, exist_ok=True)
attack_image_paths = [os.path.join(attack_dir, f"{metric}_RandomFlip_attack.png") 
                      for metric in ["MCC", "ACC", "TPR", "F1"]]
# attack_image_path = os.path.join(attack_dir, "RandomFlip_attack.png")
attack_csv_path = os.path.join(attack_dir, "RandomFlip_attack.csv")

# Bước 4: Thực hiện tấn công
perform_attack(
    attacker=attacker,               # Đối tượng tấn công
    model=trained_model,             # Mô hình bị tấn công
    model_clean=model_clean,         # Mô hình gốc làm tham chiếu
    train_loader=train_loader,       # Bộ dữ liệu huấn luyện
    test_loader=test_loader,         # Bộ dữ liệu kiểm tra
    N_iter=args.n_iter,              # Số vòng lặp tấn công
    writer=writer,                   # TensorBoard writer để ghi log
    file=attack_image_paths,          # Lưu ảnh vào thư mục tấn công
    csv_file=attack_csv_path, 
    csv_save_path=args.save_path,    # Đường dẫn lưu file CSV
    attack_type= 2,                  # Chế độ tấn công random
)

writer.close()  # Đóng TensorBoard writer

# best_mcc = validate_score(trained_model ,test_loader)
# print(f"\nMCC after 100 times Random attack: {best_mcc}")

results = validate_score(trained_model, test_loader)
print(f"MCC after 100 times random attack: {results['MCC']}")
print(f"Accuracy after 100 times random attack: {results['Accuracy']}")
print(f"TPR after 100 times random attack: {results['TPR']}")
print(f"F1-score after 100 times random attack: {results['F1 Score']}")
# Out:
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.980.
# F1-score: 0.979.
# Attack sample size is 256
# **********************************
# attacked module: classifier
# attacked weight index: 296
# weight before attack: tensor(0.0183, device='cuda:0')
# weight after attack: tensor(4096., device='cuda:0')
# Iteration: [001/040]   Attack Time 5.002 (5.002)
# Bit flips: 1
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.980.
# F1-score: 0.979.
# Iteration Time 5.874 (5.874)
# **********************************
# attacked module: classifier
# attacked weight index: 488
# weight before attack: tensor(0.0647, device='cuda:0')
# weight after attack: tensor(4., device='cuda:0')
# Iteration: [002/040]   Attack Time 5.034 (5.018)
# Bit flips: 2
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.979.
# F1-score: 0.979.
# Iteration Time 5.883 (5.878)
# **********************************
# attacked module: classifier
# attacked weight index: 220
# weight before attack: tensor(-0.0515, device='cuda:0')
# weight after attack: tensor(-17., device='cuda:0')
# Iteration: [003/040]   Attack Time 4.634 (4.890)
# Bit flips: 3
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.979.
# F1-score: 0.979.
# Iteration Time 6.099 (5.952)
# **********************************
# attacked module: classifier
# attacked weight index: 18
# weight before attack: tensor(0.0596, device='cuda:0')
# weight after attack: tensor(1., device='cuda:0')
# Iteration: [004/040]   Attack Time 4.887 (4.889)
# Bit flips: 4
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.979.
# F1-score: 0.979.
# Iteration Time 6.017 (5.968)
# **********************************
# attacked module: classifier
# attacked weight index: 100
# weight before attack: tensor(0.0403, device='cuda:0')
# weight after attack: tensor(8192., device='cuda:0')
# Iteration: [005/040]   Attack Time 4.888 (4.889)
# Bit flips: 5
# Hamming distance: 0
# **Test** MCC: -0.003. Val_Loss: 1.905
# ACC: 0.000.
# TPR: 0.016.
# F1-score: 0.005.
# Iteration Time 6.001 (5.975)
# **********************************
# attacked module: classifier
# attacked weight index: 489
# weight before attack: tensor(0.0373, device='cuda:0')
# weight after attack: tensor(4096., device='cuda:0')
# Iteration: [006/040]   Attack Time 5.036 (4.913)
# Bit flips: 6
# Hamming distance: 0
# **Test** MCC: 0.500. Val_Loss: 0.978
# ACC: 0.927.
# TPR: 0.279.
# F1-score: 0.269.
# Iteration Time 6.045 (5.986)
# **********************************
# attacked module: classifier
# attacked weight index: 125
# weight before attack: tensor(0.0120, device='cuda:0')
# weight after attack: tensor(128., device='cuda:0')
# Iteration: [007/040]   Attack Time 4.765 (4.892)
# Bit flips: 7
# Hamming distance: 0
# **Test** MCC: 0.500. Val_Loss: 0.978
# ACC: 0.927.
# TPR: 0.279.
# F1-score: 0.269.
# Iteration Time 6.097 (6.002)
# **********************************
# attacked module: classifier
# attacked weight index: 372
# weight before attack: tensor(0.0598, device='cuda:0')
# weight after attack: tensor(1024., device='cuda:0')
# Iteration: [008/040]   Attack Time 4.918 (4.895)
# Bit flips: 8
# Hamming distance: 0
# **Test** MCC: 0.500. Val_Loss: 0.978
# ACC: 0.927.
# TPR: 0.279.
# F1-score: 0.269.
# Iteration Time 6.068 (6.010)
# **********************************
# attacked module: classifier
# attacked weight index: 325
# weight before attack: tensor(0.0468, device='cuda:0')
# weight after attack: tensor(64., device='cuda:0')
# Iteration: [009/040]   Attack Time 5.031 (4.910)
# Bit flips: 9
# Hamming distance: 0
# **Test** MCC: 0.500. Val_Loss: 0.978
# ACC: 0.927.
# TPR: 0.279.
# F1-score: 0.269.
# Iteration Time 6.213 (6.033)
# **********************************
# attacked module: classifier
# attacked weight index: 148
# weight before attack: tensor(-0.0639, device='cuda:0')
# weight after attack: tensor(-16385., device='cuda:0')
# Iteration: [010/040]   Attack Time 4.785 (4.898)
# Bit flips: 10
# Hamming distance: 0
# **Test** MCC: 0.543. Val_Loss: 0.972
# ACC: 0.933.
# TPR: 0.595.
# F1-score: 0.382.
# Iteration Time 6.208 (6.051)
# **********************************
# attacked module: classifier
# attacked weight index: 493
# weight before attack: tensor(0.0155, device='cuda:0')
# weight after attack: tensor(2., device='cuda:0')
# Iteration: [011/040]   Attack Time 4.941 (4.902)
# Bit flips: 11
# Hamming distance: 0
# **Test** MCC: 0.543. Val_Loss: 0.972
# ACC: 0.933.
# TPR: 0.590.
# F1-score: 0.377.
# Iteration Time 6.133 (6.058)
# **********************************
# attacked module: classifier
# attacked weight index: 436
# weight before attack: tensor(0.0664, device='cuda:0')
# weight after attack: tensor(8192., device='cuda:0')
# Iteration: [012/040]   Attack Time 4.968 (4.907)
# Bit flips: 12
# Hamming distance: 0
# **Test** MCC: 0.543. Val_Loss: 0.972
# ACC: 0.933.
# TPR: 0.590.
# F1-score: 0.377.
# Iteration Time 6.079 (6.060)
# **********************************
# attacked module: classifier
# attacked weight index: 460
# weight before attack: tensor(-0.0133, device='cuda:0')
# weight after attack: tensor(-513., device='cuda:0')
# Iteration: [013/040]   Attack Time 5.013 (4.915)
# Bit flips: 13
# Hamming distance: 0
# **Test** MCC: 0.543. Val_Loss: 0.972
# ACC: 0.933.
# TPR: 0.590.
# F1-score: 0.377.
# Iteration Time 5.971 (6.053)
# **********************************
# attacked module: classifier
# attacked weight index: 220
# weight before attack: tensor(-17., device='cuda:0')
# weight after attack: tensor(-273., device='cuda:0')
# Iteration: [014/040]   Attack Time 4.777 (4.906)
# Bit flips: 14
# Hamming distance: 0
# **Test** MCC: 0.543. Val_Loss: 0.972
# ACC: 0.933.
# TPR: 0.590.
# F1-score: 0.377.
# Iteration Time 6.372 (6.076)
# **********************************
# attacked module: classifier
# attacked weight index: 475
# weight before attack: tensor(0.0154, device='cuda:0')
# weight after attack: tensor(64., device='cuda:0')
# Iteration: [015/040]   Attack Time 4.996 (4.912)
# Bit flips: 15
# Hamming distance: 0
# **Test** MCC: 0.543. Val_Loss: 0.972
# ACC: 0.933.
# TPR: 0.590.
# F1-score: 0.377.
# Iteration Time 6.119 (6.079)
# **********************************
# attacked module: classifier
# attacked weight index: 85
# weight before attack: tensor(0.0274, device='cuda:0')
# weight after attack: tensor(8192., device='cuda:0')
# Iteration: [016/040]   Attack Time 5.091 (4.923)
# Bit flips: 16
# Hamming distance: 0
# **Test** MCC: 0.493. Val_Loss: 0.978
# ACC: 0.927.
# TPR: 0.261.
# F1-score: 0.261.
# Iteration Time 5.996 (6.073)
# **********************************
# attacked module: classifier
# attacked weight index: 385
# weight before attack: tensor(0.0535, device='cuda:0')
# weight after attack: tensor(64., device='cuda:0')
# Iteration: [017/040]   Attack Time 4.691 (4.909)
# Bit flips: 17
# Hamming distance: 0
# **Test** MCC: 0.493. Val_Loss: 0.978
# ACC: 0.927.
# TPR: 0.261.
# F1-score: 0.261.
# Iteration Time 6.243 (6.083)
# **********************************
# attacked module: classifier
# attacked weight index: 366
# weight before attack: tensor(-0.0197, device='cuda:0')
# weight after attack: tensor(-257., device='cuda:0')
# Iteration: [018/040]   Attack Time 4.974 (4.913)
# Bit flips: 18
# Hamming distance: 0
# **Test** MCC: 0.493. Val_Loss: 0.978
# ACC: 0.927.
# TPR: 0.261.
# F1-score: 0.261.
# Iteration Time 6.120 (6.085)
# **********************************
# attacked module: classifier
# attacked weight index: 96
# weight before attack: tensor(-0.0390, device='cuda:0')
# weight after attack: tensor(-8193., device='cuda:0')
# Iteration: [019/040]   Attack Time 5.008 (4.918)
# Bit flips: 19
# Hamming distance: 0
# **Test** MCC: 0.493. Val_Loss: 0.978
# ACC: 0.927.
# TPR: 0.261.
# F1-score: 0.261.
# Iteration Time 6.003 (6.081)
# **********************************
# attacked module: classifier
# attacked weight index: 76
# weight before attack: tensor(0.0121, device='cuda:0')
# weight after attack: tensor(1., device='cuda:0')
# Iteration: [020/040]   Attack Time 5.173 (4.931)
# Bit flips: 20
# Hamming distance: 0
# **Test** MCC: 0.493. Val_Loss: 0.978
# ACC: 0.927.
# TPR: 0.261.
# F1-score: 0.261.
# Iteration Time 6.173 (6.086)
# **********************************
# attacked module: classifier
# attacked weight index: 458
# weight before attack: tensor(-0.0024, device='cuda:0')
# weight after attack: tensor(-1025., device='cuda:0')
# Iteration: [021/040]   Attack Time 4.769 (4.923)
# Bit flips: 21
# Hamming distance: 0
# **Test** MCC: 0.493. Val_Loss: 0.978
# ACC: 0.927.
# TPR: 0.261.
# F1-score: 0.261.
# Iteration Time 6.138 (6.088)
# **********************************
# attacked module: classifier
# attacked weight index: 296
# weight before attack: tensor(4096., device='cuda:0')
# weight after attack: tensor(12288., device='cuda:0')
# Iteration: [022/040]   Attack Time 4.972 (4.925)
# Bit flips: 22
# Hamming distance: 0
# **Test** MCC: 0.493. Val_Loss: 0.978
# ACC: 0.927.
# TPR: 0.261.
# F1-score: 0.261.
# Iteration Time 5.981 (6.083)
# **********************************
# attacked module: classifier
# attacked weight index: 374
# weight before attack: tensor(0.0586, device='cuda:0')
# weight after attack: tensor(2., device='cuda:0')
# Iteration: [023/040]   Attack Time 5.308 (4.942)
# Bit flips: 23
# Hamming distance: 0
# **Test** MCC: 0.493. Val_Loss: 0.978
# ACC: 0.927.
# TPR: 0.261.
# F1-score: 0.261.
# Iteration Time 5.950 (6.078)
# **********************************
# attacked module: classifier
# attacked weight index: 198
# weight before attack: tensor(0.0662, device='cuda:0')
# weight after attack: tensor(8., device='cuda:0')
# Iteration: [024/040]   Attack Time 4.923 (4.941)
# Bit flips: 24
# Hamming distance: 0
# **Test** MCC: 0.493. Val_Loss: 0.978
# ACC: 0.927.
# TPR: 0.261.
# F1-score: 0.261.
# Iteration Time 6.117 (6.079)
# **********************************
# attacked module: classifier
# attacked weight index: 391
# weight before attack: tensor(-0.0243, device='cuda:0')
# weight after attack: tensor(-129., device='cuda:0')
# Iteration: [025/040]   Attack Time 4.862 (4.938)
# Bit flips: 25
# Hamming distance: 0
# **Test** MCC: 0.493. Val_Loss: 0.978
# ACC: 0.927.
# TPR: 0.261.
# F1-score: 0.261.
# Iteration Time 6.161 (6.082)
# **********************************
# attacked module: classifier
# attacked weight index: 176
# weight before attack: tensor(0.0005, device='cuda:0')
# weight after attack: tensor(512., device='cuda:0')
# Iteration: [026/040]   Attack Time 4.980 (4.939)
# Bit flips: 26
# Hamming distance: 0
# **Test** MCC: 0.494. Val_Loss: 0.978
# ACC: 0.927.
# TPR: 0.264.
# F1-score: 0.263.
# Iteration Time 6.009 (6.080)
# **********************************
# attacked module: classifier
# attacked weight index: 140
# weight before attack: tensor(0.0534, device='cuda:0')
# weight after attack: tensor(256., device='cuda:0')
# Iteration: [027/040]   Attack Time 4.960 (4.940)
# Bit flips: 27
# Hamming distance: 0
# **Test** MCC: 0.494. Val_Loss: 0.978
# ACC: 0.927.
# TPR: 0.264.
# F1-score: 0.263.
# Iteration Time 5.965 (6.075)
# **********************************
# attacked module: classifier
# attacked weight index: 117
# weight before attack: tensor(-0.0060, device='cuda:0')
# weight after attack: tensor(-65., device='cuda:0')
# Iteration: [028/040]   Attack Time 4.800 (4.935)
# Bit flips: 28
# Hamming distance: 0
# **Test** MCC: 0.494. Val_Loss: 0.978
# ACC: 0.927.
# TPR: 0.264.
# F1-score: 0.263.
# Iteration Time 6.259 (6.082)
# **********************************
# attacked module: classifier
# attacked weight index: 384
# weight before attack: tensor(-0.0493, device='cuda:0')
# weight after attack: tensor(-2., device='cuda:0')
# Iteration: [029/040]   Attack Time 4.741 (4.928)
# Bit flips: 29
# Hamming distance: 0
# **Test** MCC: 0.494. Val_Loss: 0.978
# ACC: 0.927.
# TPR: 0.264.
# F1-score: 0.263.
# Iteration Time 5.026 (6.046)
# **********************************
# attacked module: classifier
# attacked weight index: 419
# weight before attack: tensor(0.0392, device='cuda:0')
# weight after attack: tensor(256., device='cuda:0')
# Iteration: [030/040]   Attack Time 4.911 (4.928)
# Bit flips: 30
# Hamming distance: 0
# **Test** MCC: 0.494. Val_Loss: 0.978
# ACC: 0.927.
# TPR: 0.264.
# F1-score: 0.263.
# Iteration Time 6.304 (6.054)
# **********************************
# attacked module: classifier
# attacked weight index: 197
# weight before attack: tensor(-0.0303, device='cuda:0')
# weight after attack: tensor(-16385., device='cuda:0')
# Iteration: [031/040]   Attack Time 4.698 (4.920)
# Bit flips: 31
# Hamming distance: 0
# **Test** MCC: 0.494. Val_Loss: 0.978
# ACC: 0.927.
# TPR: 0.264.
# F1-score: 0.264.
# Iteration Time 6.123 (6.056)
# **********************************
# attacked module: classifier
# attacked weight index: 63
# weight before attack: tensor(0.0492, device='cuda:0')
# weight after attack: tensor(128., device='cuda:0')
# Iteration: [032/040]   Attack Time 4.942 (4.921)
# Bit flips: 32
# Hamming distance: 0
# **Test** MCC: 0.494. Val_Loss: 0.978
# ACC: 0.927.
# TPR: 0.270.
# F1-score: 0.268.
# Iteration Time 5.936 (6.053)
# **********************************
# attacked module: classifier
# attacked weight index: 306
# weight before attack: tensor(-0.0043, device='cuda:0')
# weight after attack: tensor(-16385., device='cuda:0')
# Iteration: [033/040]   Attack Time 5.051 (4.925)
# Bit flips: 33
# Hamming distance: 0
# **Test** MCC: 0.133. Val_Loss: 0.978
# ACC: 0.927.
# TPR: 0.299.
# F1-score: 0.287.
# Iteration Time 6.079 (6.053)
# **********************************
# attacked module: classifier
# attacked weight index: 238
# weight before attack: tensor(-0.0483, device='cuda:0')
# weight after attack: tensor(32767., device='cuda:0')
# Iteration: [034/040]   Attack Time 4.848 (4.923)
# Bit flips: 34
# Hamming distance: 0
# **Test** MCC: -0.947. Val_Loss: 1.905
# ACC: 0.000.
# TPR: 0.000.
# F1-score: 0.000.
# Iteration Time 6.108 (6.055)
# **********************************
# attacked module: classifier
# attacked weight index: 108
# weight before attack: tensor(0.0609, device='cuda:0')
# weight after attack: tensor(4096., device='cuda:0')
# Iteration: [035/040]   Attack Time 4.904 (4.922)
# Bit flips: 35
# Hamming distance: 0
# **Test** MCC: -0.947. Val_Loss: 1.905
# ACC: 0.000.
# TPR: 0.000.
# F1-score: 0.000.
# Iteration Time 6.168 (6.058)
# **********************************
# attacked module: classifier
# attacked weight index: 268
# weight before attack: tensor(0.0408, device='cuda:0')
# weight after attack: tensor(64., device='cuda:0')
# Iteration: [036/040]   Attack Time 5.090 (4.927)
# Bit flips: 36
# Hamming distance: 0
# **Test** MCC: -0.947. Val_Loss: 1.905
# ACC: 0.000.
# TPR: 0.000.
# F1-score: 0.000.
# Iteration Time 5.985 (6.056)
# **********************************
# attacked module: classifier
# attacked weight index: 448
# weight before attack: tensor(0.0524, device='cuda:0')
# weight after attack: tensor(2048., device='cuda:0')
# Iteration: [037/040]   Attack Time 5.134 (4.933)
# Bit flips: 37
# Hamming distance: 0
# **Test** MCC: -0.947. Val_Loss: 1.905
# ACC: 0.000.
# TPR: 0.000.
# F1-score: 0.000.
# Iteration Time 6.215 (6.060)
# **********************************
# attacked module: classifier
# attacked weight index: 169
# weight before attack: tensor(-0.0172, device='cuda:0')
# weight after attack: tensor(-513., device='cuda:0')
# Iteration: [038/040]   Attack Time 4.833 (4.930)
# Bit flips: 38
# Hamming distance: 0
# **Test** MCC: -0.947. Val_Loss: 1.905
# ACC: 0.000.
# TPR: 0.000.
# F1-score: 0.000.
# Iteration Time 6.243 (6.065)
# **********************************
# attacked module: classifier
# attacked weight index: 277
# weight before attack: tensor(-0.0086, device='cuda:0')
# weight after attack: tensor(-33., device='cuda:0')
# Iteration: [039/040]   Attack Time 4.960 (4.931)
# Bit flips: 39
# Hamming distance: 0
# **Test** MCC: -0.947. Val_Loss: 1.905
# ACC: 0.000.
# TPR: 0.000.
# F1-score: 0.000.
# Iteration Time 6.115 (6.067)
# **********************************
# attacked module: classifier
# attacked weight index: 105
# weight before attack: tensor(-0.0376, device='cuda:0')
# weight after attack: tensor(-2., device='cuda:0')
# Iteration: [040/040]   Attack Time 5.067 (4.934)
# Bit flips: 40
# Hamming distance: 0
# **Test** MCC: -0.947. Val_Loss: 1.905
# ACC: 0.000.
# TPR: 0.000.
# F1-score: 0.000.
# Iteration Time 6.064 (6.066)
# Plot saved as CustomModel2/RandomFlip_attack/MCC_RandomFlip_attack.png
# Plot saved as CustomModel2/RandomFlip_attack/ACC_RandomFlip_attack.png
# Plot saved as CustomModel2/RandomFlip_attack/TPR_RandomFlip_attack.png
# Plot saved as CustomModel2/RandomFlip_attack/F1_RandomFlip_attack.png
# [Combined Plot] Saved as CustomModel2/RandomFlip_attack/combined_metrics_RandomFlip_attack.png
# MCC after 100 times random attack: -0.947048576686237
# Accuracy after 100 times random attack: 7.142857142857143e-06
# TPR after 100 times random attack: 2.5937183383991898e-06
# F1-score after 100 times random attack: 4.7619047619047615e-06

# %%
model_path = os.path.join("CustomModel2", "best_model.pth")
if not os.path.exists(model_path):
    raise FileNotFoundError(f"Không tìm thấy mô hình tại: {model_path}")

trained_model = CustomModel2()

trained_model.load_state_dict(torch.load(model_path, map_location=torch.device('cuda' if torch.cuda.is_available() else 'cpu')))
trained_model = trained_model.to(device)


# Bước 2: Tạo bản sao của mô hình để làm tham chiếu
model_clean = copy.deepcopy(trained_model)

# Bước 3: Khởi tạo đối tượng tấn công BFA
attacker = BFA(criterion=criterion, model=trained_model, k_top=10)

# Định nghĩa đường dẫn để lưu kết quả tấn công
attack_dir = os.path.join("CustomModel2", "PBS_to_RandomFlip_attack")

os.makedirs(attack_dir, exist_ok=True)
attack_image_paths = [os.path.join(attack_dir, f"{metric}_PBS_to_RandomFlip_attack.png") 
                      for metric in ["MCC", "ACC", "TPR", "F1"]]
# attack_image_path = os.path.join(attack_dir, "PBS_to_RandomFlip_attack.png")
attack_csv_path = os.path.join(attack_dir, "PBS_to_RandomFlip_attack.csv")

# Bước 4: Thực hiện tấn công
perform_attack(
    attacker=attacker,               # Đối tượng tấn công
    model=trained_model,             # Mô hình bị tấn công
    model_clean=model_clean,         # Mô hình gốc làm tham chiếu
    train_loader=train_loader,       # Bộ dữ liệu huấn luyện
    test_loader=test_loader,         # Bộ dữ liệu kiểm tra
    N_iter=args.n_iter,              # Số vòng lặp tấn công
    writer=writer,                   # TensorBoard writer để ghi log
    file=attack_image_paths,          # Lưu ảnh vào thư mục tấn công
    csv_file=attack_csv_path, 
    csv_save_path=args.save_path,    # Đường dẫn lưu file CSV
    attack_type= 3,                  # Chế độ tấn công PBS -> random
)

writer.close()  # Đóng TensorBoard writer
# best_mcc = validate_score( trained_model,test_loader)
# print(f"\nMCC after 100 times PBS to Random: {best_mcc}")

results = validate_score(trained_model, test_loader)
print(f"MCC after 100 times PBS to Random: {results['MCC']}")
print(f"Accuracy after 100 times PBS to Random: {results['Accuracy']}")
print(f"TPR after 100 times PBS to Random: {results['TPR']}")
print(f"F1-score after 100 times PBS to Random: {results['F1 Score']}")
# Out:
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.980.
# F1-score: 0.979.
# Attack sample size is 256
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 463
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-513., device='cuda:0')
# Iteration: [001/040]   Attack Time 11.698 (11.698)
# Loss before attack: 0.9048
# Loss after attack: 0.9048
# Bit flips: 201
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.977.
# F1-score: 0.976.
# Iteration Time 6.131 (6.131)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 321
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-2., device='cuda:0')
# Iteration: [002/040]   Attack Time 11.582 (11.640)
# Loss before attack: 0.9048
# Loss after attack: 0.9048
# Bit flips: 402
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.977.
# F1-score: 0.976.
# Iteration Time 6.054 (6.093)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 24
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(16., device='cuda:0')
# Iteration: [003/040]   Attack Time 11.341 (11.540)
# Loss before attack: 0.9048
# Loss after attack: 0.9048
# Bit flips: 603
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.977.
# F1-score: 0.976.
# Iteration Time 6.081 (6.089)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 119
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(2., device='cuda:0')
# Iteration: [004/040]   Attack Time 11.205 (11.456)
# Loss before attack: 0.9048
# Loss after attack: 0.9048
# Bit flips: 804
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.977.
# F1-score: 0.976.
# Iteration Time 6.260 (6.132)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 374
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(64., device='cuda:0')
# Iteration: [005/040]   Attack Time 11.008 (11.367)
# Loss before attack: 0.9048
# Loss after attack: 0.9048
# Bit flips: 1005
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.977.
# F1-score: 0.976.
# Iteration Time 6.181 (6.142)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 377
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(256., device='cuda:0')
# Iteration: [006/040]   Attack Time 11.419 (11.375)
# Loss before attack: 0.9048
# Loss after attack: 0.9048
# Bit flips: 1206
# Hamming distance: 0
# **Test** MCC: 0.478. Val_Loss: 1.832
# ACC: 0.073.
# TPR: 0.598.
# F1-score: 0.337.
# Iteration Time 6.061 (6.128)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 278
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(64., device='cuda:0')
# Iteration: [007/040]   Attack Time 11.227 (11.354)
# Loss before attack: 1.8189
# Loss after attack: 1.8189
# Bit flips: 1407
# Hamming distance: 0
# **Test** MCC: 0.406. Val_Loss: 1.838
# ACC: 0.066.
# TPR: 0.325.
# F1-score: 0.308.
# Iteration Time 6.051 (6.117)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 384
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-4097., device='cuda:0')
# Iteration: [008/040]   Attack Time 11.257 (11.342)
# Loss before attack: 1.8228
# Loss after attack: 1.8228
# Bit flips: 1608
# Hamming distance: 0
# **Test** MCC: 0.303. Val_Loss: 1.715
# ACC: 0.189.
# TPR: 0.368.
# F1-score: 0.384.
# Iteration Time 6.110 (6.116)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 261
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-17., device='cuda:0')
# Iteration: [009/040]   Attack Time 11.495 (11.359)
# Loss before attack: 1.6861
# Loss after attack: 1.6861
# Bit flips: 1809
# Hamming distance: 0
# **Test** MCC: 0.303. Val_Loss: 1.715
# ACC: 0.189.
# TPR: 0.368.
# F1-score: 0.384.
# Iteration Time 6.011 (6.104)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 345
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-513., device='cuda:0')
# Iteration: [010/040]   Attack Time 11.552 (11.378)
# Loss before attack: 1.6861
# Loss after attack: 1.6861
# Bit flips: 2010
# Hamming distance: 0
# **Test** MCC: 0.303. Val_Loss: 1.715
# ACC: 0.189.
# TPR: 0.368.
# F1-score: 0.384.
# Iteration Time 6.012 (6.095)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 256
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(4., device='cuda:0')
# Iteration: [011/040]   Attack Time 11.064 (11.350)
# Loss before attack: 1.6861
# Loss after attack: 1.6861
# Bit flips: 2211
# Hamming distance: 0
# **Test** MCC: 0.303. Val_Loss: 1.715
# ACC: 0.189.
# TPR: 0.368.
# F1-score: 0.384.
# Iteration Time 6.206 (6.105)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 234
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(256., device='cuda:0')
# Iteration: [012/040]   Attack Time 10.895 (11.312)
# Loss before attack: 1.6861
# Loss after attack: 1.6861
# Bit flips: 2412
# Hamming distance: 0
# **Test** MCC: 0.303. Val_Loss: 1.716
# ACC: 0.189.
# TPR: 0.368.
# F1-score: 0.383.
# Iteration Time 6.335 (6.124)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 294
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-129., device='cuda:0')
# Iteration: [013/040]   Attack Time 10.979 (11.286)
# Loss before attack: 1.6900
# Loss after attack: 1.6900
# Bit flips: 2613
# Hamming distance: 0
# **Test** MCC: 0.303. Val_Loss: 1.716
# ACC: 0.189.
# TPR: 0.368.
# F1-score: 0.383.
# Iteration Time 6.169 (6.128)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 399
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-257., device='cuda:0')
# Iteration: [014/040]   Attack Time 11.193 (11.280)
# Loss before attack: 1.6900
# Loss after attack: 1.6900
# Bit flips: 2814
# Hamming distance: 0
# **Test** MCC: 0.303. Val_Loss: 1.716
# ACC: 0.189.
# TPR: 0.368.
# F1-score: 0.383.
# Iteration Time 6.029 (6.121)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 384
# weight before attack: tensor(-4097., device='cuda:0')
# weight after attack: tensor(-4161., device='cuda:0')
# Iteration: [015/040]   Attack Time 11.295 (11.281)
# Loss before attack: 1.6900
# Loss after attack: 1.6900
# Bit flips: 3015
# Hamming distance: 0
# **Test** MCC: 0.302. Val_Loss: 1.713
# ACC: 0.192.
# TPR: 0.369.
# F1-score: 0.385.
# Iteration Time 5.998 (6.113)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 132
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-5., device='cuda:0')
# Iteration: [016/040]   Attack Time 11.485 (11.294)
# Loss before attack: 1.6824
# Loss after attack: 1.6824
# Bit flips: 3216
# Hamming distance: 0
# **Test** MCC: 0.302. Val_Loss: 1.713
# ACC: 0.192.
# TPR: 0.369.
# F1-score: 0.385.
# Iteration Time 5.999 (6.105)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 59
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-3., device='cuda:0')
# Iteration: [017/040]   Attack Time 11.422 (11.301)
# Loss before attack: 1.6824
# Loss after attack: 1.6824
# Bit flips: 3417
# Hamming distance: 0
# **Test** MCC: 0.302. Val_Loss: 1.713
# ACC: 0.192.
# TPR: 0.369.
# F1-score: 0.385.
# Iteration Time 5.898 (6.093)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 63
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(16384., device='cuda:0')
# Iteration: [018/040]   Attack Time 11.390 (11.306)
# Loss before attack: 1.6824
# Loss after attack: 1.6824
# Bit flips: 3618
# Hamming distance: 0
# **Test** MCC: 0.016. Val_Loss: 1.779
# ACC: 0.126.
# TPR: 0.042.
# F1-score: 0.060.
# Iteration Time 6.154 (6.097)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 438
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(4., device='cuda:0')
# Iteration: [019/040]   Attack Time 11.011 (11.290)
# Loss before attack: 1.7669
# Loss after attack: 1.7669
# Bit flips: 3819
# Hamming distance: 0
# **Test** MCC: 0.018. Val_Loss: 1.773
# ACC: 0.132.
# TPR: 0.044.
# F1-score: 0.062.
# Iteration Time 6.326 (6.109)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 121
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-2., device='cuda:0')
# Iteration: [020/040]   Attack Time 11.154 (11.284)
# Loss before attack: 1.7603
# Loss after attack: 1.7603
# Bit flips: 4020
# Hamming distance: 0
# **Test** MCC: 0.018. Val_Loss: 1.773
# ACC: 0.132.
# TPR: 0.044.
# F1-score: 0.062.
# Iteration Time 6.234 (6.115)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 280
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-17., device='cuda:0')
# Iteration: [021/040]   Attack Time 11.476 (11.293)
# Loss before attack: 1.7603
# Loss after attack: 1.7603
# Bit flips: 4221
# Hamming distance: 0
# **Test** MCC: 0.019. Val_Loss: 1.772
# ACC: 0.132.
# TPR: 0.044.
# F1-score: 0.062.
# Iteration Time 6.260 (6.122)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 316
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(1024., device='cuda:0')
# Iteration: [022/040]   Attack Time 11.434 (11.299)
# Loss before attack: 1.7564
# Loss after attack: 1.7564
# Bit flips: 4422
# Hamming distance: 0
# **Test** MCC: 0.019. Val_Loss: 1.772
# ACC: 0.132.
# TPR: 0.044.
# F1-score: 0.062.
# Iteration Time 6.209 (6.126)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 476
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-2., device='cuda:0')
# Iteration: [023/040]   Attack Time 11.458 (11.306)
# Loss before attack: 1.7564
# Loss after attack: 1.7564
# Bit flips: 4623
# Hamming distance: 0
# **Test** MCC: 0.019. Val_Loss: 1.772
# ACC: 0.132.
# TPR: 0.044.
# F1-score: 0.062.
# Iteration Time 5.899 (6.116)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 40
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(16., device='cuda:0')
# Iteration: [024/040]   Attack Time 11.462 (11.313)
# Loss before attack: 1.7564
# Loss after attack: 1.7564
# Bit flips: 4824
# Hamming distance: 0
# **Test** MCC: 0.019. Val_Loss: 1.772
# ACC: 0.132.
# TPR: 0.044.
# F1-score: 0.062.
# Iteration Time 5.922 (6.108)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 26
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-257., device='cuda:0')
# Iteration: [025/040]   Attack Time 11.402 (11.316)
# Loss before attack: 1.7564
# Loss after attack: 1.7564
# Bit flips: 5025
# Hamming distance: 0
# **Test** MCC: 0.019. Val_Loss: 1.772
# ACC: 0.132.
# TPR: 0.044.
# F1-score: 0.062.
# Iteration Time 6.315 (6.116)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 413
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(8192., device='cuda:0')
# Iteration: [026/040]   Attack Time 11.196 (11.311)
# Loss before attack: 1.7564
# Loss after attack: 1.7564
# Bit flips: 5226
# Hamming distance: 0
# **Test** MCC: 0.474. Val_Loss: 0.978
# ACC: 0.927.
# TPR: 0.271.
# F1-score: 0.262.
# Iteration Time 6.487 (6.130)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 296
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(512., device='cuda:0')
# Iteration: [027/040]   Attack Time 11.232 (11.309)
# Loss before attack: 0.9908
# Loss after attack: 0.9908
# Bit flips: 5427
# Hamming distance: 0
# **Test** MCC: 0.474. Val_Loss: 0.978
# ACC: 0.927.
# TPR: 0.271.
# F1-score: 0.262.
# Iteration Time 6.273 (6.136)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 396
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-1025., device='cuda:0')
# Iteration: [028/040]   Attack Time 11.278 (11.307)
# Loss before attack: 0.9908
# Loss after attack: 0.9908
# Bit flips: 5628
# Hamming distance: 0
# **Test** MCC: 0.474. Val_Loss: 0.978
# ACC: 0.927.
# TPR: 0.271.
# F1-score: 0.262.
# Iteration Time 5.894 (6.127)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 496
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(32767., device='cuda:0')
# Iteration: [029/040]   Attack Time 11.701 (11.321)
# Loss before attack: 0.9908
# Loss after attack: 0.9908
# Bit flips: 5829
# Hamming distance: 0
# **Test** MCC: 0.474. Val_Loss: 0.978
# ACC: 0.927.
# TPR: 0.271.
# F1-score: 0.262.
# Iteration Time 6.199 (6.130)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 414
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-5., device='cuda:0')
# Iteration: [030/040]   Attack Time 11.526 (11.328)
# Loss before attack: 0.9908
# Loss after attack: 0.9908
# Bit flips: 6030
# Hamming distance: 0
# **Test** MCC: 0.474. Val_Loss: 0.978
# ACC: 0.927.
# TPR: 0.271.
# F1-score: 0.262.
# Iteration Time 6.229 (6.133)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 384
# weight before attack: tensor(-4161., device='cuda:0')
# weight after attack: tensor(-4673., device='cuda:0')
# Iteration: [031/040]   Attack Time 11.758 (11.342)
# Loss before attack: 0.9908
# Loss after attack: 0.9908
# Bit flips: 6231
# Hamming distance: 0
# **Test** MCC: 0.474. Val_Loss: 0.978
# ACC: 0.927.
# TPR: 0.271.
# F1-score: 0.262.
# Iteration Time 6.177 (6.134)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 72
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-8193., device='cuda:0')
# Iteration: [032/040]   Attack Time 11.629 (11.351)
# Loss before attack: 0.9908
# Loss after attack: 0.9908
# Bit flips: 6432
# Hamming distance: 0
# **Test** MCC: 0.474. Val_Loss: 0.978
# ACC: 0.927.
# TPR: 0.271.
# F1-score: 0.262.
# Iteration Time 6.023 (6.131)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 490
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(-32768., device='cuda:0')
# Iteration: [033/040]   Attack Time 11.393 (11.352)
# Loss before attack: 0.9908
# Loss after attack: 0.9908
# Bit flips: 6633
# Hamming distance: 0
# **Test** MCC: -0.053. Val_Loss: 1.905
# ACC: 0.000.
# TPR: 0.009.
# F1-score: 0.000.
# Iteration Time 6.305 (6.136)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 11
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(-32768., device='cuda:0')
# Iteration: [034/040]   Attack Time 11.391 (11.353)
# Loss before attack: 1.9048
# Loss after attack: 1.9048
# Bit flips: 6834
# Hamming distance: 0
# **Test** MCC: 0.230. Val_Loss: 1.838
# ACC: 0.066.
# TPR: 0.247.
# F1-score: 0.246.
# Iteration Time 6.570 (6.149)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 330
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(256., device='cuda:0')
# Iteration: [035/040]   Attack Time 11.610 (11.360)
# Loss before attack: 1.8228
# Loss after attack: 1.8228
# Bit flips: 7035
# Hamming distance: 0
# **Test** MCC: 0.230. Val_Loss: 1.838
# ACC: 0.066.
# TPR: 0.247.
# F1-score: 0.246.
# Iteration Time 6.125 (6.148)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 397
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(64., device='cuda:0')
# Iteration: [036/040]   Attack Time 11.519 (11.365)
# Loss before attack: 1.8228
# Loss after attack: 1.8228
# Bit flips: 7236
# Hamming distance: 0
# **Test** MCC: 0.230. Val_Loss: 1.838
# ACC: 0.066.
# TPR: 0.247.
# F1-score: 0.246.
# Iteration Time 6.202 (6.150)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 452
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(32767., device='cuda:0')
# Iteration: [037/040]   Attack Time 11.360 (11.365)
# Loss before attack: 1.8228
# Loss after attack: 1.8228
# Bit flips: 7437
# Hamming distance: 0
# **Test** MCC: 0.230. Val_Loss: 1.838
# ACC: 0.066.
# TPR: 0.247.
# F1-score: 0.246.
# Iteration Time 6.022 (6.146)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 361
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(32767., device='cuda:0')
# Iteration: [038/040]   Attack Time 11.441 (11.367)
# Loss before attack: 1.8228
# Loss after attack: 1.8228
# Bit flips: 7638
# Hamming distance: 0
# **Test** MCC: 0.230. Val_Loss: 1.838
# ACC: 0.066.
# TPR: 0.247.
# F1-score: 0.246.
# Iteration Time 6.031 (6.143)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 436
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(16384., device='cuda:0')
# Iteration: [039/040]   Attack Time 11.622 (11.373)
# Loss before attack: 1.8228
# Loss after attack: 1.8228
# Bit flips: 7839
# Hamming distance: 0
# **Test** MCC: 0.434. Val_Loss: 1.121
# ACC: 0.784.
# TPR: 0.438.
# F1-score: 0.460.
# Iteration Time 6.167 (6.144)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 16
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(64., device='cuda:0')
# Iteration: [040/040]   Attack Time 11.221 (11.369)
# Loss before attack: 1.1197
# Loss after attack: 1.1197
# Bit flips: 8040
# Hamming distance: 0
# **Test** MCC: 0.434. Val_Loss: 1.121
# ACC: 0.784.
# TPR: 0.438.
# F1-score: 0.460.
# Iteration Time 6.110 (6.143)
# Plot saved as CustomModel2/PBS_to_RandomFlip_attack/MCC_PBS_to_RandomFlip_attack.png
# Plot saved as CustomModel2/PBS_to_RandomFlip_attack/ACC_PBS_to_RandomFlip_attack.png
# Plot saved as CustomModel2/PBS_to_RandomFlip_attack/TPR_PBS_to_RandomFlip_attack.png
# Plot saved as CustomModel2/PBS_to_RandomFlip_attack/F1_PBS_to_RandomFlip_attack.png
# [Combined Plot] Saved as CustomModel2/PBS_to_RandomFlip_attack/combined_metrics_PBS_to_RandomFlip_attack.png
# MCC after 100 times PBS to Random: 0.4337219596638426
# Accuracy after 100 times PBS to Random: 0.78385
# TPR after 100 times PBS to Random: 0.4380660780078511
# F1-score after 100 times PBS to Random: 0.46035046291707965

# %%
# Bước 1: Tải mô hình đã huấn luyện
model_path = os.path.join("CustomModel2", "best_model.pth")
if not os.path.exists(model_path):
    raise FileNotFoundError(f"Không tìm thấy mô hình tại: {model_path}")

trained_model = CustomModel2()

trained_model.load_state_dict(torch.load(model_path, map_location=torch.device('cuda' if torch.cuda.is_available() else 'cpu')))
trained_model = trained_model.to(device)

# Bước 2: Tạo bản sao của mô hình để làm tham chiếu
model_clean = copy.deepcopy(trained_model)

# Bước 3: Khởi tạo đối tượng tấn công BFA
attacker = BFA(criterion=criterion, model=trained_model, k_top=10)

# Định nghĩa đường dẫn để lưu kết quả tấn công
attack_dir = os.path.join("CustomModel2", "RandomFlip_to_PBS_attack")

os.makedirs(attack_dir, exist_ok=True)
attack_image_paths = [os.path.join(attack_dir, f"{metric}_RandomFlip_to_PBS_attack.png") 
                      for metric in ["MCC", "ACC", "TPR", "F1"]]
# attack_image_path = os.path.join(attack_dir, "RandomFlip_to_PBS_attack.png")
attack_csv_path = os.path.join(attack_dir, "RandomFlip_to_PBS_attack.csv")

# Bước 4: Thực hiện tấn công
perform_attack(
    attacker=attacker,               # Đối tượng tấn công
    model=trained_model,             # Mô hình bị tấn công
    model_clean=model_clean,         # Mô hình gốc làm tham chiếu
    train_loader=train_loader,       # Bộ dữ liệu huấn luyện
    test_loader=test_loader,         # Bộ dữ liệu kiểm tra
    N_iter=args.n_iter,              # Số vòng lặp tấn công
    writer=writer,                   # TensorBoard writer để ghi log
    file=attack_image_paths,          # Lưu ảnh vào thư mục tấn công
    csv_file=attack_csv_path,  
    csv_save_path=args.save_path,    # Đường dẫn lưu file CSV
    attack_type= 4,                  # Chế độ tấn công Random -> PBS
)

writer.close()  # Đóng TensorBoard writer
# best_mcc = validate_score( trained_model,test_loader)
# print(f"\nMCC after 100 times Random to PBS: {best_mcc}")

results = validate_score(trained_model, test_loader)
print(f"MCC before attack: {round(results['MCC'], 5)}")
print(f"Accuracy before attack: {round(results['Accuracy'], 5)}")
print(f"TPR before attack: {round(results['TPR'], 5)}")
print(f"F1-score before attack: {round(results['F1 Score'], 5)}")
# Out:
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.980.
# F1-score: 0.979.
# Attack sample size is 256
# **********************************
# attacked module: classifier
# attacked weight index: 121
# weight before attack: tensor(-0.0369, device='cuda:0')
# weight after attack: tensor(-33., device='cuda:0')
# attacked module: classifier
# Iteration: [001/040]   Attack Time 12.416 (12.416)
# Loss before attack: 0.9048
# Loss after attack: 0.9048
# Bit flips: 201
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.980.
# F1-score: 0.979.
# Iteration Time 6.884 (6.884)
# **********************************
# attacked module: classifier
# attacked weight index: 493
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(4., device='cuda:0')
# attacked module: classifier
# Iteration: [002/040]   Attack Time 12.521 (12.468)
# Loss before attack: 0.9048
# Loss after attack: 0.9048
# Bit flips: 402
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.980.
# F1-score: 0.979.
# Iteration Time 6.738 (6.811)
# **********************************
# attacked module: classifier
# attacked weight index: 449
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-2., device='cuda:0')
# attacked module: classifier
# Iteration: [003/040]   Attack Time 12.526 (12.487)
# Loss before attack: 0.9048
# Loss after attack: 0.9048
# Bit flips: 603
# Hamming distance: 0
# **Test** MCC: 0.998. Val_Loss: 0.905
# ACC: 1.000.
# TPR: 0.980.
# F1-score: 0.979.
# Iteration Time 6.555 (6.726)
# **********************************
# attacked module: classifier
# attacked weight index: 200
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(16., device='cuda:0')
# attacked module: classifier
# Iteration: [004/040]   Attack Time 12.548 (12.503)
# Loss before attack: 0.9087
# Loss after attack: 0.9087
# Bit flips: 804
# Hamming distance: 0
# **Test** MCC: 0.950. Val_Loss: 0.912
# ACC: 0.993.
# TPR: 0.716.
# F1-score: 0.699.
# Iteration Time 6.418 (6.649)
# **********************************
# attacked module: classifier
# attacked weight index: 177
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(2048., device='cuda:0')
# attacked module: classifier
# Iteration: [005/040]   Attack Time 12.680 (12.538)
# Loss before attack: 1.8267
# Loss after attack: 1.8267
# Bit flips: 1005
# Hamming distance: 0
# **Test** MCC: 0.450. Val_Loss: 1.838
# ACC: 0.067.
# TPR: 0.270.
# F1-score: 0.257.
# Iteration Time 6.969 (6.713)
# **********************************
# attacked module: classifier
# attacked weight index: 314
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(4096., device='cuda:0')
# attacked module: classifier
# Iteration: [006/040]   Attack Time 12.383 (12.512)
# Loss before attack: 1.9009
# Loss after attack: 1.9009
# Bit flips: 1206
# Hamming distance: 0
# **Test** MCC: 0.044. Val_Loss: 1.898
# ACC: 0.007.
# TPR: 0.208.
# F1-score: 0.046.
# Iteration Time 6.789 (6.725)
# **********************************
# attacked module: classifier
# attacked weight index: 406
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-257., device='cuda:0')
# attacked module: classifier
# Iteration: [007/040]   Attack Time 12.512 (12.512)
# Loss before attack: 1.9009
# Loss after attack: 1.9009
# Bit flips: 1407
# Hamming distance: 0
# **Test** MCC: 0.044. Val_Loss: 1.898
# ACC: 0.007.
# TPR: 0.208.
# F1-score: 0.046.
# Iteration Time 6.642 (6.714)
# **********************************
# attacked module: classifier
# attacked weight index: 162
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-65., device='cuda:0')
# attacked module: classifier
# Iteration: [008/040]   Attack Time 12.518 (12.513)
# Loss before attack: 1.9009
# Loss after attack: 1.9009
# Bit flips: 1608
# Hamming distance: 0
# **Test** MCC: 0.044. Val_Loss: 1.898
# ACC: 0.007.
# TPR: 0.208.
# F1-score: 0.046.
# Iteration Time 6.474 (6.684)
# **********************************
# attacked module: classifier
# attacked weight index: 140
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(4096., device='cuda:0')
# attacked module: classifier
# Iteration: [009/040]   Attack Time 12.604 (12.523)
# Loss before attack: 1.9009
# Loss after attack: 1.9009
# Bit flips: 1809
# Hamming distance: 0
# **Test** MCC: 0.044. Val_Loss: 1.898
# ACC: 0.007.
# TPR: 0.208.
# F1-score: 0.046.
# Iteration Time 6.905 (6.708)
# **********************************
# attacked module: classifier
# attacked weight index: 419
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(512., device='cuda:0')
# attacked module: classifier
# Iteration: [010/040]   Attack Time 12.360 (12.507)
# Loss before attack: 1.9009
# Loss after attack: 1.9009
# Bit flips: 2010
# Hamming distance: 0
# **Test** MCC: 0.044. Val_Loss: 1.898
# ACC: 0.007.
# TPR: 0.208.
# F1-score: 0.045.
# Iteration Time 7.046 (6.742)
# **********************************
# attacked module: classifier
# attacked weight index: 322
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-65., device='cuda:0')
# attacked module: classifier
# Iteration: [011/040]   Attack Time 12.639 (12.519)
# Loss before attack: 1.9009
# Loss after attack: 1.9009
# Bit flips: 2211
# Hamming distance: 0
# **Test** MCC: 0.044. Val_Loss: 1.898
# ACC: 0.007.
# TPR: 0.208.
# F1-score: 0.046.
# Iteration Time 6.312 (6.703)
# **********************************
# attacked module: classifier
# attacked weight index: 203
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-4097., device='cuda:0')
# attacked module: classifier
# Iteration: [012/040]   Attack Time 11.433 (12.428)
# Loss before attack: 1.9009
# Loss after attack: 1.9009
# Bit flips: 2412
# Hamming distance: 0
# **Test** MCC: 0.044. Val_Loss: 1.898
# ACC: 0.007.
# TPR: 0.208.
# F1-score: 0.046.
# Iteration Time 5.944 (6.640)
# **********************************
# attacked module: classifier
# attacked weight index: 19
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-16385., device='cuda:0')
# attacked module: classifier
# Iteration: [013/040]   Attack Time 11.427 (12.351)
# Loss before attack: 1.9009
# Loss after attack: 1.9009
# Bit flips: 2613
# Hamming distance: 0
# **Test** MCC: 0.044. Val_Loss: 1.898
# ACC: 0.007.
# TPR: 0.208.
# F1-score: 0.046.
# Iteration Time 6.062 (6.595)
# **********************************
# attacked module: classifier
# attacked weight index: 258
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-8193., device='cuda:0')
# attacked module: classifier
# Iteration: [014/040]   Attack Time 11.513 (12.291)
# Loss before attack: 1.9009
# Loss after attack: 1.9009
# Bit flips: 2814
# Hamming distance: 0
# **Test** MCC: 0.044. Val_Loss: 1.898
# ACC: 0.007.
# TPR: 0.208.
# F1-score: 0.046.
# Iteration Time 6.028 (6.555)
# **********************************
# attacked module: classifier
# attacked weight index: 427
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(32767., device='cuda:0')
# attacked module: classifier
# Iteration: [015/040]   Attack Time 11.316 (12.226)
# Loss before attack: 0.9830
# Loss after attack: 0.9830
# Bit flips: 3015
# Hamming distance: 0
# **Test** MCC: 0.543. Val_Loss: 0.972
# ACC: 0.933.
# TPR: 0.590.
# F1-score: 0.377.
# Iteration Time 6.164 (6.529)
# **********************************
# attacked module: classifier
# attacked weight index: 463
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-2., device='cuda:0')
# attacked module: classifier
# Iteration: [016/040]   Attack Time 10.985 (12.149)
# Loss before attack: 0.9830
# Loss after attack: 0.9830
# Bit flips: 3216
# Hamming distance: 0
# **Test** MCC: 0.543. Val_Loss: 0.972
# ACC: 0.933.
# TPR: 0.590.
# F1-score: 0.377.
# Iteration Time 6.263 (6.512)
# **********************************
# attacked module: classifier
# attacked weight index: 160
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-129., device='cuda:0')
# attacked module: classifier
# Iteration: [017/040]   Attack Time 11.427 (12.106)
# Loss before attack: 0.9830
# Loss after attack: 0.9830
# Bit flips: 3417
# Hamming distance: 0
# **Test** MCC: 0.543. Val_Loss: 0.972
# ACC: 0.933.
# TPR: 0.590.
# F1-score: 0.377.
# Iteration Time 6.233 (6.496)
# **********************************
# attacked module: classifier
# attacked weight index: 107
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-3., device='cuda:0')
# attacked module: classifier
# Iteration: [018/040]   Attack Time 11.425 (12.068)
# Loss before attack: 0.9830
# Loss after attack: 0.9830
# Bit flips: 3618
# Hamming distance: 0
# **Test** MCC: 0.543. Val_Loss: 0.972
# ACC: 0.933.
# TPR: 0.590.
# F1-score: 0.377.
# Iteration Time 6.118 (6.475)
# **********************************
# attacked module: classifier
# attacked weight index: 217
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(32767., device='cuda:0')
# attacked module: classifier
# Iteration: [019/040]   Attack Time 11.485 (12.038)
# Loss before attack: 0.9830
# Loss after attack: 0.9830
# Bit flips: 3819
# Hamming distance: 0
# **Test** MCC: 0.543. Val_Loss: 0.972
# ACC: 0.933.
# TPR: 0.590.
# F1-score: 0.377.
# Iteration Time 6.084 (6.454)
# **********************************
# attacked module: classifier
# attacked weight index: 490
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(32., device='cuda:0')
# attacked module: classifier
# Iteration: [020/040]   Attack Time 11.411 (12.006)
# Loss before attack: 0.9830
# Loss after attack: 0.9830
# Bit flips: 4020
# Hamming distance: 0
# **Test** MCC: 0.543. Val_Loss: 0.972
# ACC: 0.933.
# TPR: 0.590.
# F1-score: 0.377.
# Iteration Time 5.917 (6.427)
# **********************************
# attacked module: classifier
# attacked weight index: 253
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(16., device='cuda:0')
# attacked module: classifier
# Iteration: [021/040]   Attack Time 10.788 (11.948)
# Loss before attack: 0.9830
# Loss after attack: 0.9830
# Bit flips: 4221
# Hamming distance: 0
# **Test** MCC: 0.543. Val_Loss: 0.972
# ACC: 0.933.
# TPR: 0.590.
# F1-score: 0.377.
# Iteration Time 5.562 (6.386)
# **********************************
# attacked module: classifier
# attacked weight index: 98
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-17., device='cuda:0')
# attacked module: classifier
# Iteration: [022/040]   Attack Time 11.706 (11.937)
# Loss before attack: 0.9830
# Loss after attack: 0.9830
# Bit flips: 4422
# Hamming distance: 0
# **Test** MCC: 0.543. Val_Loss: 0.972
# ACC: 0.933.
# TPR: 0.590.
# F1-score: 0.377.
# Iteration Time 5.914 (6.365)
# **********************************
# attacked module: classifier
# attacked weight index: 329
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-3., device='cuda:0')
# attacked module: classifier
# Iteration: [023/040]   Attack Time 11.445 (11.916)
# Loss before attack: 0.9830
# Loss after attack: 0.9830
# Bit flips: 4623
# Hamming distance: 0
# **Test** MCC: 0.543. Val_Loss: 0.972
# ACC: 0.933.
# TPR: 0.590.
# F1-score: 0.377.
# Iteration Time 6.272 (6.361)
# **********************************
# attacked module: classifier
# attacked weight index: 490
# weight before attack: tensor(32., device='cuda:0')
# weight after attack: tensor(16416., device='cuda:0')
# attacked module: classifier
# Iteration: [024/040]   Attack Time 11.132 (11.883)
# Loss before attack: 0.9830
# Loss after attack: 0.9830
# Bit flips: 4824
# Hamming distance: 0
# **Test** MCC: 0.263. Val_Loss: 0.972
# ACC: 0.933.
# TPR: 0.619.
# F1-score: 0.606.
# Iteration Time 6.364 (6.361)
# **********************************
# attacked module: classifier
# attacked weight index: 180
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(64., device='cuda:0')
# attacked module: classifier
# Iteration: [025/040]   Attack Time 10.947 (11.846)
# Loss before attack: 0.9830
# Loss after attack: 0.9830
# Bit flips: 5025
# Hamming distance: 0
# **Test** MCC: 0.263. Val_Loss: 0.972
# ACC: 0.933.
# TPR: 0.619.
# F1-score: 0.606.
# Iteration Time 6.262 (6.357)
# **********************************
# attacked module: classifier
# attacked weight index: 274
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-1025., device='cuda:0')
# attacked module: classifier
# Iteration: [026/040]   Attack Time 11.648 (11.838)
# Loss before attack: 0.9830
# Loss after attack: 0.9830
# Bit flips: 5226
# Hamming distance: 0
# **Test** MCC: 0.263. Val_Loss: 0.972
# ACC: 0.933.
# TPR: 0.619.
# F1-score: 0.606.
# Iteration Time 6.129 (6.348)
# **********************************
# attacked module: classifier
# attacked weight index: 281
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-1025., device='cuda:0')
# attacked module: classifier
# Iteration: [027/040]   Attack Time 11.393 (11.822)
# Loss before attack: 0.9830
# Loss after attack: 0.9830
# Bit flips: 5427
# Hamming distance: 0
# **Test** MCC: 0.263. Val_Loss: 0.972
# ACC: 0.933.
# TPR: 0.619.
# F1-score: 0.606.
# Iteration Time 6.058 (6.337)
# **********************************
# attacked module: classifier
# attacked weight index: 295
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(512., device='cuda:0')
# attacked module: classifier
# Iteration: [028/040]   Attack Time 11.037 (11.794)
# Loss before attack: 0.9830
# Loss after attack: 0.9830
# Bit flips: 5628
# Hamming distance: 0
# **Test** MCC: 0.263. Val_Loss: 0.972
# ACC: 0.933.
# TPR: 0.619.
# F1-score: 0.606.
# Iteration Time 6.133 (6.330)
# **********************************
# attacked module: classifier
# attacked weight index: 398
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-5., device='cuda:0')
# attacked module: classifier
# Iteration: [029/040]   Attack Time 11.480 (11.783)
# Loss before attack: 0.9830
# Loss after attack: 0.9830
# Bit flips: 5829
# Hamming distance: 0
# **Test** MCC: 0.263. Val_Loss: 0.972
# ACC: 0.933.
# TPR: 0.619.
# F1-score: 0.606.
# Iteration Time 6.011 (6.319)
# **********************************
# attacked module: classifier
# attacked weight index: 238
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-4097., device='cuda:0')
# attacked module: classifier
# Iteration: [030/040]   Attack Time 11.317 (11.767)
# Loss before attack: 0.9830
# Loss after attack: 0.9830
# Bit flips: 6030
# Hamming distance: 0
# **Test** MCC: 0.263. Val_Loss: 0.972
# ACC: 0.933.
# TPR: 0.619.
# F1-score: 0.606.
# Iteration Time 6.142 (6.313)
# **********************************
# attacked module: classifier
# attacked weight index: 69
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(8192., device='cuda:0')
# attacked module: classifier
# Iteration: [031/040]   Attack Time 10.965 (11.742)
# Loss before attack: 0.9830
# Loss after attack: 0.9830
# Bit flips: 6231
# Hamming distance: 0
# **Test** MCC: 0.263. Val_Loss: 0.972
# ACC: 0.933.
# TPR: 0.619.
# F1-score: 0.606.
# Iteration Time 6.211 (6.310)
# **********************************
# attacked module: classifier
# attacked weight index: 459
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-65., device='cuda:0')
# attacked module: classifier
# Iteration: [032/040]   Attack Time 11.108 (11.722)
# Loss before attack: 0.9830
# Loss after attack: 0.9830
# Bit flips: 6432
# Hamming distance: 0
# **Test** MCC: 0.263. Val_Loss: 0.972
# ACC: 0.933.
# TPR: 0.619.
# F1-score: 0.606.
# Iteration Time 6.064 (6.302)
# **********************************
# attacked module: classifier
# attacked weight index: 193
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-5., device='cuda:0')
# attacked module: classifier
# Iteration: [033/040]   Attack Time 10.927 (11.698)
# Loss before attack: 0.9830
# Loss after attack: 0.9830
# Bit flips: 6633
# Hamming distance: 0
# **Test** MCC: 0.263. Val_Loss: 0.972
# ACC: 0.933.
# TPR: 0.619.
# F1-score: 0.606.
# Iteration Time 6.179 (6.298)
# **********************************
# attacked module: classifier
# attacked weight index: 327
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-16385., device='cuda:0')
# attacked module: classifier
# Iteration: [034/040]   Attack Time 11.194 (11.683)
# Loss before attack: 0.9830
# Loss after attack: 0.9830
# Bit flips: 6834
# Hamming distance: 0
# **Test** MCC: 0.263. Val_Loss: 0.972
# ACC: 0.933.
# TPR: 0.619.
# F1-score: 0.606.
# Iteration Time 6.126 (6.293)
# **********************************
# attacked module: classifier
# attacked weight index: 496
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-65., device='cuda:0')
# attacked module: classifier
# Iteration: [035/040]   Attack Time 11.354 (11.673)
# Loss before attack: 0.9830
# Loss after attack: 0.9830
# Bit flips: 7035
# Hamming distance: 0
# **Test** MCC: 0.263. Val_Loss: 0.972
# ACC: 0.933.
# TPR: 0.619.
# F1-score: 0.606.
# Iteration Time 5.982 (6.284)
# **********************************
# attacked module: classifier
# attacked weight index: 77
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(8., device='cuda:0')
# attacked module: classifier
# Iteration: [036/040]   Attack Time 11.074 (11.657)
# Loss before attack: 0.9830
# Loss after attack: 0.9830
# Bit flips: 7236
# Hamming distance: 0
# **Test** MCC: 0.263. Val_Loss: 0.972
# ACC: 0.933.
# TPR: 0.619.
# F1-score: 0.606.
# Iteration Time 5.997 (6.276)
# **********************************
# attacked module: classifier
# attacked weight index: 497
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-33., device='cuda:0')
# attacked module: classifier
# Iteration: [037/040]   Attack Time 11.400 (11.650)
# Loss before attack: 0.9830
# Loss after attack: 0.9830
# Bit flips: 7437
# Hamming distance: 0
# **Test** MCC: 0.263. Val_Loss: 0.972
# ACC: 0.933.
# TPR: 0.619.
# F1-score: 0.606.
# Iteration Time 5.975 (6.268)
# **********************************
# attacked module: classifier
# attacked weight index: 362
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(2., device='cuda:0')
# attacked module: classifier
# Iteration: [038/040]   Attack Time 11.228 (11.639)
# Loss before attack: 0.9830
# Loss after attack: 0.9830
# Bit flips: 7638
# Hamming distance: 0
# **Test** MCC: 0.263. Val_Loss: 0.972
# ACC: 0.933.
# TPR: 0.619.
# F1-score: 0.606.
# Iteration Time 6.092 (6.264)
# **********************************
# attacked module: classifier
# attacked weight index: 437
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(32767., device='cuda:0')
# attacked module: classifier
# Iteration: [039/040]   Attack Time 11.040 (11.623)
# Loss before attack: 0.9830
# Loss after attack: 0.9830
# Bit flips: 7839
# Hamming distance: 0
# **Test** MCC: 0.263. Val_Loss: 0.972
# ACC: 0.933.
# TPR: 0.619.
# F1-score: 0.606.
# Iteration Time 6.235 (6.263)
# **********************************
# attacked module: classifier
# attacked weight index: 180
# weight before attack: tensor(64., device='cuda:0')
# weight after attack: tensor(192., device='cuda:0')
# attacked module: classifier
# Iteration: [040/040]   Attack Time 11.208 (11.613)
# Loss before attack: 0.9830
# Loss after attack: 0.9830
# Bit flips: 8040
# Hamming distance: 0
# **Test** MCC: 0.263. Val_Loss: 0.972
# ACC: 0.933.
# TPR: 0.619.
# F1-score: 0.606.
# Iteration Time 6.128 (6.260)
# Plot saved as CustomModel2/RandomFlip_to_PBS_attack/MCC_RandomFlip_to_PBS_attack.png
# Plot saved as CustomModel2/RandomFlip_to_PBS_attack/ACC_RandomFlip_to_PBS_attack.png
# Plot saved as CustomModel2/RandomFlip_to_PBS_attack/TPR_RandomFlip_to_PBS_attack.png
# Plot saved as CustomModel2/RandomFlip_to_PBS_attack/F1_RandomFlip_to_PBS_attack.png
# [Combined Plot] Saved as CustomModel2/RandomFlip_to_PBS_attack/combined_metrics_RandomFlip_to_PBS_attack.png
# MCC before attack: 0.2626
# Accuracy before attack: 0.93321
# TPR before attack: 0.61903
# F1-score before attack: 0.60636

# %%
'''
model_names = ["CustomModel", "CustomModel2"]
attack_types = ["PBS", "RandomFlip", "PBS_to_RandomFlip", "RandomFlip_to_PBS"]

def aggregate_results(model_name, attack_types):
    
    aggregate_dir = os.path.join(model_name, "Aggregate_Results")
    os.makedirs(aggregate_dir, exist_ok=True)

    results = []

    # Đọc kết quả từ từng kịch bản tấn công
    for attack_type in attack_types:
        csv_file_path = os.path.join(model_name, f"{attack_type}_attack", f"{attack_type}_attack.csv")
        if os.path.exists(csv_file_path):
            df = pd.read_csv(csv_file_path)
            
            mcc_values = df['MCC'].tolist()
            results.append(mcc_values)
        else:
            print(f"File {csv_file_path} không tồn tại.")

    # Ghi kết quả tổng hợp vào file CSV
    aggregate_df = pd.DataFrame(results, index=attack_types).T
    aggregate_csv_path = os.path.join(aggregate_dir, "aggregated_results.csv")
    aggregate_df.to_csv(aggregate_csv_path)

    # Vẽ đồ thị so sánh
    plt.figure(figsize=(10, 6))
    for i, attack_type in enumerate(attack_types):
        plt.plot(aggregate_df.index, aggregate_df[attack_type], marker='o', label=attack_type)

    plt.title(f'So sánh MCC giữa các kịch bản tấn công cho {model_name}', fontsize=14)
    plt.xlabel('Epoch', fontsize=12)
    plt.ylabel('MCC', fontsize=12)
    plt.grid(True, linestyle='--', alpha=0.7)
    plt.legend()
    plt.tight_layout()

    epochs = aggregate_df.index.astype(int).tolist()
    plt.xticks(epochs, epochs)
    
    plot_path = os.path.join(aggregate_dir, f"{model_name}_comparison_plot.png")
    plt.savefig(plot_path)
    plt.close()
    print(f"Đồ thị đã được lưu tại {plot_path}")

for model_name in model_names:
    aggregate_results(model_name, attack_types)
'''
# Out:
# Đồ thị đã được lưu tại CustomModel/Aggregate_Results/CustomModel_comparison_plot.png
# Đồ thị đã được lưu tại CustomModel2/Aggregate_Results/CustomModel2_comparison_plot.png

# %%
import seaborn as sns

# Cấu hình style đồ thị khoa học (phiên bản mới)
sns.set_style("whitegrid")  # Thay thế plt.style.use('seaborn')
sns.set_palette("husl")
plt.rcParams['font.family'] = 'DejaVu Sans, sans-serif'  # Font phù hợp

def plot_attack_comparison(model_names, attack_types):
    """Vẽ biểu đồ so sánh MCC giữa các phương pháp tấn công"""
    
    fig, axes = plt.subplots(1, 2, figsize=(18, 7), sharey=True)
    
    for idx, model_name in enumerate(model_names):
        # Đọc dữ liệu đã tổng hợp
        aggregate_path = os.path.join(model_name, "Aggregate_Results", "aggregated_results.csv")
        if not os.path.exists(aggregate_path):
            print(f"Không tìm thấy file tổng hợp cho {model_name}")
            continue
            
        df = pd.read_csv(aggregate_path, index_col=0)
        
        # Chuẩn bị dữ liệu vẽ
        df_melted = df.reset_index().melt(id_vars='index', 
                                         value_vars=attack_types,
                                         var_name='Attack Type',
                                         value_name='MCC')
        
        # Vẽ biểu đồ với seaborn
        sns.lineplot(data=df_melted, x='index', y='MCC', hue='Attack Type',
                     style='Attack Type', markers=True, dashes=False, 
                     ax=axes[idx], linewidth=2.5, markersize=8,
                     errorbar=None)  # Tắt confidence interval
        
        # Tùy chỉnh đồ thị
        axes[idx].set_title(f'{model_name} Performance Under Attack', fontsize=14, pad=20)
        axes[idx].set_xlabel('Attack Iteration', fontsize=12)
        axes[idx].set_ylabel('Matthews Correlation Coefficient', fontsize=12)
        axes[idx].grid(True, linestyle='--', alpha=0.6)
        axes[idx].legend(title='Attack Strategy', title_fontsize='12', fontsize=10)
        
        # Highlight điểm quan trọng
        min_mcc = df.min().min()
        axes[idx].axhline(y=min_mcc, color='r', linestyle='--', alpha=0.5)
        axes[idx].text(x=0, y=min_mcc+0.05, 
                      s=f'Min MCC: {min_mcc:.3f}', 
                      color='r', fontsize=10)

    # Lưu đồ thị
    output_dir = "Comparative_Analysis"
    os.makedirs(output_dir, exist_ok=True)
    output_path = os.path.join(output_dir, "Model_attack_comparison.png")
    
    plt.tight_layout()
    plt.savefig(output_path, dpi=300, bbox_inches='tight')
    plt.close()
    print(f"Đã lưu biểu đồ so sánh tại: {output_path}")

# Chạy hàm
model_names = ["CustomModel", "CustomModel2"] 
attack_types = ["PBS", "RandomFlip", "PBS_to_RandomFlip", "RandomFlip_to_PBS"]
plot_attack_comparison(model_names, attack_types)
# Out:
# /opt/tljh/user/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/tljh/user/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/tljh/user/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/tljh/user/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/tljh/user/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/tljh/user/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/tljh/user/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/tljh/user/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/tljh/user/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/tljh/user/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/tljh/user/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/tljh/user/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/tljh/user/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/tljh/user/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/tljh/user/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/tljh/user/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/tljh/user/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/tljh/user/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/tljh/user/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/tljh/user/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/tljh/user/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/tljh/user/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/tljh/user/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/tljh/user/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Đã lưu biểu đồ so sánh tại: Comparative_Analysis/Model_attack_comparison.png
