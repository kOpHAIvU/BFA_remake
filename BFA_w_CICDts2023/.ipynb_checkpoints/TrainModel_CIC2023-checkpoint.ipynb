# %%
from __future__ import division
from __future__ import absolute_import
import torch.nn.functional as F

import os, sys, random
import time
import copy
import torch
import torch.backends.cudnn as cudnn
import torchvision.datasets as dsetẢ
import torchvision.transforms as transforms
import pandas as pd
import numpy as np
from torch.utils.tensorboard import SummaryWriter
import logging
from sklearn.model_selection import train_test_split
from sklearn.metrics import matthews_corrcoef
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from sklearn.preprocessing import StandardScaler, LabelEncoder
import math
# Out:
# 2025-04-22 12:46:47.544598: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-04-22 12:46:47.544627: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-04-22 12:46:47.545398: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-22 12:46:47.550374: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
class RecorderMeter(object):
    """Computes and stores the minimum loss value and its epoch index, along with MCC"""

    def __init__(self, total_epoch):
        self.reset(total_epoch)

    def reset(self, total_epoch):
        assert total_epoch > 0
        self.total_epoch = total_epoch
        self.current_epoch = 0
        self.epoch_losses = np.zeros((self.total_epoch, 2), dtype=np.float32)  # [epoch, train/val]
        self.epoch_losses = self.epoch_losses - 1

        self.epoch_mcc = np.zeros((self.total_epoch, 2), dtype=np.float32)  # [epoch, train/val]
        self.epoch_mcc = self.epoch_mcc

    def update(self, idx, train_loss, train_mcc, val_loss, val_mcc):
        assert idx >= 0 and idx < self.total_epoch, 'total_epoch : {} , but update with the {} index'.format(
            self.total_epoch, idx)
        self.epoch_losses[idx, 0] = train_loss
        self.epoch_losses[idx, 1] = val_loss
        self.epoch_mcc[idx, 0] = train_mcc
        self.epoch_mcc[idx, 1] = val_mcc
        self.current_epoch = idx + 1

    def max_mcc(self, istrain):
        if self.current_epoch <= 0:
            return 0
        if istrain:
            return self.epoch_mcc[:self.current_epoch, 0].max()
        else:
            return self.epoch_mcc[:self.current_epoch, 1].max()

# %%
def time_string():
    ISOTIMEFORMAT = '%Y-%m-%d %X'
    string = '[{}]'.format(
        time.strftime(ISOTIMEFORMAT, time.gmtime(time.time())))
    return string


def convert_secs2time(epoch_time):
    need_hour = int(epoch_time / 3600)
    need_mins = int((epoch_time - 3600 * need_hour) / 60)
    need_secs = int(epoch_time - 3600 * need_hour - 60 * need_mins)
    return need_hour, need_mins, need_secs


def time_file_str():
    ISOTIMEFORMAT = '%Y-%m-%d'
    string = '{}'.format(time.strftime(ISOTIMEFORMAT,
                                       time.gmtime(time.time())))
    return string + '-{}'.format(random.randint(1, 10000))

# %% [markdown]
# ### Class quan_Linear

# %%
class quan_Linear(nn.Linear):
    def __init__(self, in_features, out_features, bias=True):
        super(quan_Linear, self).__init__(in_features, out_features, bias=bias)

        self.N_bits = 8
        self.full_lvls = 2**self.N_bits
        self.half_lvls = (self.full_lvls - 2) / 2
        # Initialize the step size
        self.step_size = nn.Parameter(torch.Tensor([1]), requires_grad=True)
        self.__reset_stepsize__()
        # flag to enable the inference with quantized weight or self.weight
        self.inf_with_weight = False  # disabled by default

        # create a vector to identify the weight to each bit
        self.b_w = nn.Parameter(2**torch.arange(start=self.N_bits - 1,
                                                end=-1,
                                                step=-1).unsqueeze(-1).float(),
                                requires_grad=False)

        self.b_w[0] = -self.b_w[0]  #in-place reverse

    def forward(self, input):
        if self.inf_with_weight:
            return F.linear(input, self.weight * self.step_size, self.bias)
        else:
            self.__reset_stepsize__()
            weight_quan = quantize(self.weight, self.step_size,
                                   self.half_lvls) * self.step_size
            return F.linear(input, weight_quan, self.bias)

    def __reset_stepsize__(self):
        with torch.no_grad():
            self.step_size.data = self.weight.abs().max() / self.half_lvls

    def __reset_weight__(self):
        '''
        This function will reconstruct the weight stored in self.weight.
        Replacing the orginal floating-point with the quantized fix-point
        weight representation.
        '''
        # replace the weight with the quantized version
        with torch.no_grad():
            self.weight.data = quantize(self.weight, self.step_size,
                                        self.half_lvls)
        # enable the flag, thus now computation does not invovle weight quantization
        self.inf_with_weight = True

# %% [markdown]
# ### Class quan_Conv1d

# %%
class quan_Conv1d(nn.Conv1d):
    def __init__(self,
                 in_channels,
                 out_channels,
                 kernel_size,
                 stride=1,
                 padding=1,
                 dilation=1,
                 groups=1,
                 bias=True):
        super(quan_Conv1d, self).__init__(in_channels,
                                          out_channels,
                                          kernel_size,
                                          stride=stride,
                                          padding=padding,
                                          dilation=dilation,
                                          groups=groups,
                                          bias=bias)

        # Số lượng bit để lượng tử hóa trọng số
        self.N_bits = 8
        self.full_lvls = 2 ** self.N_bits
        self.half_lvls = (self.full_lvls - 2) / 2

        # Bước lượng tử hóa (step size), là một tham số có thể học được
        self.step_size = nn.Parameter(torch.Tensor([1]), requires_grad=True)
        self.__reset_stepsize__()

        # Cờ để bật hoặc tắt sử dụng trọng số lượng tử hóa
        self.inf_with_weight = False  # Tắt theo mặc định

        # Tạo một vector để biểu diễn trọng số cho từng bit
        self.b_w = nn.Parameter(2 ** torch.arange(start=self.N_bits - 1,
                                                  end=-1,
                                                  step=-1).unsqueeze(-1).float(),
                                requires_grad=False)
        self.b_w[0] = -self.b_w[0]  # Biến đổi MSB thành giá trị âm để hỗ trợ bù hai

    def __reset_stepsize__(self):
        """Hàm này dùng để đặt lại giá trị `step_size`."""
        # Giá trị này có thể được tùy chỉnh tùy thuộc vào yêu cầu của mô hình
        self.step_size.data.fill_(1.0)

    def forward(self, x):
        # Kiểm tra cờ `inf_with_weight` để quyết định sử dụng trọng số đã lượng tử hóa hay không
        if self.inf_with_weight:
            quantized_weight = self.quantize_weight(self.weight)
            return nn.functional.conv1d(x, quantized_weight, self.bias, self.stride,
                                        self.padding, self.dilation, self.groups)
        else:
            return nn.functional.conv1d(x, self.weight, self.bias, self.stride,
                                        self.padding, self.dilation, self.groups)

    def quantize_weight(self, weight):
        """Lượng tử hóa trọng số theo số bit đã định."""
        # Tạo trọng số lượng tử hóa bằng cách sử dụng step_size
        quantized_weight = torch.round(weight / self.step_size) * self.step_size
        quantized_weight = torch.clamp(quantized_weight, -self.half_lvls * self.step_size,
                                       (self.half_lvls - 1) * self.step_size)
        return quantized_weight

# %%
def change_quan_bitwidth(model, n_bit):
    '''This script change the quantization bit-width of entire model to n_bit'''
    for m in model.modules():
        if isinstance(m, quan_Conv1d) or isinstance(m, quan_Linear):
            m.N_bits = n_bit
            # print("Change weight bit-width as {}.".format(m.N_bits))
            m.b_w.data = m.b_w.data[-m.N_bits:]
            m.b_w[0] = -m.b_w[0]
            print(m.b_w)
    return

# %%
class _quantize_func(torch.autograd.Function):
    @staticmethod
    def forward(ctx, input, step_size, half_lvls):
        # ctx is a context object that can be used to stash information
        # for backward computation
        ctx.step_size = step_size
        ctx.half_lvls = half_lvls
        output = F.hardtanh(input,
                            min_val=-ctx.half_lvls * ctx.step_size.item(),
                            max_val=ctx.half_lvls * ctx.step_size.item())

        output = torch.round(output / ctx.step_size)
        return output

    @staticmethod
    def backward(ctx, grad_output):
        grad_input = grad_output.clone() / ctx.step_size

        return grad_input, None, None

quantize = _quantize_func.apply

# %%
class _bin_func(torch.autograd.Function):

    @staticmethod
    def forward(ctx, input, mu):
        ctx.mu = mu
        output = input.clone().zero_()
        output[input.ge(0)] = 1
        output[input.lt(0)] = -1

        return output

    @staticmethod
    def backward(ctx, grad_output):
        grad_input = grad_output.clone() / ctx.mu
        return grad_input, None

w_bin = _bin_func.apply

# %%
def quantize(tensor, step_size, half_lvls):
    """Quantization function."""
    return torch.clamp(torch.round(tensor / step_size), min=-half_lvls, max=half_lvls)

# %% [markdown]
# ### Class CustomBlock

# %%
class CustomBlock(nn.Module):
    def __init__(self, in_features, out_features, bias=True, apply_softmax=False):
        super(CustomBlock, self).__init__()
        self.N_bits = 16
        self.full_lvls = 2 ** self.N_bits
        self.half_lvls = (self.full_lvls - 2) / 2
        self.apply_softmax = apply_softmax

        # Initialize the step size
        self.step_size = nn.Parameter(torch.Tensor([1]), requires_grad=True)

        # Initialize weights and bias
        self.weight = nn.Parameter(torch.Tensor(out_features, in_features))
        self.bias = nn.Parameter(torch.Tensor(out_features)) if bias else None

        # Reset parameters
        self.__reset_stepsize__()
        self.reset_parameters()

        # Flag for inference with quantized weights
        self.inf_with_weight = False

        self.b_w = nn.Parameter(2**torch.arange(start=self.N_bits - 1,
                                             end=-1,
                                             step=-1).unsqueeze(-1).float(),
                           requires_grad=False)
        self.b_w[0] = -self.b_w[0]  #in-place reverse
        
    def reset_parameters(self):
        nn.init.kaiming_uniform_(self.weight, a=5 ** 0.5)
        if self.bias is not None:
            nn.init.zeros_(self.bias)

    def forward(self, input):
        if self.inf_with_weight:
            weight_applied = self.weight * self.step_size
        else:
            self.__reset_stepsize__()
            weight_quan = quantize(self.weight, self.step_size, self.half_lvls) * self.step_size
            weight_applied = weight_quan

        # Linear transformation
        input = input.view(input.size(0), -1)  # Flatten input to 2D for matmul
        output = input @ weight_applied.T
        if self.bias is not None:
            output += self.bias

        if self.apply_softmax:
            output = F.softmax(output, dim=-1)
        return output

    def __reset_stepsize__(self):
        with torch.no_grad():
            self.step_size.data = self.weight.abs().max() / self.half_lvls

    def __reset_weight__(self):
        with torch.no_grad():
            self.weight.data = quantize(self.weight, self.step_size, self.half_lvls)
        self.inf_with_weight = True

# %%
class DownsampleA(nn.Module):
    def __init__(self, nIn, nOut, stride):
        super(DownsampleA, self).__init__()
        assert stride == 2
        self.avg = nn.AvgPool1d(kernel_size=1, stride=stride)

    def forward(self, x):
        x = self.avg(x)
        return torch.cat((x, x.mul(0)), 1)
        
class SEBlock(nn.Module):
    expansion = 1

    def __init__(self, inplanes, planes, stride=1, downsample=None):
        super(SEBlock, self).__init__()
        self.conv_a = quan_Conv1d(inplanes, planes, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn_a = nn.BatchNorm1d(planes)
        self.dropout_a = nn.Dropout(p=0.3)  # Dropout sau BatchNorm

        self.conv_b = quan_Conv1d(planes, planes, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn_b = nn.BatchNorm1d(planes)
        self.dropout_b = nn.Dropout(p=0.3)  # Dropout sau BatchNorm

        self.downsample = downsample

    def forward(self, x):
        residual = x
        
        basicblock = self.conv_a(x)
        basicblock = self.bn_a(basicblock)
        basicblock = F.relu(basicblock, inplace=True)
        basicblock = self.dropout_a(basicblock)  # Áp dụng dropout

        basicblock = self.conv_b(basicblock)
        basicblock = self.bn_b(basicblock)
        basicblock = self.dropout_b(basicblock)  # Áp dụng dropout

        if self.downsample:
            residual = self.downsample(x)

        return F.relu(residual + basicblock, inplace=True)

# %% [markdown]
# ### Class CustomModel

# %%
class CustomModel(nn.Module):
    def __init__(self, input_size=39, hidden_sizes=[32, 64, 128, 256, 512], output_size=34):
        super(CustomModel, self).__init__()
        self.fc1 = quan_Conv1d(input_size, hidden_sizes[0], kernel_size=3, stride=1, padding=1)
        self.bn_1 = nn.BatchNorm1d(hidden_sizes[0])

        self.inplanes = 32
        self.stage_1 = self._make_layer(SEBlock, 32, 16, 1)
        self.stage_2 = self._make_layer(SEBlock, 64, 16, 2)
        self.stage_3 = self._make_layer(SEBlock, 128, 16, 2)
        self.avgpool = nn.AdaptiveAvgPool1d(1)

        self.classifier = CustomBlock(128 * SEBlock.expansion, output_size)

        for m in self.modules():
            if isinstance(m, nn.Conv1d):
                n = m.kernel_size[0] * m.out_channels
                m.weight.data.normal_(0, math.sqrt(2. / n))
                #m.bias.data.zero_()
            elif isinstance(m, nn.BatchNorm1d):
                m.weight.data.fill_(1)
                m.bias.data.zero_()
            elif isinstance(m, nn.Linear):
                init.kaiming_normal(m.weight)
                m.bias.data.zero_()
        
    def _make_layer(self, block, planes, blocks, stride=1):
        downsample = None
        downsample = None
        if stride == 2 or self.inplanes != planes * SEBlock.expansion:
            downsample = DownsampleA(self.inplanes, planes * SEBlock.expansion, stride) if stride == 2 else None

        layers = []
        layers.append(block(self.inplanes, planes, stride=1, downsample=downsample))
        self.inplanes = planes * SEBlock.expansion
        for i in range(1, blocks):
            layers.append(block(self.inplanes, planes))

        return nn.Sequential(*layers)
    def forward(self, x):
        x = self.fc1(x)
        x = F.relu(self.bn_1(x), inplace=True)
        
        x = self.stage_1(x)
        x = self.stage_2(x)
        x = self.stage_3(x)

        x = self.avgpool(x)
        x = x.view(x.size(0), -1)
        return self.classifier(x)

# %% [markdown]
# ### Class CustomModel2

# %%
class CustomModel2(nn.Module):
    def __init__(self, input_size=39, hidden_sizes=[32, 64, 128, 100], output_size=34):
        super(CustomModel2, self).__init__()
        self.hidden_sizes = hidden_sizes

        # Define layers
        self.fc1 = nn.Conv1d(input_size, hidden_sizes[0], kernel_size=3, stride=2, padding=1)
        self.pool = nn.AdaptiveMaxPool1d(1)
        self.activation = nn.ReLU()
        self.dropout = nn.Dropout(0.1)
        
        self.stage_1 = nn.Conv1d(hidden_sizes[0], hidden_sizes[1], kernel_size=3, stride=2, padding=1)
        self.stage_2 = nn.Conv1d(hidden_sizes[1], hidden_sizes[2], kernel_size=3, stride=2, padding=1)
        self.stage_3 = nn.Conv1d(hidden_sizes[2], hidden_sizes[3], kernel_size=3, stride=2, padding=1)

        # Global Pooling
        self.global_pool = nn.AdaptiveAvgPool1d(1)

        # Classifier
        self.classifier = CustomBlock(hidden_sizes[-1], output_size, apply_softmax=True)
        nn.Dropout(0.15)
        
    def forward(self, x):
        # Pass through layers
        x = self.fc1(x)
        x = self.activation(self.pool(x))

        x = self.stage_1(x)
        x = self.activation(self.pool(x))

        x = self.stage_2(x)
        x = self.activation(self.pool(x))

        x = self.stage_3(x)
        x = self.activation(self.pool(x))

        # Global Pooling
        x = self.global_pool(x)
        x = x.view(x.size(0), -1)  # Flatten
        return self.classifier(x)

# %% [markdown]
# ### Init dataset

# %%
class Args:
    def __init__(self):
        self.arch = 'CustomModel'
        self.data_path = '../../dataset/'
        self.dataset = 'inid'
        self.save_path = './save/attack_random'
        self.epochs = 20
        self.optimizer = 'SGD'
        self.test_batch_size = 32
        self.learning_rate = 0.001
        self.momentum = 0.9
        self.decay = 1e-4
        self.schedule = [80, 120]
        self.gammas = [0.1, 0.1]
        self.print_freq = 100
        self.resume = 'save\model_best.pth.tar'
        self.start_epoch = 0
        self.enable_bfa = False
        self.evaluate = False
        self.ngpu = 1
        self.gpu_id = 0
        self.workers = 4
        self.manualSeed = None
        self.quan_bitwidth = 16
        self.reset_weight = False
        self.bfa = True
        self.attack_sample_size = 128
        self.n_iter = 25
        self.k_top = None
        self.random_bfa = True
        self.progressive_bit_search= True
        self.random_flip = True
        self.clustering = False
        self.lambda_coeff = 1e-3
        self.use_cuda = True  

args = Args()
args.use_cuda = torch.cuda.is_available()

# %%
# Thiết lập cấu hình logging
logging.basicConfig(level=logging.INFO, format='%(message)s')
logger = logging.getLogger()

# Init logger
if not os.path.isdir(args.save_path):
    os.makedirs(args.save_path)

# Tạo tệp log
log_file_path = os.path.join(args.save_path, 'log_seed_{}.txt'.format(args.manualSeed))
file_handler = logging.FileHandler(log_file_path)
file_handler.setLevel(logging.INFO)

# Định dạng cho tệp log
formatter = logging.Formatter('%(asctime)s - %(message)s')
file_handler.setFormatter(formatter)

# Thêm file handler vào logger
logger.addHandler(file_handler)

# Ghi log vào console và tệp
logger.info('Save path: {}'.format(args.save_path))
state = {k: getattr(args, k) for k in dir(args) if not k.startswith('__')}
logger.info('State: {}'.format(state))
logger.info("Random Seed: {}".format(args.manualSeed))
logger.info("Python version: {}".format(sys.version.replace('\n', ' ')))
logger.info("Torch version: {}".format(torch.__version__))
logger.info("CUDNN version: {}".format(torch.backends.cudnn.version()))

# Init the tensorboard path and writer
tb_path = os.path.join(args.save_path, 'tb_log', 'run_' + str(args.manualSeed))
writer = SummaryWriter(tb_path)
# Out:
# Save path: ./save/attack_random
# State: {'arch': 'CustomModel', 'attack_sample_size': 128, 'bfa': True, 'clustering': False, 'data_path': '../../dataset/', 'dataset': 'inid', 'decay': 0.0001, 'enable_bfa': False, 'epochs': 20, 'evaluate': False, 'gammas': [0.1, 0.1], 'gpu_id': 0, 'k_top': None, 'lambda_coeff': 0.001, 'learning_rate': 0.001, 'manualSeed': None, 'momentum': 0.9, 'n_iter': 25, 'ngpu': 1, 'optimizer': 'SGD', 'print_freq': 100, 'progressive_bit_search': True, 'quan_bitwidth': 16, 'random_bfa': True, 'random_flip': True, 'reset_weight': False, 'resume': 'save\\model_best.pth.tar', 'save_path': './save/attack_random', 'schedule': [80, 120], 'start_epoch': 0, 'test_batch_size': 32, 'use_cuda': True, 'workers': 4}
# Random Seed: None
# Python version: 3.10.14 | packaged by conda-forge | (main, Mar 20 2024, 12:45:18) [GCC 12.3.0]
# Torch version: 2.2.2+cu118
# CUDNN version: 8907

# %%
# Init dataset
if not os.path.isdir(args.data_path):
    os.makedirs(args.data_path)

if args.dataset == 'inid':
    print("Inid dataset import sucsess!")
else:
    assert False, "Unknow dataset : {}".format(args.dataset)
# Out:
# Inid dataset import sucsess!

# %%
# Init dataset
if args.dataset == 'inid':
    data = pd.read_csv("../../dataset/CIC_IoT_Dataset2023.csv", skipinitialspace=True)
    
    # Remove duplicates and handle NaN values
    data = data.drop(columns=['Cat'])
    data = data.drop_duplicates()
    data.replace([np.inf, -np.inf], np.nan, inplace=True)
    data.fillna(0, inplace=True)
    
    # Separate labels and data
    datalabel = data[['Label']]
    data = data.drop(columns=['Label'])
    
    # Normalize numerical columns
    scaler = StandardScaler()
    data[['Header_Length', 'Protocol Type', 'Time_To_Live', 'Rate']] = scaler.fit_transform(
        data[['Header_Length', 'Protocol Type', 'Time_To_Live', 'Rate']]
    )
    
    # Label Encoding
    onc = LabelEncoder()
    y = onc.fit_transform(datalabel['Label'].to_numpy().reshape(-1, 1))
    
    # Split data into training and testing sets
    X_train, X_test, y_train, y_test = train_test_split(data, y, test_size=0.2, random_state=100)
    
    # Normalize X_train and X_test
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)
    
    # Convert y_train and y_test to Tensor
    y_train = torch.LongTensor(y_train)
    y_test = torch.LongTensor(y_test)
    
    # Check data types
    print("Data type of y_train:", y_train.shape)
    print("Data type of y_test:", y_test.shape)
    
    # Create DataLoader for training set
    train_loader = DataLoader(
        torch.utils.data.TensorDataset(
            torch.FloatTensor(X_train),
            y_train
        ),
        batch_size=256,
        num_workers=5,
        shuffle=True,
        pin_memory=True 
    )
    
    # Create DataLoader for testing set
    test_loader = DataLoader(
        torch.utils.data.TensorDataset(
            torch.FloatTensor(X_test),
            y_test
        ),
        batch_size=256,
        num_workers=5,
        shuffle=False,
        pin_memory=True 
    )
else:
    # Code for other datasets
    train_loader = torch.utils.data.DataLoader(
        train_data,
        batch_size=args.attack_sample_size,
        shuffle=True,
        num_workers=args.workers,
        pin_memory=True 
    )
    test_loader = torch.utils.data.DataLoader(
        test_data,
        batch_size=args.test_batch_size,
        shuffle=False,
        num_workers=args.workers,
        pin_memory=True 
    )

logger.info("=> creating model '{}'".format(args.arch))
data
# Out:
# /opt/tljh/user/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# => creating model 'CustomModel'
# Data type of y_train: torch.Size([435954])
# Data type of y_test: torch.Size([108989])
#         Header_Length  Protocol Type  Time_To_Live      Rate  fin_flag_number  \
# 0            0.672433      -0.384137     -0.241073  0.033427             0.00
# 1           -1.615759       3.780463     -0.201938 -0.679955             0.00
# 2           -0.705996       0.733195     -0.085147 -0.166566             0.00
# 3            0.727570      -0.384137      2.641403 -0.790616             0.10
# 4           -1.579001      -0.892015     -0.204384  0.131488             0.00
# ...               ...            ...           ...       ...              ...
# 712305      -1.606570       3.780463      0.148435 -0.699755             0.00
# 712306       0.681623      -0.384137     -0.201938  0.267584             0.00
# 712307      -0.696806       0.733195     -0.201938  0.777507             0.00
# 712308       0.681623      -0.384137      0.031644 -0.461580             0.98
# 712309       0.681623      -0.384137     -0.201938 -0.049287             0.00
#
#         syn_flag_number  rst_flag_number  psh_flag_number  ack_flag_number  \
# 0                   0.0             0.00             0.99             0.99
# 1                   0.0             0.00             0.00             0.00
# 2                   0.0             0.00             0.00             0.00
# 3                   0.0             0.30             0.20             0.40
# 4                   0.0             0.00             0.00             0.01
# ...                 ...              ...              ...              ...
# 712305              0.0             0.00             0.00             0.00
# 712306              1.0             0.00             0.00             0.00
# 712307              0.0             0.00             0.00             0.00
# 712308              0.0             0.98             0.01             0.02
# 712309              1.0             0.00             0.00             0.00
#
#         ece_flag_number  ...   LLC  Tot sum  Min   Max     AVG         Std  \
# 0                   0.0  ...  0.99     6421   60   481   64.21   42.100000
# 1                   0.0  ...  1.00    57320   98   578  573.20   48.000000
# 2                   0.0  ...  1.00     6010   60    70   60.10    1.000000
# 3                   0.0  ...  0.90     2223   54  1500  222.30  451.596686
# 4                   0.0  ...  1.00     6006   60    66   60.06    0.600000
# ...                 ...  ...   ...      ...  ...   ...     ...         ...
# 712305              0.0  ...  1.00    56436   70   578  564.36   79.049086
# 712306              0.0  ...  1.00     6000   60    60   60.00    0.000000
# 712307              0.0  ...  1.00     6000   60    60   60.00    0.000000
# 712308              0.0  ...  1.00     6061   60   121   60.61    6.100000
# 712309              0.0  ...  1.00     6000   60    60   60.00    0.000000
#
#         Tot size       IAT  Number       Variance
# 0          64.21  0.000039     100    1772.410000
# 1         573.20  0.000271     100    2304.000000
# 2          60.10  0.000057     100       1.000000
# 3         222.30  0.004766      10  203939.566667
# 4          60.06  0.000035     100       0.360000
# ...          ...       ...     ...            ...
# 712305    564.36  0.000325     100    6248.757980
# 712306     60.00  0.000034     100       0.000000
# 712307     60.00  0.000020     100       0.000000
# 712308     60.61  0.000102     100      37.210000
# 712309     60.00  0.000048     100       0.000000
#
# [544943 rows x 39 columns]

# %%
def mcc_score(preds, targets):
    preds = preds.cpu().numpy()
    targets = targets.cpu().numpy()
    return matthews_corrcoef(targets, preds)

# %%
def mcc2(outputs_label, outputs_cat, y_label_batch, y_cat_batch):
    """Compute MCC for each output of the model (label, category)."""
    with torch.no_grad():
        # Ensure target has at least one dimension
        if y_label_batch.dim() == 0:
            y_label_batch = y_label_batch.unsqueeze(0)
        if y_cat_batch.dim() == 0:
            y_cat_batch = y_cat_batch.unsqueeze(0)

        # Get the predicted classes (top-1 prediction) for each output
        _, pred_label = outputs_label.topk(1, 1, True, True)
        _, pred_cat = outputs_cat.topk(1, 1, True, True)

        # Compute MCC for each output type
        mcc_label = mcc_score(pred_label.view(-1), y_label_batch)
        mcc_cat = mcc_score(pred_cat.view(-1), y_cat_batch)

        return mcc_label, mcc_cat


def mcc(output, target):
    """Compute the Matthews Correlation Coefficient (MCC) for the given output and target."""
    with torch.no_grad():
        # Ensure target has at least one dimension
        if target.dim() == 0:
            target = target.unsqueeze(0)

        # Get the predicted classes (top-1 prediction)
        _, pred = output.topk(1, 1, True, True)
        return mcc_score(pred.view(-1), target)

# %%
class AverageMeter(object):
    """Computes and stores the average and current value"""

    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

# %% [markdown]
# ### Train dataset

# %%
torch.cuda.empty_cache()
def train(train_loader, model, criterion, optimizer, epoch):
    batch_time = AverageMeter()
    data_time = AverageMeter()
    losses = AverageMeter()
    mcc_meter = AverageMeter()  # Track MCC instead of accuracy

    # Switch to train mode
    model.train()

    end = time.time()
    for i, (input, target) in enumerate(train_loader):
        # Measure data loading time
        data_time.update(time.time() - end)

        if args.use_cuda:
            input = input.cuda(non_blocking=True)
            target = target.cuda(non_blocking=True)
            
        input = input.view(input.size(0), 39, -1)  # Reshape input
        
        # Compute output and loss
        output = model(input)
        loss = criterion(output, target)

        if args.clustering:
            loss += clustering_loss(model, args.lambda_coeff)

        # Compute MCC and record loss
        mcc_value = mcc(output.data, target)  # MCC calculation instead of topk accuracy
        losses.update(loss.item(), input.size(0))
        mcc_meter.update(mcc_value, input.size(0))

        # Compute gradient and do SGD step
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # Measure elapsed time
        batch_time.update(time.time() - end)
        end = time.time()

    return mcc_meter.avg, losses.avg


def validate(val_loader, model, criterion, summary_output=True):
    losses = AverageMeter()
    mcc_meter = AverageMeter()
    acc_meter = AverageMeter()
    tpr_meter = AverageMeter()
    f1_meter = AverageMeter()

    # Chuyển model sang chế độ đánh giá
    model.eval()
    output_summary = []

    with torch.no_grad():
        for i, (input, target) in enumerate(test_loader):
            if input.size(1) == 39 and input.dim() == 2:  # Kiểm tra nếu thiếu chiều thứ 3
                input = input.unsqueeze(-1)

            if torch.cuda.is_available() and args.use_cuda:
                target = target.cuda(non_blocking=True)
                input = input.cuda(non_blocking=True)

            # Tính toán output và loss
            output = model(input)
            pred = torch.argmax(output, dim=1)  # Chọn nhãn dự đoán có xác suất cao nhất
            loss = criterion(output, target)
            losses.update(loss.item(), input.size(0))  # Cập nhật losses

            # Chuyển sang numpy để tính toán các chỉ số
            pred_np = pred.cpu().numpy()
            target_np = target.cpu().numpy()

            if summary_output:
                tmp_list = output.max(1, keepdim=True)[1].flatten().cpu().numpy() # get the index of the max log-probability
                output_summary.append(tmp_list)

            # Tính các chỉ số đánh giá
            mcc_value = matthews_corrcoef(target_np, pred_np)
            acc_value = accuracy_score(target_np, pred_np)
            tpr_value = recall_score(target_np, pred_np, average='macro')  # Macro recall ~ TPR
            f1_value = f1_score(target_np, pred_np, average='macro')

            # Cập nhật giá trị trung bình
            mcc_meter.update(mcc_value, input.size(0))
            acc_meter.update(acc_value, input.size(0))
            tpr_meter.update(tpr_value, input.size(0))
            f1_meter.update(f1_value, input.size(0))

    return mcc_meter.avg, acc_meter.avg, tpr_meter.avg, f1_meter.avg, losses.avg, output_summary

# %% [markdown]
# ### Test dataset

# %%
from sklearn.metrics import matthews_corrcoef, accuracy_score, recall_score, f1_score
import warnings
from sklearn.exceptions import UndefinedMetricWarning

# Tắt cảnh báo UndefinedMetricWarning
warnings.filterwarnings("ignore", category=UndefinedMetricWarning)

def validate_score(model, test_loader):
    losses = AverageMeter()
    mcc_meter = AverageMeter()
    acc_meter = AverageMeter()
    tpr_meter = AverageMeter()
    f1_meter = AverageMeter()

    with torch.no_grad():
        for i, (input, target) in enumerate(test_loader):
            if input.size(1) == 39 and input.dim() == 2:  # Kiểm tra nếu thiếu chiều thứ 3
                input = input.unsqueeze(-1)

            if torch.cuda.is_available() and args.use_cuda:
                target = target.cuda(non_blocking=True)
                input = input.cuda(non_blocking=True)

            # Tính toán output và loss
            output = model(input)
            pred = torch.argmax(output, dim=1)  # Chọn nhãn dự đoán có xác suất cao nhất

            # Chuyển sang numpy để tính toán các chỉ số
            pred_np = pred.cpu().numpy()
            target_np = target.cpu().numpy()

            # Tính các chỉ số đánh giá
            mcc_value = matthews_corrcoef(target_np, pred_np)
            acc_value = accuracy_score(target_np, pred_np)
            tpr_value = recall_score(target_np, pred_np, average='macro')  # Macro recall ~ TPR
            f1_value = f1_score(target_np, pred_np, average='macro')

            # Cập nhật giá trị trung bình
            mcc_meter.update(mcc_value, input.size(0))
            acc_meter.update(acc_value, input.size(0))
            tpr_meter.update(tpr_value, input.size(0))
            f1_meter.update(f1_value, input.size(0))

    return {
        "MCC": mcc_meter.avg,
        "Accuracy": acc_meter.avg,
        "TPR": tpr_meter.avg,
        "F1 Score": f1_meter.avg
    }

# %% [markdown]
# ### class BFA

# %%
class BFA(object):
    def __init__(self, criterion, model, k_top=10):
        self.criterion = criterion
        self.loss_dict = {}
        self.bit_counter = 0
        self.k_top = k_top
        self.n_bits2flip = 0
        self.loss = 0
        self.num_bit_flipped = 0
        
        # Attributes for random attack
        self.module_list = []

        for name, m in model.named_modules():
            if isinstance(m, (quan_Conv1d, quan_Linear, CustomBlock)):
                self.module_list.append(name)

    def flip_bit(self, m):
        '''
        the data type of input param is 32-bit floating, then return the data should
        be in the same data_type.
        '''
        if self.k_top is None:
            k_top = m.weight.detach().flatten().__len__()
        else: 
            k_top = self.k_top
        # 1. flatten the gradient tensor to perform topk
        w_grad_topk, w_idx_topk = m.weight.grad.detach().abs().view(-1).topk(k_top)
        # update the b_grad to its signed representation
        w_grad_topk = m.weight.grad.detach().view(-1)[w_idx_topk]

        # 2. create the b_grad matrix in shape of [N_bits, k_top]
        b_grad_topk = w_grad_topk * m.b_w.data

        # 3. generate the gradient mask to zero-out the bit-gradient
        # which can not be flipped
        b_grad_topk_sign = (b_grad_topk.sign() +
                            1) * 0.5  # zero -> negative, one -> positive
        # convert to twos complement into unsigned integer
        w_bin = int2bin(m.weight.detach().view(-1), m.N_bits).short()
        w_bin_topk = w_bin[w_idx_topk]  # get the weights whose grads are topk
        
        # generate two's complement bit-map
        b_bin_topk = (w_bin_topk.repeat(m.N_bits, 1) & m.b_w.abs().repeat(1, k_top).short()) \
           // m.b_w.abs().repeat(1, k_top).short()

        grad_mask = b_bin_topk ^ b_grad_topk_sign.short()

        # 4. apply the gradient mask upon ```b_grad_topk``` and in-place update it
        b_grad_topk *= grad_mask.float()

        # 5. identify the several maximum of absolute bit gradient and return the index, the number of bits to flip is self.n_bits2flip

        grad_max = b_grad_topk.abs().max()
        num_elements = b_grad_topk.nelement()  # Get the total number of elements
        k = min(self.n_bits2flip, num_elements)  # Clamp the value of k
    
        _, b_grad_max_idx = b_grad_topk.abs().view(-1).topk(k)  # Use clamped k
        bit2flip = b_grad_topk.clone().view(-1).zero_()

        if grad_max.item() != 0:  # ensure the max grad is not zero
            bit2flip[b_grad_max_idx] = 1
            bit2flip = bit2flip.view(b_grad_topk.size())
        else:
            pass

        # 6. Based on the identified bit indexed by ```bit2flip```, generate another
        # mask, then perform the bitwise xor operation to realize the bit-flip.
        bit2flip = bit2flip.reshape(m.b_w.abs().shape[0], -1)  # Định hình lại

        w_bin_topk_flipped = (bit2flip.short() * m.b_w.abs().short()).sum(0, dtype=torch.int16) \
            ^ w_bin_topk

        # 7. update the weight in the original weight tensor
        w_bin[w_idx_topk] = w_bin_topk_flipped  # in-place change
        param_flipped = bin2int(w_bin,
                                m.N_bits).view(m.weight.data.size()).float()

        return param_flipped

    def progressive_bit_search(self, model, data, target, test_loader):
        ''' 
        Given the model, based on the current data and target, go through
        all the layers and identify the bits to be flipped. 
        '''
        model.eval()
        output = model(data)
        self.loss = self.criterion(output, target)
    
        # Zero out the grads first, then get the grads
        for m in model.modules():
            if isinstance(m, (quan_Conv1d, quan_Linear, CustomBlock)):
                if m.weight.grad is not None:
                    m.weight.grad.data.zero_()
    
        self.loss.backward()
        self.loss_max = self.loss.item()
        attack_log = []
        max_loss_module = None
    
        # 3. Flip bits until no further loss degradation is observed
        while self.loss_max <= self.loss.item():
            self.n_bits2flip += 1
            self.loss_dict = {}
    
            for name, module in model.named_modules():
                if isinstance(module, CustomBlock) or isinstance(module, quan_Conv1d):
                    clean_weight = module.weight.data.detach()
                    attack_weight = self.flip_bit(module)
                    self.num_bit_flipped += 1
    
                    module.weight.data = attack_weight
                    output = model(data)
    
                    self.loss_dict[name] = self.criterion(output, target).item()
                    module.weight.data = clean_weight
    
            # Check if loss_dict is not empty
            if not self.loss_dict:
                break
    
            max_loss_module = max(self.loss_dict.items(), key=lambda item: item[1])[0]
            self.loss_max = self.loss_dict[max_loss_module]
    
            if self.n_bits2flip == 100:
                break
    
        # Check if max_loss_module was never assigned
        if max_loss_module is None:
            attack_last_status = [self.bit_counter, "No module attacked", "No attack", "No attack"]
            return [], validate_score(model, test_loader), self.bit_counter, attack_last_status
    
        weight_prior = None
        weight_post = None
    
        # If loss_max does lead to degradation, change that layer's weight
        for module_idx, (name, module) in enumerate(model.named_modules()):
            if name == max_loss_module:
                attack_weight = self.flip_bit(module)
                self.num_bit_flipped += 1
    
                ###########################################################
                ## Attack profiling
                ##########################################################
                
                weight_mismatch = attack_weight - module.weight.detach()
                attack_weight_idx = torch.nonzero(weight_mismatch)
                print('attacked module:', max_loss_module)
                
                attack_log = []
                for i in range(attack_weight_idx.size(0)):
                    weight_idx = attack_weight_idx[i, :].cpu().numpy()
                    weight_prior = module.weight.detach()[tuple(weight_idx)].item()
                    weight_post = attack_weight[tuple(weight_idx)].item()
                
                    tmp_list = [module_idx, self.bit_counter + (i + 1), max_loss_module,
                                weight_idx, weight_prior, weight_post]
                    attack_log.append(tmp_list)
    
                module.weight.data = attack_weight
    
        self.bit_counter += self.n_bits2flip
        self.n_bits2flip = 0
    
        if weight_prior is None or weight_post is None:
            attack_last_status = [self.bit_counter, max_loss_module, "No attack", "No attack"]
        else:
            attack_last_status = [self.bit_counter, max_loss_module, weight_prior, weight_post]
        
        return attack_log, validate_score(model, test_loader), self.bit_counter, attack_last_status

    def random_flip_one_bit(self, model, test_loader):
        """
        Randomly flip one bit in the weight of a chosen module.
        """
        weight_prior = None
        weight_post = None
        
        chosen_module = random.choice(self.module_list)
        for name, m in model.named_modules():
            if name == chosen_module:
                flatten_weight = m.weight.detach().view(-1)
                chosen_idx = random.choice(range(flatten_weight.numel()))
                bin_w = int2bin(flatten_weight[chosen_idx], m.N_bits).short()
                bit_idx = random.choice(range(m.N_bits))
                mask = (bin_w.clone().zero_() + 1) * (2 ** bit_idx)
                bin_w = bin_w ^ mask
                int_w = bin2int(bin_w, m.N_bits).float()

                ##############################################
                ###   attack profiling
                ###############################################
                
                weight_mismatch = flatten_weight[chosen_idx] - int_w
                attack_weight_idx = chosen_idx

                print('attacked module:', chosen_module)
                
                attack_log = []
                weight_idx = chosen_idx
                weight_prior = flatten_weight[chosen_idx]
                weight_post = int_w

                print('attacked weight index:', weight_idx)
                print('weight before attack:', weight_prior)
                print('weight after attack:', weight_post)

                tmp_list = ["module_idx", self.bit_counter + 1, "loss",
                            weight_idx, weight_prior, weight_post]
                attack_log.append(tmp_list)                            

                self.bit_counter += 1
                flatten_weight[chosen_idx] = int_w
                m.weight.data = flatten_weight.view(m.weight.data.size())
                
        if weight_prior is None or weight_post is None:
            attack_last_status = [self.bit_counter, chosen_module, "No attack", "No attack"]
        else:
            attack_last_status = [self.bit_counter, chosen_module, weight_prior, weight_post]

        return attack_log, validate_score(model, test_loader), self.bit_counter, attack_last_status

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
net = CustomModel().to(device)

if args.use_cuda:
    if args.ngpu > 1:
        net = torch.nn.DataParallel(net, device_ids=list(range(args.ngpu)))
criterion = torch.nn.CrossEntropyLoss()
optimizer = optim.AdamW(net.parameters(), lr=0.001, weight_decay=0.01)
# optimizer = optim.Adam(net.parameters(), lr=0.001)

# separate the parameters thus param groups can be updated by different optimizer
all_param = [
    param for name, param in net.named_parameters()
    if not 'step_size' in name
]

step_param = [
    param for name, param in net.named_parameters() if 'step_size' in name 
]

if args.optimizer == "SGD":
    print("using SGD as optimizer")
    optimizer = torch.optim.SGD(all_param,
                                lr=0.01,
                                momentum=0.9,
                                weight_decay=0.0001,
                                nesterov=True)

elif args.optimizer == "Adam":
    print("using Adam as optimizer")
    optimizer = torch.optim.Adam(filter(lambda param: param.requires_grad,
                                        all_param),
                                 lr=0.001,
                                 #momentum=0.9,
                                 weight_decay=0.001)


elif args.optimizer == "RMSprop":
    print("using RMSprop as optimizer")
    optimizer = torch.optim.RMSprop(
        filter(lambda param: param.requires_grad, net.parameters()),
        lr=0.01,
        alpha=0.99,
        eps=1e-08,
        momentum=0.9,
        weight_decay=0.0001)
# Out:
# using SGD as optimizer

# %% [markdown]
# ## BFA Attack

# %%
if args.use_cuda:
    net.cuda()
    criterion.cuda()

if args.resume:
    if os.path.isfile(args.resume):
        checkpoint = torch.load(args.resume)
        if not args.fine_tune:
            args.start_epoch = checkpoint['epoch']
            recorder = checkpoint['recorder']
            optimizer.load_state_dict(checkpoint['optimizer'])

        state_tmp = net.state_dict()
        if 'state_dict' in checkpoint.keys():
            state_tmp.update(checkpoint['state_dict'])
        else:
            state_tmp.update(checkpoint)

        net.load_state_dict(state_tmp, strict=False)
    else:
        print("No checkpoint found at '{}'".format(args.resume))
else:
    print("Do not use any checkpoint for {} model".format(args.arch))


# Configure the quantization bit-width
if args.quan_bitwidth is not None:
    change_quan_bitwidth(net, args.quan_bitwidth)

# Update the step_size once the model is loaded. This is used for quantization.
for m in net.modules():
    if isinstance(m, quan_Conv1d) or isinstance(m, quan_Linear) or isinstance(m, CustomBlock) or m.__class__.__name__ == "CustomBlock" or m.__class__.__name__ == "quan_Conv1d":
        m.__reset_stepsize__()

# Block for weight reset
if args.reset_weight:
    for m in net.modules():
        if isinstance(m, quan_Conv1d) or isinstance(m, quan_Linear) or isinstance(m, CustomBlock):
            m.__reset_weight__()

attacker = BFA(criterion, net, args.k_top)  # Khởi tạo đối tượng tấn công
net_clean = copy.deepcopy(net)
    # weight_conversion(net)

if args.enable_bfa:
    perform_attack(attacker, net, net_clean, train_loader, test_loader,
                   args.n_iter, writer, csv_save_path=args.save_path,
                   random_attack=args.random_bfa)

if args.evaluate:
    print("Evaluate mode")
    _, _, _, _, _, _, output_summary = validate(test_loader, net, criterion, summary_output=True)
    pd.DataFrame(output_summary).to_csv(os.path.join(args.save_path, 'output_summary_{}.csv'.format(args.arch)),
                                        header=['top-1 output'], index=False)
# Out:
# No checkpoint found at 'save\model_best.pth.tar'
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')
# Parameter containing:
# tensor([[128.],
#         [ 64.],
#         [ 32.],
#         [ 16.],
#         [  8.],
#         [  4.],
#         [  2.],
#         [  1.]], device='cuda:0')

# %%
def adjust_learning_rate(optimizer, epoch, gammas, schedule):
    """Sets the learning rate to the initial LR decayed by 10 every 30 epochs"""
    lr = args.learning_rate
    mu = args.momentum

    if args.optimizer != "YF":
        assert len(gammas) == len(
            schedule), "length of gammas and schedule should be equal"
        for (gamma, step) in zip(gammas, schedule):
            if (epoch >= step):
                lr = lr * gamma
            else:
                break
        for param_group in optimizer.param_groups:
            param_group['lr'] = lr

    elif args.optimizer == "YF":
        lr = optimizer._lr
        mu = optimizer._mu

    return lr, mu

# %%
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
if args.ngpu == 1:
    os.environ["CUDA_VISIBLE_DEVICES"] = str(
        args.gpu_id)  # make only device #gpu_id visible, then

args.use_cuda = args.ngpu > 0 and torch.cuda.is_available()  # check GPU

# Give a random seed if no manual configuration
if args.manualSeed is None:
    args.manualSeed = random.randint(1, 10000)
random.seed(args.manualSeed)
torch.manual_seed(args.manualSeed)

if args.use_cuda:
    torch.cuda.manual_seed_all(args.manualSeed)

cudnn.benchmark = True

if args.use_cuda:
    print(f"Using GPU: {args.gpu_id} with seed: {args.manualSeed}")
else:
    print(f"Using CPU with seed: {args.manualSeed}")
# Out:
# Using GPU: 0 with seed: 2698

# %%
# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# model = CustomModel().to(device)
# criterion = torch.nn.CrossEntropyLoss()
# # criterion = nn.CrossEntropyLoss()
# optimizer = optim.AdamW(model.parameters(), lr=0.001, weight_decay=0.01)
# #optimizer = optim.Adam(model.parameters(), lr=0.001)

# num_epochs = 50

# best_val_loss = float('inf')
# patience = 10  # Số epoch để chờ trước khi dừng
# counter = 0
# scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=5)

# # Vòng lặp huấn luyện
# best_val_loss = float('inf')
# best_mcc = -1  # Khởi tạo MCC tốt nhất

# # Vòng lặp huấn luyện
# for epoch in range(num_epochs):
#     train_mcc, train_loss = train(train_loader, model, criterion, optimizer, epoch)
#     val_mcc, val_loss, output_summary = validate(test_loader, model, criterion, summary_output=True)
#     scheduler.step(val_loss)

#     if val_loss < best_val_loss:
#         best_val_loss = val_loss
#         best_mcc = val_mcc  # Lưu MCC tốt nhất
#         counter = 0

#         save_dir = "CustomModel"
#         save_path = os.path.join(save_dir, "best_model.pth")

#         if not os.path.exists(save_dir):
#             os.makedirs(save_dir)

#         torch.save(model.state_dict(), save_path)
    
#     else:
#         counter += 1
#         if counter >= patience:
#             print("Early stopping triggered")
#             break

#     print(f"Epoch {epoch+1}/{num_epochs}")
#     print(f"Train Loss: {train_loss:.4f}, Train MCC: {train_mcc:.4f}")
#     print(f"Validation Loss: {val_loss:.4f}, Validation MCC: {val_mcc:.4f}")
# print(f"Best MCC during training: {best_mcc}")

# %% [markdown]
# ## Random Attack
#
# ### import data_conversion

# %%
def int2bin(input, num_bits):
    '''
    convert the signed integer value into unsigned integer (2's complement equivalently).
    Note that, the conversion is different depends on number of bit used.
    '''
    output = input.clone()
    if num_bits == 1: # when it is binary, the conversion is different
        output = output/2 + .5
    elif num_bits > 1:
        output[input.lt(0)] = 2**num_bits + output[input.lt(0)]

    return output


def bin2int(input, num_bits):
    '''
    convert the unsigned integer (2's complement equivantly) back to the signed integer format
    with the bitwise operations. Note that, in order to perform the bitwise operation, the input
    tensor has to be in the integer format.
    '''
    if num_bits == 1:
        output = input*2-1
    elif num_bits > 1:
        mask = 2**(num_bits - 1) - 1
        output = -(input & ~mask) + (input & mask)
    return output


def weight_conversion(model):
    '''
    Perform the weight data type conversion between:
        signed integer <==> two's complement (unsigned integer)
    Such conversion is used as additional step to ensure the conversion correctness

    Note that, the data type conversion chosen is depend on the bits:
        N_bits <= 8   .char()   --> torch.CharTensor(), 8-bit signed integer
        N_bits <= 16  .short()  --> torch.shortTensor(), 16 bit signed integer
        N_bits <= 32  .int()    --> torch.IntTensor(), 32 bit signed integer
    '''
    for m in model.modules():
        if isinstance(m, quan_Conv1d) or isinstance(m, quan_Linear):
            w_bin = int2bin(m.weight.data, m.N_bits).short()
            m.weight.data = bin2int(w_bin, m.N_bits).float()
    return

def count_ones(t, n_bits):
    counter = 0
    for i in range(n_bits):
        counter += ((t & 2**i) // 2**i).sum()
    return counter.item()


def hamming_distance(model1, model2):
    '''
    Given two model whose structure, name and so on are identical.
    The only difference between the model1 and model2 are the weight.
    The function compute the hamming distance bewtween the bianry weights
    (two's complement) of model1 and model2.
    '''
    # TODO: add the function check model1 and model2 are same structure
    # check the keys of state_dict match or not.

    H_dist = 0  # hamming distance counter

    for name, module in model1.named_modules():
        if isinstance(module, quan_Conv1d) or isinstance(module, quan_Linear):
            # remember to convert the tensor into integer for bitwise operations
            binW_model1 = int2bin(model1.state_dict()[name + '.weight'],
                                  module.N_bits).short()
            binW_model2 = int2bin(model2.state_dict()[name + '.weight'],
                                  module.N_bits).short()
            H_dist += count_ones(binW_model1 ^ binW_model2, module.N_bits)

    return H_dist

# %% [markdown]
# ## Vẽ đồ thị MCC sau mỗi epoch

# %%
import matplotlib.pyplot as plt

def plot_mcc_vs_epoch(images_filename, x_data, y_data):
    titles = ["MCC", "ACC", "TPR", "F1-Score"]
    
    for image_filename, title in zip(images_filename, titles):
        if len(x_data) != len(y_data):
            raise ValueError("x_data and y_data must have the same length.")
    
        plt.figure(figsize=(10, 6))
        plt.plot(x_data, y_data, marker='o', linestyle='-', color='b', label='MCC')
        plt.title(f'{title} after Epochs', fontsize=14) 
        plt.xlabel('Epoch', fontsize=12)
        plt.ylabel(title, fontsize=12)
        
        plt.grid(True, linestyle='--', alpha=0.7)
        plt.legend()
        plt.tight_layout()
        
        min_x, max_x = min(x_data), max(x_data)
        plt.xticks(range(min_x, max_x + 1, 2))
        # Save the plot as an image file
        plt.savefig(image_filename)
        plt.close()
        print(f"Plot saved as {image_filename}")

def plot_combined_metrics(image_filename, x_data, metric_dict):
    colors = {
        "MCC": "blue",
        "ACC": "orange",
        "TPR": "green",
        "F1": "red"
    }

    plt.figure(figsize=(10, 6))
    for metric in ["MCC", "ACC", "TPR", "F1"]:
        y = [float(v) for v in metric_dict[metric]]
        plt.plot(x_data, y, label=metric, color=colors[metric], linewidth=2)
        plt.fill_between(x_data,
                         [v * 0.95 for v in y],
                         [v * 1.05 for v in y],
                         alpha=0.2, color=colors[metric])

    plt.xlabel("Epoch", fontsize=12)
    plt.ylabel("Metric Value (%)", fontsize=12)
    plt.title("Combined Metrics during Attack", fontsize=14)
    plt.legend()
    plt.grid(True, linestyle="--", alpha=0.7)
    plt.tight_layout()
    plt.savefig(image_filename)
    plt.close()
    print(f"[Combined Plot] Saved as {image_filename}")

# %%
import csv
def perform_attack(attacker, model, model_clean, train_loader, test_loader,
                   N_iter, writer, file, csv_file, csv_save_path=None, attack_type=1,):
    model.eval()
    losses = AverageMeter()
    iter_time = AverageMeter()
    attack_time = AverageMeter()

    for _, (data, target) in enumerate(train_loader):
        if args.use_cuda:
            target = target.cuda()
            data = data.cuda()

        data = data.unsqueeze(-1)  # Kích thước [512, 39, 1]
        _, target = model(data).data.max(1)
        break

    val_mcc_top1, val_acc_top1, val_tpr_top1, val_f1score_top1, val_loss, output_summary = validate(test_loader, model, attacker.criterion, summary_output=True)
    print(f'**Test** MCC: {val_mcc_top1:.3f}. Val_Loss: {val_loss:.3f}')
    print(f'ACC: {val_acc_top1:.3f}.')
    print(f'TPR: {val_tpr_top1:.3f}.')
    print(f'F1-score: {val_f1score_top1:.3f}.')

    tmp_df = pd.DataFrame(output_summary)
    tmp_df['BFA iteration'] = 0
    tmp_df.to_csv(os.path.join(args.save_path, 'output_summary_{}_BFA_0.csv'.format(args.arch)), index=False)

    writer.add_scalar('attack/val_top1_acc', val_mcc_top1, 0)
    writer.add_scalar('attack/val_loss', val_loss, 0)

    print('Attack sample size is {}'.format(data.size()[0]))
    end = time.time()
    df = pd.DataFrame()
    last_val_mcc_top1 = val_mcc_top1
    last_val_acc_top1 = val_acc_top1
    last_val_tpr_top1 = val_tpr_top1
    last_val_f1score_top1 = val_f1score_top1

    MCC_data = [val_mcc_top1]
    epochs = [0]
    all_attack_status = []
    
    metric_dict = {
            "MCC": [val_mcc_top1],
            "ACC": [val_acc_top1],
            "TPR": [val_tpr_top1],
            "F1": [val_f1score_top1]
        }
    
    for i_iter in range(N_iter):
        print('**********************************')        
        if attack_type == 1:
            attack_log, new_mcc, bit_count, attack_last_status = attacker.progressive_bit_search(model, data, target, test_loader)
            MCC_data.append(new_mcc['MCC'])
            epochs.append(i_iter)
        elif attack_type == 2:
            attack_log, new_mcc, bit_count, attack_last_status = attacker.random_flip_one_bit(model, test_loader)
            MCC_data.append(new_mcc['MCC'])
            epochs.append(i_iter)
        elif attack_type == 3:
            attack_log, new_mcc, bit_count, attack_last_status = attacker.progressive_bit_search(model, data, target, test_loader)
            attack_log, new_mcc, bit_count, attack_last_status = attacker.random_flip_one_bit(model, test_loader)
            MCC_data.append(new_mcc['MCC'])
            epochs.append(i_iter)
        elif attack_type == 4:
            attack_log, new_mcc, bit_count, attack_last_status = attacker.random_flip_one_bit(model, test_loader)
            attack_log, new_mcc, bit_count, attack_last_status = attacker.progressive_bit_search(model, data, target, test_loader)
            MCC_data.append(new_mcc['MCC'])
            epochs.append(i_iter)
            
        metric_dict["MCC"].append(new_mcc["MCC"])
        metric_dict["ACC"].append(new_mcc["Accuracy"])
        metric_dict["TPR"].append(new_mcc["TPR"])
        metric_dict["F1"].append(new_mcc["F1 Score"])
        
        attack_time.update(time.time() - end)
        end = time.time()

        h_dist = hamming_distance(model, model_clean)

        if hasattr(attacker, "loss_max"):
            losses.update(attacker.loss_max, data.size(0))

        print('Iteration: [{:03d}/{:03d}]   Attack Time {attack_time.val:.3f} ({attack_time.avg:.3f})'.format(i_iter + 1, N_iter, attack_time=attack_time))

        try:
            print('Loss before attack: {:.4f}'.format(attacker.loss.item()))
            print('Loss after attack: {:.4f}'.format(attacker.loss_max))
        except:
            pass

        print('Bit flips: {:.0f}'.format(attacker.bit_counter))
        print('Hamming distance: {:.0f}'.format(h_dist))

        writer.add_scalar('attack/bit_flip', attacker.bit_counter, i_iter + 1)
        writer.add_scalar('attack/h_dist', h_dist, i_iter + 1)
        writer.add_scalar('attack/sample_loss', losses.avg, i_iter + 1)

        val_mcc_top1, val_acc_top1, val_tpr_top1, val_f1score_top1, val_loss, output_summary = validate(test_loader, model, attacker.criterion, summary_output=True)
        print(f'**Test** MCC: {val_mcc_top1:.3f}. Val_Loss: {val_loss:.3f}')
        print(f'ACC: {val_acc_top1:.3f}.')
        print(f'TPR: {val_tpr_top1:.3f}.')
        print(f'F1-score: {val_f1score_top1:.3f}.')
        
        tmp_df = pd.DataFrame(output_summary)
        tmp_df['BFA iteration'] = i_iter + 1
        tmp_df.to_csv(os.path.join(args.save_path, 'output_summary_{}_BFA_{}.csv'.format(args.arch, i_iter + 1)), index=False)

        # last_val_mcc_top1 = val_mcc_top1
        # last_val_acc_top1 = val_acc_top1
        # last_val_tpr_top1 = val_tpr_top1
        # last_val_f1score_top1 = val_f1score_top1
        
        mcc_drop = last_val_mcc_top1 - val_mcc_top1
        last_val_mcc_top1 = val_mcc_top1

        acc_drop = last_val_acc_top1 - val_acc_top1
        last_val_acc_top1 = val_acc_top1

        tpr_drop = last_val_tpr_top1 - val_tpr_top1
        last_val_tpr_top1 = val_tpr_top1

        f1score_drop = last_val_f1score_top1 - val_f1score_top1
        last_val_f1score_top1 = val_f1score_top1

        attack_last_status.append(round(val_mcc_top1, 5))
        attack_last_status.append(round(mcc_drop, 5))
        
        attack_last_status.append(round(val_acc_top1, 5))
        attack_last_status.append(round(acc_drop, 5))
        
        attack_last_status.append(round(val_tpr_top1, 5))
        attack_last_status.append(round(tpr_drop, 5))
        
        attack_last_status.append(round(val_f1score_top1, 5))
        attack_last_status.append(round(f1score_drop, 5))

        for entry in attack_log:
            entry.append(val_mcc_top1)
            entry.append(mcc_drop)

            entry.append(val_acc_top1)
            entry.append(acc_drop)

            entry.append(val_tpr_top1)
            entry.append(tpr_drop)

            entry.append(val_f1score_top1)
            entry.append(f1score_drop)
            
        df = pd.concat([df, pd.DataFrame(attack_log)], ignore_index=True)

        writer.add_scalar('attack/val_top1_acc', val_mcc_top1, i_iter + 1)
        writer.add_scalar('attack/val_loss', val_loss, i_iter + 1)

        iter_time.update(time.time() - end)
        print('Iteration Time {iter_time.val:.3f} ({iter_time.avg:.3f})'.format(iter_time=iter_time))
        end = time.time()

        all_attack_status.append(attack_last_status)

    column_list = ['module idx', 'bit-flip idx', 'module name', 'weight idx', 'weight before attack', 'weight after attack'
                    , 'validation mcc', 'mcc drop'
                    , "ACC", "ACC Drop"
                    , "TPR", "TPR Drop"
                    , "F1-score", "F1-score Drop",]
    df.columns = column_list
    df['trial seed'] = args.manualSeed

    if csv_save_path is not None:
        csv_file_name = 'attack_profile_{}.csv'.format(args.manualSeed)
        df.to_csv(os.path.join(csv_save_path, csv_file_name), index=None)
        
    # Vẽ đồ thị với MCC
    plot_mcc_vs_epoch(file, epochs, MCC_data)
    
    try:
        if isinstance(file, list) and len(file) > 0:
            first_image_name = os.path.basename(file[0])
            suffix = first_image_name.split("_", 1)[-1] if "_" in first_image_name else "attack.png"
            combined_plot_path = os.path.join(os.path.dirname(file[0]), f"combined_metrics_{suffix}")
        else:
            combined_plot_path = "combined_metrics.png"

        plot_combined_metrics(combined_plot_path, epochs, metric_dict)
    except Exception as e:
        print(f"[Warning] Plotting combined metrics failed: {e}")
        
    with open(csv_file, mode='w', newline='') as file:
        writer = csv.writer(file)
        
        # Ghi tiêu đề (nếu cần)
        writer.writerow(["Bit Counter", "Module", "Weight Before Attack", "Weight After Attack"
                         , "MCC", "MCC Drop"
                         , "ACC", "ACC Drop"
                         , "TPR", "TPR Drop"
                         , "F1-score", "F1-score Drop",])
        
        # Ghi dữ liệu
        writer.writerows(all_attack_status)
    
    return

# %% [markdown]
# ## Train CustomModel

# %%
# Bước 1: Tải mô hình đã huấn luyện
model_path = os.path.join("CustomModel", "best_model.pth")
# Kiểm tra xem tệp có tồn tại không
if not os.path.exists(model_path):
    raise FileNotFoundError(f"Không tìm thấy mô hình tại: {model_path}")

trained_model = CustomModel()

# Tải trọng số từ file best_model.pth
trained_model.load_state_dict(torch.load(model_path, map_location=torch.device('cuda' if torch.cuda.is_available() else 'cpu')))
trained_model = trained_model.to(device)

results = validate_score(trained_model, test_loader)
print(f"MCC before attack: {results['MCC']}")
print(f"Accuracy before attack: {results['Accuracy']}")
print(f"TPR before attack: {results['TPR']}")
print(f"F1-score before attack: {results['F1 Score']}")
# Out:
# MCC before attack: 0.7458979917458696
# Accuracy before attack: 0.764067933461175
# TPR before attack: 0.7061466910740501
# F1-score before attack: 0.695576108960066

# %% [markdown]
# ## Attack CustomModel

# %%
# Bước 2: Tạo bản sao của mô hình để làm tham chiếu
model_clean = copy.deepcopy(trained_model)

# Bước 3: Khởi tạo đối tượng tấn công BFA
attacker = BFA(criterion=criterion, model=trained_model, k_top=10)

# Định nghĩa đường dẫn để lưu kết quả tấn công
attack_dir = os.path.join("CustomModel", "PBS_attack")

os.makedirs(attack_dir, exist_ok=True)
attack_image_paths = [os.path.join(attack_dir, f"{metric}_PBS_attack.png") 
                      for metric in ["MCC", "ACC", "TPR", "F1"]]
# attack_image_path = os.path.join(attack_dir, "PBS_attack.png")
attack_csv_path = os.path.join(attack_dir, "PBS_attack.csv")

# Bước 4: Thực hiện tấn công
perform_attack(
    attacker=attacker,               # Đối tượng tấn công
    model=trained_model,             # Mô hình bị tấn công
    model_clean=model_clean,         # Mô hình gốc làm tham chiếu
    train_loader=train_loader,       # Bộ dữ liệu huấn luyện
    test_loader=test_loader,         # Bộ dữ liệu kiểm tra
    N_iter=args.n_iter,              # Số vòng lặp tấn công
    writer=writer,                   # TensorBoard writer để ghi log
    file=attack_image_paths,          # Lưu ảnh vào thư mục tấn công
    csv_file=attack_csv_path, 
    csv_save_path=args.save_path,    # Đường dẫn lưu file CSV
    attack_type= 1,                  # Chế độ tấn công PBS
)

writer.close()  # Đóng TensorBoard writer
# best_mcc = validate_score(trained_model, test_loader)
# print(f"\nMCC after 100 times PBS attack: {best_mcc}")

results = validate_score(trained_model, test_loader)
print(f"MCC after 100 times PBS attack: {results['MCC']}")
print(f"Accuracy after 100 times PBS attack: {results['Accuracy']}")
print(f"TPR after 100 times PBS attack: {results['TPR']}")
print(f"F1-score after 100 times PBS attack: {results['F1 Score']}")
# Out:
# **Test** MCC: 0.749. Val_Loss: 0.461
# ACC: 0.767.
# TPR: 0.710.
# F1-score: 0.700.
# Attack sample size is 256
# **********************************
# attacked module: fc1
# Iteration: [001/025]   Attack Time 8.057 (8.057)
# Loss before attack: 0.2972
# Loss after attack: 26.8242
# Bit flips: 1
# Hamming distance: 1
# **Test** MCC: 0.096. Val_Loss: 31.568
# ACC: 0.120.
# TPR: 0.123.
# F1-score: 0.085.
# Iteration Time 7.778 (7.778)
# **********************************
# attacked module: stage_1.6.conv_a
# Iteration: [002/025]   Attack Time 9.047 (8.552)
# Loss before attack: 26.8242
# Loss after attack: 664.1572
# Bit flips: 2
# Hamming distance: 2
# **Test** MCC: 0.127. Val_Loss: 804.332
# ACC: 0.148.
# TPR: 0.144.
# F1-score: 0.114.
# Iteration Time 7.415 (7.597)
# **********************************
# attacked module: stage_1.6.conv_b
# Iteration: [003/025]   Attack Time 7.992 (8.366)
# Loss before attack: 664.1572
# Loss after attack: 45934.7695
# Bit flips: 3
# Hamming distance: 3
# **Test** MCC: 0.129. Val_Loss: 55689.162
# ACC: 0.134.
# TPR: 0.131.
# F1-score: 0.094.
# Iteration Time 7.396 (7.530)
# **********************************
# attacked module: stage_3.1.conv_a
# Iteration: [004/025]   Attack Time 12.417 (9.378)
# Loss before attack: 45934.7695
# Loss after attack: 1021955.7500
# Bit flips: 4
# Hamming distance: 4
# **Test** MCC: 0.160. Val_Loss: 1167252.483
# ACC: 0.107.
# TPR: 0.092.
# F1-score: 0.056.
# Iteration Time 7.398 (7.497)
# **********************************
# attacked module: classifier
# Iteration: [005/025]   Attack Time 8.012 (9.105)
# Loss before attack: 1021955.7500
# Loss after attack: 16738236.0000
# Bit flips: 5
# Hamming distance: 4
# **Test** MCC: 0.113. Val_Loss: 19583597.615
# ACC: 0.104.
# TPR: 0.091.
# F1-score: 0.068.
# Iteration Time 7.801 (7.558)
# **********************************
# attacked module: stage_3.1.conv_b
# Iteration: [006/025]   Attack Time 12.646 (9.695)
# Loss before attack: 16738236.0000
# Loss after attack: 1431607040.0000
# Bit flips: 6
# Hamming distance: 5
# **Test** MCC: 0.036. Val_Loss: 1676936832.859
# ACC: 0.068.
# TPR: 0.046.
# F1-score: 0.013.
# Iteration Time 7.493 (7.547)
# **********************************
# attacked module: stage_1.4.conv_b
# Iteration: [007/025]   Attack Time 8.094 (9.466)
# Loss before attack: 1431607040.0000
# Loss after attack: 11837148160.0000
# Bit flips: 7
# Hamming distance: 6
# **Test** MCC: -0.031. Val_Loss: 13822787417.588
# ACC: 0.006.
# TPR: 0.008.
# F1-score: 0.004.
# Iteration Time 7.102 (7.483)
# **********************************
# attacked module: stage_1.4.conv_a
# Iteration: [008/025]   Attack Time 7.989 (9.282)
# Loss before attack: 11837148160.0000
# Loss after attack: 1336374067200.0000
# Bit flips: 8
# Hamming distance: 7
# **Test** MCC: 0.042. Val_Loss: 1565287627071.389
# ACC: 0.077.
# TPR: 0.049.
# F1-score: 0.012.
# Iteration Time 7.298 (7.460)
# **********************************
# attacked module: stage_3.10.conv_a
# Iteration: [009/025]   Attack Time 12.721 (9.664)
# Loss before attack: 1336374067200.0000
# Loss after attack: 10461771726848.0000
# Bit flips: 9
# Hamming distance: 8
# **Test** MCC: -0.000. Val_Loss: 12579740632364.230
# ACC: 0.078.
# TPR: 0.046.
# F1-score: 0.008.
# Iteration Time 7.425 (7.456)
# **********************************
# attacked module: stage_1.3.conv_b
# Iteration: [010/025]   Attack Time 8.059 (9.503)
# Loss before attack: 10461771726848.0000
# Loss after attack: 78756328767488.0000
# Bit flips: 10
# Hamming distance: 9
# **Test** MCC: 0.007. Val_Loss: 93801066715683.516
# ACC: 0.079.
# TPR: 0.047.
# F1-score: 0.010.
# Iteration Time 7.672 (7.478)
# **********************************
# attacked module: stage_1.3.conv_a
# Iteration: [011/025]   Attack Time 8.226 (9.387)
# Loss before attack: 78756328767488.0000
# Loss after attack: 10660556579012608.0000
# Bit flips: 11
# Hamming distance: 10
# **Test** MCC: -0.001. Val_Loss: 12817083343646980.000
# ACC: 0.078.
# TPR: 0.046.
# F1-score: 0.008.
# Iteration Time 7.461 (7.476)
# **********************************
# attacked module: stage_3.2.conv_b
# Iteration: [012/025]   Attack Time 12.912 (9.681)
# Loss before attack: 10660556579012608.0000
# Loss after attack: 68756400569843712.0000
# Bit flips: 12
# Hamming distance: 11
# **Test** MCC: -0.000. Val_Loss: 82672603270283104.000
# ACC: 0.078.
# TPR: 0.046.
# F1-score: 0.007.
# Iteration Time 7.437 (7.473)
# **********************************
# attacked module: stage_3.2.conv_a
# Iteration: [013/025]   Attack Time 12.553 (9.902)
# Loss before attack: 68756400569843712.0000
# Loss after attack: 15351495696217800704.0000
# Bit flips: 13
# Hamming distance: 12
# **Test** MCC: -0.001. Val_Loss: 18461309291803848704.000
# ACC: 0.078.
# TPR: 0.046.
# F1-score: 0.008.
# Iteration Time 7.605 (7.483)
# **********************************
# attacked module: stage_1.1.conv_a
# Iteration: [014/025]   Attack Time 8.290 (9.787)
# Loss before attack: 15351495696217800704.0000
# Loss after attack: 91778997543671693312.0000
# Bit flips: 14
# Hamming distance: 13
# **Test** MCC: -0.003. Val_Loss: 110368272261478776832.000
# ACC: 0.078.
# TPR: 0.046.
# F1-score: 0.007.
# Iteration Time 7.596 (7.491)
# **********************************
# attacked module: stage_1.1.conv_b
# Iteration: [015/025]   Attack Time 8.199 (9.681)
# Loss before attack: 91778997543671693312.0000
# Loss after attack: 6726755421525760802816.0000
# Bit flips: 15
# Hamming distance: 14
# **Test** MCC: -0.004. Val_Loss: 8088323920432874913792.000
# ACC: 0.078.
# TPR: 0.046.
# F1-score: 0.007.
# Iteration Time 7.340 (7.481)
# **********************************
# attacked module: stage_1.10.conv_b
# Iteration: [016/025]   Attack Time 8.072 (9.580)
# Loss before attack: 6726755421525760802816.0000
# Loss after attack: 37867062804065174945792.0000
# Bit flips: 16
# Hamming distance: 15
# **Test** MCC: -0.049. Val_Loss: 45539542177200713236480.000
# ACC: 0.070.
# TPR: 0.041.
# F1-score: 0.007.
# Iteration Time 7.494 (7.482)
# **********************************
# attacked module: stage_1.10.conv_a
# Iteration: [017/025]   Attack Time 8.182 (9.498)
# Loss before attack: 37867062804065174945792.0000
# Loss after attack: 7357392793000190721130496.0000
# Bit flips: 17
# Hamming distance: 16
# **Test** MCC: 0.001. Val_Loss: 8848042211442682278969344.000
# ACC: 0.078.
# TPR: 0.047.
# F1-score: 0.008.
# Iteration Time 7.448 (7.480)
# **********************************
# attacked module: stage_1.2.conv_b
# Iteration: [018/025]   Attack Time 8.135 (9.422)
# Loss before attack: 7357392793000190721130496.0000
# Loss after attack: 41039532228565877779333120.0000
# Bit flips: 18
# Hamming distance: 17
# **Test** MCC: -0.004. Val_Loss: 49356373951425285889982464.000
# ACC: 0.078.
# TPR: 0.046.
# F1-score: 0.008.
# Iteration Time 7.407 (7.476)
# **********************************
# attacked module: stage_1.2.conv_a
# Iteration: [019/025]   Attack Time 8.296 (9.363)
# Loss before attack: 41039532228565877779333120.0000
# Loss after attack: 7747991410810709771756240896.0000
# Bit flips: 19
# Hamming distance: 18
# **Test** MCC: -0.000. Val_Loss: 9316255491617263484087042048.000
# ACC: 0.078.
# TPR: 0.046.
# F1-score: 0.007.
# Iteration Time 7.439 (7.474)
# **********************************
# attacked module: stage_1.7.conv_b
# Iteration: [020/025]   Attack Time 8.611 (9.326)
# Loss before attack: 7747991410810709771756240896.0000
# Loss after attack: 37710242681280581285112184832.0000
# Bit flips: 20
# Hamming distance: 19
# **Test** MCC: 0.002. Val_Loss: 45345168863901933313258946560.000
# ACC: 0.078.
# TPR: 0.047.
# F1-score: 0.008.
# Iteration Time 7.754 (7.488)
# **********************************
# attacked module: stage_1.7.conv_a
# Iteration: [021/025]   Attack Time 8.224 (9.273)
# Loss before attack: 37710242681280581285112184832.0000
# Loss after attack: 13418165067654394408840825143296.0000
# Bit flips: 21
# Hamming distance: 20
# **Test** MCC: -0.000. Val_Loss: 16132696308840393304490006020096.000
# ACC: 0.078.
# TPR: 0.046.
# F1-score: 0.007.
# Iteration Time 7.483 (7.488)
# **********************************
# attacked module: stage_1.9.conv_b
# Iteration: [022/025]   Attack Time 8.177 (9.223)
# Loss before attack: 13418165067654394408840825143296.0000
# Loss after attack: 62550938954318237416654974746624.0000
# Bit flips: 22
# Hamming distance: 21
# **Test** MCC: 0.001. Val_Loss: 75212027528118727856858377224192.000
# ACC: 0.078.
# TPR: 0.047.
# F1-score: 0.007.
# Iteration Time 7.481 (7.487)
# **********************************
# attacked module: stage_1.9.conv_a
# Iteration: [023/025]   Attack Time 8.102 (9.174)
# Loss before attack: 62550938954318237416654974746624.0000
# Loss after attack: 12608132098032483891623803624620032.0000
# Bit flips: 23
# Hamming distance: 22
# **Test** MCC: 0.000. Val_Loss: 15159480896214211612589101007503360.000
# ACC: 0.078.
# TPR: 0.046.
# F1-score: 0.007.
# Iteration Time 7.409 (7.484)
# **********************************
# attacked module: stage_3.3.conv_b
# Iteration: [024/025]   Attack Time 12.578 (9.316)
# Loss before attack: 12608132098032483891623803624620032.0000
# Loss after attack: 57522067396072751296730610630918144.0000
# Bit flips: 24
# Hamming distance: 23
# **Test** MCC: 0.001. Val_Loss: 69145056532400765623833706253778944.000
# ACC: 0.078.
# TPR: 0.047.
# F1-score: 0.007.
# Iteration Time 7.699 (7.493)
# **********************************
# attacked module: stage_3.5.conv_b
# Iteration: [025/025]   Attack Time 12.811 (9.456)
# Loss before attack: 57522067396072751296730610630918144.0000
# Loss after attack: 252372675819474992591436557504741376.0000
# Bit flips: 25
# Hamming distance: 24
# **Test** MCC: 0.001. Val_Loss: 303508821662885251370158633491890176.000
# ACC: 0.078.
# TPR: 0.046.
# F1-score: 0.007.
# Iteration Time 7.373 (7.488)
# Plot saved as CustomModel/PBS_attack/MCC_PBS_attack.png
# Plot saved as CustomModel/PBS_attack/ACC_PBS_attack.png
# Plot saved as CustomModel/PBS_attack/TPR_PBS_attack.png
# Plot saved as CustomModel/PBS_attack/F1_PBS_attack.png
# [Combined Plot] Saved as CustomModel/PBS_attack/combined_metrics_PBS_attack.png
# MCC after 100 times PBS attack: 0.0007229571365487091
# Accuracy after 100 times PBS attack: 0.07832900567947224
# TPR after 100 times PBS attack: 0.04634407623312451
# F1-score after 100 times PBS attack: 0.006833489352735042

# %%
# Bước 1: Tải mô hình đã huấn luyện
model_path = os.path.join("CustomModel", "best_model.pth")

trained_model = CustomModel()

# Tải trọng số từ file best_model.pth
trained_model.load_state_dict(torch.load(model_path, map_location=torch.device('cuda' if torch.cuda.is_available() else 'cpu')))
trained_model = trained_model.to(device)

# Bước 2: Tạo bản sao của mô hình để làm tham chiếu
model_clean = copy.deepcopy(trained_model)

# Bước 3: Khởi tạo đối tượng tấn công BFA
attacker = BFA(criterion=criterion, model=trained_model, k_top=10)

# Định nghĩa đường dẫn để lưu kết quả tấn công
attack_dir = os.path.join("CustomModel", "RandomFlip_attack")

os.makedirs(attack_dir, exist_ok=True)
attack_image_paths = [os.path.join(attack_dir, f"{metric}_RandomFlip_attack.png") 
                      for metric in ["MCC", "ACC", "TPR", "F1"]]
# attack_image_path = os.path.join(attack_dir, "RandomFlip_attack.png")
attack_csv_path = os.path.join(attack_dir, "RandomFlip_attack.csv")

# Bước 4: Thực hiện tấn công
perform_attack(
    attacker=attacker,               # Đối tượng tấn công
    model=trained_model,             # Mô hình bị tấn công
    model_clean=model_clean,         # Mô hình gốc làm tham chiếu
    train_loader=train_loader,       # Bộ dữ liệu huấn luyện
    test_loader=test_loader,         # Bộ dữ liệu kiểm tra
    N_iter=args.n_iter,              # Số vòng lặp tấn công
    writer=writer,                   # TensorBoard writer để ghi log
    file=attack_image_paths,          # Lưu ảnh vào thư mục tấn công
    csv_file=attack_csv_path, 
    csv_save_path=args.save_path,    # Đường dẫn lưu file CSV
    attack_type= 2,                  # Chế độ tấn công random
)

writer.close()  # Đóng TensorBoard writer

# best_mcc = validate_score(trained_model ,test_loader)
# print(f"\nMCC after 100 times random attack: {best_mcc}")

results = validate_score(trained_model, test_loader)
print(f"MCC after 100 times random attack: {results['MCC']}")
print(f"Accuracy after 100 times random attack: {results['Accuracy']}")
print(f"TPR after 100 times random attack: {results['TPR']}")
print(f"F1-score after 100 times random attack: {results['F1 Score']}")
# Out:
# **Test** MCC: 0.749. Val_Loss: 0.461
# ACC: 0.767.
# TPR: 0.711.
# F1-score: 0.701.
# Attack sample size is 256
# **********************************
# attacked module: stage_1.13.conv_b
# attacked weight index: 2460
# weight before attack: tensor(-0.0498, device='cuda:0')
# weight after attack: tensor(-2., device='cuda:0')
# Iteration: [001/025]   Attack Time 6.709 (6.709)
# Bit flips: 1
# Hamming distance: 1
# **Test** MCC: 0.749. Val_Loss: 0.461
# ACC: 0.767.
# TPR: 0.711.
# F1-score: 0.701.
# Iteration Time 7.505 (7.505)
# **********************************
# attacked module: stage_1.8.conv_a
# attacked weight index: 975
# weight before attack: tensor(0.1299, device='cuda:0')
# weight after attack: tensor(32., device='cuda:0')
# Iteration: [002/025]   Attack Time 6.440 (6.575)
# Bit flips: 2
# Hamming distance: 2
# **Test** MCC: 0.749. Val_Loss: 0.461
# ACC: 0.767.
# TPR: 0.711.
# F1-score: 0.701.
# Iteration Time 7.195 (7.350)
# **********************************
# attacked module: stage_1.11.conv_a
# attacked weight index: 1879
# weight before attack: tensor(-0.1217, device='cuda:0')
# weight after attack: tensor(-33., device='cuda:0')
# Iteration: [003/025]   Attack Time 6.466 (6.538)
# Bit flips: 3
# Hamming distance: 3
# **Test** MCC: 0.749. Val_Loss: 0.461
# ACC: 0.767.
# TPR: 0.711.
# F1-score: 0.701.
# Iteration Time 7.210 (7.303)
# **********************************
# attacked module: stage_1.2.conv_b
# attacked weight index: 1556
# weight before attack: tensor(-0.0008, device='cuda:0')
# weight after attack: tensor(-9., device='cuda:0')
# Iteration: [004/025]   Attack Time 6.596 (6.553)
# Bit flips: 4
# Hamming distance: 4
# **Test** MCC: 0.749. Val_Loss: 0.461
# ACC: 0.767.
# TPR: 0.711.
# F1-score: 0.701.
# Iteration Time 7.587 (7.374)
# **********************************
# attacked module: stage_3.8.conv_b
# attacked weight index: 394
# weight before attack: tensor(-0.0349, device='cuda:0')
# weight after attack: tensor(-2., device='cuda:0')
# Iteration: [005/025]   Attack Time 6.681 (6.578)
# Bit flips: 5
# Hamming distance: 5
# **Test** MCC: 0.749. Val_Loss: 0.461
# ACC: 0.767.
# TPR: 0.711.
# F1-score: 0.701.
# Iteration Time 7.568 (7.413)
# **********************************
# attacked module: stage_2.10.conv_a
# attacked weight index: 5086
# weight before attack: tensor(0.1712, device='cuda:0')
# weight after attack: tensor(-128., device='cuda:0')
# Iteration: [006/025]   Attack Time 6.710 (6.600)
# Bit flips: 6
# Hamming distance: 6
# **Test** MCC: 0.749. Val_Loss: 0.461
# ACC: 0.767.
# TPR: 0.711.
# F1-score: 0.701.
# Iteration Time 7.294 (7.393)
# **********************************
# attacked module: stage_3.6.conv_a
# attacked weight index: 44023
# weight before attack: tensor(-0.1032, device='cuda:0')
# weight after attack: tensor(-2., device='cuda:0')
# Iteration: [007/025]   Attack Time 6.550 (6.593)
# Bit flips: 7
# Hamming distance: 7
# **Test** MCC: 0.749. Val_Loss: 0.461
# ACC: 0.767.
# TPR: 0.711.
# F1-score: 0.701.
# Iteration Time 7.712 (7.439)
# **********************************
# attacked module: stage_2.5.conv_a
# attacked weight index: 2786
# weight before attack: tensor(0.0110, device='cuda:0')
# weight after attack: tensor(4., device='cuda:0')
# Iteration: [008/025]   Attack Time 6.620 (6.597)
# Bit flips: 8
# Hamming distance: 8
# **Test** MCC: 0.749. Val_Loss: 0.461
# ACC: 0.767.
# TPR: 0.711.
# F1-score: 0.701.
# Iteration Time 7.430 (7.438)
# **********************************
# attacked module: stage_1.15.conv_b
# attacked weight index: 1885
# weight before attack: tensor(-0.0450, device='cuda:0')
# weight after attack: tensor(-2., device='cuda:0')
# Iteration: [009/025]   Attack Time 6.448 (6.580)
# Bit flips: 9
# Hamming distance: 9
# **Test** MCC: 0.749. Val_Loss: 0.461
# ACC: 0.767.
# TPR: 0.711.
# F1-score: 0.701.
# Iteration Time 7.432 (7.437)
# **********************************
# attacked module: stage_2.1.conv_b
# attacked weight index: 6341
# weight before attack: tensor(-0.0231, device='cuda:0')
# weight after attack: tensor(-5., device='cuda:0')
# Iteration: [010/025]   Attack Time 6.642 (6.586)
# Bit flips: 10
# Hamming distance: 10
# **Test** MCC: 0.749. Val_Loss: 0.461
# ACC: 0.767.
# TPR: 0.711.
# F1-score: 0.701.
# Iteration Time 7.516 (7.445)
# **********************************
# attacked module: stage_1.5.conv_b
# attacked weight index: 1861
# weight before attack: tensor(0.1916, device='cuda:0')
# weight after attack: tensor(4., device='cuda:0')
# Iteration: [011/025]   Attack Time 6.638 (6.591)
# Bit flips: 11
# Hamming distance: 11
# **Test** MCC: 0.749. Val_Loss: 0.461
# ACC: 0.767.
# TPR: 0.711.
# F1-score: 0.701.
# Iteration Time 7.533 (7.453)
# **********************************
# attacked module: stage_1.13.conv_a
# attacked weight index: 1325
# weight before attack: tensor(-0.0042, device='cuda:0')
# weight after attack: tensor(-3., device='cuda:0')
# Iteration: [012/025]   Attack Time 6.544 (6.587)
# Bit flips: 12
# Hamming distance: 12
# **Test** MCC: 0.749. Val_Loss: 0.461
# ACC: 0.767.
# TPR: 0.711.
# F1-score: 0.701.
# Iteration Time 7.602 (7.465)
# **********************************
# attacked module: stage_3.5.conv_a
# attacked weight index: 23334
# weight before attack: tensor(-0.0551, device='cuda:0')
# weight after attack: tensor(-2., device='cuda:0')
# Iteration: [013/025]   Attack Time 6.586 (6.587)
# Bit flips: 13
# Hamming distance: 13
# **Test** MCC: 0.749. Val_Loss: 0.461
# ACC: 0.767.
# TPR: 0.711.
# F1-score: 0.701.
# Iteration Time 7.616 (7.477)
# **********************************
# attacked module: stage_3.14.conv_a
# attacked weight index: 29585
# weight before attack: tensor(0.0461, device='cuda:0')
# weight after attack: tensor(4., device='cuda:0')
# Iteration: [014/025]   Attack Time 6.616 (6.589)
# Bit flips: 14
# Hamming distance: 14
# **Test** MCC: 0.749. Val_Loss: 0.461
# ACC: 0.767.
# TPR: 0.711.
# F1-score: 0.701.
# Iteration Time 7.544 (7.482)
# **********************************
# attacked module: stage_3.11.conv_a
# attacked weight index: 44346
# weight before attack: tensor(0.0228, device='cuda:0')
# weight after attack: tensor(64., device='cuda:0')
# Iteration: [015/025]   Attack Time 6.555 (6.587)
# Bit flips: 15
# Hamming distance: 15
# **Test** MCC: 0.749. Val_Loss: 0.461
# ACC: 0.767.
# TPR: 0.711.
# F1-score: 0.701.
# Iteration Time 7.239 (7.466)
# **********************************
# attacked module: stage_2.4.conv_a
# attacked weight index: 9504
# weight before attack: tensor(-0.0079, device='cuda:0')
# weight after attack: tensor(-33., device='cuda:0')
# Iteration: [016/025]   Attack Time 6.589 (6.587)
# Bit flips: 16
# Hamming distance: 16
# **Test** MCC: 0.749. Val_Loss: 0.461
# ACC: 0.767.
# TPR: 0.711.
# F1-score: 0.701.
# Iteration Time 7.504 (7.468)
# **********************************
# attacked module: stage_1.5.conv_a
# attacked weight index: 2113
# weight before attack: tensor(-0.0448, device='cuda:0')
# weight after attack: tensor(-65., device='cuda:0')
# Iteration: [017/025]   Attack Time 6.692 (6.593)
# Bit flips: 17
# Hamming distance: 17
# **Test** MCC: 0.749. Val_Loss: 0.461
# ACC: 0.767.
# TPR: 0.711.
# F1-score: 0.701.
# Iteration Time 7.692 (7.481)
# **********************************
# attacked module: stage_3.2.conv_b
# attacked weight index: 44424
# weight before attack: tensor(0.0069, device='cuda:0')
# weight after attack: tensor(2., device='cuda:0')
# Iteration: [018/025]   Attack Time 6.581 (6.592)
# Bit flips: 18
# Hamming distance: 18
# **Test** MCC: 0.749. Val_Loss: 0.461
# ACC: 0.767.
# TPR: 0.711.
# F1-score: 0.701.
# Iteration Time 7.550 (7.485)
# **********************************
# attacked module: stage_3.8.conv_a
# attacked weight index: 31883
# weight before attack: tensor(0.0051, device='cuda:0')
# weight after attack: tensor(8., device='cuda:0')
# Iteration: [019/025]   Attack Time 6.603 (6.593)
# Bit flips: 19
# Hamming distance: 19
# **Test** MCC: 0.749. Val_Loss: 0.461
# ACC: 0.767.
# TPR: 0.711.
# F1-score: 0.701.
# Iteration Time 7.408 (7.481)
# **********************************
# attacked module: stage_3.11.conv_a
# attacked weight index: 21741
# weight before attack: tensor(0.0025, device='cuda:0')
# weight after attack: tensor(16., device='cuda:0')
# Iteration: [020/025]   Attack Time 6.739 (6.600)
# Bit flips: 20
# Hamming distance: 20
# **Test** MCC: 0.749. Val_Loss: 0.461
# ACC: 0.767.
# TPR: 0.711.
# F1-score: 0.701.
# Iteration Time 7.771 (7.495)
# **********************************
# attacked module: stage_3.2.conv_a
# attacked weight index: 958
# weight before attack: tensor(-0.0899, device='cuda:0')
# weight after attack: tensor(127., device='cuda:0')
# Iteration: [021/025]   Attack Time 6.975 (6.618)
# Bit flips: 21
# Hamming distance: 21
# **Test** MCC: 0.700. Val_Loss: 0.648
# ACC: 0.721.
# TPR: 0.598.
# F1-score: 0.574.
# Iteration Time 7.705 (7.505)
# **********************************
# attacked module: stage_3.9.conv_a
# attacked weight index: 16691
# weight before attack: tensor(-0.0125, device='cuda:0')
# weight after attack: tensor(127., device='cuda:0')
# Iteration: [022/025]   Attack Time 6.596 (6.617)
# Bit flips: 22
# Hamming distance: 22
# **Test** MCC: 0.700. Val_Loss: 0.648
# ACC: 0.721.
# TPR: 0.598.
# F1-score: 0.574.
# Iteration Time 7.593 (7.509)
# **********************************
# attacked module: stage_3.15.conv_a
# attacked weight index: 48020
# weight before attack: tensor(0.0111, device='cuda:0')
# weight after attack: tensor(32., device='cuda:0')
# Iteration: [023/025]   Attack Time 6.663 (6.619)
# Bit flips: 23
# Hamming distance: 23
# **Test** MCC: 0.700. Val_Loss: 0.648
# ACC: 0.721.
# TPR: 0.598.
# F1-score: 0.574.
# Iteration Time 7.586 (7.513)
# **********************************
# attacked module: stage_3.14.conv_b
# attacked weight index: 8823
# weight before attack: tensor(-0.0240, device='cuda:0')
# weight after attack: tensor(-2., device='cuda:0')
# Iteration: [024/025]   Attack Time 6.573 (6.617)
# Bit flips: 24
# Hamming distance: 24
# **Test** MCC: 0.700. Val_Loss: 0.648
# ACC: 0.721.
# TPR: 0.598.
# F1-score: 0.574.
# Iteration Time 7.333 (7.505)
# **********************************
# attacked module: stage_1.14.conv_b
# attacked weight index: 33
# weight before attack: tensor(0.0010, device='cuda:0')
# weight after attack: tensor(64., device='cuda:0')
# Iteration: [025/025]   Attack Time 6.571 (6.615)
# Bit flips: 25
# Hamming distance: 25
# **Test** MCC: 0.700. Val_Loss: 0.648
# ACC: 0.721.
# TPR: 0.598.
# F1-score: 0.574.
# Iteration Time 7.554 (7.507)
# Plot saved as CustomModel/RandomFlip_attack/MCC_RandomFlip_attack.png
# Plot saved as CustomModel/RandomFlip_attack/ACC_RandomFlip_attack.png
# Plot saved as CustomModel/RandomFlip_attack/TPR_RandomFlip_attack.png
# Plot saved as CustomModel/RandomFlip_attack/F1_RandomFlip_attack.png
# [Combined Plot] Saved as CustomModel/RandomFlip_attack/combined_metrics_RandomFlip_attack.png
# MCC after 100 times random attack: 0.6998620919185196
# Accuracy after 100 times random attack: 0.7209167897677747
# TPR after 100 times random attack: 0.5975357034005326
# F1-score after 100 times random attack: 0.5741364250914144

# %%
# Bước 1: Tải mô hình đã huấn luyện
model_path = os.path.join("CustomModel", "best_model.pth")
trained_model = CustomModel()

# Tải trọng số từ file best_model.pth
trained_model.load_state_dict(torch.load(model_path, map_location=torch.device('cuda' if torch.cuda.is_available() else 'cpu')))
trained_model = trained_model.to(device)

# Bước 2: Tạo bản sao của mô hình để làm tham chiếu
model_clean = copy.deepcopy(trained_model)

# Bước 3: Khởi tạo đối tượng tấn công BFA
attacker = BFA(criterion=criterion, model=trained_model, k_top=10)

# Định nghĩa đường dẫn để lưu kết quả tấn công
attack_dir = os.path.join("CustomModel", "PBS_to_RandomFlip_attack")

os.makedirs(attack_dir, exist_ok=True)
attack_image_paths = [os.path.join(attack_dir, f"{metric}_PBS_to_RandomFlip_attack.png") 
                      for metric in ["MCC", "ACC", "TPR", "F1"]]
# attack_image_path = os.path.join(attack_dir, "PBS_to_RandomFlip_attack.png")
attack_csv_path = os.path.join(attack_dir, "PBS_to_RandomFlip_attack.csv")

# Bước 4: Thực hiện tấn công
perform_attack(
    attacker=attacker,               # Đối tượng tấn công
    model=trained_model,             # Mô hình bị tấn công
    model_clean=model_clean,         # Mô hình gốc làm tham chiếu
    train_loader=train_loader,       # Bộ dữ liệu huấn luyện
    test_loader=test_loader,         # Bộ dữ liệu kiểm tra
    N_iter=args.n_iter,              # Số vòng lặp tấn công
    writer=writer,                   # TensorBoard writer để ghi log
    file=attack_image_paths,          # Lưu ảnh vào thư mục tấn công
    csv_file=attack_csv_path,
    csv_save_path=args.save_path,    # Đường dẫn lưu file CSV
    attack_type= 3,                  # Chế độ tấn công PBS -> random
)

writer.close()  # Đóng TensorBoard writer
# best_mcc = validate_score( trained_model,test_loader)
# print(f"\nMCC after 100 times PBS to Random: {best_mcc}")

results = validate_score(trained_model, test_loader)
print(f"MCC after 100 times PBS to Random: {results['MCC']}")
print(f"Accuracy after 100 times PBS to Random: {results['Accuracy']}")
print(f"TPR after 100 times PBS to Random: {results['TPR']}")
print(f"F1-score after 100 times PBS to Random: {results['F1 Score']}")
# Out:
# **Test** MCC: 0.749. Val_Loss: 0.461
# ACC: 0.767.
# TPR: 0.711.
# F1-score: 0.701.
# Attack sample size is 256
# **********************************
# attacked module: fc1
# attacked module: stage_1.8.conv_a
# attacked weight index: 232
# weight before attack: tensor(0.3742, device='cuda:0')
# weight after attack: tensor(-128., device='cuda:0')
# Iteration: [001/025]   Attack Time 14.857 (14.857)
# Loss before attack: 0.3118
# Loss after attack: 23.7418
# Bit flips: 2
# Hamming distance: 2
# **Test** MCC: 0.085. Val_Loss: 23.412
# ACC: 0.121.
# TPR: 0.120.
# F1-score: 0.085.
# Iteration Time 7.488 (7.488)
# **********************************
# attacked module: stage_1.6.conv_a
# attacked module: stage_3.8.conv_a
# attacked weight index: 8982
# weight before attack: tensor(-0.0082, device='cuda:0')
# weight after attack: tensor(-5., device='cuda:0')
# Iteration: [002/025]   Attack Time 14.448 (14.653)
# Loss before attack: 23.6901
# Loss after attack: 554.8066
# Bit flips: 4
# Hamming distance: 4
# **Test** MCC: 0.120. Val_Loss: 562.978
# ACC: 0.154.
# TPR: 0.141.
# F1-score: 0.116.
# Iteration Time 7.380 (7.434)
# **********************************
# attacked module: stage_1.6.conv_b
# attacked module: stage_2.3.conv_b
# attacked weight index: 5150
# weight before attack: tensor(0.0006, device='cuda:0')
# weight after attack: tensor(-128., device='cuda:0')
# Iteration: [003/025]   Attack Time 14.530 (14.612)
# Loss before attack: 554.8066
# Loss after attack: 38240.8711
# Bit flips: 6
# Hamming distance: 6
# **Test** MCC: 0.109. Val_Loss: 38837.414
# ACC: 0.132.
# TPR: 0.126.
# F1-score: 0.090.
# Iteration Time 7.515 (7.461)
# **********************************
# attacked module: classifier
# attacked module: stage_2.10.conv_b
# attacked weight index: 7864
# weight before attack: tensor(-0.0253, device='cuda:0')
# weight after attack: tensor(-5., device='cuda:0')
# Iteration: [004/025]   Attack Time 14.885 (14.680)
# Loss before attack: 38240.8711
# Loss after attack: 829206.6875
# Bit flips: 8
# Hamming distance: 7
# **Test** MCC: 0.098. Val_Loss: 897090.672
# ACC: 0.128.
# TPR: 0.118.
# F1-score: 0.077.
# Iteration Time 7.604 (7.497)
# **********************************
# attacked module: stage_3.10.conv_a
# attacked module: stage_1.0.conv_a
# attacked weight index: 2510
# weight before attack: tensor(0.0274, device='cuda:0')
# weight after attack: tensor(-128., device='cuda:0')
# Iteration: [005/025]   Attack Time 19.835 (15.711)
# Loss before attack: 829206.6875
# Loss after attack: 7578123.0000
# Bit flips: 10
# Hamming distance: 9
# **Test** MCC: 0.110. Val_Loss: 8219541.522
# ACC: 0.109.
# TPR: 0.089.
# F1-score: 0.052.
# Iteration Time 7.522 (7.502)
# **********************************
# attacked module: stage_1.4.conv_b
# attacked module: stage_1.8.conv_a
# attacked weight index: 2555
# weight before attack: tensor(-0.0229, device='cuda:0')
# weight after attack: tensor(-5., device='cuda:0')
# Iteration: [006/025]   Attack Time 14.672 (15.538)
# Loss before attack: 7578123.0000
# Loss after attack: 62290440.0000
# Bit flips: 12
# Hamming distance: 11
# **Test** MCC: 0.081. Val_Loss: 67317532.062
# ACC: 0.102.
# TPR: 0.082.
# F1-score: 0.066.
# Iteration Time 7.226 (7.456)
# **********************************
# attacked module: stage_1.4.conv_a
# attacked module: stage_2.13.conv_a
# attacked weight index: 9826
# weight before attack: tensor(0.2915, device='cuda:0')
# weight after attack: tensor(64., device='cuda:0')
# Iteration: [007/025]   Attack Time 14.342 (15.367)
# Loss before attack: 62290440.0000
# Loss after attack: 6876941312.0000
# Bit flips: 14
# Hamming distance: 13
# **Test** MCC: 0.093. Val_Loss: 7458522581.777
# ACC: 0.094.
# TPR: 0.079.
# F1-score: 0.046.
# Iteration Time 7.442 (7.454)
# **********************************
# attacked module: stage_1.3.conv_b
# attacked module: stage_3.2.conv_b
# attacked weight index: 15663
# weight before attack: tensor(-0.0184, device='cuda:0')
# weight after attack: tensor(-3., device='cuda:0')
# Iteration: [008/025]   Attack Time 14.316 (15.236)
# Loss before attack: 6876941824.0000
# Loss after attack: 54559883264.0000
# Bit flips: 16
# Hamming distance: 15
# **Test** MCC: -0.002. Val_Loss: 58972857742.395
# ACC: 0.034.
# TPR: 0.047.
# F1-score: 0.018.
# Iteration Time 7.283 (7.433)
# **********************************
# attacked module: stage_1.3.conv_a
# attacked module: stage_2.5.conv_a
# attacked weight index: 8953
# weight before attack: tensor(0.2789, device='cuda:0')
# weight after attack: tensor(4., device='cuda:0')
# Iteration: [009/025]   Attack Time 14.788 (15.186)
# Loss before attack: 54559883264.0000
# Loss after attack: 7090771853312.0000
# Bit flips: 18
# Hamming distance: 17
# **Test** MCC: 0.106. Val_Loss: 7691619106534.889
# ACC: 0.105.
# TPR: 0.085.
# F1-score: 0.049.
# Iteration Time 7.381 (7.427)
# **********************************
# attacked module: stage_3.7.conv_b
# attacked module: stage_2.0.conv_b
# attacked weight index: 7015
# weight before attack: tensor(-0.0635, device='cuda:0')
# weight after attack: tensor(127., device='cuda:0')
# Iteration: [010/025]   Attack Time 19.165 (15.584)
# Loss before attack: 7090771853312.0000
# Loss after attack: 43415299424256.0000
# Bit flips: 20
# Hamming distance: 19
# **Test** MCC: 0.074. Val_Loss: 46865926431543.117
# ACC: 0.094.
# TPR: 0.079.
# F1-score: 0.065.
# Iteration Time 7.386 (7.423)
# **********************************
# attacked module: stage_3.7.conv_a
# attacked module: stage_1.15.conv_a
# attacked weight index: 1198
# weight before attack: tensor(0.2800, device='cuda:0')
# weight after attack: tensor(64., device='cuda:0')
# Iteration: [011/025]   Attack Time 19.160 (15.909)
# Loss before attack: 43415299424256.0000
# Loss after attack: 3769392684859392.0000
# Bit flips: 22
# Hamming distance: 21
# **Test** MCC: 0.027. Val_Loss: 4070671996925161.500
# ACC: 0.039.
# TPR: 0.052.
# F1-score: 0.013.
# Iteration Time 7.302 (7.412)
# **********************************
# attacked module: stage_1.1.conv_a
# attacked module: stage_2.8.conv_a
# attacked weight index: 5884
# weight before attack: tensor(0.2243, device='cuda:0')
# weight after attack: tensor(1., device='cuda:0')
# Iteration: [012/025]   Attack Time 14.621 (15.802)
# Loss before attack: 3771721094004736.0000
# Loss after attack: 22785355556061184.0000
# Bit flips: 24
# Hamming distance: 23
# **Test** MCC: 0.013. Val_Loss: 24587193398507232.000
# ACC: 0.036.
# TPR: 0.050.
# F1-score: 0.010.
# Iteration Time 7.145 (7.390)
# **********************************
# attacked module: stage_1.1.conv_b
# attacked module: stage_3.8.conv_b
# attacked weight index: 23017
# weight before attack: tensor(0.2388, device='cuda:0')
# weight after attack: tensor(1., device='cuda:0')
# Iteration: [013/025]   Attack Time 14.587 (15.708)
# Loss before attack: 22786592506642432.0000
# Loss after attack: 1671130543187558400.0000
# Bit flips: 26
# Hamming distance: 25
# **Test** MCC: 0.013. Val_Loss: 1803565949732365312.000
# ACC: 0.036.
# TPR: 0.050.
# F1-score: 0.010.
# Iteration Time 7.456 (7.395)
# **********************************
# attacked module: stage_1.10.conv_b
# attacked module: stage_1.5.conv_a
# attacked weight index: 2782
# weight before attack: tensor(-0.1225, device='cuda:0')
# weight after attack: tensor(-17., device='cuda:0')
# Iteration: [014/025]   Attack Time 14.593 (15.628)
# Loss before attack: 1671130543187558400.0000
# Loss after attack: 9637916507828649984.0000
# Bit flips: 28
# Hamming distance: 27
# **Test** MCC: -0.009. Val_Loss: 10402328461890594816.000
# ACC: 0.028.
# TPR: 0.046.
# F1-score: 0.003.
# Iteration Time 7.508 (7.403)
# **********************************
# attacked module: stage_1.10.conv_a
# attacked module: stage_2.5.conv_b
# attacked weight index: 6900
# weight before attack: tensor(0.0339, device='cuda:0')
# weight after attack: tensor(8., device='cuda:0')
# Iteration: [015/025]   Attack Time 14.584 (15.559)
# Loss before attack: 9637916507828649984.0000
# Loss after attack: 1879098374810203324416.0000
# Bit flips: 30
# Hamming distance: 29
# **Test** MCC: 0.043. Val_Loss: 2027951318306425405440.000
# ACC: 0.037.
# TPR: 0.051.
# F1-score: 0.011.
# Iteration Time 7.032 (7.378)
# **********************************
# attacked module: stage_1.2.conv_b
# attacked module: stage_2.0.conv_a
# attacked weight index: 4956
# weight before attack: tensor(0.0031, device='cuda:0')
# weight after attack: tensor(32., device='cuda:0')
# Iteration: [016/025]   Attack Time 14.355 (15.484)
# Loss before attack: 1879098374810203324416.0000
# Loss after attack: 10237909183911595868160.0000
# Bit flips: 32
# Hamming distance: 31
# **Test** MCC: -0.009. Val_Loss: 11048769875867584167936.000
# ACC: 0.029.
# TPR: 0.047.
# F1-score: 0.004.
# Iteration Time 7.324 (7.375)
# **********************************
# attacked module: stage_1.2.conv_a
# attacked module: stage_3.1.conv_b
# attacked weight index: 39067
# weight before attack: tensor(0.0689, device='cuda:0')
# weight after attack: tensor(1., device='cuda:0')
# Iteration: [017/025]   Attack Time 14.657 (15.435)
# Loss before attack: 10237909183911595868160.0000
# Loss after attack: 1922311853260804085252096.0000
# Bit flips: 34
# Hamming distance: 33
# **Test** MCC: 0.001. Val_Loss: 2074902865599136775798784.000
# ACC: 0.031.
# TPR: 0.048.
# F1-score: 0.006.
# Iteration Time 7.425 (7.378)
# **********************************
# attacked module: stage_1.7.conv_b
# attacked module: stage_1.12.conv_a
# attacked weight index: 2948
# weight before attack: tensor(-0.0973, device='cuda:0')
# weight after attack: tensor(-2., device='cuda:0')
# Iteration: [018/025]   Attack Time 14.226 (15.368)
# Loss before attack: 1922311853260804085252096.0000
# Loss after attack: 9832126120502237079797760.0000
# Bit flips: 36
# Hamming distance: 35
# **Test** MCC: 0.023. Val_Loss: 10614421645461532130148352.000
# ACC: 0.031.
# TPR: 0.048.
# F1-score: 0.006.
# Iteration Time 7.384 (7.378)
# **********************************
# attacked module: stage_1.7.conv_a
# attacked module: stage_3.11.conv_b
# attacked weight index: 25465
# weight before attack: tensor(-0.1767, device='cuda:0')
# weight after attack: tensor(-2., device='cuda:0')
# Iteration: [019/025]   Attack Time 14.878 (15.342)
# Loss before attack: 9832126120502237079797760.0000
# Loss after attack: 3541724096712543061585952768.0000
# Bit flips: 38
# Hamming distance: 37
# **Test** MCC: 0.018. Val_Loss: 3822680924276398251480973312.000
# ACC: 0.031.
# TPR: 0.048.
# F1-score: 0.005.
# Iteration Time 7.399 (7.379)
# **********************************
# attacked module: stage_1.9.conv_b
# attacked module: stage_1.12.conv_b
# attacked weight index: 1205
# weight before attack: tensor(0.0819, device='cuda:0')
# weight after attack: tensor(-128., device='cuda:0')
# Iteration: [020/025]   Attack Time 14.320 (15.291)
# Loss before attack: 3541724096712543061585952768.0000
# Loss after attack: 17383499718316588843902435328.0000
# Bit flips: 40
# Hamming distance: 39
# **Test** MCC: 0.038. Val_Loss: 18763299281864414236533325824.000
# ACC: 0.039.
# TPR: 0.052.
# F1-score: 0.013.
# Iteration Time 7.550 (7.388)
# **********************************
# attacked module: stage_1.9.conv_a
# attacked module: stage_2.14.conv_a
# attacked weight index: 11883
# weight before attack: tensor(0.0447, device='cuda:0')
# weight after attack: tensor(16., device='cuda:0')
# Iteration: [021/025]   Attack Time 14.645 (15.260)
# Loss before attack: 17383499718316588843902435328.0000
# Loss after attack: 3549628648739360348705478672384.0000
# Bit flips: 42
# Hamming distance: 41
# **Test** MCC: 0.021. Val_Loss: 3830336971926929849883415281664.000
# ACC: 0.031.
# TPR: 0.048.
# F1-score: 0.006.
# Iteration Time 7.424 (7.389)
# **********************************
# attacked module: stage_3.5.conv_b
# attacked module: stage_2.15.conv_b
# attacked weight index: 7906
# weight before attack: tensor(-0.2211, device='cuda:0')
# weight after attack: tensor(-17., device='cuda:0')
# Iteration: [022/025]   Attack Time 19.092 (15.434)
# Loss before attack: 3549628648739360348705478672384.0000
# Loss after attack: 16148323349567978371471722414080.0000
# Bit flips: 44
# Hamming distance: 43
# **Test** MCC: 0.112. Val_Loss: 17427679013687366098245929402368.000
# ACC: 0.083.
# TPR: 0.075.
# F1-score: 0.039.
# Iteration Time 7.348 (7.387)
# **********************************
# attacked module: stage_3.5.conv_a
# attacked module: stage_2.7.conv_b
# attacked weight index: 11275
# weight before attack: tensor(-0.1885, device='cuda:0')
# weight after attack: tensor(-3., device='cuda:0')
# Iteration: [023/025]   Attack Time 19.145 (15.596)
# Loss before attack: 16148323349567978371471722414080.0000
# Loss after attack: 1004966223077077955409552265445376.0000
# Bit flips: 46
# Hamming distance: 45
# **Test** MCC: 0.001. Val_Loss: 1084361104170001867613161981476864.000
# ACC: 0.028.
# TPR: 0.046.
# F1-score: 0.003.
# Iteration Time 7.354 (7.386)
# **********************************
# attacked module: stage_1.12.conv_a
# attacked module: stage_2.11.conv_b
# attacked weight index: 4518
# weight before attack: tensor(0.0770, device='cuda:0')
# weight after attack: tensor(64., device='cuda:0')
# Iteration: [024/025]   Attack Time 14.666 (15.557)
# Loss before attack: 1004966223077077955409552265445376.0000
# Loss after attack: 4548482310758709372998914968387584.0000
# Bit flips: 48
# Hamming distance: 47
# **Test** MCC: 0.000. Val_Loss: 4908296281486222102787068115550208.000
# ACC: 0.028.
# TPR: 0.046.
# F1-score: 0.003.
# Iteration Time 7.413 (7.387)
# **********************************
# attacked module: stage_1.12.conv_b
# attacked module: stage_3.6.conv_b
# attacked weight index: 4522
# weight before attack: tensor(-0.1147, device='cuda:0')
# weight after attack: tensor(-3., device='cuda:0')
# Iteration: [025/025]   Attack Time 14.836 (15.528)
# Loss before attack: 4548482310758709372998914968387584.0000
# Loss after attack: 282602973508417693243629187194945536.0000
# Bit flips: 50
# Hamming distance: 49
# **Test** MCC: 0.000. Val_Loss: 304974523205291122331861878482927616.000
# ACC: 0.028.
# TPR: 0.046.
# F1-score: 0.003.
# Iteration Time 7.232 (7.381)
# Plot saved as CustomModel/PBS_to_RandomFlip_attack/MCC_PBS_to_RandomFlip_attack.png
# Plot saved as CustomModel/PBS_to_RandomFlip_attack/ACC_PBS_to_RandomFlip_attack.png
# Plot saved as CustomModel/PBS_to_RandomFlip_attack/TPR_PBS_to_RandomFlip_attack.png
# Plot saved as CustomModel/PBS_to_RandomFlip_attack/F1_PBS_to_RandomFlip_attack.png
# [Combined Plot] Saved as CustomModel/PBS_to_RandomFlip_attack/combined_metrics_PBS_to_RandomFlip_attack.png
# MCC after 100 times PBS to Random: 0.0003051715414987519
# Accuracy after 100 times PBS to Random: 0.028195505968492234
# TPR after 100 times PBS to Random: 0.046197404093500795
# F1-score after 100 times PBS to Random: 0.0026413239452855127

# %%
# Bước 1: Tải mô hình đã huấn luyện
model_path = os.path.join("CustomModel", "best_model.pth")
trained_model = CustomModel()

# Tải trọng số từ file best_model.pth
trained_model.load_state_dict(torch.load(model_path, map_location=torch.device('cuda' if torch.cuda.is_available() else 'cpu')))
trained_model = trained_model.to(device)

# Bước 2: Tạo bản sao của mô hình để làm tham chiếu
model_clean = copy.deepcopy(trained_model)

# Bước 3: Khởi tạo đối tượng tấn công BFA
attacker = BFA(criterion=criterion, model=trained_model, k_top=10)

# Định nghĩa đường dẫn để lưu kết quả tấn công
attack_dir = os.path.join("CustomModel", "RandomFlip_to_PBS_attack")

os.makedirs(attack_dir, exist_ok=True)
attack_image_paths = [os.path.join(attack_dir, f"{metric}_RandomFlip_to_PBS_attack.png") 
                      for metric in ["MCC", "ACC", "TPR", "F1"]]
# attack_image_path = os.path.join(attack_dir, "RandomFlip_to_PBS_attack.png")
attack_csv_path = os.path.join(attack_dir, "RandomFlip_to_PBS_attack.csv")

# Bước 4: Thực hiện tấn công
perform_attack(
    attacker=attacker,               # Đối tượng tấn công
    model=trained_model,             # Mô hình bị tấn công
    model_clean=model_clean,         # Mô hình gốc làm tham chiếu
    train_loader=train_loader,       # Bộ dữ liệu huấn luyện
    test_loader=test_loader,         # Bộ dữ liệu kiểm tra
    N_iter=args.n_iter,              # Số vòng lặp tấn công
    writer=writer,                   # TensorBoard writer để ghi log
    file=attack_image_paths,          # Lưu ảnh vào thư mục tấn công
    csv_file=attack_csv_path,  
    csv_save_path=args.save_path,    # Đường dẫn lưu file CSV
    attack_type= 4,                  # Chế độ tấn công Random -> PBS
)

writer.close()  # Đóng TensorBoard writer
# best_mcc = validate_score( trained_model,test_loader)
# print(f"\nMCC after 100 times random to PBS: {best_mcc}")

results = validate_score(trained_model, test_loader)
print(f"MCC after 100 times random to PBS: {results['MCC']}")
print(f"Accuracy after 100 times random to PBS: {results['Accuracy']}")
print(f"TPR after 100 times random to PBS: {results['TPR']}")
print(f"F1-score after 100 times random to PBS: {results['F1 Score']}")
# Out:
# **Test** MCC: 0.749. Val_Loss: 0.461
# ACC: 0.767.
# TPR: 0.711.
# F1-score: 0.701.
# Attack sample size is 256
# **********************************
# attacked module: stage_3.7.conv_b
# attacked weight index: 20829
# weight before attack: tensor(-0.0251, device='cuda:0')
# weight after attack: tensor(-9., device='cuda:0')
# attacked module: fc1
# Iteration: [001/025]   Attack Time 15.035 (15.035)
# Loss before attack: 0.2941
# Loss after attack: 91.6126
# Bit flips: 2
# Hamming distance: 2
# **Test** MCC: -0.002. Val_Loss: 87.681
# ACC: 0.032.
# TPR: 0.055.
# F1-score: 0.036.
# Iteration Time 7.416 (7.416)
# **********************************
# attacked module: stage_3.5.conv_b
# attacked weight index: 39581
# weight before attack: tensor(-0.0659, device='cuda:0')
# weight after attack: tensor(127., device='cuda:0')
# attacked module: stage_1.0.conv_b
# Iteration: [002/025]   Attack Time 14.808 (14.921)
# Loss before attack: 91.6126
# Loss after attack: 2937.7314
# Bit flips: 4
# Hamming distance: 4
# **Test** MCC: 0.073. Val_Loss: 2942.140
# ACC: 0.117.
# TPR: 0.086.
# F1-score: 0.056.
# Iteration Time 7.282 (7.349)
# **********************************
# attacked module: stage_2.10.conv_a
# attacked weight index: 6832
# weight before attack: tensor(0.1311, device='cuda:0')
# weight after attack: tensor(1., device='cuda:0')
# attacked module: stage_1.0.conv_a
# Iteration: [003/025]   Attack Time 14.423 (14.755)
# Loss before attack: 2937.7314
# Loss after attack: 591473.0625
# Bit flips: 6
# Hamming distance: 6
# **Test** MCC: 0.079. Val_Loss: 589133.316
# ACC: 0.120.
# TPR: 0.100.
# F1-score: 0.068.
# Iteration Time 7.674 (7.457)
# **********************************
# attacked module: stage_3.3.conv_a
# attacked weight index: 2273
# weight before attack: tensor(0.0334, device='cuda:0')
# weight after attack: tensor(16., device='cuda:0')
# attacked module: classifier
# Iteration: [004/025]   Attack Time 16.373 (15.160)
# Loss before attack: 591473.0625
# Loss after attack: 10638523.0000
# Bit flips: 8
# Hamming distance: 7
# **Test** MCC: 0.079. Val_Loss: 10739473.536
# ACC: 0.117.
# TPR: 0.099.
# F1-score: 0.065.
# Iteration Time 7.801 (7.543)
# **********************************
# attacked module: stage_2.2.conv_b
# attacked weight index: 3612
# weight before attack: tensor(-0.0758, device='cuda:0')
# weight after attack: tensor(-17., device='cuda:0')
# attacked module: stage_2.12.conv_b
# Iteration: [005/025]   Attack Time 16.356 (15.399)
# Loss before attack: 10638523.0000
# Loss after attack: 130046032.0000
# Bit flips: 10
# Hamming distance: 9
# **Test** MCC: 0.038. Val_Loss: 130860841.868
# ACC: 0.097.
# TPR: 0.066.
# F1-score: 0.033.
# Iteration Time 7.856 (7.606)
# **********************************
# attacked module: stage_2.12.conv_a
# attacked weight index: 7856
# weight before attack: tensor(0.0727, device='cuda:0')
# weight after attack: tensor(4., device='cuda:0')
# attacked module: stage_2.12.conv_a
# Iteration: [006/025]   Attack Time 16.030 (15.504)
# Loss before attack: 130046032.0000
# Loss after attack: 13237475328.0000
# Bit flips: 12
# Hamming distance: 11
# **Test** MCC: 0.018. Val_Loss: 13320542604.450
# ACC: 0.089.
# TPR: 0.048.
# F1-score: 0.011.
# Iteration Time 7.937 (7.661)
# **********************************
# attacked module: stage_3.13.conv_a
# attacked weight index: 30697
# weight before attack: tensor(0.2115, device='cuda:0')
# weight after attack: tensor(4., device='cuda:0')
# attacked module: stage_1.4.conv_b
# Iteration: [007/025]   Attack Time 15.386 (15.487)
# Loss before attack: 13237475328.0000
# Loss after attack: 200887828480.0000
# Bit flips: 14
# Hamming distance: 13
# **Test** MCC: 0.020. Val_Loss: 202145846844.737
# ACC: 0.089.
# TPR: 0.046.
# F1-score: 0.011.
# Iteration Time 7.942 (7.701)
# **********************************
# attacked module: stage_1.1.conv_a
# attacked weight index: 2518
# weight before attack: tensor(0.2337, device='cuda:0')
# weight after attack: tensor(1., device='cuda:0')
# attacked module: stage_1.4.conv_a
# Iteration: [008/025]   Attack Time 15.706 (15.515)
# Loss before attack: 200887828480.0000
# Loss after attack: 19763141017600.0000
# Bit flips: 16
# Hamming distance: 15
# **Test** MCC: 0.021. Val_Loss: 19886943882148.836
# ACC: 0.090.
# TPR: 0.048.
# F1-score: 0.012.
# Iteration Time 7.785 (7.712)
# **********************************
# attacked module: stage_2.15.conv_b
# attacked weight index: 3365
# weight before attack: tensor(-0.0053, device='cuda:0')
# weight after attack: tensor(127., device='cuda:0')
# attacked module: stage_2.1.conv_b
# Iteration: [009/025]   Attack Time 16.288 (15.600)
# Loss before attack: 19763141017600.0000
# Loss after attack: 229699984818176.0000
# Bit flips: 18
# Hamming distance: 17
# **Test** MCC: 0.023. Val_Loss: 231135260685422.719
# ACC: 0.090.
# TPR: 0.047.
# F1-score: 0.012.
# Iteration Time 7.772 (7.718)
# **********************************
# attacked module: stage_2.6.conv_a
# attacked weight index: 2814
# weight before attack: tensor(-0.0294, device='cuda:0')
# weight after attack: tensor(-9., device='cuda:0')
# attacked module: stage_2.1.conv_a
# Iteration: [010/025]   Attack Time 16.342 (15.675)
# Loss before attack: 229699984818176.0000
# Loss after attack: 22834990345617408.0000
# Bit flips: 20
# Hamming distance: 19
# **Test** MCC: 0.022. Val_Loss: 22979067681705476.000
# ACC: 0.090.
# TPR: 0.049.
# F1-score: 0.013.
# Iteration Time 7.785 (7.725)
# **********************************
# attacked module: stage_3.2.conv_b
# attacked weight index: 19302
# weight before attack: tensor(-0.0103, device='cuda:0')
# weight after attack: tensor(127., device='cuda:0')
# attacked module: stage_1.2.conv_b
# Iteration: [011/025]   Attack Time 15.314 (15.642)
# Loss before attack: 22834990345617408.0000
# Loss after attack: 253809580528631808.0000
# Bit flips: 22
# Hamming distance: 21
# **Test** MCC: 0.014. Val_Loss: 255391800704116288.000
# ACC: 0.088.
# TPR: 0.047.
# F1-score: 0.010.
# Iteration Time 7.768 (7.729)
# **********************************
# attacked module: stage_1.7.conv_b
# attacked weight index: 2078
# weight before attack: tensor(-0.0161, device='cuda:0')
# weight after attack: tensor(-3., device='cuda:0')
# attacked module: stage_1.2.conv_a
# Iteration: [012/025]   Attack Time 15.566 (15.636)
# Loss before attack: 253809580528631808.0000
# Loss after attack: 29395296034033238016.0000
# Bit flips: 24
# Hamming distance: 23
# **Test** MCC: 0.027. Val_Loss: 29581684811418107904.000
# ACC: 0.091.
# TPR: 0.050.
# F1-score: 0.016.
# Iteration Time 7.856 (7.739)
# **********************************
# attacked module: stage_3.0.conv_a
# attacked weight index: 20039
# weight before attack: tensor(0.0434, device='cuda:0')
# weight after attack: tensor(64., device='cuda:0')
# attacked module: stage_2.8.conv_a
# Iteration: [013/025]   Attack Time 16.464 (15.699)
# Loss before attack: 29395296034033238016.0000
# Loss after attack: 297264984032309936128.0000
# Bit flips: 26
# Hamming distance: 25
# **Test** MCC: 0.033. Val_Loss: 299123770642718195712.000
# ACC: 0.093.
# TPR: 0.053.
# F1-score: 0.021.
# Iteration Time 7.910 (7.753)
# **********************************
# attacked module: stage_1.3.conv_b
# attacked weight index: 1371
# weight before attack: tensor(0.0038, device='cuda:0')
# weight after attack: tensor(4., device='cuda:0')
# attacked module: stage_2.8.conv_b
# Iteration: [014/025]   Attack Time 16.101 (15.728)
# Loss before attack: 297264984032309936128.0000
# Loss after attack: 44723761711539363512320.0000
# Bit flips: 28
# Hamming distance: 27
# **Test** MCC: 0.033. Val_Loss: 45006717757042227937280.000
# ACC: 0.093.
# TPR: 0.053.
# F1-score: 0.021.
# Iteration Time 7.637 (7.744)
# **********************************
# attacked module: stage_3.15.conv_b
# attacked weight index: 25491
# weight before attack: tensor(-0.0175, device='cuda:0')
# weight after attack: tensor(-5., device='cuda:0')
# attacked module: stage_1.3.conv_b
# Iteration: [015/025]   Attack Time 15.523 (15.714)
# Loss before attack: 44723761711539363512320.0000
# Loss after attack: 419196350352338450382848.0000
# Bit flips: 30
# Hamming distance: 29
# **Test** MCC: 0.035. Val_Loss: 421842733631373876133888.000
# ACC: 0.091.
# TPR: 0.050.
# F1-score: 0.018.
# Iteration Time 7.821 (7.749)
# **********************************
# attacked module: stage_2.4.conv_a
# attacked weight index: 1511
# weight before attack: tensor(-0.0215, device='cuda:0')
# weight after attack: tensor(-3., device='cuda:0')
# attacked module: stage_1.3.conv_a
# Iteration: [016/025]   Attack Time 15.449 (15.698)
# Loss before attack: 419196350352338450382848.0000
# Loss after attack: 54941233758500335673933824.0000
# Bit flips: 32
# Hamming distance: 31
# **Test** MCC: 0.039. Val_Loss: 55284569460393944291475456.000
# ACC: 0.094.
# TPR: 0.056.
# F1-score: 0.025.
# Iteration Time 7.923 (7.760)
# **********************************
# attacked module: stage_2.13.conv_a
# attacked weight index: 3495
# weight before attack: tensor(-0.0312, device='cuda:0')
# weight after attack: tensor(-3., device='cuda:0')
# attacked module: stage_2.0.conv_b
# Iteration: [017/025]   Attack Time 16.415 (15.740)
# Loss before attack: 54941233758500335673933824.0000
# Loss after attack: 479025861762828879584559104.0000
# Bit flips: 34
# Hamming distance: 33
# **Test** MCC: 0.009. Val_Loss: 482001690379027530236559360.000
# ACC: 0.087.
# TPR: 0.047.
# F1-score: 0.009.
# Iteration Time 7.917 (7.770)
# **********************************
# attacked module: stage_3.9.conv_a
# attacked weight index: 24884
# weight before attack: tensor(-0.0144, device='cuda:0')
# weight after attack: tensor(-2., device='cuda:0')
# attacked module: stage_2.0.conv_a
# Iteration: [018/025]   Attack Time 15.802 (15.743)
# Loss before attack: 479025861762828879584559104.0000
# Loss after attack: 66689627815670793540141580288.0000
# Bit flips: 36
# Hamming distance: 35
# **Test** MCC: 0.023. Val_Loss: 67104088552610405014482976768.000
# ACC: 0.090.
# TPR: 0.048.
# F1-score: 0.013.
# Iteration Time 7.800 (7.771)
# **********************************
# attacked module: stage_3.7.conv_b
# attacked weight index: 7619
# weight before attack: tensor(0.0100, device='cuda:0')
# weight after attack: tensor(8., device='cuda:0')
# attacked module: stage_1.15.conv_b
# Iteration: [019/025]   Attack Time 15.567 (15.734)
# Loss before attack: 66689627815670793540141580288.0000
# Loss after attack: 543267084818422058529461370880.0000
# Bit flips: 38
# Hamming distance: 37
# **Test** MCC: 0.027. Val_Loss: 546693773454123784944383688704.000
# ACC: 0.090.
# TPR: 0.052.
# F1-score: 0.018.
# Iteration Time 7.776 (7.772)
# **********************************
# attacked module: stage_1.2.conv_a
# attacked weight index: 598
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-9., device='cuda:0')
# attacked module: stage_1.15.conv_a
# Iteration: [020/025]   Attack Time 15.453 (15.720)
# Loss before attack: 543267084818422058529461370880.0000
# Loss after attack: 68179291371368560338684228927488.0000
# Bit flips: 40
# Hamming distance: 39
# **Test** MCC: 0.015. Val_Loss: 68605107510788578577671528644608.000
# ACC: 0.088.
# TPR: 0.047.
# F1-score: 0.010.
# Iteration Time 7.904 (7.778)
# **********************************
# attacked module: stage_2.10.conv_b
# attacked weight index: 10968
# weight before attack: tensor(0.0087, device='cuda:0')
# weight after attack: tensor(32., device='cuda:0')
# attacked module: stage_1.1.conv_b
# Iteration: [021/025]   Attack Time 15.446 (15.707)
# Loss before attack: 68179291371368560338684228927488.0000
# Loss after attack: 524710286258281752872456317566976.0000
# Bit flips: 42
# Hamming distance: 41
# **Test** MCC: 0.013. Val_Loss: 528013979717777972459270762921984.000
# ACC: 0.088.
# TPR: 0.046.
# F1-score: 0.009.
# Iteration Time 7.940 (7.786)
# **********************************
# attacked module: stage_1.11.conv_a
# attacked weight index: 686
# weight before attack: tensor(-0.0019, device='cuda:0')
# weight after attack: tensor(-9., device='cuda:0')
# attacked module: stage_1.1.conv_a
# Iteration: [022/025]   Attack Time 15.500 (15.698)
# Loss before attack: 524710286258281752872456317566976.0000
# Loss after attack: 58114669292878662834324821396946944.0000
# Bit flips: 44
# Hamming distance: 43
# **Test** MCC: 0.022. Val_Loss: 58476059650343085419011807679348736.000
# ACC: 0.089.
# TPR: 0.048.
# F1-score: 0.012.
# Iteration Time 7.975 (7.794)
# **********************************
# attacked module: stage_3.1.conv_b
# attacked weight index: 17970
# weight before attack: tensor(-0.0146, device='cuda:0')
# weight after attack: tensor(-3., device='cuda:0')
# attacked module: stage_2.2.conv_b
# Iteration: [023/025]   Attack Time 16.286 (15.723)
# Loss before attack: 58114669292878662834324821396946944.0000
# Loss after attack: 419631447773744721346011174918946816.0000
# Bit flips: 46
# Hamming distance: 45
# **Test** MCC: 0.028. Val_Loss: 422228730516603539112676749452771328.000
# ACC: 0.090.
# TPR: 0.049.
# F1-score: 0.014.
# Iteration Time 8.123 (7.809)
# **********************************
# attacked module: stage_1.14.conv_b
# attacked weight index: 18
# weight before attack: tensor(-0.0107, device='cuda:0')
# weight after attack: tensor(-65., device='cuda:0')
# attacked module: stage_1.5.conv_b
# Iteration: [024/025]   Attack Time 15.416 (15.710)
# Loss before attack: 419631447773744721346011174918946816.0000
# Loss after attack: inf
# Bit flips: 48
# Hamming distance: 47
# **Test** MCC: 0.004. Val_Loss: inf
# ACC: 0.087.
# TPR: 0.046.
# F1-score: 0.008.
# Iteration Time 7.772 (7.807)
# **********************************
# attacked module: stage_1.5.conv_a
# attacked weight index: 2937
# weight before attack: tensor(-0.0328, device='cuda:0')
# weight after attack: tensor(-65., device='cuda:0')
# attacked module: fc1
# Iteration: [025/025]   Attack Time 156.645 (21.348)
# Loss before attack: inf
# Loss after attack: inf
# Bit flips: 149
# Hamming distance: 126
# **Test** MCC: 0.001. Val_Loss: inf
# ACC: 0.087.
# TPR: 0.046.
# F1-score: 0.008.
# Iteration Time 7.791 (7.807)
# Plot saved as CustomModel/RandomFlip_to_PBS_attack/MCC_RandomFlip_to_PBS_attack.png
# Plot saved as CustomModel/RandomFlip_to_PBS_attack/ACC_RandomFlip_to_PBS_attack.png
# Plot saved as CustomModel/RandomFlip_to_PBS_attack/TPR_RandomFlip_to_PBS_attack.png
# Plot saved as CustomModel/RandomFlip_to_PBS_attack/F1_RandomFlip_to_PBS_attack.png
# [Combined Plot] Saved as CustomModel/RandomFlip_to_PBS_attack/combined_metrics_RandomFlip_to_PBS_attack.png
# MCC after 100 times random to PBS: 0.001406022054212994
# Accuracy after 100 times random to PBS: 0.08690785308609125
# TPR after 100 times random to PBS: 0.0463253783226756
# F1-score after 100 times random to PBS: 0.00766806886183379

# %% [markdown]
# ## Train CustomModel2

# %%
# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# model = CustomModel2().to(device)
# criterion = torch.nn.CrossEntropyLoss()
# optimizer = optim.AdamW(model.parameters(), lr=0.001, weight_decay=0.01)

# best_val_loss = float('inf')
# patience = 10  # Số epoch để chờ trước khi dừng
# counter = 0
# scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=5)

# # Vòng lặp huấn luyện
# best_val_loss = float('inf')
# best_mcc = -1  # Khởi tạo MCC tốt nhất

# # Vòng lặp huấn luyện
# for epoch in range(num_epochs):
#     train_mcc, train_loss = train(train_loader, model, criterion, optimizer, epoch)
#     val_mcc, val_loss, output_summary = validate(test_loader, model, criterion, summary_output=True)
#     scheduler.step(val_loss)

#     if val_loss < best_val_loss:
#         best_val_loss = val_loss
#         best_mcc = val_mcc  # Lưu MCC tốt nhất
#         counter = 0

#         save_dir = "CustomModel2"
#         save_path = os.path.join(save_dir, "model.pth")

#         if not os.path.exists(save_dir):
#             os.makedirs(save_dir)

#         torch.save(model.state_dict(), save_path)
#     else:
#         counter += 1
#         if counter >= patience:
#             print("Early stopping triggered")
#             break

#     print(f"Epoch {epoch+1}/{num_epochs}")
#     print(f"Train Loss: {train_loss:.4f}, Train MCC: {train_mcc:.4f}")
#     print(f"Validation Loss: {val_loss:.4f}, Validation MCC: {val_mcc:.4f}")
# print(f"Best MCC during training: {best_mcc}")

# %% [markdown]
# ## Attack second model

# %%
model_path = os.path.join("CustomModel2", "model.pth")
if not os.path.exists(model_path):
    raise FileNotFoundError(f"Không tìm thấy mô hình tại: {model_path}")

trained_model = CustomModel2()

trained_model.load_state_dict(torch.load(model_path, map_location=torch.device('cuda' if torch.cuda.is_available() else 'cpu')))
trained_model = trained_model.to(device)

# best_mcc = validate_score(trained_model, test_loader)
# print(f"MCC before attack: {best_mcc}")

results = validate_score(trained_model, test_loader)
print(f"MCC before attack: {results['MCC']}")
print(f"Accuracy before attack: {results['Accuracy']}")
print(f"TPR before attack: {results['TPR']}")
print(f"F1-score before attack: {results['F1 Score']}")
# Out:
# MCC before attack: 0.713019661995725
# Accuracy before attack: 0.725146574424942
# TPR before attack: 0.5750286438492276
# F1-score before attack: 0.5156814372130539

# %%
model_path = os.path.join("CustomModel2", "model.pth")

trained_model = CustomModel2()

trained_model.load_state_dict(torch.load(model_path, map_location=torch.device('cuda' if torch.cuda.is_available() else 'cpu')))
trained_model = trained_model.to(device)

model_clean = copy.deepcopy(trained_model)

attacker = BFA(criterion=criterion, model=trained_model, k_top=10)

# Định nghĩa đường dẫn để lưu kết quả tấn công
attack_dir = os.path.join("CustomModel2", "PBS_attack")

os.makedirs(attack_dir, exist_ok=True)
attack_image_paths = [os.path.join(attack_dir, f"{metric}_PBS_attack.png") 
                      for metric in ["MCC", "ACC", "TPR", "F1"]]
# attack_image_path = os.path.join(attack_dir, "PBS_attack.png")
attack_csv_path = os.path.join(attack_dir, "PBS_attack.csv")

perform_attack(
    attacker=attacker,               # Đối tượng tấn công
    model=trained_model,             # Mô hình bị tấn công
    model_clean=model_clean,         # Mô hình gốc làm tham chiếu
    train_loader=train_loader,       # Bộ dữ liệu huấn luyện
    test_loader=test_loader,         # Bộ dữ liệu kiểm tra
    N_iter=args.n_iter,              # Số vòng lặp tấn công
    writer=writer,                   # TensorBoard writer để ghi log
    file=attack_image_paths,          # Lưu ảnh vào thư mục tấn công
    csv_file=attack_csv_path,  
    csv_save_path=args.save_path,    # Đường dẫn lưu file CSV
    attack_type= 1,                  # Chế độ tấn công PBS
)

writer.close()  # Đóng TensorBoard writer
# best_mcc = validate_score(trained_model, test_loader)
# print(f"\nMCC after 100 times PBS: {best_mcc}")

results = validate_score(trained_model, test_loader)
print(f"MCC after 100 times PBS attack: {results['MCC']}")
print(f"Accuracy after 100 times PBS attack: {results['Accuracy']}")
print(f"TPR after 100 times PBS attack: {results['TPR']}")
print(f"F1-score after 100 times PBS attack: {results['F1 Score']}")
# Out:
# **Test** MCC: 0.713. Val_Loss: 2.851
# ACC: 0.725.
# TPR: 0.575.
# F1-score: 0.516.
# Attack sample size is 256
# **********************************
# attacked module: classifier
# Iteration: [001/025]   Attack Time 3.200 (3.200)
# Loss before attack: 2.5850
# Loss after attack: 2.6464
# Bit flips: 1
# Hamming distance: 0
# **Test** MCC: 0.661. Val_Loss: 2.899
# ACC: 0.677.
# TPR: 0.483.
# F1-score: 0.435.
# Iteration Time 3.271 (3.271)
# **********************************
# attacked module: classifier
# Iteration: [002/025]   Attack Time 4.068 (3.634)
# Loss before attack: 2.6464
# Loss after attack: 2.6464
# Bit flips: 101
# Hamming distance: 0
# **Test** MCC: 0.661. Val_Loss: 2.899
# ACC: 0.677.
# TPR: 0.483.
# F1-score: 0.435.
# Iteration Time 3.283 (3.277)
# **********************************
# attacked module: classifier
# Iteration: [003/025]   Attack Time 3.378 (3.548)
# Loss before attack: 2.6464
# Loss after attack: 2.6464
# Bit flips: 201
# Hamming distance: 0
# **Test** MCC: 0.661. Val_Loss: 2.899
# ACC: 0.677.
# TPR: 0.483.
# F1-score: 0.435.
# Iteration Time 3.041 (3.198)
# **********************************
# attacked module: classifier
# Iteration: [004/025]   Attack Time 2.957 (3.401)
# Loss before attack: 2.6464
# Loss after attack: 2.6464
# Bit flips: 301
# Hamming distance: 0
# **Test** MCC: 0.661. Val_Loss: 2.899
# ACC: 0.677.
# TPR: 0.483.
# F1-score: 0.435.
# Iteration Time 2.846 (3.110)
# **********************************
# attacked module: classifier
# Iteration: [005/025]   Attack Time 2.719 (3.264)
# Loss before attack: 2.6464
# Loss after attack: 2.6464
# Bit flips: 401
# Hamming distance: 0
# **Test** MCC: 0.661. Val_Loss: 2.899
# ACC: 0.677.
# TPR: 0.483.
# F1-score: 0.435.
# Iteration Time 2.807 (3.050)
# **********************************
# attacked module: classifier
# Iteration: [006/025]   Attack Time 2.702 (3.170)
# Loss before attack: 2.6464
# Loss after attack: 2.6464
# Bit flips: 501
# Hamming distance: 0
# **Test** MCC: 0.661. Val_Loss: 2.899
# ACC: 0.677.
# TPR: 0.483.
# F1-score: 0.435.
# Iteration Time 2.938 (3.031)
# **********************************
# attacked module: classifier
# Iteration: [007/025]   Attack Time 2.713 (3.105)
# Loss before attack: 2.6464
# Loss after attack: 2.6464
# Bit flips: 601
# Hamming distance: 0
# **Test** MCC: 0.661. Val_Loss: 2.899
# ACC: 0.677.
# TPR: 0.483.
# F1-score: 0.435.
# Iteration Time 2.857 (3.006)
# **********************************
# attacked module: classifier
# Iteration: [008/025]   Attack Time 2.762 (3.062)
# Loss before attack: 2.6464
# Loss after attack: 2.6464
# Bit flips: 701
# Hamming distance: 0
# **Test** MCC: 0.661. Val_Loss: 2.899
# ACC: 0.677.
# TPR: 0.483.
# F1-score: 0.435.
# Iteration Time 2.614 (2.957)
# **********************************
# attacked module: classifier
# Iteration: [009/025]   Attack Time 2.592 (3.010)
# Loss before attack: 2.6464
# Loss after attack: 2.6464
# Bit flips: 801
# Hamming distance: 0
# **Test** MCC: 0.661. Val_Loss: 2.899
# ACC: 0.677.
# TPR: 0.483.
# F1-score: 0.435.
# Iteration Time 2.810 (2.941)
# **********************************
# attacked module: classifier
# Iteration: [010/025]   Attack Time 2.666 (2.976)
# Loss before attack: 2.6464
# Loss after attack: 2.6464
# Bit flips: 901
# Hamming distance: 0
# **Test** MCC: 0.661. Val_Loss: 2.899
# ACC: 0.677.
# TPR: 0.483.
# F1-score: 0.435.
# Iteration Time 2.806 (2.927)
# **********************************
# attacked module: classifier
# Iteration: [011/025]   Attack Time 2.645 (2.946)
# Loss before attack: 2.6464
# Loss after attack: 2.6464
# Bit flips: 1001
# Hamming distance: 0
# **Test** MCC: 0.661. Val_Loss: 2.899
# ACC: 0.677.
# TPR: 0.483.
# F1-score: 0.435.
# Iteration Time 2.769 (2.913)
# **********************************
# attacked module: classifier
# Iteration: [012/025]   Attack Time 2.652 (2.921)
# Loss before attack: 2.6464
# Loss after attack: 2.6464
# Bit flips: 1101
# Hamming distance: 0
# **Test** MCC: 0.661. Val_Loss: 2.899
# ACC: 0.677.
# TPR: 0.483.
# F1-score: 0.435.
# Iteration Time 2.865 (2.909)
# **********************************
# attacked module: classifier
# Iteration: [013/025]   Attack Time 2.681 (2.903)
# Loss before attack: 2.6464
# Loss after attack: 2.6464
# Bit flips: 1201
# Hamming distance: 0
# **Test** MCC: 0.661. Val_Loss: 2.899
# ACC: 0.677.
# TPR: 0.483.
# F1-score: 0.435.
# Iteration Time 2.886 (2.907)
# **********************************
# attacked module: classifier
# Iteration: [014/025]   Attack Time 2.743 (2.891)
# Loss before attack: 2.6464
# Loss after attack: 2.6464
# Bit flips: 1301
# Hamming distance: 0
# **Test** MCC: 0.661. Val_Loss: 2.899
# ACC: 0.677.
# TPR: 0.483.
# F1-score: 0.435.
# Iteration Time 2.810 (2.900)
# **********************************
# attacked module: classifier
# Iteration: [015/025]   Attack Time 2.762 (2.883)
# Loss before attack: 2.6464
# Loss after attack: 2.6464
# Bit flips: 1401
# Hamming distance: 0
# **Test** MCC: 0.661. Val_Loss: 2.899
# ACC: 0.677.
# TPR: 0.483.
# F1-score: 0.435.
# Iteration Time 2.870 (2.898)
# **********************************
# attacked module: classifier
# Iteration: [016/025]   Attack Time 2.814 (2.878)
# Loss before attack: 2.6464
# Loss after attack: 2.6464
# Bit flips: 1501
# Hamming distance: 0
# **Test** MCC: 0.661. Val_Loss: 2.899
# ACC: 0.677.
# TPR: 0.483.
# F1-score: 0.435.
# Iteration Time 2.884 (2.897)
# **********************************
# attacked module: classifier
# Iteration: [017/025]   Attack Time 2.750 (2.871)
# Loss before attack: 2.6464
# Loss after attack: 2.6464
# Bit flips: 1601
# Hamming distance: 0
# **Test** MCC: 0.661. Val_Loss: 2.899
# ACC: 0.677.
# TPR: 0.483.
# F1-score: 0.435.
# Iteration Time 2.833 (2.894)
# **********************************
# attacked module: classifier
# Iteration: [018/025]   Attack Time 2.759 (2.865)
# Loss before attack: 2.6464
# Loss after attack: 2.6464
# Bit flips: 1701
# Hamming distance: 0
# **Test** MCC: 0.661. Val_Loss: 2.899
# ACC: 0.677.
# TPR: 0.483.
# F1-score: 0.435.
# Iteration Time 2.856 (2.891)
# **********************************
# attacked module: classifier
# Iteration: [019/025]   Attack Time 2.630 (2.852)
# Loss before attack: 2.6464
# Loss after attack: 2.6464
# Bit flips: 1801
# Hamming distance: 0
# **Test** MCC: 0.661. Val_Loss: 2.899
# ACC: 0.677.
# TPR: 0.483.
# F1-score: 0.435.
# Iteration Time 2.858 (2.890)
# **********************************
# attacked module: classifier
# Iteration: [020/025]   Attack Time 2.713 (2.845)
# Loss before attack: 2.6464
# Loss after attack: 2.6464
# Bit flips: 1901
# Hamming distance: 0
# **Test** MCC: 0.661. Val_Loss: 2.899
# ACC: 0.677.
# TPR: 0.483.
# F1-score: 0.435.
# Iteration Time 2.814 (2.886)
# **********************************
# attacked module: classifier
# Iteration: [021/025]   Attack Time 2.776 (2.842)
# Loss before attack: 2.6464
# Loss after attack: 2.6464
# Bit flips: 2001
# Hamming distance: 0
# **Test** MCC: 0.661. Val_Loss: 2.899
# ACC: 0.677.
# TPR: 0.483.
# F1-score: 0.435.
# Iteration Time 2.805 (2.882)
# **********************************
# attacked module: classifier
# Iteration: [022/025]   Attack Time 2.567 (2.829)
# Loss before attack: 2.6464
# Loss after attack: 2.6464
# Bit flips: 2101
# Hamming distance: 0
# **Test** MCC: 0.661. Val_Loss: 2.899
# ACC: 0.677.
# TPR: 0.483.
# F1-score: 0.435.
# Iteration Time 2.685 (2.873)
# **********************************
# attacked module: classifier
# Iteration: [023/025]   Attack Time 2.573 (2.818)
# Loss before attack: 2.6464
# Loss after attack: 2.6464
# Bit flips: 2201
# Hamming distance: 0
# **Test** MCC: 0.661. Val_Loss: 2.899
# ACC: 0.677.
# TPR: 0.483.
# F1-score: 0.435.
# Iteration Time 2.845 (2.872)
# **********************************
# attacked module: classifier
# Iteration: [024/025]   Attack Time 2.734 (2.815)
# Loss before attack: 2.6464
# Loss after attack: 2.6464
# Bit flips: 2301
# Hamming distance: 0
# **Test** MCC: 0.661. Val_Loss: 2.899
# ACC: 0.677.
# TPR: 0.483.
# F1-score: 0.435.
# Iteration Time 2.773 (2.868)
# **********************************
# attacked module: classifier
# Iteration: [025/025]   Attack Time 2.711 (2.811)
# Loss before attack: 2.6464
# Loss after attack: 2.6464
# Bit flips: 2401
# Hamming distance: 0
# **Test** MCC: 0.661. Val_Loss: 2.899
# ACC: 0.677.
# TPR: 0.483.
# F1-score: 0.435.
# Iteration Time 2.718 (2.862)
# Plot saved as CustomModel2/PBS_attack/MCC_PBS_attack.png
# Plot saved as CustomModel2/PBS_attack/ACC_PBS_attack.png
# Plot saved as CustomModel2/PBS_attack/TPR_PBS_attack.png
# Plot saved as CustomModel2/PBS_attack/F1_PBS_attack.png
# [Combined Plot] Saved as CustomModel2/PBS_attack/combined_metrics_PBS_attack.png
# MCC after 100 times PBS attack: 0.6612743462999665
# Accuracy after 100 times PBS attack: 0.677004101331327
# TPR after 100 times PBS attack: 0.4829373339200396
# F1-score after 100 times PBS attack: 0.4354109642091606

# %%
model_path = os.path.join("CustomModel2", "model.pth")
trained_model = CustomModel2()

trained_model.load_state_dict(torch.load(model_path, map_location=torch.device('cuda' if torch.cuda.is_available() else 'cpu')))
trained_model = trained_model.to(device)

# Bước 2: Tạo bản sao của mô hình để làm tham chiếu
model_clean = copy.deepcopy(trained_model)

# Bước 3: Khởi tạo đối tượng tấn công BFA
attacker = BFA(criterion=criterion, model=trained_model, k_top=10)

# Định nghĩa đường dẫn để lưu kết quả tấn công
attack_dir = os.path.join("CustomModel2", "RandomFlip_attack")

os.makedirs(attack_dir, exist_ok=True)
attack_image_paths = [os.path.join(attack_dir, f"{metric}_RandomFlip_attack.png") 
                      for metric in ["MCC", "ACC", "TPR", "F1"]]
# attack_image_path = os.path.join(attack_dir, "RandomFlip_attack.png")
attack_csv_path = os.path.join(attack_dir, "RandomFlip_attack.csv")

# Bước 4: Thực hiện tấn công
perform_attack(
    attacker=attacker,               # Đối tượng tấn công
    model=trained_model,             # Mô hình bị tấn công
    model_clean=model_clean,         # Mô hình gốc làm tham chiếu
    train_loader=train_loader,       # Bộ dữ liệu huấn luyện
    test_loader=test_loader,         # Bộ dữ liệu kiểm tra
    N_iter=args.n_iter,              # Số vòng lặp tấn công
    writer=writer,                   # TensorBoard writer để ghi log
    file=attack_image_paths,          # Lưu ảnh vào thư mục tấn công
    csv_file=attack_csv_path, 
    csv_save_path=args.save_path,    # Đường dẫn lưu file CSV
    attack_type= 2,                  # Chế độ tấn công random
)

writer.close()  # Đóng TensorBoard writer

# best_mcc = validate_score(trained_model ,test_loader)
# print(f"\nMCC after 100 times Random attack: {best_mcc}")

results = validate_score(trained_model, test_loader)
print(f"MCC after 100 times random attack: {results['MCC']}")
print(f"Accuracy after 100 times random attack: {results['Accuracy']}")
print(f"TPR after 100 times random attack: {results['TPR']}")
print(f"F1-score after 100 times random attack: {results['F1 Score']}")
# Out:
# **Test** MCC: 0.713. Val_Loss: 2.851
# ACC: 0.725.
# TPR: 0.575.
# F1-score: 0.516.
# Attack sample size is 256
# **********************************
# attacked module: classifier
# attacked weight index: 1264
# weight before attack: tensor(0.0115, device='cuda:0')
# weight after attack: tensor(2048., device='cuda:0')
# Iteration: [001/025]   Attack Time 2.567 (2.567)
# Bit flips: 1
# Hamming distance: 0
# **Test** MCC: 0.254. Val_Loss: 3.348
# ACC: 0.228.
# TPR: 0.136.
# F1-score: 0.107.
# Iteration Time 2.879 (2.879)
# **********************************
# attacked module: classifier
# attacked weight index: 2575
# weight before attack: tensor(0.0247, device='cuda:0')
# weight after attack: tensor(1., device='cuda:0')
# Iteration: [002/025]   Attack Time 2.520 (2.544)
# Bit flips: 2
# Hamming distance: 0
# **Test** MCC: 0.253. Val_Loss: 3.348
# ACC: 0.228.
# TPR: 0.136.
# F1-score: 0.107.
# Iteration Time 2.811 (2.845)
# **********************************
# attacked module: classifier
# attacked weight index: 412
# weight before attack: tensor(0.0315, device='cuda:0')
# weight after attack: tensor(4096., device='cuda:0')
# Iteration: [003/025]   Attack Time 2.513 (2.533)
# Bit flips: 3
# Hamming distance: 0
# **Test** MCC: 0.030. Val_Loss: 3.481
# ACC: 0.088.
# TPR: 0.051.
# F1-score: 0.010.
# Iteration Time 2.805 (2.832)
# **********************************
# attacked module: classifier
# attacked weight index: 920
# weight before attack: tensor(-0.0344, device='cuda:0')
# weight after attack: tensor(-513., device='cuda:0')
# Iteration: [004/025]   Attack Time 2.495 (2.524)
# Bit flips: 4
# Hamming distance: 0
# **Test** MCC: 0.030. Val_Loss: 3.481
# ACC: 0.088.
# TPR: 0.051.
# F1-score: 0.010.
# Iteration Time 2.684 (2.795)
# **********************************
# attacked module: classifier
# attacked weight index: 731
# weight before attack: tensor(0.0068, device='cuda:0')
# weight after attack: tensor(8192., device='cuda:0')
# Iteration: [005/025]   Attack Time 2.459 (2.511)
# Bit flips: 5
# Hamming distance: 0
# **Test** MCC: 0.030. Val_Loss: 3.481
# ACC: 0.088.
# TPR: 0.051.
# F1-score: 0.010.
# Iteration Time 2.909 (2.818)
# **********************************
# attacked module: classifier
# attacked weight index: 1921
# weight before attack: tensor(0.0317, device='cuda:0')
# weight after attack: tensor(64., device='cuda:0')
# Iteration: [006/025]   Attack Time 2.453 (2.501)
# Bit flips: 6
# Hamming distance: 0
# **Test** MCC: 0.020. Val_Loss: 3.485
# ACC: 0.088.
# TPR: 0.050.
# F1-score: 0.011.
# Iteration Time 2.819 (2.818)
# **********************************
# attacked module: classifier
# attacked weight index: 1356
# weight before attack: tensor(-0.0010, device='cuda:0')
# weight after attack: tensor(4., device='cuda:0')
# Iteration: [007/025]   Attack Time 2.466 (2.496)
# Bit flips: 7
# Hamming distance: 0
# **Test** MCC: 0.020. Val_Loss: 3.485
# ACC: 0.088.
# TPR: 0.050.
# F1-score: 0.011.
# Iteration Time 2.686 (2.799)
# **********************************
# attacked module: classifier
# attacked weight index: 2044
# weight before attack: tensor(0.0154, device='cuda:0')
# weight after attack: tensor(8., device='cuda:0')
# Iteration: [008/025]   Attack Time 2.452 (2.491)
# Bit flips: 8
# Hamming distance: 0
# **Test** MCC: 0.020. Val_Loss: 3.485
# ACC: 0.088.
# TPR: 0.050.
# F1-score: 0.011.
# Iteration Time 2.868 (2.808)
# **********************************
# attacked module: classifier
# attacked weight index: 2772
# weight before attack: tensor(-0.0265, device='cuda:0')
# weight after attack: tensor(-65., device='cuda:0')
# Iteration: [009/025]   Attack Time 2.532 (2.495)
# Bit flips: 9
# Hamming distance: 0
# **Test** MCC: 0.020. Val_Loss: 3.485
# ACC: 0.088.
# TPR: 0.050.
# F1-score: 0.011.
# Iteration Time 2.877 (2.815)
# **********************************
# attacked module: classifier
# attacked weight index: 2081
# weight before attack: tensor(-0.0295, device='cuda:0')
# weight after attack: tensor(-16385., device='cuda:0')
# Iteration: [010/025]   Attack Time 2.502 (2.496)
# Bit flips: 10
# Hamming distance: 0
# **Test** MCC: 0.020. Val_Loss: 3.485
# ACC: 0.088.
# TPR: 0.050.
# F1-score: 0.011.
# Iteration Time 2.743 (2.808)
# **********************************
# attacked module: classifier
# attacked weight index: 2355
# weight before attack: tensor(-0.0331, device='cuda:0')
# weight after attack: tensor(-33., device='cuda:0')
# Iteration: [011/025]   Attack Time 2.531 (2.499)
# Bit flips: 11
# Hamming distance: 0
# **Test** MCC: 0.020. Val_Loss: 3.485
# ACC: 0.088.
# TPR: 0.050.
# F1-score: 0.011.
# Iteration Time 2.811 (2.808)
# **********************************
# attacked module: classifier
# attacked weight index: 3055
# weight before attack: tensor(0.0138, device='cuda:0')
# weight after attack: tensor(2048., device='cuda:0')
# Iteration: [012/025]   Attack Time 2.507 (2.500)
# Bit flips: 12
# Hamming distance: 0
# **Test** MCC: 0.034. Val_Loss: 3.488
# ACC: 0.088.
# TPR: 0.049.
# F1-score: 0.014.
# Iteration Time 2.866 (2.813)
# **********************************
# attacked module: classifier
# attacked weight index: 3261
# weight before attack: tensor(-0.0174, device='cuda:0')
# weight after attack: tensor(-16385., device='cuda:0')
# Iteration: [013/025]   Attack Time 2.510 (2.500)
# Bit flips: 13
# Hamming distance: 0
# **Test** MCC: 0.034. Val_Loss: 3.488
# ACC: 0.088.
# TPR: 0.049.
# F1-score: 0.014.
# Iteration Time 2.726 (2.806)
# **********************************
# attacked module: classifier
# attacked weight index: 1795
# weight before attack: tensor(-0.0215, device='cuda:0')
# weight after attack: tensor(-33., device='cuda:0')
# Iteration: [014/025]   Attack Time 2.408 (2.494)
# Bit flips: 14
# Hamming distance: 0
# **Test** MCC: 0.033. Val_Loss: 3.488
# ACC: 0.087.
# TPR: 0.045.
# F1-score: 0.010.
# Iteration Time 2.771 (2.804)
# **********************************
# attacked module: classifier
# attacked weight index: 2583
# weight before attack: tensor(0.0422, device='cuda:0')
# weight after attack: tensor(1024., device='cuda:0')
# Iteration: [015/025]   Attack Time 2.389 (2.487)
# Bit flips: 15
# Hamming distance: 0
# **Test** MCC: 0.034. Val_Loss: 3.488
# ACC: 0.088.
# TPR: 0.046.
# F1-score: 0.011.
# Iteration Time 2.717 (2.798)
# **********************************
# attacked module: classifier
# attacked weight index: 3386
# weight before attack: tensor(-0.0090, device='cuda:0')
# weight after attack: tensor(-17., device='cuda:0')
# Iteration: [016/025]   Attack Time 2.448 (2.484)
# Bit flips: 16
# Hamming distance: 0
# **Test** MCC: 0.034. Val_Loss: 3.488
# ACC: 0.088.
# TPR: 0.046.
# F1-score: 0.011.
# Iteration Time 2.871 (2.803)
# **********************************
# attacked module: classifier
# attacked weight index: 75
# weight before attack: tensor(0.0212, device='cuda:0')
# weight after attack: tensor(128., device='cuda:0')
# Iteration: [017/025]   Attack Time 2.544 (2.488)
# Bit flips: 17
# Hamming distance: 0
# **Test** MCC: 0.033. Val_Loss: 3.488
# ACC: 0.087.
# TPR: 0.044.
# F1-score: 0.010.
# Iteration Time 2.767 (2.801)
# **********************************
# attacked module: classifier
# attacked weight index: 1098
# weight before attack: tensor(-0.0051, device='cuda:0')
# weight after attack: tensor(-17., device='cuda:0')
# Iteration: [018/025]   Attack Time 2.427 (2.484)
# Bit flips: 18
# Hamming distance: 0
# **Test** MCC: 0.033. Val_Loss: 3.488
# ACC: 0.087.
# TPR: 0.044.
# F1-score: 0.010.
# Iteration Time 2.765 (2.799)
# **********************************
# attacked module: classifier
# attacked weight index: 2204
# weight before attack: tensor(0.0295, device='cuda:0')
# weight after attack: tensor(4096., device='cuda:0')
# Iteration: [019/025]   Attack Time 2.497 (2.485)
# Bit flips: 19
# Hamming distance: 0
# **Test** MCC: -0.072. Val_Loss: 3.575
# ACC: 0.000.
# TPR: 0.001.
# F1-score: 0.001.
# Iteration Time 2.834 (2.800)
# **********************************
# attacked module: classifier
# attacked weight index: 1480
# weight before attack: tensor(0.0200, device='cuda:0')
# weight after attack: tensor(1., device='cuda:0')
# Iteration: [020/025]   Attack Time 2.560 (2.489)
# Bit flips: 20
# Hamming distance: 0
# **Test** MCC: -0.072. Val_Loss: 3.575
# ACC: 0.000.
# TPR: 0.001.
# F1-score: 0.001.
# Iteration Time 2.904 (2.806)
# **********************************
# attacked module: classifier
# attacked weight index: 2923
# weight before attack: tensor(-0.0217, device='cuda:0')
# weight after attack: tensor(-257., device='cuda:0')
# Iteration: [021/025]   Attack Time 2.557 (2.492)
# Bit flips: 21
# Hamming distance: 0
# **Test** MCC: -0.072. Val_Loss: 3.575
# ACC: 0.000.
# TPR: 0.001.
# F1-score: 0.001.
# Iteration Time 2.761 (2.804)
# **********************************
# attacked module: classifier
# attacked weight index: 2626
# weight before attack: tensor(-0.0435, device='cuda:0')
# weight after attack: tensor(-9., device='cuda:0')
# Iteration: [022/025]   Attack Time 2.451 (2.490)
# Bit flips: 22
# Hamming distance: 0
# **Test** MCC: -0.072. Val_Loss: 3.575
# ACC: 0.000.
# TPR: 0.001.
# F1-score: 0.001.
# Iteration Time 2.818 (2.804)
# **********************************
# attacked module: classifier
# attacked weight index: 4
# weight before attack: tensor(-0.0356, device='cuda:0')
# weight after attack: tensor(-129., device='cuda:0')
# Iteration: [023/025]   Attack Time 2.423 (2.487)
# Bit flips: 23
# Hamming distance: 0
# **Test** MCC: -0.072. Val_Loss: 3.575
# ACC: 0.000.
# TPR: 0.001.
# F1-score: 0.001.
# Iteration Time 2.759 (2.802)
# **********************************
# attacked module: classifier
# attacked weight index: 2577
# weight before attack: tensor(-0.0037, device='cuda:0')
# weight after attack: tensor(-5., device='cuda:0')
# Iteration: [024/025]   Attack Time 2.809 (2.501)
# Bit flips: 24
# Hamming distance: 0
# **Test** MCC: -0.072. Val_Loss: 3.575
# ACC: 0.000.
# TPR: 0.001.
# F1-score: 0.001.
# Iteration Time 2.783 (2.801)
# **********************************
# attacked module: classifier
# attacked weight index: 3095
# weight before attack: tensor(-0.0295, device='cuda:0')
# weight after attack: tensor(-8193., device='cuda:0')
# Iteration: [025/025]   Attack Time 2.513 (2.501)
# Bit flips: 25
# Hamming distance: 0
# **Test** MCC: -0.074. Val_Loss: 3.574
# ACC: 0.000.
# TPR: 0.001.
# F1-score: 0.001.
# Iteration Time 2.761 (2.800)
# Plot saved as CustomModel2/RandomFlip_attack/MCC_RandomFlip_attack.png
# Plot saved as CustomModel2/RandomFlip_attack/ACC_RandomFlip_attack.png
# Plot saved as CustomModel2/RandomFlip_attack/TPR_RandomFlip_attack.png
# Plot saved as CustomModel2/RandomFlip_attack/F1_RandomFlip_attack.png
# [Combined Plot] Saved as CustomModel2/RandomFlip_attack/combined_metrics_RandomFlip_attack.png
# MCC after 100 times random attack: -0.07433334415980525
# Accuracy after 100 times random attack: 0.0004771123691381699
# TPR after 100 times random attack: 0.0010451038357704194
# F1-score after 100 times random attack: 0.0011206276769294848

# %%
model_path = os.path.join("CustomModel2", "model.pth")
if not os.path.exists(model_path):
    raise FileNotFoundError(f"Không tìm thấy mô hình tại: {model_path}")

trained_model = CustomModel2()

trained_model.load_state_dict(torch.load(model_path, map_location=torch.device('cuda' if torch.cuda.is_available() else 'cpu')))
trained_model = trained_model.to(device)


# Bước 2: Tạo bản sao của mô hình để làm tham chiếu
model_clean = copy.deepcopy(trained_model)

# Bước 3: Khởi tạo đối tượng tấn công BFA
attacker = BFA(criterion=criterion, model=trained_model, k_top=10)

# Định nghĩa đường dẫn để lưu kết quả tấn công
attack_dir = os.path.join("CustomModel2", "PBS_to_RandomFlip_attack")

os.makedirs(attack_dir, exist_ok=True)
attack_image_paths = [os.path.join(attack_dir, f"{metric}_PBS_to_RandomFlip_attack.png") 
                      for metric in ["MCC", "ACC", "TPR", "F1"]]
# attack_image_path = os.path.join(attack_dir, "PBS_to_RandomFlip_attack.png")
attack_csv_path = os.path.join(attack_dir, "PBS_to_RandomFlip_attack.csv")

# Bước 4: Thực hiện tấn công
perform_attack(
    attacker=attacker,               # Đối tượng tấn công
    model=trained_model,             # Mô hình bị tấn công
    model_clean=model_clean,         # Mô hình gốc làm tham chiếu
    train_loader=train_loader,       # Bộ dữ liệu huấn luyện
    test_loader=test_loader,         # Bộ dữ liệu kiểm tra
    N_iter=args.n_iter,              # Số vòng lặp tấn công
    writer=writer,                   # TensorBoard writer để ghi log
    file=attack_image_paths,          # Lưu ảnh vào thư mục tấn công
    csv_file=attack_csv_path, 
    csv_save_path=args.save_path,    # Đường dẫn lưu file CSV
    attack_type= 3,                  # Chế độ tấn công PBS -> random
)

writer.close()  # Đóng TensorBoard writer
# best_mcc = validate_score( trained_model,test_loader)
# print(f"\nMCC after 100 times PBS to Random: {best_mcc}")

results = validate_score(trained_model, test_loader)
print(f"MCC after 100 times PBS to Random: {results['MCC']}")
print(f"Accuracy after 100 times PBS to Random: {results['Accuracy']}")
print(f"TPR after 100 times PBS to Random: {results['TPR']}")
print(f"F1-score after 100 times PBS to Random: {results['F1 Score']}")
# Out:
# **Test** MCC: 0.713. Val_Loss: 2.851
# ACC: 0.725.
# TPR: 0.575.
# F1-score: 0.516.
# Attack sample size is 256
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 3053
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(2., device='cuda:0')
# Iteration: [001/025]   Attack Time 5.288 (5.288)
# Loss before attack: 2.5808
# Loss after attack: 2.6377
# Bit flips: 2
# Hamming distance: 0
# **Test** MCC: 0.661. Val_Loss: 2.899
# ACC: 0.677.
# TPR: 0.483.
# F1-score: 0.435.
# Iteration Time 2.869 (2.869)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 737
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-17., device='cuda:0')
# Iteration: [002/025]   Attack Time 5.233 (5.260)
# Loss before attack: 2.6377
# Loss after attack: 2.6377
# Bit flips: 103
# Hamming distance: 0
# **Test** MCC: 0.661. Val_Loss: 2.899
# ACC: 0.677.
# TPR: 0.483.
# F1-score: 0.435.
# Iteration Time 2.968 (2.918)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 813
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(1., device='cuda:0')
# Iteration: [003/025]   Attack Time 5.337 (5.286)
# Loss before attack: 2.6377
# Loss after attack: 2.6377
# Bit flips: 204
# Hamming distance: 0
# **Test** MCC: 0.661. Val_Loss: 2.899
# ACC: 0.677.
# TPR: 0.483.
# F1-score: 0.436.
# Iteration Time 2.865 (2.901)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 2845
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-16385., device='cuda:0')
# Iteration: [004/025]   Attack Time 5.158 (5.254)
# Loss before attack: 2.6377
# Loss after attack: 2.6377
# Bit flips: 305
# Hamming distance: 0
# **Test** MCC: 0.661. Val_Loss: 2.899
# ACC: 0.677.
# TPR: 0.483.
# F1-score: 0.436.
# Iteration Time 2.853 (2.889)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 786
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-5., device='cuda:0')
# Iteration: [005/025]   Attack Time 5.176 (5.238)
# Loss before attack: 2.6377
# Loss after attack: 2.6377
# Bit flips: 406
# Hamming distance: 0
# **Test** MCC: 0.661. Val_Loss: 2.899
# ACC: 0.677.
# TPR: 0.483.
# F1-score: 0.436.
# Iteration Time 2.895 (2.890)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 933
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-1025., device='cuda:0')
# Iteration: [006/025]   Attack Time 4.970 (5.194)
# Loss before attack: 2.6377
# Loss after attack: 2.6377
# Bit flips: 507
# Hamming distance: 0
# **Test** MCC: 0.577. Val_Loss: 2.981
# ACC: 0.595.
# TPR: 0.437.
# F1-score: 0.389.
# Iteration Time 2.704 (2.859)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 693
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-4097., device='cuda:0')
# Iteration: [007/025]   Attack Time 4.960 (5.160)
# Loss before attack: 2.7119
# Loss after attack: 2.7119
# Bit flips: 608
# Hamming distance: 0
# **Test** MCC: 0.577. Val_Loss: 2.981
# ACC: 0.595.
# TPR: 0.437.
# F1-score: 0.389.
# Iteration Time 2.916 (2.867)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 466
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(8., device='cuda:0')
# Iteration: [008/025]   Attack Time 5.233 (5.169)
# Loss before attack: 2.7119
# Loss after attack: 2.7119
# Bit flips: 709
# Hamming distance: 0
# **Test** MCC: 0.577. Val_Loss: 2.981
# ACC: 0.595.
# TPR: 0.437.
# F1-score: 0.389.
# Iteration Time 2.921 (2.874)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 1586
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-2., device='cuda:0')
# Iteration: [009/025]   Attack Time 5.325 (5.187)
# Loss before attack: 2.7119
# Loss after attack: 2.7119
# Bit flips: 810
# Hamming distance: 0
# **Test** MCC: 0.577. Val_Loss: 2.981
# ACC: 0.595.
# TPR: 0.437.
# F1-score: 0.389.
# Iteration Time 2.792 (2.865)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 260
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(-32768., device='cuda:0')
# Iteration: [010/025]   Attack Time 5.404 (5.208)
# Loss before attack: 2.7119
# Loss after attack: 2.7119
# Bit flips: 911
# Hamming distance: 0
# **Test** MCC: 0.577. Val_Loss: 2.981
# ACC: 0.595.
# TPR: 0.437.
# F1-score: 0.389.
# Iteration Time 2.864 (2.865)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 357
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(4., device='cuda:0')
# Iteration: [011/025]   Attack Time 5.173 (5.205)
# Loss before attack: 2.7119
# Loss after attack: 2.7119
# Bit flips: 1012
# Hamming distance: 0
# **Test** MCC: 0.577. Val_Loss: 2.981
# ACC: 0.595.
# TPR: 0.437.
# F1-score: 0.389.
# Iteration Time 2.888 (2.867)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 6
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-5., device='cuda:0')
# Iteration: [012/025]   Attack Time 5.294 (5.213)
# Loss before attack: 2.7119
# Loss after attack: 2.7119
# Bit flips: 1113
# Hamming distance: 0
# **Test** MCC: 0.577. Val_Loss: 2.981
# ACC: 0.595.
# TPR: 0.437.
# F1-score: 0.389.
# Iteration Time 2.795 (2.861)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 1912
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(64., device='cuda:0')
# Iteration: [013/025]   Attack Time 5.213 (5.213)
# Loss before attack: 2.7119
# Loss after attack: 2.7119
# Bit flips: 1214
# Hamming distance: 0
# **Test** MCC: 0.577. Val_Loss: 2.981
# ACC: 0.595.
# TPR: 0.437.
# F1-score: 0.389.
# Iteration Time 2.895 (2.864)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 585
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(512., device='cuda:0')
# Iteration: [014/025]   Attack Time 5.287 (5.218)
# Loss before attack: 2.7119
# Loss after attack: 2.7119
# Bit flips: 1315
# Hamming distance: 0
# **Test** MCC: 0.577. Val_Loss: 2.981
# ACC: 0.595.
# TPR: 0.437.
# F1-score: 0.389.
# Iteration Time 2.965 (2.871)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 1004
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(8192., device='cuda:0')
# Iteration: [015/025]   Attack Time 5.148 (5.213)
# Loss before attack: 2.7119
# Loss after attack: 2.7119
# Bit flips: 1416
# Hamming distance: 0
# **Test** MCC: 0.223. Val_Loss: 3.417
# ACC: 0.159.
# TPR: 0.188.
# F1-score: 0.176.
# Iteration Time 2.858 (2.870)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 700
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(16384., device='cuda:0')
# Iteration: [016/025]   Attack Time 5.132 (5.208)
# Loss before attack: 3.4350
# Loss after attack: 3.4350
# Bit flips: 1517
# Hamming distance: 0
# **Test** MCC: 0.119. Val_Loss: 3.475
# ACC: 0.101.
# TPR: 0.103.
# F1-score: 0.061.
# Iteration Time 2.837 (2.868)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 3300
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-16385., device='cuda:0')
# Iteration: [017/025]   Attack Time 5.347 (5.216)
# Loss before attack: 3.4897
# Loss after attack: 3.4897
# Bit flips: 1618
# Hamming distance: 0
# **Test** MCC: 0.119. Val_Loss: 3.475
# ACC: 0.101.
# TPR: 0.103.
# F1-score: 0.061.
# Iteration Time 2.841 (2.866)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 2064
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(32767., device='cuda:0')
# Iteration: [018/025]   Attack Time 4.931 (5.201)
# Loss before attack: 3.4897
# Loss after attack: 3.4897
# Bit flips: 1719
# Hamming distance: 0
# **Test** MCC: 0.018. Val_Loss: 3.517
# ACC: 0.059.
# TPR: 0.046.
# F1-score: 0.006.
# Iteration Time 2.692 (2.857)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 159
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-2., device='cuda:0')
# Iteration: [019/025]   Attack Time 4.991 (5.190)
# Loss before attack: 3.5757
# Loss after attack: 3.5757
# Bit flips: 1820
# Hamming distance: 0
# **Test** MCC: 0.018. Val_Loss: 3.517
# ACC: 0.059.
# TPR: 0.046.
# F1-score: 0.006.
# Iteration Time 2.764 (2.852)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 2541
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(16., device='cuda:0')
# Iteration: [020/025]   Attack Time 5.024 (5.181)
# Loss before attack: 3.5757
# Loss after attack: 3.5757
# Bit flips: 1921
# Hamming distance: 0
# **Test** MCC: 0.018. Val_Loss: 3.517
# ACC: 0.059.
# TPR: 0.046.
# F1-score: 0.006.
# Iteration Time 2.718 (2.845)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 3269
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-8193., device='cuda:0')
# Iteration: [021/025]   Attack Time 4.918 (5.169)
# Loss before attack: 3.5757
# Loss after attack: 3.5757
# Bit flips: 2022
# Hamming distance: 0
# **Test** MCC: 0.018. Val_Loss: 3.517
# ACC: 0.059.
# TPR: 0.046.
# F1-score: 0.006.
# Iteration Time 2.826 (2.844)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 909
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(4., device='cuda:0')
# Iteration: [022/025]   Attack Time 5.008 (5.161)
# Loss before attack: 3.5757
# Loss after attack: 3.5757
# Bit flips: 2123
# Hamming distance: 0
# **Test** MCC: 0.018. Val_Loss: 3.517
# ACC: 0.059.
# TPR: 0.046.
# F1-score: 0.006.
# Iteration Time 2.635 (2.835)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 2038
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-513., device='cuda:0')
# Iteration: [023/025]   Attack Time 5.128 (5.160)
# Loss before attack: 3.5757
# Loss after attack: 3.5757
# Bit flips: 2224
# Hamming distance: 0
# **Test** MCC: 0.018. Val_Loss: 3.517
# ACC: 0.059.
# TPR: 0.045.
# F1-score: 0.006.
# Iteration Time 2.797 (2.833)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 1060
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(128., device='cuda:0')
# Iteration: [024/025]   Attack Time 5.180 (5.161)
# Loss before attack: 3.5757
# Loss after attack: 3.5757
# Bit flips: 2325
# Hamming distance: 0
# **Test** MCC: 0.018. Val_Loss: 3.517
# ACC: 0.059.
# TPR: 0.045.
# F1-score: 0.006.
# Iteration Time 2.761 (2.830)
# **********************************
# attacked module: classifier
# attacked module: classifier
# attacked weight index: 604
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(2., device='cuda:0')
# Iteration: [025/025]   Attack Time 5.190 (5.162)
# Loss before attack: 3.5757
# Loss after attack: 3.5757
# Bit flips: 2426
# Hamming distance: 0
# **Test** MCC: 0.018. Val_Loss: 3.517
# ACC: 0.059.
# TPR: 0.045.
# F1-score: 0.006.
# Iteration Time 2.725 (2.826)
# Plot saved as CustomModel2/PBS_to_RandomFlip_attack/MCC_PBS_to_RandomFlip_attack.png
# Plot saved as CustomModel2/PBS_to_RandomFlip_attack/ACC_PBS_to_RandomFlip_attack.png
# Plot saved as CustomModel2/PBS_to_RandomFlip_attack/TPR_PBS_to_RandomFlip_attack.png
# Plot saved as CustomModel2/PBS_to_RandomFlip_attack/F1_PBS_to_RandomFlip_attack.png
# [Combined Plot] Saved as CustomModel2/PBS_to_RandomFlip_attack/combined_metrics_PBS_to_RandomFlip_attack.png
# MCC after 100 times PBS to Random: 0.017952141546180113
# Accuracy after 100 times PBS to Random: 0.05887750139922378
# TPR after 100 times PBS to Random: 0.04543357427973119
# F1-score after 100 times PBS to Random: 0.006308735186238418

# %%
# Bước 1: Tải mô hình đã huấn luyện
model_path = os.path.join("CustomModel2", "model.pth")
if not os.path.exists(model_path):
    raise FileNotFoundError(f"Không tìm thấy mô hình tại: {model_path}")

trained_model = CustomModel2()

trained_model.load_state_dict(torch.load(model_path, map_location=torch.device('cuda' if torch.cuda.is_available() else 'cpu')))
trained_model = trained_model.to(device)

# Bước 2: Tạo bản sao của mô hình để làm tham chiếu
model_clean = copy.deepcopy(trained_model)

# Bước 3: Khởi tạo đối tượng tấn công BFA
attacker = BFA(criterion=criterion, model=trained_model, k_top=10)

# Định nghĩa đường dẫn để lưu kết quả tấn công
attack_dir = os.path.join("CustomModel2", "RandomFlip_to_PBS_attack")

os.makedirs(attack_dir, exist_ok=True)
attack_image_paths = [os.path.join(attack_dir, f"{metric}_RandomFlip_to_PBS_attack.png") 
                      for metric in ["MCC", "ACC", "TPR", "F1"]]
# attack_image_path = os.path.join(attack_dir, "RandomFlip_to_PBS_attack.png")
attack_csv_path = os.path.join(attack_dir, "RandomFlip_to_PBS_attack.csv")

# Bước 4: Thực hiện tấn công
perform_attack(
    attacker=attacker,               # Đối tượng tấn công
    model=trained_model,             # Mô hình bị tấn công
    model_clean=model_clean,         # Mô hình gốc làm tham chiếu
    train_loader=train_loader,       # Bộ dữ liệu huấn luyện
    test_loader=test_loader,         # Bộ dữ liệu kiểm tra
    N_iter=args.n_iter,              # Số vòng lặp tấn công
    writer=writer,                   # TensorBoard writer để ghi log
    file=attack_image_paths,          # Lưu ảnh vào thư mục tấn công
    csv_file=attack_csv_path,  
    csv_save_path=args.save_path,    # Đường dẫn lưu file CSV
    attack_type= 4,                  # Chế độ tấn công Random -> PBS
)

writer.close()  # Đóng TensorBoard writer
# best_mcc = validate_score( trained_model,test_loader)
# print(f"\nMCC after 100 times Random to PBS: {best_mcc}")

results = validate_score(trained_model, test_loader)
print(f"MCC after 100 times random to PBS: {results['MCC']}")
print(f"Accuracy after 100 times random to PBS: {results['Accuracy']}")
print(f"TPR after 100 times random to PBS: {results['TPR']}")
print(f"F1-score after 100 times random to PBS: {results['F1 Score']}")
# Out:
# **Test** MCC: 0.713. Val_Loss: 2.851
# ACC: 0.725.
# TPR: 0.575.
# F1-score: 0.516.
# Attack sample size is 256
# **********************************
# attacked module: classifier
# attacked weight index: 3057
# weight before attack: tensor(-0.0341, device='cuda:0')
# weight after attack: tensor(-8193., device='cuda:0')
# attacked module: classifier
# Iteration: [001/025]   Attack Time 5.308 (5.308)
# Loss before attack: 3.5410
# Loss after attack: 2.6416
# Bit flips: 101
# Hamming distance: 0
# **Test** MCC: 0.661. Val_Loss: 2.899
# ACC: 0.677.
# TPR: 0.483.
# F1-score: 0.435.
# Iteration Time 2.997 (2.997)
# **********************************
# attacked module: classifier
# attacked weight index: 1181
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-257., device='cuda:0')
# attacked module: classifier
# Iteration: [002/025]   Attack Time 5.688 (5.498)
# Loss before attack: 2.6416
# Loss after attack: 2.6416
# Bit flips: 202
# Hamming distance: 0
# **Test** MCC: 0.661. Val_Loss: 2.899
# ACC: 0.677.
# TPR: 0.483.
# F1-score: 0.435.
# Iteration Time 3.037 (3.017)
# **********************************
# attacked module: classifier
# attacked weight index: 704
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(1., device='cuda:0')
# attacked module: classifier
# Iteration: [003/025]   Attack Time 5.621 (5.539)
# Loss before attack: 2.6416
# Loss after attack: 2.6416
# Bit flips: 303
# Hamming distance: 0
# **Test** MCC: 0.661. Val_Loss: 2.899
# ACC: 0.677.
# TPR: 0.483.
# F1-score: 0.435.
# Iteration Time 3.090 (3.041)
# **********************************
# attacked module: classifier
# attacked weight index: 1129
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-513., device='cuda:0')
# attacked module: classifier
# Iteration: [004/025]   Attack Time 5.695 (5.578)
# Loss before attack: 2.6416
# Loss after attack: 2.6416
# Bit flips: 404
# Hamming distance: 0
# **Test** MCC: 0.661. Val_Loss: 2.899
# ACC: 0.677.
# TPR: 0.483.
# F1-score: 0.435.
# Iteration Time 2.989 (3.028)
# **********************************
# attacked module: classifier
# attacked weight index: 3169
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(32., device='cuda:0')
# attacked module: classifier
# Iteration: [005/025]   Attack Time 5.497 (5.562)
# Loss before attack: 3.5483
# Loss after attack: 3.5483
# Bit flips: 505
# Hamming distance: 0
# **Test** MCC: 0.089. Val_Loss: 3.547
# ACC: 0.029.
# TPR: 0.053.
# F1-score: 0.056.
# Iteration Time 3.074 (3.037)
# **********************************
# attacked module: classifier
# attacked weight index: 755
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-257., device='cuda:0')
# attacked module: classifier
# Iteration: [006/025]   Attack Time 5.584 (5.566)
# Loss before attack: 3.5483
# Loss after attack: 3.5483
# Bit flips: 606
# Hamming distance: 0
# **Test** MCC: 0.089. Val_Loss: 3.547
# ACC: 0.029.
# TPR: 0.053.
# F1-score: 0.056.
# Iteration Time 3.133 (3.053)
# **********************************
# attacked module: classifier
# attacked weight index: 1799
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(-32768., device='cuda:0')
# attacked module: classifier
# Iteration: [007/025]   Attack Time 5.639 (5.576)
# Loss before attack: 3.5483
# Loss after attack: 3.5483
# Bit flips: 707
# Hamming distance: 0
# **Test** MCC: 0.089. Val_Loss: 3.547
# ACC: 0.029.
# TPR: 0.053.
# F1-score: 0.056.
# Iteration Time 3.016 (3.048)
# **********************************
# attacked module: classifier
# attacked weight index: 838
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(2., device='cuda:0')
# attacked module: classifier
# Iteration: [008/025]   Attack Time 5.671 (5.588)
# Loss before attack: 3.5483
# Loss after attack: 3.5483
# Bit flips: 808
# Hamming distance: 0
# **Test** MCC: 0.089. Val_Loss: 3.547
# ACC: 0.029.
# TPR: 0.053.
# F1-score: 0.056.
# Iteration Time 2.914 (3.031)
# **********************************
# attacked module: classifier
# attacked weight index: 265
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-513., device='cuda:0')
# attacked module: classifier
# Iteration: [009/025]   Attack Time 5.605 (5.590)
# Loss before attack: 3.5483
# Loss after attack: 3.5483
# Bit flips: 909
# Hamming distance: 0
# **Test** MCC: 0.089. Val_Loss: 3.547
# ACC: 0.029.
# TPR: 0.053.
# F1-score: 0.056.
# Iteration Time 3.010 (3.029)
# **********************************
# attacked module: classifier
# attacked weight index: 543
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-65., device='cuda:0')
# attacked module: classifier
# Iteration: [010/025]   Attack Time 5.773 (5.608)
# Loss before attack: 3.5483
# Loss after attack: 3.5483
# Bit flips: 1010
# Hamming distance: 0
# **Test** MCC: 0.089. Val_Loss: 3.547
# ACC: 0.029.
# TPR: 0.053.
# F1-score: 0.056.
# Iteration Time 2.953 (3.021)
# **********************************
# attacked module: classifier
# attacked weight index: 1791
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-129., device='cuda:0')
# attacked module: classifier
# Iteration: [011/025]   Attack Time 5.488 (5.597)
# Loss before attack: 3.5483
# Loss after attack: 3.5483
# Bit flips: 1111
# Hamming distance: 0
# **Test** MCC: 0.089. Val_Loss: 3.547
# ACC: 0.029.
# TPR: 0.053.
# F1-score: 0.056.
# Iteration Time 2.882 (3.009)
# **********************************
# attacked module: classifier
# attacked weight index: 1886
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(64., device='cuda:0')
# attacked module: classifier
# Iteration: [012/025]   Attack Time 5.836 (5.617)
# Loss before attack: 3.5718
# Loss after attack: 3.5718
# Bit flips: 1212
# Hamming distance: 0
# **Test** MCC: 0.006. Val_Loss: 3.571
# ACC: 0.005.
# TPR: 0.023.
# F1-score: 0.009.
# Iteration Time 3.135 (3.019)
# **********************************
# attacked module: classifier
# attacked weight index: 2255
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(1024., device='cuda:0')
# attacked module: classifier
# Iteration: [013/025]   Attack Time 5.750 (5.627)
# Loss before attack: 3.5561
# Loss after attack: 3.5561
# Bit flips: 1313
# Hamming distance: 0
# **Test** MCC: 0.016. Val_Loss: 3.546
# ACC: 0.029.
# TPR: 0.058.
# F1-score: 0.004.
# Iteration Time 3.107 (3.026)
# **********************************
# attacked module: classifier
# attacked weight index: 686
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-8193., device='cuda:0')
# attacked module: classifier
# Iteration: [014/025]   Attack Time 5.592 (5.625)
# Loss before attack: 3.5561
# Loss after attack: 3.5561
# Bit flips: 1414
# Hamming distance: 0
# **Test** MCC: 0.016. Val_Loss: 3.546
# ACC: 0.029.
# TPR: 0.058.
# F1-score: 0.004.
# Iteration Time 2.944 (3.020)
# **********************************
# attacked module: classifier
# attacked weight index: 2212
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(8., device='cuda:0')
# attacked module: classifier
# Iteration: [015/025]   Attack Time 5.558 (5.620)
# Loss before attack: 3.5561
# Loss after attack: 3.5561
# Bit flips: 1515
# Hamming distance: 0
# **Test** MCC: 0.016. Val_Loss: 3.546
# ACC: 0.029.
# TPR: 0.058.
# F1-score: 0.004.
# Iteration Time 3.003 (3.019)
# **********************************
# attacked module: classifier
# attacked weight index: 1062
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(8192., device='cuda:0')
# attacked module: classifier
# Iteration: [016/025]   Attack Time 5.777 (5.630)
# Loss before attack: 3.5561
# Loss after attack: 3.5561
# Bit flips: 1616
# Hamming distance: 0
# **Test** MCC: 0.016. Val_Loss: 3.546
# ACC: 0.029.
# TPR: 0.058.
# F1-score: 0.004.
# Iteration Time 3.143 (3.027)
# **********************************
# attacked module: classifier
# attacked weight index: 1256
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(1., device='cuda:0')
# attacked module: classifier
# Iteration: [017/025]   Attack Time 5.548 (5.625)
# Loss before attack: 3.5561
# Loss after attack: 3.5561
# Bit flips: 1717
# Hamming distance: 0
# **Test** MCC: 0.016. Val_Loss: 3.546
# ACC: 0.029.
# TPR: 0.058.
# F1-score: 0.004.
# Iteration Time 3.035 (3.027)
# **********************************
# attacked module: classifier
# attacked weight index: 362
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(8192., device='cuda:0')
# attacked module: classifier
# Iteration: [018/025]   Attack Time 5.684 (5.629)
# Loss before attack: 3.5561
# Loss after attack: 3.5561
# Bit flips: 1818
# Hamming distance: 0
# **Test** MCC: 0.016. Val_Loss: 3.546
# ACC: 0.029.
# TPR: 0.058.
# F1-score: 0.004.
# Iteration Time 2.893 (3.020)
# **********************************
# attacked module: classifier
# attacked weight index: 3091
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(1024., device='cuda:0')
# attacked module: classifier
# Iteration: [019/025]   Attack Time 5.601 (5.627)
# Loss before attack: 3.5561
# Loss after attack: 3.5561
# Bit flips: 1919
# Hamming distance: 0
# **Test** MCC: 0.016. Val_Loss: 3.546
# ACC: 0.029.
# TPR: 0.058.
# F1-score: 0.004.
# Iteration Time 3.047 (3.021)
# **********************************
# attacked module: classifier
# attacked weight index: 821
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(1024., device='cuda:0')
# attacked module: classifier
# Iteration: [020/025]   Attack Time 5.643 (5.628)
# Loss before attack: 3.4663
# Loss after attack: 3.4663
# Bit flips: 2020
# Hamming distance: 0
# **Test** MCC: 0.109. Val_Loss: 3.460
# ACC: 0.116.
# TPR: 0.102.
# F1-score: 0.030.
# Iteration Time 3.064 (3.023)
# **********************************
# attacked module: classifier
# attacked weight index: 1201
# weight before attack: tensor(0., device='cuda:0')
# weight after attack: tensor(8., device='cuda:0')
# attacked module: classifier
# Iteration: [021/025]   Attack Time 5.781 (5.635)
# Loss before attack: 3.4663
# Loss after attack: 3.4663
# Bit flips: 2121
# Hamming distance: 0
# **Test** MCC: 0.109. Val_Loss: 3.460
# ACC: 0.116.
# TPR: 0.102.
# F1-score: 0.030.
# Iteration Time 3.031 (3.024)
# **********************************
# attacked module: classifier
# attacked weight index: 2316
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-9., device='cuda:0')
# attacked module: classifier
# Iteration: [022/025]   Attack Time 5.447 (5.627)
# Loss before attack: 3.4663
# Loss after attack: 3.4663
# Bit flips: 2222
# Hamming distance: 0
# **Test** MCC: 0.109. Val_Loss: 3.460
# ACC: 0.116.
# TPR: 0.102.
# F1-score: 0.030.
# Iteration Time 2.863 (3.016)
# **********************************
# attacked module: classifier
# attacked weight index: 1777
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-33., device='cuda:0')
# attacked module: classifier
# Iteration: [023/025]   Attack Time 5.508 (5.622)
# Loss before attack: 3.4663
# Loss after attack: 3.4663
# Bit flips: 2323
# Hamming distance: 0
# **Test** MCC: 0.109. Val_Loss: 3.460
# ACC: 0.116.
# TPR: 0.102.
# F1-score: 0.030.
# Iteration Time 3.039 (3.017)
# **********************************
# attacked module: classifier
# attacked weight index: 3178
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-9., device='cuda:0')
# attacked module: classifier
# Iteration: [024/025]   Attack Time 5.579 (5.620)
# Loss before attack: 3.4663
# Loss after attack: 3.4663
# Bit flips: 2424
# Hamming distance: 0
# **Test** MCC: 0.109. Val_Loss: 3.460
# ACC: 0.116.
# TPR: 0.102.
# F1-score: 0.030.
# Iteration Time 3.025 (3.018)
# **********************************
# attacked module: classifier
# attacked weight index: 2649
# weight before attack: tensor(-1., device='cuda:0')
# weight after attack: tensor(-2., device='cuda:0')
# attacked module: classifier
# Iteration: [025/025]   Attack Time 5.777 (5.626)
# Loss before attack: 3.4663
# Loss after attack: 3.4663
# Bit flips: 2525
# Hamming distance: 0
# **Test** MCC: 0.109. Val_Loss: 3.460
# ACC: 0.116.
# TPR: 0.102.
# F1-score: 0.030.
# Iteration Time 3.050 (3.019)
# Plot saved as CustomModel2/RandomFlip_to_PBS_attack/MCC_RandomFlip_to_PBS_attack.png
# Plot saved as CustomModel2/RandomFlip_to_PBS_attack/ACC_RandomFlip_to_PBS_attack.png
# Plot saved as CustomModel2/RandomFlip_to_PBS_attack/TPR_RandomFlip_to_PBS_attack.png
# Plot saved as CustomModel2/RandomFlip_to_PBS_attack/F1_RandomFlip_to_PBS_attack.png
# [Combined Plot] Saved as CustomModel2/RandomFlip_to_PBS_attack/combined_metrics_RandomFlip_to_PBS_attack.png
# MCC after 100 times random to PBS: 0.10882392154167796
# Accuracy after 100 times random to PBS: 0.11602088284138766
# TPR after 100 times random to PBS: 0.10176128326114142
# F1-score after 100 times random to PBS: 0.030437216599933974

# %%
model_names = ["CustomModel", "CustomModel2"]
attack_types = ["PBS", "RandomFlip", "PBS_to_RandomFlip", "RandomFlip_to_PBS"]

def aggregate_results(model_name, attack_types):
    
    aggregate_dir = os.path.join(model_name, "Aggregate_Results")
    os.makedirs(aggregate_dir, exist_ok=True)

    results = []

    # Đọc kết quả từ từng kịch bản tấn công
    for attack_type in attack_types:
        csv_file_path = os.path.join(model_name, f"{attack_type}_attack", f"{attack_type}_attack.csv")
        if os.path.exists(csv_file_path):
            df = pd.read_csv(csv_file_path)
            
            mcc_values = df['MCC'].tolist()
            results.append(mcc_values)
        else:
            print(f"File {csv_file_path} không tồn tại.")

    # Ghi kết quả tổng hợp vào file CSV
    aggregate_df = pd.DataFrame(results, index=attack_types).T
    aggregate_csv_path = os.path.join(aggregate_dir, "aggregated_results.csv")
    aggregate_df.to_csv(aggregate_csv_path)

    # Vẽ đồ thị so sánh
    plt.figure(figsize=(10, 6))
    for i, attack_type in enumerate(attack_types):
        plt.plot(aggregate_df.index, aggregate_df[attack_type], marker='o', label=attack_type)

    plt.title(f'So sánh MCC giữa các kịch bản tấn công cho {model_name}', fontsize=14)
    plt.xlabel('Epoch', fontsize=12)
    plt.ylabel('MCC', fontsize=12)
    plt.grid(True, linestyle='--', alpha=0.7)
    plt.legend()
    plt.tight_layout()

    epochs = aggregate_df.index.astype(int).tolist()
    plt.xticks(epochs, epochs)
    
    plot_path = os.path.join(aggregate_dir, f"{model_name}_comparison_plot.png")
    plt.savefig(plot_path)
    plt.close()
    print(f"Đồ thị đã được lưu tại {plot_path}")

for model_name in model_names:
    aggregate_results(model_name, attack_types)
# Out:
# Đồ thị đã được lưu tại CustomModel/Aggregate_Results/CustomModel_comparison_plot.png
# Đồ thị đã được lưu tại CustomModel2/Aggregate_Results/CustomModel2_comparison_plot.png

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")
sns.set_palette("husl")
plt.rcParams['font.family'] = 'DejaVu Sans, sans-serif'

def plot_attack_comparison_separate(model_names, attack_types):
    """Vẽ biểu đồ riêng biệt cho từng model, so sánh MCC giữa các phương pháp tấn công"""
    
    output_dir = "Comparative_Analysis"
    os.makedirs(output_dir, exist_ok=True)

    for model_name in model_names:
        aggregate_path = os.path.join(model_name, "Aggregate_Results", "aggregated_results.csv")
        if not os.path.exists(aggregate_path):
            print(f"Không tìm thấy file tổng hợp cho {model_name}")
            continue

        df = pd.read_csv(aggregate_path, index_col=0)

        # Chuẩn bị dữ liệu để vẽ
        df_melted = df.reset_index().melt(
            id_vars='index',
            value_vars=attack_types,
            var_name='Attack Type',
            value_name='MCC'
        )

        # Tạo một figure riêng cho từng model
        plt.figure(figsize=(10, 6))
        sns.lineplot(
            data=df_melted, x='index', y='MCC', hue='Attack Type',
            style='Attack Type', markers=True, dashes=False,
            linewidth=2.5, markersize=8, errorbar=None
        )

        # Tùy chỉnh biểu đồ
        plt.xlabel('Attack Iteration', fontsize=12)
        plt.ylabel('Matthews Correlation Coefficient', fontsize=12)
        plt.grid(True, linestyle='--', alpha=0.6)
        plt.legend(title='Attack Strategy', title_fontsize='12', fontsize=10)

        plt.xticks(ticks=range(int(df.index.min()), int(df.index.max()) + 1, 2))


        # Highlight MCC thấp nhất
        min_mcc = df[attack_types].min().min()
        plt.axhline(y=min_mcc, color='r', linestyle='--', alpha=0.5)
        plt.text(x=0, y=min_mcc + 0.05,
                 s=f'Min MCC: {min_mcc:.3f}',
                 color='r', fontsize=10)

        # Lưu hình
        output_path = os.path.join(output_dir, f"{model_name}_CIC23_attack_comparison.png")
        plt.tight_layout()
        plt.savefig(output_path, dpi=300, bbox_inches='tight')
        plt.close()
        print(f"Đã lưu biểu đồ cho {model_name} tại: {output_path}")

# Gọi hàm
model_names = ["CustomModel", "CustomModel2"]
attack_types = ["PBS", "RandomFlip", "PBS_to_RandomFlip", "RandomFlip_to_PBS"]
plot_attack_comparison_separate(model_names, attack_types)
# Out:
# /opt/tljh/user/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/tljh/user/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/tljh/user/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/tljh/user/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/tljh/user/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/tljh/user/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/tljh/user/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/tljh/user/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/tljh/user/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/tljh/user/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/tljh/user/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/tljh/user/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Đã lưu biểu đồ cho CustomModel tại: Comparative_Analysis/CustomModel_attack_comparison.png
# /opt/tljh/user/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/tljh/user/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/tljh/user/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/tljh/user/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/tljh/user/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/tljh/user/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/tljh/user/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/tljh/user/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/tljh/user/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/tljh/user/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/tljh/user/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/tljh/user/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Đã lưu biểu đồ cho CustomModel2 tại: Comparative_Analysis/CustomModel2_attack_comparison.png
